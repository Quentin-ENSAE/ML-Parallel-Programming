# %% [markdown]
# ## Calcul de l'attention (avec numpy)

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
# ------------------------
# Fonction d'attention (inchangée)
# ------------------------
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def run_attention_once(x, block_size):
    seq_len, d_model = x.shape
    output = np.zeros_like(x)
    for i in range(0, seq_len, block_size):
        end = min(i + block_size, seq_len)
        Q = x[i:end]
        K = x[i:end]
        V = x[i:end]
        scores = Q @ K.T / np.sqrt(d_model)
        weights = softmax(scores)
        output[i:end] = weights @ V
    return output

# %% [markdown]
# ## Grille exhaustive qui teste toutes les combinaisons
#
# * Mesure initiale : pour chaque block_size, effectue initial_repeats mesures et stocke les temps.
#
# * Choix du candidat : identifie le bloc dont la moyenne des temps initiaux est la plus faible.
#
# * Échauffement : relance 5 mesures supplémentaires sur ce “best” pour estimer son intervalle de confiance (IC) à 95 % (Student-t).
#
# * Itération : jusqu’à max_iter, répète :
#
# * Recalcule la moyenne, l’écart-type et l’IC supérieur du “best”.
#
# * Sélectionne tous les blocs dont la moyenne courante ≤ IC supérieur.
#
# * Mesure chacun de ces candidats une fois de plus.
#
# * Met à jour le “best” en choisissant, parmi les candidats, celui à la plus petite moyenne.
#
# * Test de confiance : pour chaque autre bloc, effectue un test t de Welch contre le “best” et calcule la p-value unilatérale.
#
# * Arrêt : dès que toutes les p-values sont < 0.05 (95 % de confiance que le “best” est plus rapide), on sort.
#
# * Résultat : retourne la taille de bloc optimale, toutes les mesures accumulées, et le nombre total de tests effectués.

# %%
import numpy as np
import time
import math
from math import sqrt
from scipy.stats import t as student_t
import matplotlib.pyplot as plt


# ------------------------
# Mesure de temps
# ------------------------
def measure_time(x, block_size):
    start = time.perf_counter()
    _ = run_attention_once(x, block_size)
    return time.perf_counter() - start

# ------------------------
# Grille jusqu'à confiance 95%
# ------------------------
def exhaustive_grid_until_confidence(x, block_sizes,
                                     initial_repeats=3,
                                     confidence=0.95,
                                     max_iter=100):
    alpha = 1 - confidence
    block_sizes = sorted(set(block_sizes))
    n_blocks = len(block_sizes)
    results = {b: [] for b in block_sizes}

    # Phase initiale
    print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            time_val = measure_time(x, b)
            results[b].append(time_val)
        med = np.median(results[b])
        print(f"Bloc {b:<4} → médiane init : {med:.5f} s")

    total_tests = initial_repeats * n_blocks

    # Itérations
    for iteration in range(1, max_iter+1):
        print(f"\n🔁 Itération {iteration} : mesure de tous les blocs")
        # Mesurer chaque bloc
        for b in block_sizes:
            time_val = measure_time(x, b)
            results[b].append(time_val)
            print(f" Bloc {b:<4} dernière mesure : {time_val:.5f} s, essais : {len(results[b])}")
        total_tests += n_blocks

        # Statistiques par bloc
        means = {b: np.mean(results[b]) for b in block_sizes}
        vars_ = {b: np.var(results[b], ddof=1) for b in block_sizes}
        ns = {b: len(results[b]) for b in block_sizes}

        # Sélection du meilleur moyen actuel
        best = min(means, key=means.get)
        print(f" Meilleur moyen actuel : Bloc {best} (mean={means[best]:.5f})")

        # Test de confiance pair à pair
        all_confident = True
        for b in block_sizes:
            if b == best: 
                continue
            diff = means[b] - means[best]
            var_diff = vars_[b]/ns[b] + vars_[best]/ns[best]
            t_stat = diff / math.sqrt(var_diff)
            # Degrés de liberté Welch-Satterthwaite
            df = (var_diff**2) / ((vars_[b]**2)/(ns[b]**2*(ns[b]-1)) +
                                  (vars_[best]**2)/(ns[best]**2*(ns[best]-1)))
            p_value = 1 - student_t.cdf(t_stat, df)
            print(f"  -> Bloc {best} vs Bloc {b}: p={p_value:.4f}")
            if p_value >= alpha:
                all_confident = False

        if all_confident:
            print("\n✅ Confiance 95% atteinte pour le meilleur bloc.")
            break

    print(f"\n✅ Résultat final : Bloc {best}, tests totaux = {total_tests}")
    return best, results, total_tests

# %%
# ------------------------
# Exécution test
# ------------------------
if __name__ == "__main__":
    seq_len, d_model = 1024, 64
    x = np.random.randn(seq_len, d_model)
    blocks = range(64, 1024, 32) # Taille de bloc à tester

    best, results, total_tests = exhaustive_grid_until_confidence(
        x, blocks, initial_repeats=3, confidence=0.95, max_iter=10
    )
# Out:
# 🔍 Phase 1 : mesures initiales
# Bloc 64   → médiane init : 0.00203 s
# Bloc 96   → médiane init : 0.00136 s
# Bloc 128  → médiane init : 0.00188 s
# Bloc 160  → médiane init : 0.00184 s
# Bloc 192  → médiane init : 0.00147 s
# Bloc 224  → médiane init : 0.00303 s
# Bloc 256  → médiane init : 0.00284 s
# Bloc 288  → médiane init : 0.00428 s
# Bloc 320  → médiane init : 0.00269 s
# Bloc 352  → médiane init : 0.00319 s
# Bloc 384  → médiane init : 0.00653 s
# Bloc 416  → médiane init : 0.00336 s
# Bloc 448  → médiane init : 0.00439 s
# Bloc 480  → médiane init : 0.00537 s
# Bloc 512  → médiane init : 0.01103 s
# Bloc 544  → médiane init : 0.00535 s
# Bloc 576  → médiane init : 0.00725 s
# Bloc 608  → médiane init : 0.01164 s
# Bloc 640  → médiane init : 0.00514 s
# Bloc 672  → médiane init : 0.01355 s
# Bloc 704  → médiane init : 0.01040 s
# Bloc 736  → médiane init : 0.02086 s
# Bloc 768  → médiane init : 0.01543 s
# Bloc 800  → médiane init : 0.01493 s
# Bloc 832  → médiane init : 0.00953 s
# Bloc 864  → médiane init : 0.01652 s
# Bloc 896  → médiane init : 0.01552 s
# Bloc 928  → médiane init : 0.01625 s
# Bloc 960  → médiane init : 0.01686 s
# Bloc 992  → médiane init : 0.01413 s
#
# 🔁 Itération 1 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00082 s, essais : 4
#  Bloc 96   dernière mesure : 0.01217 s, essais : 4
#  Bloc 128  dernière mesure : 0.01316 s, essais : 4
#  Bloc 160  dernière mesure : 0.00692 s, essais : 4
#  Bloc 192  dernière mesure : 0.00182 s, essais : 4
#  Bloc 224  dernière mesure : 0.00725 s, essais : 4
#  Bloc 256  dernière mesure : 0.00701 s, essais : 4
#  Bloc 288  dernière mesure : 0.00233 s, essais : 4
#  Bloc 320  dernière mesure : 0.00785 s, essais : 4
#  Bloc 352  dernière mesure : 0.00979 s, essais : 4
#  Bloc 384  dernière mesure : 0.01491 s, essais : 4
#  Bloc 416  dernière mesure : 0.00689 s, essais : 4
#  Bloc 448  dernière mesure : 0.00814 s, essais : 4
#  Bloc 480  dernière mesure : 0.00531 s, essais : 4
#  Bloc 512  dernière mesure : 0.00851 s, essais : 4
#  Bloc 544  dernière mesure : 0.00824 s, essais : 4
#  Bloc 576  dernière mesure : 0.01085 s, essais : 4
#  Bloc 608  dernière mesure : 0.00491 s, essais : 4
#  Bloc 640  dernière mesure : 0.00953 s, essais : 4
#  Bloc 672  dernière mesure : 0.00526 s, essais : 4
#  Bloc 704  dernière mesure : 0.00487 s, essais : 4
#  Bloc 736  dernière mesure : 0.00516 s, essais : 4
#  Bloc 768  dernière mesure : 0.00659 s, essais : 4
#  Bloc 800  dernière mesure : 0.01414 s, essais : 4
#  Bloc 832  dernière mesure : 0.01439 s, essais : 4
#  Bloc 864  dernière mesure : 0.01854 s, essais : 4
#  Bloc 896  dernière mesure : 0.02313 s, essais : 4
#  Bloc 928  dernière mesure : 0.01825 s, essais : 4
#  Bloc 960  dernière mesure : 0.01794 s, essais : 4
#  Bloc 992  dernière mesure : 0.02064 s, essais : 4
#  Meilleur moyen actuel : Bloc 64 (mean=0.00177)
#   -> Bloc 64 vs Bloc 96: p=0.1549
#   -> Bloc 64 vs Bloc 128: p=0.0953
#   -> Bloc 64 vs Bloc 160: p=0.1237
#   -> Bloc 64 vs Bloc 192: p=0.3258
#   -> Bloc 64 vs Bloc 224: p=0.0391
#   -> Bloc 64 vs Bloc 256: p=0.0593
#   -> Bloc 64 vs Bloc 288: p=0.0166
#   -> Bloc 64 vs Bloc 320: p=0.0601
#   -> Bloc 64 vs Bloc 352: p=0.0831
#   -> Bloc 64 vs Bloc 384: p=0.0444
#   -> Bloc 64 vs Bloc 416: p=0.0375
#   -> Bloc 64 vs Bloc 448: p=0.0130
#   -> Bloc 64 vs Bloc 480: p=0.0064
#   -> Bloc 64 vs Bloc 512: p=0.0012
#   -> Bloc 64 vs Bloc 544: p=0.0041
#   -> Bloc 64 vs Bloc 576: p=0.0054
#   -> Bloc 64 vs Bloc 608: p=0.0241
#   -> Bloc 64 vs Bloc 640: p=0.0131
#   -> Bloc 64 vs Bloc 672: p=0.0393
#   -> Bloc 64 vs Bloc 704: p=0.1560
#   -> Bloc 64 vs Bloc 736: p=0.0563
#   -> Bloc 64 vs Bloc 768: p=0.0077
#   -> Bloc 64 vs Bloc 800: p=0.0094
#   -> Bloc 64 vs Bloc 832: p=0.0048
#   -> Bloc 64 vs Bloc 864: p=0.0088
#   -> Bloc 64 vs Bloc 896: p=0.0222
#   -> Bloc 64 vs Bloc 928: p=0.0032
#   -> Bloc 64 vs Bloc 960: p=0.0000
#   -> Bloc 64 vs Bloc 992: p=0.0565
#
# 🔁 Itération 2 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00446 s, essais : 5
#  Bloc 96   dernière mesure : 0.00328 s, essais : 5
#  Bloc 128  dernière mesure : 0.00726 s, essais : 5
#  Bloc 160  dernière mesure : 0.00161 s, essais : 5
#  Bloc 192  dernière mesure : 0.01357 s, essais : 5
#  Bloc 224  dernière mesure : 0.01544 s, essais : 5
#  Bloc 256  dernière mesure : 0.00327 s, essais : 5
#  Bloc 288  dernière mesure : 0.01480 s, essais : 5
#  Bloc 320  dernière mesure : 0.00773 s, essais : 5
#  Bloc 352  dernière mesure : 0.00865 s, essais : 5
#  Bloc 384  dernière mesure : 0.00897 s, essais : 5
#  Bloc 416  dernière mesure : 0.01490 s, essais : 5
#  Bloc 448  dernière mesure : 0.01043 s, essais : 5
#  Bloc 480  dernière mesure : 0.01083 s, essais : 5
#  Bloc 512  dernière mesure : 0.01944 s, essais : 5
#  Bloc 544  dernière mesure : 0.00668 s, essais : 5
#  Bloc 576  dernière mesure : 0.00648 s, essais : 5
#  Bloc 608  dernière mesure : 0.00863 s, essais : 5
#  Bloc 640  dernière mesure : 0.01761 s, essais : 5
#  Bloc 672  dernière mesure : 0.00628 s, essais : 5
#  Bloc 704  dernière mesure : 0.00465 s, essais : 5
#  Bloc 736  dernière mesure : 0.01077 s, essais : 5
#  Bloc 768  dernière mesure : 0.00693 s, essais : 5
#  Bloc 800  dernière mesure : 0.00559 s, essais : 5
#  Bloc 832  dernière mesure : 0.01920 s, essais : 5
#  Bloc 864  dernière mesure : 0.01611 s, essais : 5
#  Bloc 896  dernière mesure : 0.01728 s, essais : 5
#  Bloc 928  dernière mesure : 0.02311 s, essais : 5
#  Bloc 960  dernière mesure : 0.01701 s, essais : 5
#  Bloc 992  dernière mesure : 0.01687 s, essais : 5
#  Meilleur moyen actuel : Bloc 64 (mean=0.00231)
#   -> Bloc 64 vs Bloc 96: p=0.1503
#   -> Bloc 64 vs Bloc 128: p=0.0625
#   -> Bloc 64 vs Bloc 160: p=0.2542
#   -> Bloc 64 vs Bloc 192: p=0.2153
#   -> Bloc 64 vs Bloc 224: p=0.0730
#   -> Bloc 64 vs Bloc 256: p=0.0873
#   -> Bloc 64 vs Bloc 288: p=0.0939
#   -> Bloc 64 vs Bloc 320: p=0.0402
#   -> Bloc 64 vs Bloc 352: p=0.0490
#   -> Bloc 64 vs Bloc 384: p=0.0187
#   -> Bloc 64 vs Bloc 416: p=0.0764
#   -> Bloc 64 vs Bloc 448: p=0.0081
#   -> Bloc 64 vs Bloc 480: p=0.0101
#   -> Bloc 64 vs Bloc 512: p=0.0042
#   -> Bloc 64 vs Bloc 544: p=0.0016
#   -> Bloc 64 vs Bloc 576: p=0.0016
#   -> Bloc 64 vs Bloc 608: p=0.0080
#   -> Bloc 64 vs Bloc 640: p=0.0162
#   -> Bloc 64 vs Bloc 672: p=0.0309
#   -> Bloc 64 vs Bloc 704: p=0.1470
#   -> Bloc 64 vs Bloc 736: p=0.0375
#   -> Bloc 64 vs Bloc 768: p=0.0056
#   -> Bloc 64 vs Bloc 800: p=0.0100
#   -> Bloc 64 vs Bloc 832: p=0.0018
#   -> Bloc 64 vs Bloc 864: p=0.0018
#   -> Bloc 64 vs Bloc 896: p=0.0088
#   -> Bloc 64 vs Bloc 928: p=0.0011
#   -> Bloc 64 vs Bloc 960: p=0.0000
#   -> Bloc 64 vs Bloc 992: p=0.0329
#
# 🔁 Itération 3 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00114 s, essais : 6
#  Bloc 96   dernière mesure : 0.01233 s, essais : 6
#  Bloc 128  dernière mesure : 0.00164 s, essais : 6
#  Bloc 160  dernière mesure : 0.00141 s, essais : 6
#  Bloc 192  dernière mesure : 0.01408 s, essais : 6
#  Bloc 224  dernière mesure : 0.00224 s, essais : 6
#  Bloc 256  dernière mesure : 0.00827 s, essais : 6
#  Bloc 288  dernière mesure : 0.01510 s, essais : 6
#  Bloc 320  dernière mesure : 0.00668 s, essais : 6
#  Bloc 352  dernière mesure : 0.00342 s, essais : 6
#  Bloc 384  dernière mesure : 0.01295 s, essais : 6
#  Bloc 416  dernière mesure : 0.00312 s, essais : 6
#  Bloc 448  dernière mesure : 0.01424 s, essais : 6
#  Bloc 480  dernière mesure : 0.01620 s, essais : 6
#  Bloc 512  dernière mesure : 0.01627 s, essais : 6
#  Bloc 544  dernière mesure : 0.01800 s, essais : 6
#  Bloc 576  dernière mesure : 0.01421 s, essais : 6
#  Bloc 608  dernière mesure : 0.00781 s, essais : 6
#  Bloc 640  dernière mesure : 0.00770 s, essais : 6
#  Bloc 672  dernière mesure : 0.00650 s, essais : 6
#  Bloc 704  dernière mesure : 0.00628 s, essais : 6
#  Bloc 736  dernière mesure : 0.00557 s, essais : 6
#  Bloc 768  dernière mesure : 0.01220 s, essais : 6
#  Bloc 800  dernière mesure : 0.00658 s, essais : 6
#  Bloc 832  dernière mesure : 0.01147 s, essais : 6
#  Bloc 864  dernière mesure : 0.01593 s, essais : 6
#  Bloc 896  dernière mesure : 0.01346 s, essais : 6
#  Bloc 928  dernière mesure : 0.01651 s, essais : 6
#  Bloc 960  dernière mesure : 0.04624 s, essais : 6
#  Bloc 992  dernière mesure : 0.02794 s, essais : 6
#  Meilleur moyen actuel : Bloc 64 (mean=0.00212)
#   -> Bloc 64 vs Bloc 96: p=0.1056
#   -> Bloc 64 vs Bloc 128: p=0.0635
#   -> Bloc 64 vs Bloc 160: p=0.2474
#   -> Bloc 64 vs Bloc 192: p=0.0915
#   -> Bloc 64 vs Bloc 224: p=0.0659
#   -> Bloc 64 vs Bloc 256: p=0.0307
#   -> Bloc 64 vs Bloc 288: p=0.0382
#   -> Bloc 64 vs Bloc 320: p=0.0109
#   -> Bloc 64 vs Bloc 352: p=0.0313
#   -> Bloc 64 vs Bloc 384: p=0.0054
#   -> Bloc 64 vs Bloc 416: p=0.0586
#   -> Bloc 64 vs Bloc 448: p=0.0054
#   -> Bloc 64 vs Bloc 480: p=0.0105
#   -> Bloc 64 vs Bloc 512: p=0.0009
#   -> Bloc 64 vs Bloc 544: p=0.0163
#   -> Bloc 64 vs Bloc 576: p=0.0013
#   -> Bloc 64 vs Bloc 608: p=0.0020
#   -> Bloc 64 vs Bloc 640: p=0.0061
#   -> Bloc 64 vs Bloc 672: p=0.0201
#   -> Bloc 64 vs Bloc 704: p=0.1320
#   -> Bloc 64 vs Bloc 736: p=0.0308
#   -> Bloc 64 vs Bloc 768: p=0.0012
#   -> Bloc 64 vs Bloc 800: p=0.0064
#   -> Bloc 64 vs Bloc 832: p=0.0004
#   -> Bloc 64 vs Bloc 864: p=0.0003
#   -> Bloc 64 vs Bloc 896: p=0.0041
#   -> Bloc 64 vs Bloc 928: p=0.0002
#   -> Bloc 64 vs Bloc 960: p=0.0042
#   -> Bloc 64 vs Bloc 992: p=0.0124
#
# 🔁 Itération 4 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00345 s, essais : 7
#  Bloc 96   dernière mesure : 0.03647 s, essais : 7
#  Bloc 128  dernière mesure : 0.00172 s, essais : 7
#  Bloc 160  dernière mesure : 0.00444 s, essais : 7
#  Bloc 192  dernière mesure : 0.00177 s, essais : 7
#  Bloc 224  dernière mesure : 0.00758 s, essais : 7
#  Bloc 256  dernière mesure : 0.00234 s, essais : 7
#  Bloc 288  dernière mesure : 0.00662 s, essais : 7
#  Bloc 320  dernière mesure : 0.01074 s, essais : 7
#  Bloc 352  dernière mesure : 0.00576 s, essais : 7
#  Bloc 384  dernière mesure : 0.01582 s, essais : 7
#  Bloc 416  dernière mesure : 0.00310 s, essais : 7
#  Bloc 448  dernière mesure : 0.00686 s, essais : 7
#  Bloc 480  dernière mesure : 0.00775 s, essais : 7
#  Bloc 512  dernière mesure : 0.01414 s, essais : 7
#  Bloc 544  dernière mesure : 0.00854 s, essais : 7
#  Bloc 576  dernière mesure : 0.00551 s, essais : 7
#  Bloc 608  dernière mesure : 0.01349 s, essais : 7
#  Bloc 640  dernière mesure : 0.00662 s, essais : 7
#  Bloc 672  dernière mesure : 0.00658 s, essais : 7
#  Bloc 704  dernière mesure : 0.01133 s, essais : 7
#  Bloc 736  dernière mesure : 0.01220 s, essais : 7
#  Bloc 768  dernière mesure : 0.00844 s, essais : 7
#  Bloc 800  dernière mesure : 0.00705 s, essais : 7
#  Bloc 832  dernière mesure : 0.01265 s, essais : 7
#  Bloc 864  dernière mesure : 0.07063 s, essais : 7
#  Bloc 896  dernière mesure : 0.02027 s, essais : 7
#  Bloc 928  dernière mesure : 0.00760 s, essais : 7
#  Bloc 960  dernière mesure : 0.01726 s, essais : 7
#  Bloc 992  dernière mesure : 0.01423 s, essais : 7
#  Meilleur moyen actuel : Bloc 64 (mean=0.00231)
#   -> Bloc 64 vs Bloc 96: p=0.0507
#   -> Bloc 64 vs Bloc 128: p=0.0762
#   -> Bloc 64 vs Bloc 160: p=0.2103
#   -> Bloc 64 vs Bloc 192: p=0.1067
#   -> Bloc 64 vs Bloc 224: p=0.0381
#   -> Bloc 64 vs Bloc 256: p=0.0435
#   -> Bloc 64 vs Bloc 288: p=0.0241
#   -> Bloc 64 vs Bloc 320: p=0.0074
#   -> Bloc 64 vs Bloc 352: p=0.0178
#   -> Bloc 64 vs Bloc 384: p=0.0024
#   -> Bloc 64 vs Bloc 416: p=0.0590
#   -> Bloc 64 vs Bloc 448: p=0.0024
#   -> Bloc 64 vs Bloc 480: p=0.0047
#   -> Bloc 64 vs Bloc 512: p=0.0002
#   -> Bloc 64 vs Bloc 544: p=0.0072
#   -> Bloc 64 vs Bloc 576: p=0.0009
#   -> Bloc 64 vs Bloc 608: p=0.0009
#   -> Bloc 64 vs Bloc 640: p=0.0033
#   -> Bloc 64 vs Bloc 672: p=0.0147
#   -> Bloc 64 vs Bloc 704: p=0.1135
#   -> Bloc 64 vs Bloc 736: p=0.0186
#   -> Bloc 64 vs Bloc 768: p=0.0006
#   -> Bloc 64 vs Bloc 800: p=0.0042
#   -> Bloc 64 vs Bloc 832: p=0.0001
#   -> Bloc 64 vs Bloc 864: p=0.0164
#   -> Bloc 64 vs Bloc 896: p=0.0013
#   -> Bloc 64 vs Bloc 928: p=0.0003
#   -> Bloc 64 vs Bloc 960: p=0.0017
#   -> Bloc 64 vs Bloc 992: p=0.0077
#
# 🔁 Itération 5 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00082 s, essais : 8
#  Bloc 96   dernière mesure : 0.00139 s, essais : 8
#  Bloc 128  dernière mesure : 0.00163 s, essais : 8
#  Bloc 160  dernière mesure : 0.00209 s, essais : 8
#  Bloc 192  dernière mesure : 0.00166 s, essais : 8
#  Bloc 224  dernière mesure : 0.00199 s, essais : 8
#  Bloc 256  dernière mesure : 0.00225 s, essais : 8
#  Bloc 288  dernière mesure : 0.00272 s, essais : 8
#  Bloc 320  dernière mesure : 0.01119 s, essais : 8
#  Bloc 352  dernière mesure : 0.00263 s, essais : 8
#  Bloc 384  dernière mesure : 0.01362 s, essais : 8
#  Bloc 416  dernière mesure : 0.00301 s, essais : 8
#  Bloc 448  dernière mesure : 0.01697 s, essais : 8
#  Bloc 480  dernière mesure : 0.02182 s, essais : 8
#  Bloc 512  dernière mesure : 0.00749 s, essais : 8
#  Bloc 544  dernière mesure : 0.00874 s, essais : 8
#  Bloc 576  dernière mesure : 0.01119 s, essais : 8
#  Bloc 608  dernière mesure : 0.00799 s, essais : 8
#  Bloc 640  dernière mesure : 0.02296 s, essais : 8
#  Bloc 672  dernière mesure : 0.01494 s, essais : 8
#  Bloc 704  dernière mesure : 0.01016 s, essais : 8
#  Bloc 736  dernière mesure : 0.01483 s, essais : 8
#  Bloc 768  dernière mesure : 0.01019 s, essais : 8
#  Bloc 800  dernière mesure : 0.01357 s, essais : 8
#  Bloc 832  dernière mesure : 0.01184 s, essais : 8
#  Bloc 864  dernière mesure : 0.00737 s, essais : 8
#  Bloc 896  dernière mesure : 0.01545 s, essais : 8
#  Bloc 928  dernière mesure : 0.01698 s, essais : 8
#  Bloc 960  dernière mesure : 0.00922 s, essais : 8
#  Bloc 992  dernière mesure : 0.01486 s, essais : 8
#  Meilleur moyen actuel : Bloc 64 (mean=0.00212)
#   -> Bloc 64 vs Bloc 96: p=0.0509
#   -> Bloc 64 vs Bloc 128: p=0.0727
#   -> Bloc 64 vs Bloc 160: p=0.1664
#   -> Bloc 64 vs Bloc 192: p=0.1001
#   -> Bloc 64 vs Bloc 224: p=0.0354
#   -> Bloc 64 vs Bloc 256: p=0.0347
#   -> Bloc 64 vs Bloc 288: p=0.0207
#   -> Bloc 64 vs Bloc 320: p=0.0025
#   -> Bloc 64 vs Bloc 352: p=0.0138
#   -> Bloc 64 vs Bloc 384: p=0.0006
#   -> Bloc 64 vs Bloc 416: p=0.0442
#   -> Bloc 64 vs Bloc 448: p=0.0016
#   -> Bloc 64 vs Bloc 480: p=0.0046
#   -> Bloc 64 vs Bloc 512: p=0.0001
#   -> Bloc 64 vs Bloc 544: p=0.0022
#   -> Bloc 64 vs Bloc 576: p=0.0002
#   -> Bloc 64 vs Bloc 608: p=0.0002
#   -> Bloc 64 vs Bloc 640: p=0.0034
#   -> Bloc 64 vs Bloc 672: p=0.0051
#   -> Bloc 64 vs Bloc 704: p=0.0958
#   -> Bloc 64 vs Bloc 736: p=0.0087
#   -> Bloc 64 vs Bloc 768: p=0.0001
#   -> Bloc 64 vs Bloc 800: p=0.0011
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0137
#   -> Bloc 64 vs Bloc 896: p=0.0004
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0012
#   -> Bloc 64 vs Bloc 992: p=0.0042
#
# 🔁 Itération 6 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00082 s, essais : 9
#  Bloc 96   dernière mesure : 0.00162 s, essais : 9
#  Bloc 128  dernière mesure : 0.00137 s, essais : 9
#  Bloc 160  dernière mesure : 0.00139 s, essais : 9
#  Bloc 192  dernière mesure : 0.00788 s, essais : 9
#  Bloc 224  dernière mesure : 0.00663 s, essais : 9
#  Bloc 256  dernière mesure : 0.00723 s, essais : 9
#  Bloc 288  dernière mesure : 0.01744 s, essais : 9
#  Bloc 320  dernière mesure : 0.00272 s, essais : 9
#  Bloc 352  dernière mesure : 0.01329 s, essais : 9
#  Bloc 384  dernière mesure : 0.00379 s, essais : 9
#  Bloc 416  dernière mesure : 0.01468 s, essais : 9
#  Bloc 448  dernière mesure : 0.01597 s, essais : 9
#  Bloc 480  dernière mesure : 0.01605 s, essais : 9
#  Bloc 512  dernière mesure : 0.01601 s, essais : 9
#  Bloc 544  dernière mesure : 0.00966 s, essais : 9
#  Bloc 576  dernière mesure : 0.00838 s, essais : 9
#  Bloc 608  dernière mesure : 0.01458 s, essais : 9
#  Bloc 640  dernière mesure : 0.01130 s, essais : 9
#  Bloc 672  dernière mesure : 0.01587 s, essais : 9
#  Bloc 704  dernière mesure : 0.01514 s, essais : 9
#  Bloc 736  dernière mesure : 0.01118 s, essais : 9
#  Bloc 768  dernière mesure : 0.00931 s, essais : 9
#  Bloc 800  dernière mesure : 0.01361 s, essais : 9
#  Bloc 832  dernière mesure : 0.01088 s, essais : 9
#  Bloc 864  dernière mesure : 0.01465 s, essais : 9
#  Bloc 896  dernière mesure : 0.01082 s, essais : 9
#  Bloc 928  dernière mesure : 0.01514 s, essais : 9
#  Bloc 960  dernière mesure : 0.02260 s, essais : 9
#  Bloc 992  dernière mesure : 0.01895 s, essais : 9
#  Meilleur moyen actuel : Bloc 64 (mean=0.00198)
#   -> Bloc 64 vs Bloc 96: p=0.0503
#   -> Bloc 64 vs Bloc 128: p=0.0711
#   -> Bloc 64 vs Bloc 160: p=0.1548
#   -> Bloc 64 vs Bloc 192: p=0.0514
#   -> Bloc 64 vs Bloc 224: p=0.0160
#   -> Bloc 64 vs Bloc 256: p=0.0111
#   -> Bloc 64 vs Bloc 288: p=0.0091
#   -> Bloc 64 vs Bloc 320: p=0.0024
#   -> Bloc 64 vs Bloc 352: p=0.0081
#   -> Bloc 64 vs Bloc 384: p=0.0006
#   -> Bloc 64 vs Bloc 416: p=0.0194
#   -> Bloc 64 vs Bloc 448: p=0.0005
#   -> Bloc 64 vs Bloc 480: p=0.0014
#   -> Bloc 64 vs Bloc 512: p=0.0000
#   -> Bloc 64 vs Bloc 544: p=0.0006
#   -> Bloc 64 vs Bloc 576: p=0.0000
#   -> Bloc 64 vs Bloc 608: p=0.0001
#   -> Bloc 64 vs Bloc 640: p=0.0011
#   -> Bloc 64 vs Bloc 672: p=0.0016
#   -> Bloc 64 vs Bloc 704: p=0.0741
#   -> Bloc 64 vs Bloc 736: p=0.0047
#   -> Bloc 64 vs Bloc 768: p=0.0000
#   -> Bloc 64 vs Bloc 800: p=0.0003
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0083
#   -> Bloc 64 vs Bloc 896: p=0.0002
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0003
#   -> Bloc 64 vs Bloc 992: p=0.0018
#
# 🔁 Itération 7 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00326 s, essais : 10
#  Bloc 96   dernière mesure : 0.00154 s, essais : 10
#  Bloc 128  dernière mesure : 0.00633 s, essais : 10
#  Bloc 160  dernière mesure : 0.00562 s, essais : 10
#  Bloc 192  dernière mesure : 0.00177 s, essais : 10
#  Bloc 224  dernière mesure : 0.00188 s, essais : 10
#  Bloc 256  dernière mesure : 0.00328 s, essais : 10
#  Bloc 288  dernière mesure : 0.00345 s, essais : 10
#  Bloc 320  dernière mesure : 0.00320 s, essais : 10
#  Bloc 352  dernière mesure : 0.00257 s, essais : 10
#  Bloc 384  dernière mesure : 0.00847 s, essais : 10
#  Bloc 416  dernière mesure : 0.00707 s, essais : 10
#  Bloc 448  dernière mesure : 0.00754 s, essais : 10
#  Bloc 480  dernière mesure : 0.00753 s, essais : 10
#  Bloc 512  dernière mesure : 0.01235 s, essais : 10
#  Bloc 544  dernière mesure : 0.01076 s, essais : 10
#  Bloc 576  dernière mesure : 0.02193 s, essais : 10
#  Bloc 608  dernière mesure : 0.00994 s, essais : 10
#  Bloc 640  dernière mesure : 0.01532 s, essais : 10
#  Bloc 672  dernière mesure : 0.01551 s, essais : 10
#  Bloc 704  dernière mesure : 0.01014 s, essais : 10
#  Bloc 736  dernière mesure : 0.00921 s, essais : 10
#  Bloc 768  dernière mesure : 0.01322 s, essais : 10
#  Bloc 800  dernière mesure : 0.01408 s, essais : 10
#  Bloc 832  dernière mesure : 0.02075 s, essais : 10
#  Bloc 864  dernière mesure : 0.01528 s, essais : 10
#  Bloc 896  dernière mesure : 0.01694 s, essais : 10
#  Bloc 928  dernière mesure : 0.01855 s, essais : 10
#  Bloc 960  dernière mesure : 0.01442 s, essais : 10
#  Bloc 992  dernière mesure : 0.02524 s, essais : 10
#  Meilleur moyen actuel : Bloc 64 (mean=0.00210)
#   -> Bloc 64 vs Bloc 96: p=0.0531
#   -> Bloc 64 vs Bloc 128: p=0.0515
#   -> Bloc 64 vs Bloc 160: p=0.1100
#   -> Bloc 64 vs Bloc 192: p=0.0607
#   -> Bloc 64 vs Bloc 224: p=0.0207
#   -> Bloc 64 vs Bloc 256: p=0.0108
#   -> Bloc 64 vs Bloc 288: p=0.0090
#   -> Bloc 64 vs Bloc 320: p=0.0025
#   -> Bloc 64 vs Bloc 352: p=0.0095
#   -> Bloc 64 vs Bloc 384: p=0.0003
#   -> Bloc 64 vs Bloc 416: p=0.0116
#   -> Bloc 64 vs Bloc 448: p=0.0003
#   -> Bloc 64 vs Bloc 480: p=0.0008
#   -> Bloc 64 vs Bloc 512: p=0.0000
#   -> Bloc 64 vs Bloc 544: p=0.0002
#   -> Bloc 64 vs Bloc 576: p=0.0003
#   -> Bloc 64 vs Bloc 608: p=0.0000
#   -> Bloc 64 vs Bloc 640: p=0.0004
#   -> Bloc 64 vs Bloc 672: p=0.0006
#   -> Bloc 64 vs Bloc 704: p=0.0643
#   -> Bloc 64 vs Bloc 736: p=0.0032
#   -> Bloc 64 vs Bloc 768: p=0.0000
#   -> Bloc 64 vs Bloc 800: p=0.0001
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0052
#   -> Bloc 64 vs Bloc 896: p=0.0001
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0002
#   -> Bloc 64 vs Bloc 992: p=0.0007
#
# 🔁 Itération 8 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00291 s, essais : 11
#  Bloc 96   dernière mesure : 0.00192 s, essais : 11
#  Bloc 128  dernière mesure : 0.00112 s, essais : 11
#  Bloc 160  dernière mesure : 0.00130 s, essais : 11
#  Bloc 192  dernière mesure : 0.00375 s, essais : 11
#  Bloc 224  dernière mesure : 0.00191 s, essais : 11
#  Bloc 256  dernière mesure : 0.00384 s, essais : 11
#  Bloc 288  dernière mesure : 0.00277 s, essais : 11
#  Bloc 320  dernière mesure : 0.00237 s, essais : 11
#  Bloc 352  dernière mesure : 0.00380 s, essais : 11
#  Bloc 384  dernière mesure : 0.00530 s, essais : 11
#  Bloc 416  dernière mesure : 0.00493 s, essais : 11
#  Bloc 448  dernière mesure : 0.00338 s, essais : 11
#  Bloc 480  dernière mesure : 0.00511 s, essais : 11
#  Bloc 512  dernière mesure : 0.00607 s, essais : 11
#  Bloc 544  dernière mesure : 0.00775 s, essais : 11
#  Bloc 576  dernière mesure : 0.00782 s, essais : 11
#  Bloc 608  dernière mesure : 0.00942 s, essais : 11
#  Bloc 640  dernière mesure : 0.01683 s, essais : 11
#  Bloc 672  dernière mesure : 0.01214 s, essais : 11
#  Bloc 704  dernière mesure : 0.00784 s, essais : 11
#  Bloc 736  dernière mesure : 0.00983 s, essais : 11
#  Bloc 768  dernière mesure : 0.01491 s, essais : 11
#  Bloc 800  dernière mesure : 0.01525 s, essais : 11
#  Bloc 832  dernière mesure : 0.01593 s, essais : 11
#  Bloc 864  dernière mesure : 0.02506 s, essais : 11
#  Bloc 896  dernière mesure : 0.01033 s, essais : 11
#  Bloc 928  dernière mesure : 0.01240 s, essais : 11
#  Bloc 960  dernière mesure : 0.03785 s, essais : 11
#  Bloc 992  dernière mesure : 0.02186 s, essais : 11
#  Meilleur moyen actuel : Bloc 64 (mean=0.00218)
#   -> Bloc 64 vs Bloc 96: p=0.0547
#   -> Bloc 64 vs Bloc 128: p=0.0637
#   -> Bloc 64 vs Bloc 160: p=0.1573
#   -> Bloc 64 vs Bloc 192: p=0.0541
#   -> Bloc 64 vs Bloc 224: p=0.0247
#   -> Bloc 64 vs Bloc 256: p=0.0081
#   -> Bloc 64 vs Bloc 288: p=0.0094
#   -> Bloc 64 vs Bloc 320: p=0.0033
#   -> Bloc 64 vs Bloc 352: p=0.0079
#   -> Bloc 64 vs Bloc 384: p=0.0002
#   -> Bloc 64 vs Bloc 416: p=0.0084
#   -> Bloc 64 vs Bloc 448: p=0.0003
#   -> Bloc 64 vs Bloc 480: p=0.0007
#   -> Bloc 64 vs Bloc 512: p=0.0000
#   -> Bloc 64 vs Bloc 544: p=0.0001
#   -> Bloc 64 vs Bloc 576: p=0.0001
#   -> Bloc 64 vs Bloc 608: p=0.0000
#   -> Bloc 64 vs Bloc 640: p=0.0001
#   -> Bloc 64 vs Bloc 672: p=0.0002
#   -> Bloc 64 vs Bloc 704: p=0.0579
#   -> Bloc 64 vs Bloc 736: p=0.0020
#   -> Bloc 64 vs Bloc 768: p=0.0000
#   -> Bloc 64 vs Bloc 800: p=0.0000
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0023
#   -> Bloc 64 vs Bloc 896: p=0.0001
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0001
#   -> Bloc 64 vs Bloc 992: p=0.0003
#
# 🔁 Itération 9 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00082 s, essais : 12
#  Bloc 96   dernière mesure : 0.00574 s, essais : 12
#  Bloc 128  dernière mesure : 0.00139 s, essais : 12
#  Bloc 160  dernière mesure : 0.00138 s, essais : 12
#  Bloc 192  dernière mesure : 0.00614 s, essais : 12
#  Bloc 224  dernière mesure : 0.00597 s, essais : 12
#  Bloc 256  dernière mesure : 0.00287 s, essais : 12
#  Bloc 288  dernière mesure : 0.00249 s, essais : 12
#  Bloc 320  dernière mesure : 0.00685 s, essais : 12
#  Bloc 352  dernière mesure : 0.00572 s, essais : 12
#  Bloc 384  dernière mesure : 0.00738 s, essais : 12
#  Bloc 416  dernière mesure : 0.00866 s, essais : 12
#  Bloc 448  dernière mesure : 0.00846 s, essais : 12
#  Bloc 480  dernière mesure : 0.00894 s, essais : 12
#  Bloc 512  dernière mesure : 0.00821 s, essais : 12
#  Bloc 544  dernière mesure : 0.00735 s, essais : 12
#  Bloc 576  dernière mesure : 0.01018 s, essais : 12
#  Bloc 608  dernière mesure : 0.01085 s, essais : 12
#  Bloc 640  dernière mesure : 0.00962 s, essais : 12
#  Bloc 672  dernière mesure : 0.00574 s, essais : 12
#  Bloc 704  dernière mesure : 0.00514 s, essais : 12
#  Bloc 736  dernière mesure : 0.00633 s, essais : 12
#  Bloc 768  dernière mesure : 0.00783 s, essais : 12
#  Bloc 800  dernière mesure : 0.00803 s, essais : 12
#  Bloc 832  dernière mesure : 0.00840 s, essais : 12
#  Bloc 864  dernière mesure : 0.00668 s, essais : 12
#  Bloc 896  dernière mesure : 0.00762 s, essais : 12
#  Bloc 928  dernière mesure : 0.01562 s, essais : 12
#  Bloc 960  dernière mesure : 0.00915 s, essais : 12
#  Bloc 992  dernière mesure : 0.01169 s, essais : 12
#  Meilleur moyen actuel : Bloc 64 (mean=0.00206)
#   -> Bloc 64 vs Bloc 96: p=0.0465
#   -> Bloc 64 vs Bloc 128: p=0.0620
#   -> Bloc 64 vs Bloc 160: p=0.1477
#   -> Bloc 64 vs Bloc 192: p=0.0304
#   -> Bloc 64 vs Bloc 224: p=0.0121
#   -> Bloc 64 vs Bloc 256: p=0.0051
#   -> Bloc 64 vs Bloc 288: p=0.0084
#   -> Bloc 64 vs Bloc 320: p=0.0011
#   -> Bloc 64 vs Bloc 352: p=0.0034
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0032
#   -> Bloc 64 vs Bloc 448: p=0.0001
#   -> Bloc 64 vs Bloc 480: p=0.0003
#   -> Bloc 64 vs Bloc 512: p=0.0000
#   -> Bloc 64 vs Bloc 544: p=0.0000
#   -> Bloc 64 vs Bloc 576: p=0.0000
#   -> Bloc 64 vs Bloc 608: p=0.0000
#   -> Bloc 64 vs Bloc 640: p=0.0000
#   -> Bloc 64 vs Bloc 672: p=0.0002
#   -> Bloc 64 vs Bloc 704: p=0.0532
#   -> Bloc 64 vs Bloc 736: p=0.0015
#   -> Bloc 64 vs Bloc 768: p=0.0000
#   -> Bloc 64 vs Bloc 800: p=0.0000
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0020
#   -> Bloc 64 vs Bloc 896: p=0.0000
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0001
#   -> Bloc 64 vs Bloc 992: p=0.0002
#
# 🔁 Itération 10 : mesure de tous les blocs
#  Bloc 64   dernière mesure : 0.00083 s, essais : 13
#  Bloc 96   dernière mesure : 0.00219 s, essais : 13
#  Bloc 128  dernière mesure : 0.00132 s, essais : 13
#  Bloc 160  dernière mesure : 0.00325 s, essais : 13
#  Bloc 192  dernière mesure : 0.00568 s, essais : 13
#  Bloc 224  dernière mesure : 0.01147 s, essais : 13
#  Bloc 256  dernière mesure : 0.00334 s, essais : 13
#  Bloc 288  dernière mesure : 0.00543 s, essais : 13
#  Bloc 320  dernière mesure : 0.00559 s, essais : 13
#  Bloc 352  dernière mesure : 0.00288 s, essais : 13
#  Bloc 384  dernière mesure : 0.00347 s, essais : 13
#  Bloc 416  dernière mesure : 0.00375 s, essais : 13
#  Bloc 448  dernière mesure : 0.00453 s, essais : 13
#  Bloc 480  dernière mesure : 0.00358 s, essais : 13
#  Bloc 512  dernière mesure : 0.00717 s, essais : 13
#  Bloc 544  dernière mesure : 0.00648 s, essais : 13
#  Bloc 576  dernière mesure : 0.00460 s, essais : 13
#  Bloc 608  dernière mesure : 0.00648 s, essais : 13
#  Bloc 640  dernière mesure : 0.00602 s, essais : 13
#  Bloc 672  dernière mesure : 0.01669 s, essais : 13
#  Bloc 704  dernière mesure : 0.00921 s, essais : 13
#  Bloc 736  dernière mesure : 0.00669 s, essais : 13
#  Bloc 768  dernière mesure : 0.01329 s, essais : 13
#  Bloc 800  dernière mesure : 0.00676 s, essais : 13
#  Bloc 832  dernière mesure : 0.01056 s, essais : 13
#  Bloc 864  dernière mesure : 0.01224 s, essais : 13
#  Bloc 896  dernière mesure : 0.01715 s, essais : 13
#  Bloc 928  dernière mesure : 0.01455 s, essais : 13
#  Bloc 960  dernière mesure : 0.01777 s, essais : 13
#  Bloc 992  dernière mesure : 0.00857 s, essais : 13
#  Meilleur moyen actuel : Bloc 64 (mean=0.00197)
#   -> Bloc 64 vs Bloc 96: p=0.0448
#   -> Bloc 64 vs Bloc 128: p=0.0606
#   -> Bloc 64 vs Bloc 160: p=0.0931
#   -> Bloc 64 vs Bloc 192: p=0.0170
#   -> Bloc 64 vs Bloc 224: p=0.0047
#   -> Bloc 64 vs Bloc 256: p=0.0027
#   -> Bloc 64 vs Bloc 288: p=0.0050
#   -> Bloc 64 vs Bloc 320: p=0.0004
#   -> Bloc 64 vs Bloc 352: p=0.0025
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0022
#   -> Bloc 64 vs Bloc 448: p=0.0001
#   -> Bloc 64 vs Bloc 480: p=0.0002
#   -> Bloc 64 vs Bloc 512: p=0.0000
#   -> Bloc 64 vs Bloc 544: p=0.0000
#   -> Bloc 64 vs Bloc 576: p=0.0000
#   -> Bloc 64 vs Bloc 608: p=0.0000
#   -> Bloc 64 vs Bloc 640: p=0.0000
#   -> Bloc 64 vs Bloc 672: p=0.0000
#   -> Bloc 64 vs Bloc 704: p=0.0449
#   -> Bloc 64 vs Bloc 736: p=0.0010
#   -> Bloc 64 vs Bloc 768: p=0.0000
#   -> Bloc 64 vs Bloc 800: p=0.0000
#   -> Bloc 64 vs Bloc 832: p=0.0000
#   -> Bloc 64 vs Bloc 864: p=0.0013
#   -> Bloc 64 vs Bloc 896: p=0.0000
#   -> Bloc 64 vs Bloc 928: p=0.0000
#   -> Bloc 64 vs Bloc 960: p=0.0000
#   -> Bloc 64 vs Bloc 992: p=0.0001
#
# ✅ Résultat final : Bloc 64, tests totaux = 390

# %% [markdown]
# # Benchmark intelligent 1

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from math import sqrt
from scipy.stats import norm
from scipy.stats import t as student_t

# %%
# ------------------------
# Fonction d'attention (inchangée)
# ------------------------
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def run_attention_once(x, block_size):
    seq_len, d_model = x.shape
    output = np.zeros_like(x)
    for i in range(0, seq_len, block_size):
        end = min(i + block_size, seq_len)
        Q = x[i:end]
        K = x[i:end]
        V = x[i:end]
        scores = Q @ K.T / np.sqrt(d_model)
        weights = softmax(scores)
        output[i:end] = weights @ V
    return output

# ------------------------
# Mesure de temps
# ------------------------
def measure_time(x, block_size):
    start = time.perf_counter()
    _ = run_attention_once(x, block_size)
    return time.perf_counter() - start

# %%
# -*- coding: utf-8 -*-
"""
Benchmark adaptatif « jusqu’à confiance ».

◾ `measure_time(x, block)` doit mesurer et renvoyer le temps d’exécution (en secondes)
   pour la taille de bloc demandée.
◾ `run_attention_once(x, block)` exécute la même opération sans rien mesurer
   (run « à blanc » pour chauffer caches, GPU, etc.).

Ces deux fonctions dépendent de ton application et doivent être définies ailleurs.
"""

from math import sqrt
import numpy as np
from scipy.stats import t as student_t


def smart_benchmark_until_confidence(
    x,
    block_sizes,
    *,
    confidence: float = 0.90,
    initial_repeats: int = 1,
    extra_repeats_best: int = 5,
    max_iter: int = 1_000,
    free_runs: int = 5,
    verbose: bool = True,
):
    """
    Recherche itérative du bloc le plus rapide jusqu’à atteindre
    une confiance `confidence` (95 % par défaut).

    Étapes
    ------
    1. `free_runs` passes à blanc sur chaque taille pour chauffer.
    2. `initial_repeats` premières mesures sur tous les blocs.
    3. On répète `extra_repeats_best` fois le bloc le plus prometteur
       pour serrer son intervalle de confiance (IC).
    4. Boucle :
       a) On calcule l’IC supérieur du best courant.
       b) Candidats = blocs dont la moyenne actuelle ≤ IC_sup.
       c) On mesure UNE fois chaque candidat.
       d) Nouveau best = bloc à plus petite moyenne parmi candidats.
       e) Test de Welch : pour chaque bloc, on construit l’IC
          (one-sided) de la différence de moyennes.
          Si, pour **tous** les blocs, l’IC est strictement ≤ 0
          ⇒ on est confiant et on s’arrête.
    """
    # ------------------------------------------------------------------
    # Préparation
    # ------------------------------------------------------------------
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}
    history = []               # (iter, best, mean, std, ci_up)
    best_blocks_by_iter = []   # suivi de l’ID du best à chaque tour

    # Réchauffe-caches
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once(x, b)

    # Mesures initiales
    if verbose:
        print("🔍 Phase 1 : évaluation initiale")
    for b in block_sizes:
        for _ in range(initial_repeats):
            t = measure_time(x, b)
            results[b].append(t)
        if verbose:
            print(f"Bloc {b:<4} → {np.mean(results[b]):.5f} s "
                  f"(n={len(results[b])})")

    # Best initial + sur-échantillonnage
    best = min(block_sizes, key=lambda b: np.mean(results[b]))
    if verbose:
        print(f"\nBest initial : {best}")
    for _ in range(extra_repeats_best):
        results[best].append(measure_time(x, best))

    # ------------------------------------------------------------------
    # Boucle principale
    # ------------------------------------------------------------------
    for it in range(1, max_iter + 1):
        # --- stats du best courant ------------------------------------
        times_best = np.asarray(results[best])
        n_best = len(times_best)
        m_best = times_best.mean()
        s_best = times_best.std(ddof=1) if n_best > 1 else 0.0
        t_crit_best = (
            student_t.ppf(1 - (1 - confidence) / 2, df=n_best - 1)
            if n_best > 1 else np.inf
        )
        ci_up_best = m_best + t_crit_best * (s_best / sqrt(n_best))

        history.append((it, best, m_best, s_best, ci_up_best))
        best_blocks_by_iter.append(best)

        if verbose:
            print(f"\n🔁 Itération {it}: "
                  f"Best={best}, mean={m_best:.5f}, σ={s_best:.5f}, "
                  f"CI_sup={ci_up_best:.5f}")

        # --- Sélection des candidats ----------------------------------
        candidates = [
            b for b in block_sizes
            if np.mean(results[b]) <= ci_up_best or b == best
        ]
        if verbose:
            print("Candidats :", candidates)

        # --- Une mesure de plus pour chaque candidat ------------------
        for b in candidates:
            t_b = measure_time(x, b)
            results[b].append(t_b)
            if verbose:
                print(f"  Bloc {b:<4} → {t_b:.5f} s (n={len(results[b])})")

        # --- Nouveau best parmi les candidats -------------------------
        best = min(candidates, key=lambda b: np.mean(results[b]))

        # --- Statistiques MAJ pour le nouveau best --------------------
        times_best = np.asarray(results[best])
        n_best = len(times_best)
        m_best = times_best.mean()
        s_best = times_best.std(ddof=1) if n_best > 1 else 0.0

        # --- Test de confiance vs tous les autres ---------------------
        all_confident = True
        for b in block_sizes:
            if b == best:
                continue

            # stats bloc b
            times_b = np.asarray(results[b])
            n_b = len(times_b)
            m_b = times_b.mean()
            s_b = times_b.std(ddof=1) if n_b > 1 else 0.0

            # variance de la diff Welch
            var_diff = (s_best ** 2) / n_best + (s_b ** 2) / n_b
            if var_diff == 0:          # toutes mesures identiques
                continue

            diff = m_b - m_best        # >0 si b plus lent
            t_stat = diff / sqrt(var_diff)

            # ddl Welch–Satterthwaite
            if n_best > 1 and n_b > 1:
                df = (
                    var_diff ** 2 /
                    (((s_best ** 4) / (n_best ** 2 * (n_best - 1))) +
                     ((s_b ** 4) / (n_b ** 2 * (n_b - 1))))
                )
            else:  # cas limite
                df = n_best + n_b - 2

            # borne supérieure (one-sided) de diff
            t_crit = student_t.ppf(confidence, df)
            ci_up_diff = diff - t_crit * sqrt(var_diff)

            # log
            if verbose:
                p_one_sided = 1 - student_t.cdf(t_stat, df)  # P(best < b)
                print(f"  P({best} < {b}) = {p_one_sided:.3f}")

            # si l'IC inclut encore des valeurs >0 → pas assez sûr
            if ci_up_diff > 0:
                all_confident = False

        if all_confident:
            if verbose:
                print("\n✅ Confiance atteinte pour le best.")
            break

    # ------------------------------------------------------------------
    # Résumé final
    # ------------------------------------------------------------------
    if verbose:
        final_median = float(np.median(results[best]))
        print(f"\n✅ Meilleure taille de bloc : {best} "
              f"({final_median:.5f} s)")
        print("🧮 Nombre total de mesures :", sum(len(v) for v in results.values()))

    return best, results, history, best_blocks_by_iter

# %%
# ------------------------
# Exécution et double graphique
# ------------------------
if __name__ == "__main__":
    seq_len, d_model = 1024, 64
    x = np.random.randn(seq_len, d_model)
    blocks = range(64, 1024, 32) # Taille de bloc à tester
    best, results, hist, best_blocks_by_iter = smart_benchmark_until_confidence(x, blocks)

    # Tracé
    fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=False)

    # --- HAUT : nuage de points de tous les temps + IC best par itération ---
    # On positionne chaque point selon son bloc (axe x=bloc, axe y=temps)
    for b in blocks:
        y = results[b]
        x_b = [b] * len(y)
        axes[0].scatter(x_b, y, label=f"Bloc {b}", alpha=0.6)
    # Ajout de l'évolution de l'IC du bloc best
    ic_means = []
    ic_uppers = []
    ic_locs = []
    for i, (iteration, bestb, m, s, ci_upper) in enumerate(hist):
        ic_means.append(m)
        ic_uppers.append(ci_upper)
        ic_locs.append(bestb)
        axes[0].errorbar(bestb, m, yerr=[[0], [ci_upper - m]], fmt='o', color='black', capsize=5, lw=2, label='IC best' if i==0 else "")

    # On force les graduations de l'axe x sur les blocs testés
    axes[0].set_xticks(list(blocks))
    axes[0].set_xticklabels([str(b) for b in blocks], rotation=45, ha="right")
    
    axes[0].set_title("Temps de calcul pour chaque bloc (nuage de points) et IC du best")
    axes[0].set_xlabel("Taille de bloc")
    axes[0].set_ylabel("Temps (s)")
    if len(blocks) < 20:
        axes[0].set_xticks(list(blocks))
        axes[0].legend()
    axes[0].grid(True)

    # --- BAS : évolution de la moyenne et de l'IC du best ---
    iterations = [h[0] for h in hist]
    axes[1].plot(iterations, ic_means, marker='o', label='Moyenne best')
    axes[1].plot(iterations, ic_uppers, marker='s', label='CI supérieur')
    axes[1].fill_between(iterations, ic_means, ic_uppers, color='orange', alpha=0.3, label='IC best')
    axes[1].set_xlabel("Itération")
    axes[1].set_ylabel("Temps (s)")
    axes[1].set_title("Évolution de la moyenne et de l'IC du best")
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()
# Out:
# 🔍 Phase 1 : évaluation initiale
# Bloc 64   → 0.00233 s (n=1)
# Bloc 96   → 0.00442 s (n=1)
# Bloc 128  → 0.00331 s (n=1)
# Bloc 160  → 0.00229 s (n=1)
# Bloc 192  → 0.00186 s (n=1)
# Bloc 224  → 0.00191 s (n=1)
# Bloc 256  → 0.00228 s (n=1)
# Bloc 288  → 0.00297 s (n=1)
# Bloc 320  → 0.00500 s (n=1)
# Bloc 352  → 0.00602 s (n=1)
# Bloc 384  → 0.00368 s (n=1)
# Bloc 416  → 0.00286 s (n=1)
# Bloc 448  → 0.00378 s (n=1)
# Bloc 480  → 0.00388 s (n=1)
# Bloc 512  → 0.00488 s (n=1)
# Bloc 544  → 0.00487 s (n=1)
# Bloc 576  → 0.00645 s (n=1)
# Bloc 608  → 0.00416 s (n=1)
# Bloc 640  → 0.00598 s (n=1)
# Bloc 672  → 0.00854 s (n=1)
# Bloc 704  → 0.00545 s (n=1)
# Bloc 736  → 0.00489 s (n=1)
# Bloc 768  → 0.00602 s (n=1)
# Bloc 800  → 0.00551 s (n=1)
# Bloc 832  → 0.00590 s (n=1)
# Bloc 864  → 0.00624 s (n=1)
# Bloc 896  → 0.00802 s (n=1)
# Bloc 928  → 0.01253 s (n=1)
# Bloc 960  → 0.00788 s (n=1)
# Bloc 992  → 0.01954 s (n=1)
#
# Best initial : 192
#
# 🔁 Itération 1: Best=192, mean=0.00469, σ=0.00527, CI_sup=0.00903
# Candidats : [64, 96, 128, 160, 192, 224, 256, 288, 320, 352, 384, 416, 448, 480, 512, 544, 576, 608, 640, 672, 704, 736, 768, 800, 832, 864, 896, 960]
#   Bloc 64   → 0.00080 s (n=2)
#   Bloc 96   → 0.00121 s (n=2)
#   Bloc 128  → 0.00334 s (n=2)
#   Bloc 160  → 0.00364 s (n=2)
#   Bloc 192  → 0.00881 s (n=7)
#   Bloc 224  → 0.00311 s (n=2)
#   Bloc 256  → 0.00245 s (n=2)
#   Bloc 288  → 0.00889 s (n=2)
#   Bloc 320  → 0.00728 s (n=2)
#   Bloc 352  → 0.00405 s (n=2)
#   Bloc 384  → 0.00297 s (n=2)
#   Bloc 416  → 0.00296 s (n=2)
#   Bloc 448  → 0.00699 s (n=2)
#   Bloc 480  → 0.00655 s (n=2)
#   Bloc 512  → 0.00561 s (n=2)
#   Bloc 544  → 0.00596 s (n=2)
#   Bloc 576  → 0.00512 s (n=2)
#   Bloc 608  → 0.00889 s (n=2)
#   Bloc 640  → 0.00895 s (n=2)
#   Bloc 672  → 0.00481 s (n=2)
#   Bloc 704  → 0.00812 s (n=2)
#   Bloc 736  → 0.01231 s (n=2)
#   Bloc 768  → 0.01369 s (n=2)
#   Bloc 800  → 0.00831 s (n=2)
#   Bloc 832  → 0.01488 s (n=2)
#   Bloc 864  → 0.00682 s (n=2)
#   Bloc 896  → 0.00667 s (n=2)
#   Bloc 960  → 0.01109 s (n=2)
#   P(64 < 96) = 0.289
#   P(64 < 128) = 0.131
#   P(64 < 160) = 0.153
#   P(64 < 192) = 0.057
#   P(64 < 224) = 0.219
#   P(64 < 256) = 0.243
#   P(64 < 288) = 0.184
#   P(64 < 320) = 0.048
#   P(64 < 352) = 0.058
#   P(64 < 384) = 0.112
#   P(64 < 416) = 0.164
#   P(64 < 448) = 0.106
#   P(64 < 480) = 0.086
#   P(64 < 512) = 0.043
#   P(64 < 544) = 0.032
#   P(64 < 576) = 0.028
#   P(64 < 608) = 0.130
#   P(64 < 640) = 0.054
#   P(64 < 672) = 0.093
#   P(64 < 704) = 0.052
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.133
#   P(64 < 800) = 0.055
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.034
#   P(64 < 896) = 0.015
#   P(64 < 928) = 0.022
#   P(64 < 960) = 0.042
#   P(64 < 992) = 0.014
#
# 🔁 Itération 2: Best=64, mean=0.00157, σ=0.00108, CI_sup=0.00640
# Candidats : [64, 96, 128, 160, 192, 224, 256, 288, 320, 352, 384, 416, 448, 480, 512, 544, 576]
#   Bloc 64   → 0.00081 s (n=3)
#   Bloc 96   → 0.00154 s (n=3)
#   Bloc 128  → 0.00209 s (n=3)
#   Bloc 160  → 0.00156 s (n=3)
#   Bloc 192  → 0.00177 s (n=8)
#   Bloc 224  → 0.00189 s (n=3)
#   Bloc 256  → 0.00286 s (n=3)
#   Bloc 288  → 0.00257 s (n=3)
#   Bloc 320  → 0.00427 s (n=3)
#   Bloc 352  → 0.00322 s (n=3)
#   Bloc 384  → 0.00585 s (n=3)
#   Bloc 416  → 0.00700 s (n=3)
#   Bloc 448  → 0.00641 s (n=3)
#   Bloc 480  → 0.00666 s (n=3)
#   Bloc 512  → 0.00742 s (n=3)
#   Bloc 544  → 0.00485 s (n=3)
#   Bloc 576  → 0.00451 s (n=3)
#   P(64 < 96) = 0.208
#   P(64 < 128) = 0.037
#   P(64 < 160) = 0.106
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.103
#   P(64 < 256) = 0.064
#   P(64 < 288) = 0.112
#   P(64 < 320) = 0.012
#   P(64 < 352) = 0.021
#   P(64 < 384) = 0.030
#   P(64 < 416) = 0.075
#   P(64 < 448) = 0.014
#   P(64 < 480) = 0.011
#   P(64 < 512) = 0.005
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.003
#   P(64 < 608) = 0.130
#   P(64 < 640) = 0.060
#   P(64 < 672) = 0.097
#   P(64 < 704) = 0.058
#   P(64 < 736) = 0.148
#   P(64 < 768) = 0.132
#   P(64 < 800) = 0.061
#   P(64 < 832) = 0.145
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.008
#   P(64 < 928) = 0.001
#   P(64 < 960) = 0.049
#   P(64 < 992) = 0.000
#
# 🔁 Itération 3: Best=64, mean=0.00131, σ=0.00088, CI_sup=0.00280
# Candidats : [64, 96, 160, 224, 256]
#   Bloc 64   → 0.00084 s (n=4)
#   Bloc 96   → 0.00230 s (n=4)
#   Bloc 160  → 0.00142 s (n=4)
#   Bloc 224  → 0.00189 s (n=4)
#   Bloc 256  → 0.00232 s (n=4)
#   P(64 < 96) = 0.107
#   P(64 < 128) = 0.015
#   P(64 < 160) = 0.079
#   P(64 < 192) = 0.036
#   P(64 < 224) = 0.043
#   P(64 < 256) = 0.018
#   P(64 < 288) = 0.108
#   P(64 < 320) = 0.013
#   P(64 < 352) = 0.021
#   P(64 < 384) = 0.029
#   P(64 < 416) = 0.072
#   P(64 < 448) = 0.016
#   P(64 < 480) = 0.012
#   P(64 < 512) = 0.005
#   P(64 < 544) = 0.000
#   P(64 < 576) = 0.002
#   P(64 < 608) = 0.129
#   P(64 < 640) = 0.065
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.064
#   P(64 < 736) = 0.147
#   P(64 < 768) = 0.131
#   P(64 < 800) = 0.066
#   P(64 < 832) = 0.144
#   P(64 < 864) = 0.000
#   P(64 < 896) = 0.012
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.053
#   P(64 < 992) = 0.000
#
# 🔁 Itération 4: Best=64, mean=0.00119, σ=0.00076, CI_sup=0.00209
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=5)
#   P(64 < 96) = 0.092
#   P(64 < 128) = 0.012
#   P(64 < 160) = 0.060
#   P(64 < 192) = 0.033
#   P(64 < 224) = 0.020
#   P(64 < 256) = 0.004
#   P(64 < 288) = 0.105
#   P(64 < 320) = 0.015
#   P(64 < 352) = 0.022
#   P(64 < 384) = 0.029
#   P(64 < 416) = 0.070
#   P(64 < 448) = 0.017
#   P(64 < 480) = 0.014
#   P(64 < 512) = 0.007
#   P(64 < 544) = 0.000
#   P(64 < 576) = 0.003
#   P(64 < 608) = 0.129
#   P(64 < 640) = 0.067
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.066
#   P(64 < 736) = 0.146
#   P(64 < 768) = 0.131
#   P(64 < 800) = 0.068
#   P(64 < 832) = 0.143
#   P(64 < 864) = 0.000
#   P(64 < 896) = 0.017
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.055
#   P(64 < 992) = 0.000
#
# 🔁 Itération 5: Best=64, mean=0.00112, σ=0.00068, CI_sup=0.00176
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=6)
#   P(64 < 96) = 0.084
#   P(64 < 128) = 0.011
#   P(64 < 160) = 0.051
#   P(64 < 192) = 0.032
#   P(64 < 224) = 0.012
#   P(64 < 256) = 0.001
#   P(64 < 288) = 0.103
#   P(64 < 320) = 0.015
#   P(64 < 352) = 0.023
#   P(64 < 384) = 0.030
#   P(64 < 416) = 0.069
#   P(64 < 448) = 0.017
#   P(64 < 480) = 0.014
#   P(64 < 512) = 0.007
#   P(64 < 544) = 0.000
#   P(64 < 576) = 0.004
#   P(64 < 608) = 0.128
#   P(64 < 640) = 0.068
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.068
#   P(64 < 736) = 0.145
#   P(64 < 768) = 0.130
#   P(64 < 800) = 0.070
#   P(64 < 832) = 0.142
#   P(64 < 864) = 0.001
#   P(64 < 896) = 0.021
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.056
#   P(64 < 992) = 0.000
#
# 🔁 Itération 6: Best=64, mean=0.00106, σ=0.00062, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00079 s (n=7)
#   P(64 < 96) = 0.079
#   P(64 < 128) = 0.012
#   P(64 < 160) = 0.047
#   P(64 < 192) = 0.031
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.102
#   P(64 < 320) = 0.016
#   P(64 < 352) = 0.023
#   P(64 < 384) = 0.030
#   P(64 < 416) = 0.068
#   P(64 < 448) = 0.018
#   P(64 < 480) = 0.015
#   P(64 < 512) = 0.008
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.005
#   P(64 < 608) = 0.128
#   P(64 < 640) = 0.069
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.068
#   P(64 < 736) = 0.145
#   P(64 < 768) = 0.130
#   P(64 < 800) = 0.070
#   P(64 < 832) = 0.142
#   P(64 < 864) = 0.001
#   P(64 < 896) = 0.023
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.057
#   P(64 < 992) = 0.000
#
# 🔁 Itération 7: Best=64, mean=0.00102, σ=0.00058, CI_sup=0.00145
# Candidats : [64]
#   Bloc 64   → 0.00226 s (n=8)
#   P(64 < 96) = 0.099
#   P(64 < 128) = 0.014
#   P(64 < 160) = 0.065
#   P(64 < 192) = 0.035
#   P(64 < 224) = 0.017
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.108
#   P(64 < 320) = 0.017
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.032
#   P(64 < 416) = 0.074
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.015
#   P(64 < 512) = 0.008
#   P(64 < 544) = 0.000
#   P(64 < 576) = 0.004
#   P(64 < 608) = 0.131
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.102
#   P(64 < 704) = 0.069
#   P(64 < 736) = 0.147
#   P(64 < 768) = 0.132
#   P(64 < 800) = 0.071
#   P(64 < 832) = 0.144
#   P(64 < 864) = 0.001
#   P(64 < 896) = 0.022
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.058
#   P(64 < 992) = 0.000
#
# 🔁 Itération 8: Best=64, mean=0.00118, σ=0.00069, CI_sup=0.00164
# Candidats : [64]
#   Bloc 64   → 0.00082 s (n=9)
#   P(64 < 96) = 0.093
#   P(64 < 128) = 0.014
#   P(64 < 160) = 0.059
#   P(64 < 192) = 0.034
#   P(64 < 224) = 0.014
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.107
#   P(64 < 320) = 0.017
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.032
#   P(64 < 416) = 0.073
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.016
#   P(64 < 512) = 0.009
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.005
#   P(64 < 608) = 0.130
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.101
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.147
#   P(64 < 768) = 0.132
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.143
#   P(64 < 864) = 0.001
#   P(64 < 896) = 0.024
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.058
#   P(64 < 992) = 0.000
#
# 🔁 Itération 9: Best=64, mean=0.00114, σ=0.00066, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=10)
#   P(64 < 96) = 0.089
#   P(64 < 128) = 0.015
#   P(64 < 160) = 0.055
#   P(64 < 192) = 0.033
#   P(64 < 224) = 0.012
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.105
#   P(64 < 320) = 0.017
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.032
#   P(64 < 416) = 0.072
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.016
#   P(64 < 512) = 0.009
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.005
#   P(64 < 608) = 0.130
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.101
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.146
#   P(64 < 768) = 0.131
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.143
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.025
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.058
#   P(64 < 992) = 0.000
#
# 🔁 Itération 10: Best=64, mean=0.00110, σ=0.00063, CI_sup=0.00147
# Candidats : [64]
#   Bloc 64   → 0.00117 s (n=11)
#   P(64 < 96) = 0.089
#   P(64 < 128) = 0.016
#   P(64 < 160) = 0.056
#   P(64 < 192) = 0.033
#   P(64 < 224) = 0.013
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.106
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.026
#   P(64 < 384) = 0.033
#   P(64 < 416) = 0.072
#   P(64 < 448) = 0.020
#   P(64 < 480) = 0.016
#   P(64 < 512) = 0.009
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.130
#   P(64 < 640) = 0.071
#   P(64 < 672) = 0.102
#   P(64 < 704) = 0.071
#   P(64 < 736) = 0.146
#   P(64 < 768) = 0.131
#   P(64 < 800) = 0.073
#   P(64 < 832) = 0.143
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.027
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 11: Best=64, mean=0.00111, σ=0.00060, CI_sup=0.00144
# Candidats : [64]
#   Bloc 64   → 0.00219 s (n=12)
#   P(64 < 96) = 0.102
#   P(64 < 128) = 0.017
#   P(64 < 160) = 0.067
#   P(64 < 192) = 0.036
#   P(64 < 224) = 0.017
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.109
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.027
#   P(64 < 384) = 0.035
#   P(64 < 416) = 0.075
#   P(64 < 448) = 0.020
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.132
#   P(64 < 640) = 0.072
#   P(64 < 672) = 0.103
#   P(64 < 704) = 0.072
#   P(64 < 736) = 0.148
#   P(64 < 768) = 0.133
#   P(64 < 800) = 0.074
#   P(64 < 832) = 0.144
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.026
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 12: Best=64, mean=0.00120, σ=0.00065, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00245 s (n=13)
#   P(64 < 96) = 0.118
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.082
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.024
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.114
#   P(64 < 320) = 0.019
#   P(64 < 352) = 0.028
#   P(64 < 384) = 0.037
#   P(64 < 416) = 0.079
#   P(64 < 448) = 0.021
#   P(64 < 480) = 0.018
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.134
#   P(64 < 640) = 0.073
#   P(64 < 672) = 0.105
#   P(64 < 704) = 0.073
#   P(64 < 736) = 0.149
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.075
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.026
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 13: Best=64, mean=0.00130, σ=0.00071, CI_sup=0.00165
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=14)
#   P(64 < 96) = 0.112
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.076
#   P(64 < 192) = 0.038
#   P(64 < 224) = 0.021
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.112
#   P(64 < 320) = 0.019
#   P(64 < 352) = 0.028
#   P(64 < 384) = 0.036
#   P(64 < 416) = 0.078
#   P(64 < 448) = 0.021
#   P(64 < 480) = 0.018
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.134
#   P(64 < 640) = 0.072
#   P(64 < 672) = 0.104
#   P(64 < 704) = 0.073
#   P(64 < 736) = 0.149
#   P(64 < 768) = 0.133
#   P(64 < 800) = 0.074
#   P(64 < 832) = 0.145
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.027
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 14: Best=64, mean=0.00126, σ=0.00070, CI_sup=0.00159
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=15)
#   P(64 < 96) = 0.106
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.071
#   P(64 < 192) = 0.037
#   P(64 < 224) = 0.019
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.111
#   P(64 < 320) = 0.019
#   P(64 < 352) = 0.028
#   P(64 < 384) = 0.036
#   P(64 < 416) = 0.077
#   P(64 < 448) = 0.021
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.133
#   P(64 < 640) = 0.072
#   P(64 < 672) = 0.104
#   P(64 < 704) = 0.072
#   P(64 < 736) = 0.148
#   P(64 < 768) = 0.133
#   P(64 < 800) = 0.074
#   P(64 < 832) = 0.145
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.027
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 15: Best=64, mean=0.00123, σ=0.00068, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=16)
#   P(64 < 96) = 0.102
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.067
#   P(64 < 192) = 0.036
#   P(64 < 224) = 0.017
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.110
#   P(64 < 320) = 0.019
#   P(64 < 352) = 0.028
#   P(64 < 384) = 0.035
#   P(64 < 416) = 0.076
#   P(64 < 448) = 0.021
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.006
#   P(64 < 608) = 0.132
#   P(64 < 640) = 0.072
#   P(64 < 672) = 0.103
#   P(64 < 704) = 0.072
#   P(64 < 736) = 0.148
#   P(64 < 768) = 0.133
#   P(64 < 800) = 0.074
#   P(64 < 832) = 0.144
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.028
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 16: Best=64, mean=0.00120, σ=0.00067, CI_sup=0.00150
# Candidats : [64]
#   Bloc 64   → 0.00239 s (n=17)
#   P(64 < 96) = 0.113
#   P(64 < 128) = 0.020
#   P(64 < 160) = 0.078
#   P(64 < 192) = 0.038
#   P(64 < 224) = 0.022
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.113
#   P(64 < 320) = 0.019
#   P(64 < 352) = 0.029
#   P(64 < 384) = 0.037
#   P(64 < 416) = 0.078
#   P(64 < 448) = 0.021
#   P(64 < 480) = 0.018
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.134
#   P(64 < 640) = 0.073
#   P(64 < 672) = 0.105
#   P(64 < 704) = 0.073
#   P(64 < 736) = 0.149
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.075
#   P(64 < 832) = 0.145
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.028
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 17: Best=64, mean=0.00127, σ=0.00071, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00285 s (n=18)
#   P(64 < 96) = 0.129
#   P(64 < 128) = 0.022
#   P(64 < 160) = 0.094
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.030
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.018
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.002
#   P(64 < 896) = 0.027
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 18: Best=64, mean=0.00136, σ=0.00078, CI_sup=0.00168
# Candidats : [64]
#   Bloc 64   → 0.00224 s (n=19)
#   P(64 < 96) = 0.138
#   P(64 < 128) = 0.024
#   P(64 < 160) = 0.104
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.035
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.028
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 19: Best=64, mean=0.00141, σ=0.00078, CI_sup=0.00172
# Candidats : [64]
#   Bloc 64   → 0.00082 s (n=20)
#   P(64 < 96) = 0.132
#   P(64 < 128) = 0.024
#   P(64 < 160) = 0.097
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.032
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.083
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.028
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 20: Best=64, mean=0.00138, σ=0.00077, CI_sup=0.00168
# Candidats : [64]
#   Bloc 64   → 0.00087 s (n=21)
#   P(64 < 96) = 0.128
#   P(64 < 128) = 0.023
#   P(64 < 160) = 0.092
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.029
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.116
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.003
#   P(64 < 896) = 0.029
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 21: Best=64, mean=0.00135, σ=0.00076, CI_sup=0.00164
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=22)
#   P(64 < 96) = 0.123
#   P(64 < 128) = 0.023
#   P(64 < 160) = 0.087
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.027
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.001
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.004
#   P(64 < 896) = 0.029
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 22: Best=64, mean=0.00133, σ=0.00075, CI_sup=0.00161
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=23)
#   P(64 < 96) = 0.119
#   P(64 < 128) = 0.022
#   P(64 < 160) = 0.083
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.025
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.114
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.038
#   P(64 < 416) = 0.080
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.105
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.004
#   P(64 < 896) = 0.029
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 23: Best=64, mean=0.00131, σ=0.00074, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00082 s (n=24)
#   P(64 < 96) = 0.115
#   P(64 < 128) = 0.022
#   P(64 < 160) = 0.080
#   P(64 < 192) = 0.038
#   P(64 < 224) = 0.023
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.113
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.029
#   P(64 < 384) = 0.038
#   P(64 < 416) = 0.079
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.018
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.134
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.105
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.149
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.005
#   P(64 < 896) = 0.030
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.060
#   P(64 < 992) = 0.000
#
# 🔁 Itération 24: Best=64, mean=0.00129, σ=0.00074, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00216 s (n=25)
#   P(64 < 96) = 0.121
#   P(64 < 128) = 0.023
#   P(64 < 160) = 0.086
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.026
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.007
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.074
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.005
#   P(64 < 896) = 0.030
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 25: Best=64, mean=0.00132, σ=0.00074, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00212 s (n=26)
#   P(64 < 96) = 0.127
#   P(64 < 128) = 0.025
#   P(64 < 160) = 0.092
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.029
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.116
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.005
#   P(64 < 896) = 0.030
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 26: Best=64, mean=0.00135, σ=0.00074, CI_sup=0.00160
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=27)
#   P(64 < 96) = 0.123
#   P(64 < 128) = 0.024
#   P(64 < 160) = 0.088
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.027
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.005
#   P(64 < 896) = 0.030
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 27: Best=64, mean=0.00133, σ=0.00074, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00214 s (n=28)
#   P(64 < 96) = 0.128
#   P(64 < 128) = 0.025
#   P(64 < 160) = 0.093
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.030
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.006
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 28: Best=64, mean=0.00136, σ=0.00074, CI_sup=0.00160
# Candidats : [64]
#   Bloc 64   → 0.00213 s (n=29)
#   P(64 < 96) = 0.134
#   P(64 < 128) = 0.027
#   P(64 < 160) = 0.098
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.033
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.006
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 29: Best=64, mean=0.00139, σ=0.00074, CI_sup=0.00162
# Candidats : [64]
#   Bloc 64   → 0.00081 s (n=30)
#   P(64 < 96) = 0.130
#   P(64 < 128) = 0.026
#   P(64 < 160) = 0.095
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.031
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.083
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.006
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 30: Best=64, mean=0.00137, σ=0.00073, CI_sup=0.00159
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=31)
#   P(64 < 96) = 0.126
#   P(64 < 128) = 0.026
#   P(64 < 160) = 0.091
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.029
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.116
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 31: Best=64, mean=0.00135, σ=0.00073, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00129 s (n=32)
#   P(64 < 96) = 0.126
#   P(64 < 128) = 0.026
#   P(64 < 160) = 0.091
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.029
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.116
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.082
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 32: Best=64, mean=0.00135, σ=0.00072, CI_sup=0.00156
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=33)
#   P(64 < 96) = 0.123
#   P(64 < 128) = 0.026
#   P(64 < 160) = 0.088
#   P(64 < 192) = 0.040
#   P(64 < 224) = 0.028
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.040
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 33: Best=64, mean=0.00133, σ=0.00071, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00079 s (n=34)
#   P(64 < 96) = 0.120
#   P(64 < 128) = 0.025
#   P(64 < 160) = 0.085
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.026
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 34: Best=64, mean=0.00131, σ=0.00071, CI_sup=0.00152
# Candidats : [64]
#   Bloc 64   → 0.00079 s (n=35)
#   P(64 < 96) = 0.117
#   P(64 < 128) = 0.025
#   P(64 < 160) = 0.082
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.025
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.114
#   P(64 < 320) = 0.020
#   P(64 < 352) = 0.030
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.080
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.011
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.074
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.076
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 35: Best=64, mean=0.00130, σ=0.00070, CI_sup=0.00150
# Candidats : [64]
#   Bloc 64   → 0.00206 s (n=36)
#   P(64 < 96) = 0.121
#   P(64 < 128) = 0.026
#   P(64 < 160) = 0.086
#   P(64 < 192) = 0.039
#   P(64 < 224) = 0.027
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.115
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.031
#   P(64 < 384) = 0.039
#   P(64 < 416) = 0.081
#   P(64 < 448) = 0.022
#   P(64 < 480) = 0.019
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.135
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.106
#   P(64 < 704) = 0.075
#   P(64 < 736) = 0.150
#   P(64 < 768) = 0.134
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.146
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 36: Best=64, mean=0.00132, σ=0.00070, CI_sup=0.00152
# Candidats : [64]
#   Bloc 64   → 0.00371 s (n=37)
#   P(64 < 96) = 0.133
#   P(64 < 128) = 0.027
#   P(64 < 160) = 0.098
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.033
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.077
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.031
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.061
#   P(64 < 992) = 0.000
#
# 🔁 Itération 37: Best=64, mean=0.00138, σ=0.00080, CI_sup=0.00161
# Candidats : [64]
#   Bloc 64   → 0.00229 s (n=38)
#   P(64 < 96) = 0.138
#   P(64 < 128) = 0.028
#   P(64 < 160) = 0.103
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.036
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 38: Best=64, mean=0.00141, σ=0.00080, CI_sup=0.00163
# Candidats : [64]
#   Bloc 64   → 0.00237 s (n=39)
#   P(64 < 96) = 0.143
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.109
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.039
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.086
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 39: Best=64, mean=0.00143, σ=0.00080, CI_sup=0.00165
# Candidats : [64]
#   Bloc 64   → 0.00160 s (n=40)
#   P(64 < 96) = 0.144
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.110
#   P(64 < 192) = 0.044
#   P(64 < 224) = 0.039
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.086
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 40: Best=64, mean=0.00144, σ=0.00079, CI_sup=0.00165
# Candidats : [64]
#   Bloc 64   → 0.00081 s (n=41)
#   P(64 < 96) = 0.141
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.106
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.038
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.007
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 41: Best=64, mean=0.00142, σ=0.00079, CI_sup=0.00163
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=42)
#   P(64 < 96) = 0.138
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.103
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.036
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 42: Best=64, mean=0.00141, σ=0.00079, CI_sup=0.00161
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=43)
#   P(64 < 96) = 0.135
#   P(64 < 128) = 0.028
#   P(64 < 160) = 0.100
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.034
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.002
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 43: Best=64, mean=0.00139, σ=0.00078, CI_sup=0.00159
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=44)
#   P(64 < 96) = 0.132
#   P(64 < 128) = 0.028
#   P(64 < 160) = 0.097
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.033
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 44: Best=64, mean=0.00138, σ=0.00078, CI_sup=0.00158
# Candidats : [64]
#   Bloc 64   → 0.00215 s (n=45)
#   P(64 < 96) = 0.136
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.101
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.035
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 45: Best=64, mean=0.00140, σ=0.00078, CI_sup=0.00159
# Candidats : [64]
#   Bloc 64   → 0.00257 s (n=46)
#   P(64 < 96) = 0.141
#   P(64 < 128) = 0.030
#   P(64 < 160) = 0.106
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.038
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.032
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 46: Best=64, mean=0.00142, σ=0.00079, CI_sup=0.00162
# Candidats : [64]
#   Bloc 64   → 0.00267 s (n=47)
#   P(64 < 96) = 0.146
#   P(64 < 128) = 0.031
#   P(64 < 160) = 0.112
#   P(64 < 192) = 0.044
#   P(64 < 224) = 0.041
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.121
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.043
#   P(64 < 416) = 0.087
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.109
#   P(64 < 704) = 0.077
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.079
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 47: Best=64, mean=0.00145, σ=0.00080, CI_sup=0.00165
# Candidats : [64]
#   Bloc 64   → 0.00081 s (n=48)
#   P(64 < 96) = 0.144
#   P(64 < 128) = 0.030
#   P(64 < 160) = 0.109
#   P(64 < 192) = 0.044
#   P(64 < 224) = 0.040
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.043
#   P(64 < 416) = 0.086
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.077
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.008
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 48: Best=64, mean=0.00144, σ=0.00080, CI_sup=0.00163
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=49)
#   P(64 < 96) = 0.141
#   P(64 < 128) = 0.030
#   P(64 < 160) = 0.106
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.038
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.120
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.148
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 49: Best=64, mean=0.00142, σ=0.00079, CI_sup=0.00161
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=50)
#   P(64 < 96) = 0.138
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.103
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.036
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 50: Best=64, mean=0.00141, σ=0.00079, CI_sup=0.00160
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=51)
#   P(64 < 96) = 0.136
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.101
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.035
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 51: Best=64, mean=0.00140, σ=0.00079, CI_sup=0.00158
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=52)
#   P(64 < 96) = 0.134
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.099
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.034
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 52: Best=64, mean=0.00139, σ=0.00079, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00222 s (n=53)
#   P(64 < 96) = 0.137
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.102
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.036
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 53: Best=64, mean=0.00140, σ=0.00079, CI_sup=0.00158
# Candidats : [64]
#   Bloc 64   → 0.00182 s (n=54)
#   P(64 < 96) = 0.138
#   P(64 < 128) = 0.030
#   P(64 < 160) = 0.103
#   P(64 < 192) = 0.043
#   P(64 < 224) = 0.037
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.138
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.152
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 54: Best=64, mean=0.00141, σ=0.00078, CI_sup=0.00159
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=55)
#   P(64 < 96) = 0.136
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.101
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.035
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.009
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 55: Best=64, mean=0.00140, σ=0.00078, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=56)
#   P(64 < 96) = 0.134
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.099
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.034
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 56: Best=64, mean=0.00139, σ=0.00077, CI_sup=0.00156
# Candidats : [64]
#   Bloc 64   → 0.00211 s (n=57)
#   P(64 < 96) = 0.136
#   P(64 < 128) = 0.030
#   P(64 < 160) = 0.102
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.036
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.119
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.085
#   P(64 < 448) = 0.024
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.136
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 57: Best=64, mean=0.00140, σ=0.00077, CI_sup=0.00157
# Candidats : [64]
#   Bloc 64   → 0.00101 s (n=58)
#   P(64 < 96) = 0.135
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.100
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.035
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.033
#   P(64 < 384) = 0.042
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.108
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 58: Best=64, mean=0.00139, σ=0.00077, CI_sup=0.00156
# Candidats : [64]
#   Bloc 64   → 0.00079 s (n=59)
#   P(64 < 96) = 0.133
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.098
#   P(64 < 192) = 0.042
#   P(64 < 224) = 0.034
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.118
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.084
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.076
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 59: Best=64, mean=0.00138, σ=0.00077, CI_sup=0.00155
# Candidats : [64]
#   Bloc 64   → 0.00076 s (n=60)
#   P(64 < 96) = 0.131
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.096
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.033
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.022
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.083
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.137
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 60: Best=64, mean=0.00137, σ=0.00076, CI_sup=0.00154
# Candidats : [64]
#   Bloc 64   → 0.00076 s (n=61)
#   P(64 < 96) = 0.129
#   P(64 < 128) = 0.029
#   P(64 < 160) = 0.094
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.032
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.117
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.083
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.009
#   P(64 < 608) = 0.136
#   P(64 < 640) = 0.075
#   P(64 < 672) = 0.107
#   P(64 < 704) = 0.076
#   P(64 < 736) = 0.151
#   P(64 < 768) = 0.135
#   P(64 < 800) = 0.078
#   P(64 < 832) = 0.147
#   P(64 < 864) = 0.010
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.062
#   P(64 < 992) = 0.000
#
# 🔁 Itération 61: Best=64, mean=0.00136, σ=0.00076, CI_sup=0.00153
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=62)
#   P(64 < 96) = 0.127
#   P(64 < 128) = 0.028
#   P(64 < 160) = 0.092
#   P(64 < 192) = 0.041
#   P(64 < 224) = 0.031
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.116
#   P(64 < 320) = 0.021
#   P(64 < 352) = 0.032
#   P(64 < 384) = 0.041
#   P(64 < 416) = 0.083
#   P(64 < 448) = 0.023
#   P(64 < 480) = 0.020
#   P(64 < 512) = 0.012
# ...
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 980: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=981)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 981: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00076 s (n=982)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 982: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=983)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 983: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00076 s (n=984)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 984: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=985)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 985: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=986)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 986: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=987)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 987: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00078 s (n=988)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 988: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=989)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 989: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=990)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 990: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00160 s (n=991)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 991: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00099 s (n=992)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 992: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00081 s (n=993)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 993: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00076 s (n=994)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 994: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00078 s (n=995)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.125
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 995: Best=64, mean=0.00084, σ=0.00051, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00532 s (n=996)
#   P(64 < 96) = 0.063
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 996: Best=64, mean=0.00085, σ=0.00052, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00080 s (n=997)
#   P(64 < 96) = 0.063
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 997: Best=64, mean=0.00085, σ=0.00052, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00086 s (n=998)
#   P(64 < 96) = 0.063
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 998: Best=64, mean=0.00085, σ=0.00052, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00077 s (n=999)
#   P(64 < 96) = 0.063
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 999: Best=64, mean=0.00085, σ=0.00052, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=1000)
#   P(64 < 96) = 0.063
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# 🔁 Itération 1000: Best=64, mean=0.00085, σ=0.00052, CI_sup=0.00087
# Candidats : [64]
#   Bloc 64   → 0.00075 s (n=1001)
#   P(64 < 96) = 0.062
#   P(64 < 128) = 0.019
#   P(64 < 160) = 0.036
#   P(64 < 192) = 0.026
#   P(64 < 224) = 0.010
#   P(64 < 256) = 0.000
#   P(64 < 288) = 0.096
#   P(64 < 320) = 0.018
#   P(64 < 352) = 0.025
#   P(64 < 384) = 0.031
#   P(64 < 416) = 0.064
#   P(64 < 448) = 0.019
#   P(64 < 480) = 0.017
#   P(64 < 512) = 0.010
#   P(64 < 544) = 0.003
#   P(64 < 576) = 0.008
#   P(64 < 608) = 0.126
#   P(64 < 640) = 0.070
#   P(64 < 672) = 0.099
#   P(64 < 704) = 0.070
#   P(64 < 736) = 0.142
#   P(64 < 768) = 0.128
#   P(64 < 800) = 0.072
#   P(64 < 832) = 0.140
#   P(64 < 864) = 0.016
#   P(64 < 896) = 0.033
#   P(64 < 928) = 0.000
#   P(64 < 960) = 0.059
#   P(64 < 992) = 0.000
#
# ✅ Meilleure taille de bloc : 64 (0.00076 s)
# 🧮 Nombre total de mesures : 1082

# %% [markdown]
# # Benchmark intelligent 2

# %%
# -*- coding: utf-8 -*-
"""
Benchmark adaptatif jusqu'à décision probabiliste.

Vous devez fournir deux fonctions adaptées à votre code :
    • measure_time(x, block)   -> float (temps en secondes)
    • run_attention_once(x, b) -> None   (exécution « à blanc »)

Logique :
---------
À chaque itération, pour chaque bloc b ≠ best on calcule
    p_better = P( temps(b) < temps(best) )

    • Si max(p_better) > 0.50  →  on bascule le best sur le bloc qui
      possède cette proba maximale.
    • Si max(p_better) < 0.05  →  on est sûr à 95 % que ‘best’ est le
      plus rapide et on s’arrête.
    • Sinon on continue, en remesurant :
         – toujours le ‘best’,
         – tous les blocs dont p_better ≥ 0.05
"""

from math import sqrt
import numpy as np
from scipy.stats import t as student_t


def _prob_b_faster_than_a(mean_a, std_a, n_a, mean_b, std_b, n_b):
    """
    P(µ_b < µ_a) avec test de Welch sur la différence de moyennes.
    """
    # variance de la différence
    var = (std_a ** 2) / n_a + (std_b ** 2) / n_b
    if var == 0:
        return 0.5          # mesures identiques, probabilité 0.5

    se = sqrt(var)
    diff = mean_b - mean_a             # <0 si b plus rapide
    t_stat = diff / se                 # statistique observée

    # ddl Welch–Satterthwaite
    df = (
        var ** 2 /
        (((std_a ** 4) / (n_a ** 2 * (n_a - 1))) +
         ((std_b ** 4) / (n_b ** 2 * (n_b - 1))))
    )

    # P(diff < 0) = CDF(-|t|)
    p = student_t.cdf(-t_stat, df)
    return p


def smart_benchmark_probabilistic(
    x,
    block_sizes,
    *,
    p_switch: float = 0.50,
    p_stop: float = 0.05,
    initial_repeats: int = 2,
    free_runs: int = 5,
    extra_repeats_best: int = 3,
    max_iter: int = 1_000,
    verbose: bool = True,
):
    # ---------------------------------------------------------------
    # Préparation
    # ---------------------------------------------------------------
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}
    history = []          # [ (iter, best, {b: p_better}) ]
    best_track = []       # suivi du best

    # (1) réchauffe-caches
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once(x, b)

    # (2) mesures initiales
    if verbose:
        print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            results[b].append(measure_time(x, b))
        if verbose:
            m = np.mean(results[b])
            print(f"Bloc {b:<4} → {m:.5f} s (n={len(results[b])})")

    # (3) best initial + répétitions bonus
    best = min(block_sizes, key=lambda b: np.mean(results[b]))
    if verbose:
        print(f"\nBest initial : {best}")
    for _ in range(extra_repeats_best):
        results[best].append(measure_time(x, best))

    # ---------------------------------------------------------------
    # Boucle principale
    # ---------------------------------------------------------------
    for it in range(1, max_iter + 1):
        # Stats de tous les blocs
        stats = {
            b: (
                np.mean(results[b]),
                np.std(results[b], ddof=1) if len(results[b]) > 1 else 0.0,
                len(results[b]),
            )
            for b in block_sizes
        }
        mean_best, std_best, n_best = stats[best]

        # Probabilités P(b < best)
        p_better = {}
        for b in block_sizes:
            if b == best:
                continue
            mean_b, std_b, n_b = stats[b]
            p = _prob_b_faster_than_a(
                mean_best, std_best, n_best,
                mean_b, std_b, n_b
            )
            p_better[b] = p

        history.append((it, best, p_better.copy()))
        best_track.append(best)

        if verbose:
            print(f"\n🔁 Itération {it}: best = {best}")
            for b, p in sorted(p_better.items()):
                print(f"  P({b} plus rapide que {best}) = {p:.3f}")

        # -----------------------------------------------------------
        # Décision : stop ? switch ?
        # -----------------------------------------------------------
        max_p = max(p_better.values(), default=0.0)
        if max_p < p_stop:
            if verbose:
                print("\n✅ Condition d’arrêt : toutes les probabilités "
                      f"< {p_stop:.2f}.")
            break

        # bloc candidat pour switch (plus forte proba > 0.50)
        if max_p > p_switch:
            new_best = max(p_better, key=p_better.get)
            if verbose:
                print(f"↪️ Switch du best : {best} → {new_best} "
                      f"(p = {max_p:.3f})")
            best = new_best
            # mettre à jour stats best
            mean_best, std_best, n_best = stats[best]

        # -----------------------------------------------------------
        # Sélection des blocs à remesurer
        #   – toujours le best
        #   – tous ceux avec p_better ≥ p_stop
        # -----------------------------------------------------------
        to_measure = [best] + [
            b for b, p in p_better.items() if p >= p_stop
        ]
        if verbose:
            print("Mesures supplémentaires :", to_measure)

        for b in to_measure:
            t = measure_time(x, b)
            results[b].append(t)
            if verbose:
                print(f"  Bloc {b:<4} → {t:.5f} s (n={len(results[b])})")

    # ---------------------------------------------------------------
    # Résultat final
    # ---------------------------------------------------------------
    if verbose:
        m_final = float(np.median(results[best]))
        tot = sum(len(v) for v in results.values())
        print(f"\n🏁 Best final : {best} (médiane = {m_final:.5f} s)")
        print("Mesures totales :", tot)

    return best, results, history, best_track

# %%
# ------------------------
# Exécution et double graphique
# ------------------------
if __name__ == "__main__":
    seq_len, d_model = 1024, 64
    x = np.random.randn(seq_len, d_model)
    blocks = range(64, 1024, 32) # Taille de bloc à tester
    best, results, hist, best_blocks_by_iter = smart_benchmark_probabilistic(x, blocks)
# Out:
# 🔍 Phase 1 : mesures initiales
# Bloc 64   → 0.00288 s (n=2)
# Bloc 96   → 0.00279 s (n=2)
# Bloc 128  → 0.00513 s (n=2)
# Bloc 160  → 0.00342 s (n=2)
# Bloc 192  → 0.00420 s (n=2)
# Bloc 224  → 0.00593 s (n=2)
# Bloc 256  → 0.00358 s (n=2)
# Bloc 288  → 0.00862 s (n=2)
# Bloc 320  → 0.00586 s (n=2)
# Bloc 352  → 0.00346 s (n=2)
# Bloc 384  → 0.01388 s (n=2)
# Bloc 416  → 0.00942 s (n=2)
# Bloc 448  → 0.00576 s (n=2)
# Bloc 480  → 0.00755 s (n=2)
# Bloc 512  → 0.00794 s (n=2)
# Bloc 544  → 0.00874 s (n=2)
# Bloc 576  → 0.00766 s (n=2)
# Bloc 608  → 0.01541 s (n=2)
# Bloc 640  → 0.00731 s (n=2)
# Bloc 672  → 0.00940 s (n=2)
# Bloc 704  → 0.01188 s (n=2)
# Bloc 736  → 0.01470 s (n=2)
# Bloc 768  → 0.01210 s (n=2)
# Bloc 800  → 0.01041 s (n=2)
# Bloc 832  → 0.01033 s (n=2)
# Bloc 864  → 0.01060 s (n=2)
# Bloc 896  → 0.01282 s (n=2)
# Bloc 928  → 0.01032 s (n=2)
# Bloc 960  → 0.01458 s (n=2)
# Bloc 992  → 0.01140 s (n=2)
#
# Best initial : 96
#
# 🔁 Itération 1: best = 96
#   P(64 plus rapide que 96) = 0.629
#   P(128 plus rapide que 96) = 0.233
#   P(160 plus rapide que 96) = 0.494
#   P(192 plus rapide que 96) = 0.304
#   P(224 plus rapide que 96) = 0.070
#   P(256 plus rapide que 96) = 0.459
#   P(288 plus rapide que 96) = 0.209
#   P(320 plus rapide que 96) = 0.307
#   P(352 plus rapide que 96) = 0.479
#   P(384 plus rapide que 96) = 0.001
#   P(416 plus rapide que 96) = 0.013
#   P(448 plus rapide que 96) = 0.234
#   P(480 plus rapide que 96) = 0.188
#   P(512 plus rapide que 96) = 0.103
#   P(544 plus rapide que 96) = 0.210
#   P(576 plus rapide que 96) = 0.138
#   P(608 plus rapide que 96) = 0.000
#   P(640 plus rapide que 96) = 0.188
#   P(672 plus rapide que 96) = 0.152
#   P(704 plus rapide que 96) = 0.080
#   P(736 plus rapide que 96) = 0.028
#   P(768 plus rapide que 96) = 0.190
#   P(800 plus rapide que 96) = 0.059
#   P(832 plus rapide que 96) = 0.051
#   P(864 plus rapide que 96) = 0.009
#   P(896 plus rapide que 96) = 0.083
#   P(928 plus rapide que 96) = 0.128
#   P(960 plus rapide que 96) = 0.046
#   P(992 plus rapide que 96) = 0.063
# ↪️ Switch du best : 96 → 64 (p = 0.629)
# Mesures supplémentaires : [64, 64, 128, 160, 192, 224, 256, 288, 320, 352, 448, 480, 512, 544, 576, 640, 672, 704, 768, 800, 832, 896, 928, 992]
#   Bloc 64   → 0.00298 s (n=3)
#   Bloc 64   → 0.00084 s (n=4)
#   Bloc 128  → 0.01218 s (n=3)
#   Bloc 160  → 0.01109 s (n=3)
#   Bloc 192  → 0.00495 s (n=3)
#   Bloc 224  → 0.00191 s (n=3)
#   Bloc 256  → 0.01225 s (n=3)
#   Bloc 288  → 0.00318 s (n=3)
#   Bloc 320  → 0.00319 s (n=3)
#   Bloc 352  → 0.00449 s (n=3)
#   Bloc 448  → 0.00464 s (n=3)
#   Bloc 480  → 0.00414 s (n=3)
#   Bloc 512  → 0.01701 s (n=3)
#   Bloc 544  → 0.01316 s (n=3)
#   Bloc 576  → 0.00829 s (n=3)
#   Bloc 640  → 0.00732 s (n=3)
#   Bloc 672  → 0.00784 s (n=3)
#   Bloc 704  → 0.00647 s (n=3)
#   Bloc 768  → 0.01172 s (n=3)
#   Bloc 800  → 0.00673 s (n=3)
#   Bloc 832  → 0.01036 s (n=3)
#   Bloc 896  → 0.01393 s (n=3)
#   Bloc 928  → 0.01043 s (n=3)
#   Bloc 992  → 0.00959 s (n=3)
#
# 🔁 Itération 2: best = 64
#   P(96 plus rapide que 64) = 0.264
#   P(128 plus rapide que 64) = 0.088
#   P(160 plus rapide que 64) = 0.165
#   P(192 plus rapide que 64) = 0.018
#   P(224 plus rapide que 64) = 0.124
#   P(256 plus rapide que 64) = 0.152
#   P(288 plus rapide que 64) = 0.140
#   P(320 plus rapide que 64) = 0.187
#   P(352 plus rapide que 64) = 0.057
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.027
#   P(448 plus rapide que 64) = 0.072
#   P(480 plus rapide que 64) = 0.094
#   P(512 plus rapide que 64) = 0.057
#   P(544 plus rapide que 64) = 0.055
#   P(576 plus rapide que 64) = 0.021
#   P(608 plus rapide que 64) = 0.000
#   P(640 plus rapide que 64) = 0.042
#   P(672 plus rapide que 64) = 0.039
#   P(704 plus rapide que 64) = 0.041
#   P(736 plus rapide que 64) = 0.047
#   P(768 plus rapide que 64) = 0.054
#   P(800 plus rapide que 64) = 0.025
#   P(832 plus rapide que 64) = 0.005
#   P(864 plus rapide que 64) = 0.025
#   P(896 plus rapide que 64) = 0.011
#   P(928 plus rapide que 64) = 0.023
#   P(960 plus rapide que 64) = 0.062
#   P(992 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 96, 128, 160, 224, 256, 288, 320, 352, 448, 480, 512, 544, 768, 960]
#   Bloc 64   → 0.00081 s (n=5)
#   Bloc 96   → 0.00594 s (n=6)
#   Bloc 128  → 0.00173 s (n=4)
#   Bloc 160  → 0.00395 s (n=4)
#   Bloc 224  → 0.00538 s (n=4)
#   Bloc 256  → 0.00237 s (n=4)
#   Bloc 288  → 0.00280 s (n=4)
#   Bloc 320  → 0.00352 s (n=4)
#   Bloc 352  → 0.00363 s (n=4)
#   Bloc 448  → 0.00420 s (n=4)
#   Bloc 480  → 0.00930 s (n=4)
#   Bloc 512  → 0.00776 s (n=4)
#   Bloc 544  → 0.01819 s (n=4)
#   Bloc 768  → 0.01662 s (n=4)
#   Bloc 960  → 0.00854 s (n=3)
#
# 🔁 Itération 3: best = 64
#   P(96 plus rapide que 64) = 0.112
#   P(128 plus rapide que 64) = 0.091
#   P(160 plus rapide que 64) = 0.099
#   P(192 plus rapide que 64) = 0.008
#   P(224 plus rapide que 64) = 0.032
#   P(256 plus rapide que 64) = 0.124
#   P(288 plus rapide que 64) = 0.107
#   P(320 plus rapide que 64) = 0.112
#   P(352 plus rapide que 64) = 0.018
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.026
#   P(448 plus rapide que 64) = 0.024
#   P(480 plus rapide que 64) = 0.024
#   P(512 plus rapide que 64) = 0.021
#   P(544 plus rapide que 64) = 0.018
#   P(576 plus rapide que 64) = 0.019
#   P(608 plus rapide que 64) = 0.000
#   P(640 plus rapide que 64) = 0.037
#   P(672 plus rapide que 64) = 0.036
#   P(704 plus rapide que 64) = 0.038
#   P(736 plus rapide que 64) = 0.046
#   P(768 plus rapide que 64) = 0.013
#   P(800 plus rapide que 64) = 0.023
#   P(832 plus rapide que 64) = 0.004
#   P(864 plus rapide que 64) = 0.025
#   P(896 plus rapide que 64) = 0.010
#   P(928 plus rapide que 64) = 0.021
#   P(960 plus rapide que 64) = 0.024
#   P(992 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 96, 128, 160, 256, 288, 320]
#   Bloc 64   → 0.00217 s (n=6)
#   Bloc 96   → 0.00753 s (n=7)
#   Bloc 128  → 0.00983 s (n=5)
#   Bloc 160  → 0.00561 s (n=5)
#   Bloc 256  → 0.00331 s (n=5)
#   Bloc 288  → 0.00533 s (n=5)
#   Bloc 320  → 0.00586 s (n=5)
#
# 🔁 Itération 4: best = 64
#   P(96 plus rapide que 64) = 0.051
#   P(128 plus rapide que 64) = 0.035
#   P(160 plus rapide que 64) = 0.049
#   P(192 plus rapide que 64) = 0.006
#   P(224 plus rapide que 64) = 0.033
#   P(256 plus rapide que 64) = 0.097
#   P(288 plus rapide que 64) = 0.060
#   P(320 plus rapide que 64) = 0.050
#   P(352 plus rapide que 64) = 0.009
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.032
#   P(448 plus rapide que 64) = 0.025
#   P(480 plus rapide que 64) = 0.025
#   P(512 plus rapide que 64) = 0.021
#   P(544 plus rapide que 64) = 0.018
#   P(576 plus rapide que 64) = 0.021
#   P(608 plus rapide que 64) = 0.000
#   P(640 plus rapide que 64) = 0.039
#   P(672 plus rapide que 64) = 0.037
#   P(704 plus rapide que 64) = 0.039
#   P(736 plus rapide que 64) = 0.049
#   P(768 plus rapide que 64) = 0.013
#   P(800 plus rapide que 64) = 0.024
#   P(832 plus rapide que 64) = 0.005
#   P(864 plus rapide que 64) = 0.030
#   P(896 plus rapide que 64) = 0.011
#   P(928 plus rapide que 64) = 0.023
#   P(960 plus rapide que 64) = 0.025
#   P(992 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 96, 256, 288, 320]
#   Bloc 64   → 0.00145 s (n=7)
#   Bloc 96   → 0.00156 s (n=8)
#   Bloc 256  → 0.00729 s (n=6)
#   Bloc 288  → 0.00747 s (n=6)
#   Bloc 320  → 0.00588 s (n=6)
#
# 🔁 Itération 5: best = 64
#   P(96 plus rapide que 64) = 0.053
#   P(128 plus rapide que 64) = 0.033
#   P(160 plus rapide que 64) = 0.046
#   P(192 plus rapide que 64) = 0.005
#   P(224 plus rapide que 64) = 0.030
#   P(256 plus rapide que 64) = 0.042
#   P(288 plus rapide que 64) = 0.023
#   P(320 plus rapide que 64) = 0.018
#   P(352 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.034
#   P(448 plus rapide que 64) = 0.023
#   P(480 plus rapide que 64) = 0.024
#   P(512 plus rapide que 64) = 0.021
#   P(544 plus rapide que 64) = 0.018
#   P(576 plus rapide que 64) = 0.021
#   P(608 plus rapide que 64) = 0.001
#   P(640 plus rapide que 64) = 0.039
#   P(672 plus rapide que 64) = 0.037
#   P(704 plus rapide que 64) = 0.039
#   P(736 plus rapide que 64) = 0.050
#   P(768 plus rapide que 64) = 0.013
#   P(800 plus rapide que 64) = 0.024
#   P(832 plus rapide que 64) = 0.006
#   P(864 plus rapide que 64) = 0.032
#   P(896 plus rapide que 64) = 0.012
#   P(928 plus rapide que 64) = 0.023
#   P(960 plus rapide que 64) = 0.025
#   P(992 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 96]
#   Bloc 64   → 0.00080 s (n=8)
#   Bloc 96   → 0.00126 s (n=9)
#
# 🔁 Itération 6: best = 64
#   P(96 plus rapide que 64) = 0.052
#   P(128 plus rapide que 64) = 0.031
#   P(160 plus rapide que 64) = 0.041
#   P(192 plus rapide que 64) = 0.004
#   P(224 plus rapide que 64) = 0.026
#   P(256 plus rapide que 64) = 0.037
#   P(288 plus rapide que 64) = 0.021
#   P(320 plus rapide que 64) = 0.015
#   P(352 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.035
#   P(448 plus rapide que 64) = 0.020
#   P(480 plus rapide que 64) = 0.023
#   P(512 plus rapide que 64) = 0.020
#   P(544 plus rapide que 64) = 0.017
#   P(576 plus rapide que 64) = 0.021
#   P(608 plus rapide que 64) = 0.001
#   P(640 plus rapide que 64) = 0.037
#   P(672 plus rapide que 64) = 0.036
#   P(704 plus rapide que 64) = 0.038
#   P(736 plus rapide que 64) = 0.050
#   P(768 plus rapide que 64) = 0.012
#   P(800 plus rapide que 64) = 0.024
#   P(832 plus rapide que 64) = 0.006
#   P(864 plus rapide que 64) = 0.033
#   P(896 plus rapide que 64) = 0.012
#   P(928 plus rapide que 64) = 0.022
#   P(960 plus rapide que 64) = 0.024
#   P(992 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 96]
#   Bloc 64   → 0.00080 s (n=9)
#   Bloc 96   → 0.00396 s (n=10)
#
# 🔁 Itération 7: best = 64
#   P(96 plus rapide que 64) = 0.027
#   P(128 plus rapide que 64) = 0.029
#   P(160 plus rapide que 64) = 0.038
#   P(192 plus rapide que 64) = 0.004
#   P(224 plus rapide que 64) = 0.024
#   P(256 plus rapide que 64) = 0.033
#   P(288 plus rapide que 64) = 0.019
#   P(320 plus rapide que 64) = 0.013
#   P(352 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(416 plus rapide que 64) = 0.035
#   P(448 plus rapide que 64) = 0.019
#   P(480 plus rapide que 64) = 0.022
#   P(512 plus rapide que 64) = 0.019
#   P(544 plus rapide que 64) = 0.017
#   P(576 plus rapide que 64) = 0.020
#   P(608 plus rapide que 64) = 0.001
#   P(640 plus rapide que 64) = 0.036
#   P(672 plus rapide que 64) = 0.035
#   P(704 plus rapide que 64) = 0.037
#   P(736 plus rapide que 64) = 0.049
#   P(768 plus rapide que 64) = 0.012
#   P(800 plus rapide que 64) = 0.023
#   P(832 plus rapide que 64) = 0.006
#   P(864 plus rapide que 64) = 0.033
#   P(896 plus rapide que 64) = 0.011
#   P(928 plus rapide que 64) = 0.022
#   P(960 plus rapide que 64) = 0.024
#   P(992 plus rapide que 64) = 0.012
#
# ✅ Condition d’arrêt : toutes les probabilités < 0.05.
#
# 🏁 Best final : 64 (médiane = 0.00145 s)
# Mesures totales : 118
