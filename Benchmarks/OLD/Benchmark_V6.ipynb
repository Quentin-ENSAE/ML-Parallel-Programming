# %% [markdown]
# ## Calcul de l'attention (avec numpy)

# %%
import numpy as np
import pandas as pd
import time
import math
from math import sqrt
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

# %%
# ------------------------
# Fonction d'attention (inchangée)
# ------------------------
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def run_attention_once_np(x, block_size):
    seq_len, d_model = x.shape
    output = np.zeros_like(x)
    for i in range(0, seq_len, block_size):
        end = min(i + block_size, seq_len)
        Q = x[i:end]
        K = x[i:end]
        V = x[i:end]
        scores = np.matmul(Q, K.T) / np.sqrt(d_model)
        weights = softmax(scores)
        output[i:end] = np.matmul(weights, V)
    return output


# ------------------------
# Mesure de temps
# ------------------------
def measure_time(x, block_size):
    start = time.perf_counter()
    _ = run_attention_once_np(x, block_size)
    return time.perf_counter() - start

# %% [markdown]
# ## Grille exhaustive qui teste toutes les combinaisons
#
# * Mesure initiale : pour chaque block_size, effectue initial_repeats mesures et stocke les temps.
#
# * Choix du candidat : identifie le bloc dont la moyenne des temps initiaux est la plus faible.
#
# * Échauffement : relance 5 mesures supplémentaires sur ce “best” pour estimer son intervalle de confiance (IC) à 95 % (Student-t).
#
# * Itération : jusqu’à max_iter, répète :
#
# * Recalcule la moyenne, l’écart-type et l’IC supérieur du “best”.
#
# * Sélectionne tous les blocs dont la moyenne courante ≤ IC supérieur.
#
# * Mesure chacun de ces candidats une fois de plus.
#
# * Met à jour le “best” en choisissant, parmi les candidats, celui à la plus petite moyenne.
#
# * Test de confiance : pour chaque autre bloc, effectue un test t de Welch contre le “best” et calcule la p-value unilatérale.
#
# * Arrêt : dès que toutes les p-values sont < 0.05 (95 % de confiance que le “best” est plus rapide), on sort.
#
# * Résultat : retourne la taille de bloc optimale, toutes les mesures accumulées, et le nombre total de tests effectués.

# %%
# ------------------------
# Grille exhaustive jusqu'à confiance 95%, avec free runs + p_history
# ------------------------
def exhaustive_grid_until_confidence(
    x,
    block_sizes,
    initial_repeats=2,
    free_runs=1,
    confidence=0.95,
    max_iter=100,
    verbose=True
):
    alpha = 1 - confidence
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}

    # Pour les tracés
    best_track = []             # meilleur par itération
    best_measurements = []      # tuples (mesure_index, best_block, time_s)
    p_history = []              # liste de dict {bloc: p_value}
    measure_counter = 0         # compteur global de mesures

    # (0) Free runs pour chauffer les caches / JIT
    if free_runs > 0 and verbose:
        print(f"⚙️  Phase 0 : {free_runs} free runs")
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once_np(x, b)
    if verbose and free_runs > 0:
        print("Fin des free runs\n")

    # Phase initiale
    if verbose:
        print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            t = measure_time(x, b)
            measure_counter += 1
            results[b].append(t)
        med = np.median(results[b])
        if verbose:
            print(f"Bloc {b:<4} → médiane init : {med:.5f} s")
    total_tests = initial_repeats * len(block_sizes)

    # Boucle d'itérations
    for it in range(1, max_iter+1):
        if verbose:
            print(f"\n🔁 Itération {it} : mesure de tous les blocs")

        # Mesures
        for b in block_sizes:
            t = measure_time(x, b)
            measure_counter += 1
            results[b].append(t)
            if verbose:
                print(f" Bloc {b:<4} → {t:.5f} s (n={len(results[b])})")

        total_tests += len(block_sizes)

        # Moyennes et variances
        means = {b: np.mean(results[b]) for b in block_sizes}
        vars_  = {b: np.var(results[b], ddof=1) for b in block_sizes}
        ns     = {b: len(results[b]) for b in block_sizes}

        # Choix du best
        best = min(means, key=means.get)
        best_track.append(best)
        if verbose:
            print(f" Meilleur moyen actuel : Bloc {best} (mean={means[best]:.5f})")
        best_measurements.append(
            (measure_counter - (len(block_sizes)-block_sizes.index(best)),
             best,
             results[best][-1])
        )

        # Test de confiance pair à pair et enregistrement p-values
        all_confident = True
        p_vals = {}
        for b in block_sizes:
            if b == best:
                continue
            diff     = means[b] - means[best]
            var_diff = vars_[b]/ns[b] + vars_[best]/ns[best]
            t_stat   = diff / math.sqrt(var_diff)
            df = (var_diff**2) / (
                (vars_[b]**2)/(ns[b]**2*(ns[b]-1)) +
                (vars_[best]**2)/(ns[best]**2*(ns[best]-1))
            )
            p_value = 1 - student_t.cdf(t_stat, df)
            p_vals[b] = p_value
            if verbose:
                print(f"  -> Bloc {best} vs Bloc {b}: p={p_value:.4f}")
            if p_value >= alpha:
                all_confident = False

        p_history.append(p_vals)

        if all_confident:
            if verbose:
                print("\n✅ Confiance 95% atteinte pour le meilleur bloc.")
            break

        if it == max_iter and verbose:
            print(f"\n❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de {confidence*100:.0f} %.")

    if verbose and it < max_iter:
        print(f"\n✅ Résultat final : Bloc {best}, tests totaux = {total_tests}")

    return best, results, total_tests, best_track, best_measurements, p_history

# %%
# ------------------------
# Exécution
# ------------------------
seq_len, d_model = 2048, 64
x = np.random.randn(seq_len, d_model)
min_size, max_size, step = 32, 512, 32
blocks = list(range(min_size, max_size, step))

best, results, total_tests, best_track, best_meas, p_hist = \
        exhaustive_grid_until_confidence(
            x, blocks,
            initial_repeats=2,
            free_runs=1,
            confidence=0.95,
            max_iter=100,
            verbose=True
        )
# Out:
# ⚙️  Phase 0 : 1 free runs
# Fin des free runs
#
# 🔍 Phase 1 : mesures initiales
# Bloc 32   → médiane init : 0.00510 s
# Bloc 64   → médiane init : 0.00496 s
# Bloc 96   → médiane init : 0.00457 s
# Bloc 128  → médiane init : 0.03503 s
# Bloc 160  → médiane init : 0.00603 s
# Bloc 192  → médiane init : 0.00673 s
# Bloc 224  → médiane init : 0.00775 s
# Bloc 256  → médiane init : 0.03017 s
# Bloc 288  → médiane init : 0.00916 s
# Bloc 320  → médiane init : 0.01032 s
# Bloc 352  → médiane init : 0.02590 s
# Bloc 384  → médiane init : 0.01189 s
# Bloc 416  → médiane init : 0.03829 s
# Bloc 448  → médiane init : 0.01293 s
# Bloc 480  → médiane init : 0.04452 s
#
# 🔁 Itération 1 : mesure de tous les blocs
#  Bloc 32   → 0.00449 s (n=3)
#  Bloc 64   → 0.00457 s (n=3)
#  Bloc 96   → 0.00514 s (n=3)
#  Bloc 128  → 0.06514 s (n=3)
#  Bloc 160  → 0.00870 s (n=3)
#  Bloc 192  → 0.00684 s (n=3)
#  Bloc 224  → 0.00730 s (n=3)
#  Bloc 256  → 0.00821 s (n=3)
#  Bloc 288  → 0.06796 s (n=3)
#  Bloc 320  → 0.01150 s (n=3)
#  Bloc 352  → 0.00965 s (n=3)
#  Bloc 384  → 0.01167 s (n=3)
#  Bloc 416  → 0.01255 s (n=3)
#  Bloc 448  → 0.05447 s (n=3)
#  Bloc 480  → 0.01369 s (n=3)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00476)
#   -> Bloc 96 vs Bloc 32: p=0.3784
#   -> Bloc 96 vs Bloc 64: p=0.4463
#   -> Bloc 96 vs Bloc 128: p=0.0888
#   -> Bloc 96 vs Bloc 160: p=0.0621
#   -> Bloc 96 vs Bloc 192: p=0.0105
#   -> Bloc 96 vs Bloc 224: p=0.0024
#   -> Bloc 96 vs Bloc 256: p=0.1623
#   -> Bloc 96 vs Bloc 288: p=0.1728
#   -> Bloc 96 vs Bloc 320: p=0.0004
#   -> Bloc 96 vs Bloc 352: p=0.1340
#   -> Bloc 96 vs Bloc 384: p=0.0001
#   -> Bloc 96 vs Bloc 416: p=0.1434
#   -> Bloc 96 vs Bloc 448: p=0.1265
#   -> Bloc 96 vs Bloc 480: p=0.1500
#
# 🔁 Itération 2 : mesure de tous les blocs
#  Bloc 32   → 0.00480 s (n=4)
#  Bloc 64   → 0.00337 s (n=4)
#  Bloc 96   → 0.00378 s (n=4)
#  Bloc 128  → 0.00515 s (n=4)
#  Bloc 160  → 0.06464 s (n=4)
#  Bloc 192  → 0.00791 s (n=4)
#  Bloc 224  → 0.00634 s (n=4)
#  Bloc 256  → 0.00755 s (n=4)
#  Bloc 288  → 0.00800 s (n=4)
#  Bloc 320  → 0.00935 s (n=4)
#  Bloc 352  → 0.06755 s (n=4)
#  Bloc 384  → 0.01050 s (n=4)
#  Bloc 416  → 0.01096 s (n=4)
#  Bloc 448  → 0.01164 s (n=4)
#  Bloc 480  → 0.06949 s (n=4)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00447)
#   -> Bloc 64 vs Bloc 32: p=0.2231
#   -> Bloc 64 vs Bloc 96: p=0.4659
#   -> Bloc 64 vs Bloc 128: p=0.0860
#   -> Bloc 64 vs Bloc 160: p=0.1634
#   -> Bloc 64 vs Bloc 192: p=0.0022
#   -> Bloc 64 vs Bloc 224: p=0.0015
#   -> Bloc 64 vs Bloc 256: p=0.1315
#   -> Bloc 64 vs Bloc 288: p=0.1437
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0693
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.1077
#   -> Bloc 64 vs Bloc 448: p=0.0879
#   -> Bloc 64 vs Bloc 480: p=0.0568
#
# 🔁 Itération 3 : mesure de tous les blocs
#  Bloc 32   → 0.00389 s (n=5)
#  Bloc 64   → 0.00330 s (n=5)
#  Bloc 96   → 0.00371 s (n=5)
#  Bloc 128  → 0.00523 s (n=5)
#  Bloc 160  → 0.00562 s (n=5)
#  Bloc 192  → 0.06617 s (n=5)
#  Bloc 224  → 0.00828 s (n=5)
#  Bloc 256  → 0.00813 s (n=5)
#  Bloc 288  → 0.00833 s (n=5)
#  Bloc 320  → 0.00945 s (n=5)
#  Bloc 352  → 0.00977 s (n=5)
#  Bloc 384  → 0.06599 s (n=5)
#  Bloc 416  → 0.01159 s (n=5)
#  Bloc 448  → 0.01198 s (n=5)
#  Bloc 480  → 0.06346 s (n=5)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00423)
#   -> Bloc 64 vs Bloc 32: p=0.1952
#   -> Bloc 64 vs Bloc 96: p=0.4099
#   -> Bloc 64 vs Bloc 128: p=0.0814
#   -> Bloc 64 vs Bloc 160: p=0.1479
#   -> Bloc 64 vs Bloc 192: p=0.1417
#   -> Bloc 64 vs Bloc 224: p=0.0002
#   -> Bloc 64 vs Bloc 256: p=0.1058
#   -> Bloc 64 vs Bloc 288: p=0.1209
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0567
#   -> Bloc 64 vs Bloc 384: p=0.0857
#   -> Bloc 64 vs Bloc 416: p=0.0802
#   -> Bloc 64 vs Bloc 448: p=0.0604
#   -> Bloc 64 vs Bloc 480: p=0.0191
#
# 🔁 Itération 4 : mesure de tous les blocs
#  Bloc 32   → 0.00765 s (n=6)
#  Bloc 64   → 0.00580 s (n=6)
#  Bloc 96   → 0.00613 s (n=6)
#  Bloc 128  → 0.00726 s (n=6)
#  Bloc 160  → 0.00788 s (n=6)
#  Bloc 192  → 0.06544 s (n=6)
#  Bloc 224  → 0.00957 s (n=6)
#  Bloc 256  → 0.01058 s (n=6)
#  Bloc 288  → 0.01130 s (n=6)
#  Bloc 320  → 0.00963 s (n=6)
#  Bloc 352  → 0.06052 s (n=6)
#  Bloc 384  → 0.01214 s (n=6)
#  Bloc 416  → 0.01751 s (n=6)
#  Bloc 448  → 0.06381 s (n=6)
#  Bloc 480  → 0.01444 s (n=6)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00449)
#   -> Bloc 64 vs Bloc 32: p=0.1731
#   -> Bloc 64 vs Bloc 96: p=0.3952
#   -> Bloc 64 vs Bloc 128: p=0.0762
#   -> Bloc 64 vs Bloc 160: p=0.1346
#   -> Bloc 64 vs Bloc 192: p=0.0670
#   -> Bloc 64 vs Bloc 224: p=0.0001
#   -> Bloc 64 vs Bloc 256: p=0.0839
#   -> Bloc 64 vs Bloc 288: p=0.0998
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0235
#   -> Bloc 64 vs Bloc 384: p=0.0672
#   -> Bloc 64 vs Bloc 416: p=0.0526
#   -> Bloc 64 vs Bloc 448: p=0.0323
#   -> Bloc 64 vs Bloc 480: p=0.0165
#
# 🔁 Itération 5 : mesure de tous les blocs
#  Bloc 32   → 0.00718 s (n=7)
#  Bloc 64   → 0.00491 s (n=7)
#  Bloc 96   → 0.00738 s (n=7)
#  Bloc 128  → 0.06510 s (n=7)
#  Bloc 160  → 0.00591 s (n=7)
#  Bloc 192  → 0.00689 s (n=7)
#  Bloc 224  → 0.00854 s (n=7)
#  Bloc 256  → 0.00921 s (n=7)
#  Bloc 288  → 0.00907 s (n=7)
#  Bloc 320  → 0.06617 s (n=7)
#  Bloc 352  → 0.01023 s (n=7)
#  Bloc 384  → 0.01595 s (n=7)
#  Bloc 416  → 0.01238 s (n=7)
#  Bloc 448  → 0.05488 s (n=7)
#  Bloc 480  → 0.01724 s (n=7)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00455)
#   -> Bloc 64 vs Bloc 32: p=0.0956
#   -> Bloc 64 vs Bloc 96: p=0.2267
#   -> Bloc 64 vs Bloc 128: p=0.0338
#   -> Bloc 64 vs Bloc 160: p=0.1279
#   -> Bloc 64 vs Bloc 192: p=0.0630
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0684
#   -> Bloc 64 vs Bloc 288: p=0.0864
#   -> Bloc 64 vs Bloc 320: p=0.0710
#   -> Bloc 64 vs Bloc 352: p=0.0208
#   -> Bloc 64 vs Bloc 384: p=0.0457
#   -> Bloc 64 vs Bloc 416: p=0.0394
#   -> Bloc 64 vs Bloc 448: p=0.0128
#   -> Bloc 64 vs Bloc 480: p=0.0124
#
# 🔁 Itération 6 : mesure de tous les blocs
#  Bloc 32   → 0.00398 s (n=8)
#  Bloc 64   → 0.00343 s (n=8)
#  Bloc 96   → 0.00369 s (n=8)
#  Bloc 128  → 0.06324 s (n=8)
#  Bloc 160  → 0.00763 s (n=8)
#  Bloc 192  → 0.00796 s (n=8)
#  Bloc 224  → 0.00870 s (n=8)
#  Bloc 256  → 0.00958 s (n=8)
#  Bloc 288  → 0.07053 s (n=8)
#  Bloc 320  → 0.01119 s (n=8)
#  Bloc 352  → 0.00952 s (n=8)
#  Bloc 384  → 0.01120 s (n=8)
#  Bloc 416  → 0.01136 s (n=8)
#  Bloc 448  → 0.05512 s (n=8)
#  Bloc 480  → 0.01410 s (n=8)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00441)
#   -> Bloc 64 vs Bloc 32: p=0.0906
#   -> Bloc 64 vs Bloc 96: p=0.2240
#   -> Bloc 64 vs Bloc 128: p=0.0138
#   -> Bloc 64 vs Bloc 160: p=0.1124
#   -> Bloc 64 vs Bloc 192: p=0.0562
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0521
#   -> Bloc 64 vs Bloc 288: p=0.0422
#   -> Bloc 64 vs Bloc 320: p=0.0548
#   -> Bloc 64 vs Bloc 352: p=0.0181
#   -> Bloc 64 vs Bloc 384: p=0.0345
#   -> Bloc 64 vs Bloc 416: p=0.0292
#   -> Bloc 64 vs Bloc 448: p=0.0046
#   -> Bloc 64 vs Bloc 480: p=0.0100
#
# 🔁 Itération 7 : mesure de tous les blocs
#  Bloc 32   → 0.00372 s (n=9)
#  Bloc 64   → 0.00330 s (n=9)
#  Bloc 96   → 0.00380 s (n=9)
#  Bloc 128  → 0.00524 s (n=9)
#  Bloc 160  → 0.06704 s (n=9)
#  Bloc 192  → 0.00824 s (n=9)
#  Bloc 224  → 0.00708 s (n=9)
#  Bloc 256  → 0.00823 s (n=9)
#  Bloc 288  → 0.00817 s (n=9)
#  Bloc 320  → 0.07058 s (n=9)
#  Bloc 352  → 0.01065 s (n=9)
#  Bloc 384  → 0.01045 s (n=9)
#  Bloc 416  → 0.01137 s (n=9)
#  Bloc 448  → 0.05800 s (n=9)
#  Bloc 480  → 0.01562 s (n=9)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00429)
#   -> Bloc 64 vs Bloc 32: p=0.0903
#   -> Bloc 64 vs Bloc 96: p=0.2044
#   -> Bloc 64 vs Bloc 128: p=0.0143
#   -> Bloc 64 vs Bloc 160: p=0.0546
#   -> Bloc 64 vs Bloc 192: p=0.0497
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0415
#   -> Bloc 64 vs Bloc 288: p=0.0376
#   -> Bloc 64 vs Bloc 320: p=0.0292
#   -> Bloc 64 vs Bloc 352: p=0.0149
#   -> Bloc 64 vs Bloc 384: p=0.0266
#   -> Bloc 64 vs Bloc 416: p=0.0214
#   -> Bloc 64 vs Bloc 448: p=0.0016
#   -> Bloc 64 vs Bloc 480: p=0.0075
#
# 🔁 Itération 8 : mesure de tous les blocs
#  Bloc 32   → 0.00379 s (n=10)
#  Bloc 64   → 0.00341 s (n=10)
#  Bloc 96   → 0.00383 s (n=10)
#  Bloc 128  → 0.00496 s (n=10)
#  Bloc 160  → 0.06482 s (n=10)
#  Bloc 192  → 0.01522 s (n=10)
#  Bloc 224  → 0.00879 s (n=10)
#  Bloc 256  → 0.00870 s (n=10)
#  Bloc 288  → 0.00921 s (n=10)
#  Bloc 320  → 0.06067 s (n=10)
#  Bloc 352  → 0.01281 s (n=10)
#  Bloc 384  → 0.01167 s (n=10)
#  Bloc 416  → 0.01082 s (n=10)
#  Bloc 448  → 0.05729 s (n=10)
#  Bloc 480  → 0.02068 s (n=10)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00420)
#   -> Bloc 64 vs Bloc 32: p=0.0867
#   -> Bloc 64 vs Bloc 96: p=0.1871
#   -> Bloc 64 vs Bloc 128: p=0.0146
#   -> Bloc 64 vs Bloc 160: p=0.0253
#   -> Bloc 64 vs Bloc 192: p=0.0368
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0323
#   -> Bloc 64 vs Bloc 288: p=0.0325
#   -> Bloc 64 vs Bloc 320: p=0.0129
#   -> Bloc 64 vs Bloc 352: p=0.0114
#   -> Bloc 64 vs Bloc 384: p=0.0194
#   -> Bloc 64 vs Bloc 416: p=0.0159
#   -> Bloc 64 vs Bloc 448: p=0.0005
#   -> Bloc 64 vs Bloc 480: p=0.0048
#
# 🔁 Itération 9 : mesure de tous les blocs
#  Bloc 32   → 0.00362 s (n=11)
#  Bloc 64   → 0.00331 s (n=11)
#  Bloc 96   → 0.00420 s (n=11)
#  Bloc 128  → 0.06568 s (n=11)
#  Bloc 160  → 0.00944 s (n=11)
#  Bloc 192  → 0.00645 s (n=11)
#  Bloc 224  → 0.00728 s (n=11)
#  Bloc 256  → 0.00777 s (n=11)
#  Bloc 288  → 0.00797 s (n=11)
#  Bloc 320  → 0.06320 s (n=11)
#  Bloc 352  → 0.01071 s (n=11)
#  Bloc 384  → 0.01086 s (n=11)
#  Bloc 416  → 0.01100 s (n=11)
#  Bloc 448  → 0.01156 s (n=11)
#  Bloc 480  → 0.05653 s (n=11)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00412)
#   -> Bloc 64 vs Bloc 32: p=0.0857
#   -> Bloc 64 vs Bloc 96: p=0.1482
#   -> Bloc 64 vs Bloc 128: p=0.0062
#   -> Bloc 64 vs Bloc 160: p=0.0220
#   -> Bloc 64 vs Bloc 192: p=0.0340
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0260
#   -> Bloc 64 vs Bloc 288: p=0.0289
#   -> Bloc 64 vs Bloc 320: p=0.0055
#   -> Bloc 64 vs Bloc 352: p=0.0093
#   -> Bloc 64 vs Bloc 384: p=0.0144
#   -> Bloc 64 vs Bloc 416: p=0.0116
#   -> Bloc 64 vs Bloc 448: p=0.0005
#   -> Bloc 64 vs Bloc 480: p=0.0018
#
# 🔁 Itération 10 : mesure de tous les blocs
#  Bloc 32   → 0.00382 s (n=12)
#  Bloc 64   → 0.00465 s (n=12)
#  Bloc 96   → 0.00395 s (n=12)
#  Bloc 128  → 0.00521 s (n=12)
#  Bloc 160  → 0.00564 s (n=12)
#  Bloc 192  → 0.06614 s (n=12)
#  Bloc 224  → 0.00972 s (n=12)
#  Bloc 256  → 0.00821 s (n=12)
#  Bloc 288  → 0.00963 s (n=12)
#  Bloc 320  → 0.00972 s (n=12)
#  Bloc 352  → 0.05979 s (n=12)
#  Bloc 384  → 0.01290 s (n=12)
#  Bloc 416  → 0.01085 s (n=12)
#  Bloc 448  → 0.01151 s (n=12)
#  Bloc 480  → 0.06306 s (n=12)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00416)
#   -> Bloc 64 vs Bloc 32: p=0.1119
#   -> Bloc 64 vs Bloc 96: p=0.1818
#   -> Bloc 64 vs Bloc 128: p=0.0065
#   -> Bloc 64 vs Bloc 160: p=0.0217
#   -> Bloc 64 vs Bloc 192: p=0.0168
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0216
#   -> Bloc 64 vs Bloc 288: p=0.0253
#   -> Bloc 64 vs Bloc 320: p=0.0050
#   -> Bloc 64 vs Bloc 352: p=0.0043
#   -> Bloc 64 vs Bloc 384: p=0.0102
#   -> Bloc 64 vs Bloc 416: p=0.0088
#   -> Bloc 64 vs Bloc 448: p=0.0005
#   -> Bloc 64 vs Bloc 480: p=0.0007
#
# 🔁 Itération 11 : mesure de tous les blocs
#  Bloc 32   → 0.00377 s (n=13)
#  Bloc 64   → 0.00339 s (n=13)
#  Bloc 96   → 0.00379 s (n=13)
#  Bloc 128  → 0.00516 s (n=13)
#  Bloc 160  → 0.00582 s (n=13)
#  Bloc 192  → 0.00710 s (n=13)
#  Bloc 224  → 0.06679 s (n=13)
#  Bloc 256  → 0.01165 s (n=13)
#  Bloc 288  → 0.01035 s (n=13)
#  Bloc 320  → 0.00987 s (n=13)
#  Bloc 352  → 0.01049 s (n=13)
#  Bloc 384  → 0.05367 s (n=13)
#  Bloc 416  → 0.01481 s (n=13)
#  Bloc 448  → 0.01159 s (n=13)
#  Bloc 480  → 0.01288 s (n=13)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00411)
#   -> Bloc 64 vs Bloc 32: p=0.1044
#   -> Bloc 64 vs Bloc 96: p=0.1667
#   -> Bloc 64 vs Bloc 128: p=0.0066
#   -> Bloc 64 vs Bloc 160: p=0.0208
#   -> Bloc 64 vs Bloc 192: p=0.0156
#   -> Bloc 64 vs Bloc 224: p=0.0425
#   -> Bloc 64 vs Bloc 256: p=0.0142
#   -> Bloc 64 vs Bloc 288: p=0.0210
#   -> Bloc 64 vs Bloc 320: p=0.0044
#   -> Bloc 64 vs Bloc 352: p=0.0036
#   -> Bloc 64 vs Bloc 384: p=0.0055
#   -> Bloc 64 vs Bloc 416: p=0.0054
#   -> Bloc 64 vs Bloc 448: p=0.0004
#   -> Bloc 64 vs Bloc 480: p=0.0006
#
# 🔁 Itération 12 : mesure de tous les blocs
#  Bloc 32   → 0.00401 s (n=14)
#  Bloc 64   → 0.05403 s (n=14)
#  Bloc 96   → 0.00501 s (n=14)
#  Bloc 128  → 0.00558 s (n=14)
#  Bloc 160  → 0.00571 s (n=14)
#  Bloc 192  → 0.00634 s (n=14)
#  Bloc 224  → 0.00711 s (n=14)
#  Bloc 256  → 0.00795 s (n=14)
#  Bloc 288  → 0.07105 s (n=14)
#  Bloc 320  → 0.01061 s (n=14)
#  Bloc 352  → 0.00968 s (n=14)
#  Bloc 384  → 0.01021 s (n=14)
#  Bloc 416  → 0.01147 s (n=14)
#  Bloc 448  → 0.05602 s (n=14)
#  Bloc 480  → 0.01273 s (n=14)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00454)
#   -> Bloc 96 vs Bloc 32: p=0.4173
#   -> Bloc 96 vs Bloc 64: p=0.1992
#   -> Bloc 96 vs Bloc 128: p=0.0074
#   -> Bloc 96 vs Bloc 160: p=0.0228
#   -> Bloc 96 vs Bloc 192: p=0.0168
#   -> Bloc 96 vs Bloc 224: p=0.0458
#   -> Bloc 96 vs Bloc 256: p=0.0152
#   -> Bloc 96 vs Bloc 288: p=0.0123
#   -> Bloc 96 vs Bloc 320: p=0.0043
#   -> Bloc 96 vs Bloc 352: p=0.0036
#   -> Bloc 96 vs Bloc 384: p=0.0053
#   -> Bloc 96 vs Bloc 416: p=0.0048
#   -> Bloc 96 vs Bloc 448: p=0.0002
#   -> Bloc 96 vs Bloc 480: p=0.0006
#
# 🔁 Itération 13 : mesure de tous les blocs
#  Bloc 32   → 0.00365 s (n=15)
#  Bloc 64   → 0.00324 s (n=15)
#  Bloc 96   → 0.00363 s (n=15)
#  Bloc 128  → 0.06132 s (n=15)
#  Bloc 160  → 0.01100 s (n=15)
#  Bloc 192  → 0.00706 s (n=15)
#  Bloc 224  → 0.00705 s (n=15)
#  Bloc 256  → 0.00806 s (n=15)
#  Bloc 288  → 0.00814 s (n=15)
#  Bloc 320  → 0.06155 s (n=15)
#  Bloc 352  → 0.01240 s (n=15)
#  Bloc 384  → 0.01035 s (n=15)
#  Bloc 416  → 0.01087 s (n=15)
#  Bloc 448  → 0.01108 s (n=15)
#  Bloc 480  → 0.06241 s (n=15)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00448)
#   -> Bloc 96 vs Bloc 32: p=0.4180
#   -> Bloc 96 vs Bloc 64: p=0.2010
#   -> Bloc 96 vs Bloc 128: p=0.0033
#   -> Bloc 96 vs Bloc 160: p=0.0192
#   -> Bloc 96 vs Bloc 192: p=0.0157
#   -> Bloc 96 vs Bloc 224: p=0.0408
#   -> Bloc 96 vs Bloc 256: p=0.0120
#   -> Bloc 96 vs Bloc 288: p=0.0111
#   -> Bloc 96 vs Bloc 320: p=0.0019
#   -> Bloc 96 vs Bloc 352: p=0.0028
#   -> Bloc 96 vs Bloc 384: p=0.0042
#   -> Bloc 96 vs Bloc 416: p=0.0035
#   -> Bloc 96 vs Bloc 448: p=0.0002
#   -> Bloc 96 vs Bloc 480: p=0.0002
#
# 🔁 Itération 14 : mesure de tous les blocs
#  Bloc 32   → 0.00377 s (n=16)
#  Bloc 64   → 0.00486 s (n=16)
#  Bloc 96   → 0.00536 s (n=16)
#  Bloc 128  → 0.00525 s (n=16)
#  Bloc 160  → 0.00574 s (n=16)
#  Bloc 192  → 0.06464 s (n=16)
#  Bloc 224  → 0.00887 s (n=16)
#  Bloc 256  → 0.00834 s (n=16)
#  Bloc 288  → 0.00799 s (n=16)
#  Bloc 320  → 0.00889 s (n=16)
#  Bloc 352  → 0.00924 s (n=16)
#  Bloc 384  → 0.06384 s (n=16)
#  Bloc 416  → 0.01177 s (n=16)
#  Bloc 448  → 0.01243 s (n=16)
#  Bloc 480  → 0.01331 s (n=16)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00452)
#   -> Bloc 32 vs Bloc 64: p=0.2020
#   -> Bloc 32 vs Bloc 96: p=0.4855
#   -> Bloc 32 vs Bloc 128: p=0.0035
#   -> Bloc 32 vs Bloc 160: p=0.0190
#   -> Bloc 32 vs Bloc 192: p=0.0077
#   -> Bloc 32 vs Bloc 224: p=0.0357
#   -> Bloc 32 vs Bloc 256: p=0.0101
#   -> Bloc 32 vs Bloc 288: p=0.0105
#   -> Bloc 32 vs Bloc 320: p=0.0018
#   -> Bloc 32 vs Bloc 352: p=0.0025
#   -> Bloc 32 vs Bloc 384: p=0.0026
#   -> Bloc 32 vs Bloc 416: p=0.0025
#   -> Bloc 32 vs Bloc 448: p=0.0001
#   -> Bloc 32 vs Bloc 480: p=0.0002
#
# 🔁 Itération 15 : mesure de tous les blocs
#  Bloc 32   → 0.04994 s (n=17)
#  Bloc 64   → 0.00539 s (n=17)
#  Bloc 96   → 0.00498 s (n=17)
#  Bloc 128  → 0.00621 s (n=17)
#  Bloc 160  → 0.00687 s (n=17)
#  Bloc 192  → 0.00757 s (n=17)
#  Bloc 224  → 0.06569 s (n=17)
#  Bloc 256  → 0.01416 s (n=17)
#  Bloc 288  → 0.00920 s (n=17)
#  Bloc 320  → 0.00962 s (n=17)
#  Bloc 352  → 0.01020 s (n=17)
#  Bloc 384  → 0.01130 s (n=17)
#  Bloc 416  → 0.04586 s (n=17)
#  Bloc 448  → 0.01576 s (n=17)
#  Bloc 480  → 0.01343 s (n=17)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00456)
#   -> Bloc 96 vs Bloc 32: p=0.1720
#   -> Bloc 96 vs Bloc 64: p=0.2001
#   -> Bloc 96 vs Bloc 128: p=0.0035
#   -> Bloc 96 vs Bloc 160: p=0.0182
#   -> Bloc 96 vs Bloc 192: p=0.0074
#   -> Bloc 96 vs Bloc 224: p=0.0218
#   -> Bloc 96 vs Bloc 256: p=0.0062
#   -> Bloc 96 vs Bloc 288: p=0.0095
#   -> Bloc 96 vs Bloc 320: p=0.0016
#   -> Bloc 96 vs Bloc 352: p=0.0022
#   -> Bloc 96 vs Bloc 384: p=0.0022
#   -> Bloc 96 vs Bloc 416: p=0.0014
#   -> Bloc 96 vs Bloc 448: p=0.0001
#   -> Bloc 96 vs Bloc 480: p=0.0002
#
# 🔁 Itération 16 : mesure de tous les blocs
#  Bloc 32   → 0.00493 s (n=18)
#  Bloc 64   → 0.00391 s (n=18)
#  Bloc 96   → 0.05778 s (n=18)
#  Bloc 128  → 0.00953 s (n=18)
#  Bloc 160  → 0.00766 s (n=18)
#  Bloc 192  → 0.00746 s (n=18)
#  Bloc 224  → 0.00830 s (n=18)
#  Bloc 256  → 0.06734 s (n=18)
#  Bloc 288  → 0.01259 s (n=18)
#  Bloc 320  → 0.01067 s (n=18)
#  Bloc 352  → 0.01071 s (n=18)
#  Bloc 384  → 0.01151 s (n=18)
#  Bloc 416  → 0.01182 s (n=18)
#  Bloc 448  → 0.05045 s (n=18)
#  Bloc 480  → 0.01229 s (n=18)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00693)
#   -> Bloc 64 vs Bloc 32: p=0.4860
#   -> Bloc 64 vs Bloc 96: p=0.4432
#   -> Bloc 64 vs Bloc 128: p=0.0092
#   -> Bloc 64 vs Bloc 160: p=0.0558
#   -> Bloc 64 vs Bloc 192: p=0.0226
#   -> Bloc 64 vs Bloc 224: p=0.0799
#   -> Bloc 64 vs Bloc 256: p=0.0577
#   -> Bloc 64 vs Bloc 288: p=0.0274
#   -> Bloc 64 vs Bloc 320: p=0.0051
#   -> Bloc 64 vs Bloc 352: p=0.0095
#   -> Bloc 64 vs Bloc 384: p=0.0106
#   -> Bloc 64 vs Bloc 416: p=0.0151
#   -> Bloc 64 vs Bloc 448: p=0.0002
#   -> Bloc 64 vs Bloc 480: p=0.0005
#
# 🔁 Itération 17 : mesure de tous les blocs
#  Bloc 32   → 0.00376 s (n=19)
#  Bloc 64   → 0.00341 s (n=19)
#  Bloc 96   → 0.00534 s (n=19)
#  Bloc 128  → 0.00666 s (n=19)
#  Bloc 160  → 0.05538 s (n=19)
#  Bloc 192  → 0.00871 s (n=19)
#  Bloc 224  → 0.00748 s (n=19)
#  Bloc 256  → 0.00804 s (n=19)
#  Bloc 288  → 0.00962 s (n=19)
#  Bloc 320  → 0.00918 s (n=19)
#  Bloc 352  → 0.06493 s (n=19)
#  Bloc 384  → 0.01530 s (n=19)
#  Bloc 416  → 0.01342 s (n=19)
#  Bloc 448  → 0.01122 s (n=19)
#  Bloc 480  → 0.06490 s (n=19)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00675)
#   -> Bloc 64 vs Bloc 32: p=0.4840
#   -> Bloc 64 vs Bloc 96: p=0.4329
#   -> Bloc 64 vs Bloc 128: p=0.0089
#   -> Bloc 64 vs Bloc 160: p=0.0276
#   -> Bloc 64 vs Bloc 192: p=0.0207
#   -> Bloc 64 vs Bloc 224: p=0.0742
#   -> Bloc 64 vs Bloc 256: p=0.0523
#   -> Bloc 64 vs Bloc 288: p=0.0244
#   -> Bloc 64 vs Bloc 320: p=0.0046
#   -> Bloc 64 vs Bloc 352: p=0.0042
#   -> Bloc 64 vs Bloc 384: p=0.0078
#   -> Bloc 64 vs Bloc 416: p=0.0111
#   -> Bloc 64 vs Bloc 448: p=0.0002
#   -> Bloc 64 vs Bloc 480: p=0.0002
#
# 🔁 Itération 18 : mesure de tous les blocs
#  Bloc 32   → 0.00358 s (n=20)
#  Bloc 64   → 0.00317 s (n=20)
#  Bloc 96   → 0.00397 s (n=20)
#  Bloc 128  → 0.00512 s (n=20)
#  Bloc 160  → 0.00628 s (n=20)
#  Bloc 192  → 0.06613 s (n=20)
#  Bloc 224  → 0.00988 s (n=20)
#  Bloc 256  → 0.00812 s (n=20)
#  Bloc 288  → 0.00813 s (n=20)
#  Bloc 320  → 0.00953 s (n=20)
#  Bloc 352  → 0.05874 s (n=20)
#  Bloc 384  → 0.01523 s (n=20)
#  Bloc 416  → 0.01111 s (n=20)
#  Bloc 448  → 0.01252 s (n=20)
#  Bloc 480  → 0.06319 s (n=20)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00657)
#   -> Bloc 64 vs Bloc 32: p=0.4816
#   -> Bloc 64 vs Bloc 96: p=0.4287
#   -> Bloc 64 vs Bloc 128: p=0.0090
#   -> Bloc 64 vs Bloc 160: p=0.0264
#   -> Bloc 64 vs Bloc 192: p=0.0095
#   -> Bloc 64 vs Bloc 224: p=0.0650
#   -> Bloc 64 vs Bloc 256: p=0.0469
#   -> Bloc 64 vs Bloc 288: p=0.0224
#   -> Bloc 64 vs Bloc 320: p=0.0042
#   -> Bloc 64 vs Bloc 352: p=0.0018
#   -> Bloc 64 vs Bloc 384: p=0.0056
#   -> Bloc 64 vs Bloc 416: p=0.0088
#   -> Bloc 64 vs Bloc 448: p=0.0001
#   -> Bloc 64 vs Bloc 480: p=0.0001
#
# 🔁 Itération 19 : mesure de tous les blocs
#  Bloc 32   → 0.00403 s (n=21)
#  Bloc 64   → 0.00565 s (n=21)
#  Bloc 96   → 0.00412 s (n=21)
#  Bloc 128  → 0.00526 s (n=21)
#  Bloc 160  → 0.00589 s (n=21)
#  Bloc 192  → 0.00624 s (n=21)
#  Bloc 224  → 0.06656 s (n=21)
#  Bloc 256  → 0.00884 s (n=21)
#  Bloc 288  → 0.00769 s (n=21)
#  Bloc 320  → 0.00870 s (n=21)
#  Bloc 352  → 0.00912 s (n=21)
#  Bloc 384  → 0.05850 s (n=21)
#  Bloc 416  → 0.01578 s (n=21)
#  Bloc 448  → 0.01144 s (n=21)
#  Bloc 480  → 0.01203 s (n=21)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00653)
#   -> Bloc 64 vs Bloc 32: p=0.4911
#   -> Bloc 64 vs Bloc 96: p=0.4368
#   -> Bloc 64 vs Bloc 128: p=0.0093
#   -> Bloc 64 vs Bloc 160: p=0.0266
#   -> Bloc 64 vs Bloc 192: p=0.0096
#   -> Bloc 64 vs Bloc 224: p=0.0320
#   -> Bloc 64 vs Bloc 256: p=0.0435
#   -> Bloc 64 vs Bloc 288: p=0.0216
#   -> Bloc 64 vs Bloc 320: p=0.0040
#   -> Bloc 64 vs Bloc 352: p=0.0017
#   -> Bloc 64 vs Bloc 384: p=0.0026
#   -> Bloc 64 vs Bloc 416: p=0.0063
#   -> Bloc 64 vs Bloc 448: p=0.0001
#   -> Bloc 64 vs Bloc 480: p=0.0001
#
# 🔁 Itération 20 : mesure de tous les blocs
#  Bloc 32   → 0.00360 s (n=22)
#  Bloc 64   → 0.00319 s (n=22)
#  Bloc 96   → 0.05411 s (n=22)
#  Bloc 128  → 0.01763 s (n=22)
#  Bloc 160  → 0.00566 s (n=22)
#  Bloc 192  → 0.00613 s (n=22)
#  Bloc 224  → 0.00693 s (n=22)
#  Bloc 256  → 0.07059 s (n=22)
#  Bloc 288  → 0.01031 s (n=22)
#  Bloc 320  → 0.01025 s (n=22)
#  Bloc 352  → 0.00966 s (n=22)
#  Bloc 384  → 0.01013 s (n=22)
#  Bloc 416  → 0.01110 s (n=22)
#  Bloc 448  → 0.04645 s (n=22)
#  Bloc 480  → 0.01177 s (n=22)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00637)
#   -> Bloc 64 vs Bloc 32: p=0.4886
#   -> Bloc 64 vs Bloc 96: p=0.2380
#   -> Bloc 64 vs Bloc 128: p=0.0071
#   -> Bloc 64 vs Bloc 160: p=0.0257
#   -> Bloc 64 vs Bloc 192: p=0.0093
#   -> Bloc 64 vs Bloc 224: p=0.0300
#   -> Bloc 64 vs Bloc 256: p=0.0207
#   -> Bloc 64 vs Bloc 288: p=0.0188
#   -> Bloc 64 vs Bloc 320: p=0.0035
#   -> Bloc 64 vs Bloc 352: p=0.0015
#   -> Bloc 64 vs Bloc 384: p=0.0022
#   -> Bloc 64 vs Bloc 416: p=0.0049
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0001
#
# 🔁 Itération 21 : mesure de tous les blocs
#  Bloc 32   → 0.00361 s (n=23)
#  Bloc 64   → 0.00322 s (n=23)
#  Bloc 96   → 0.00382 s (n=23)
#  Bloc 128  → 0.00502 s (n=23)
#  Bloc 160  → 0.06563 s (n=23)
#  Bloc 192  → 0.00943 s (n=23)
#  Bloc 224  → 0.00888 s (n=23)
#  Bloc 256  → 0.00869 s (n=23)
#  Bloc 288  → 0.00765 s (n=23)
#  Bloc 320  → 0.00848 s (n=23)
#  Bloc 352  → 0.05869 s (n=23)
#  Bloc 384  → 0.01035 s (n=23)
#  Bloc 416  → 0.01059 s (n=23)
#  Bloc 448  → 0.01106 s (n=23)
#  Bloc 480  → 0.06313 s (n=23)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00624)
#   -> Bloc 64 vs Bloc 32: p=0.4864
#   -> Bloc 64 vs Bloc 96: p=0.2361
#   -> Bloc 64 vs Bloc 128: p=0.0071
#   -> Bloc 64 vs Bloc 160: p=0.0122
#   -> Bloc 64 vs Bloc 192: p=0.0084
#   -> Bloc 64 vs Bloc 224: p=0.0269
#   -> Bloc 64 vs Bloc 256: p=0.0185
#   -> Bloc 64 vs Bloc 288: p=0.0173
#   -> Bloc 64 vs Bloc 320: p=0.0032
#   -> Bloc 64 vs Bloc 352: p=0.0006
#   -> Bloc 64 vs Bloc 384: p=0.0019
#   -> Bloc 64 vs Bloc 416: p=0.0038
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 22 : mesure de tous les blocs
#  Bloc 32   → 0.00440 s (n=24)
#  Bloc 64   → 0.00378 s (n=24)
#  Bloc 96   → 0.00366 s (n=24)
#  Bloc 128  → 0.00612 s (n=24)
#  Bloc 160  → 0.00574 s (n=24)
#  Bloc 192  → 0.00617 s (n=24)
#  Bloc 224  → 0.06409 s (n=24)
#  Bloc 256  → 0.00862 s (n=24)
#  Bloc 288  → 0.00932 s (n=24)
#  Bloc 320  → 0.00939 s (n=24)
#  Bloc 352  → 0.00904 s (n=24)
#  Bloc 384  → 0.01015 s (n=24)
#  Bloc 416  → 0.06414 s (n=24)
#  Bloc 448  → 0.01238 s (n=24)
#  Bloc 480  → 0.01339 s (n=24)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00613)
#   -> Bloc 64 vs Bloc 32: p=0.4827
#   -> Bloc 64 vs Bloc 96: p=0.2367
#   -> Bloc 64 vs Bloc 128: p=0.0069
#   -> Bloc 64 vs Bloc 160: p=0.0120
#   -> Bloc 64 vs Bloc 192: p=0.0082
#   -> Bloc 64 vs Bloc 224: p=0.0129
#   -> Bloc 64 vs Bloc 256: p=0.0167
#   -> Bloc 64 vs Bloc 288: p=0.0155
#   -> Bloc 64 vs Bloc 320: p=0.0029
#   -> Bloc 64 vs Bloc 352: p=0.0006
#   -> Bloc 64 vs Bloc 384: p=0.0016
#   -> Bloc 64 vs Bloc 416: p=0.0021
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 23 : mesure de tous les blocs
#  Bloc 32   → 0.00384 s (n=25)
#  Bloc 64   → 0.00383 s (n=25)
#  Bloc 96   → 0.04968 s (n=25)
#  Bloc 128  → 0.00867 s (n=25)
#  Bloc 160  → 0.00762 s (n=25)
#  Bloc 192  → 0.00651 s (n=25)
#  Bloc 224  → 0.00715 s (n=25)
#  Bloc 256  → 0.00810 s (n=25)
#  Bloc 288  → 0.06882 s (n=25)
#  Bloc 320  → 0.01004 s (n=25)
#  Bloc 352  → 0.01095 s (n=25)
#  Bloc 384  → 0.01036 s (n=25)
#  Bloc 416  → 0.01162 s (n=25)
#  Bloc 448  → 0.05786 s (n=25)
#  Bloc 480  → 0.01304 s (n=25)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00604)
#   -> Bloc 64 vs Bloc 32: p=0.4827
#   -> Bloc 64 vs Bloc 96: p=0.1324
#   -> Bloc 64 vs Bloc 128: p=0.0064
#   -> Bloc 64 vs Bloc 160: p=0.0112
#   -> Bloc 64 vs Bloc 192: p=0.0079
#   -> Bloc 64 vs Bloc 224: p=0.0122
#   -> Bloc 64 vs Bloc 256: p=0.0152
#   -> Bloc 64 vs Bloc 288: p=0.0075
#   -> Bloc 64 vs Bloc 320: p=0.0025
#   -> Bloc 64 vs Bloc 352: p=0.0005
#   -> Bloc 64 vs Bloc 384: p=0.0014
#   -> Bloc 64 vs Bloc 416: p=0.0016
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 24 : mesure de tous les blocs
#  Bloc 32   → 0.00359 s (n=26)
#  Bloc 64   → 0.00552 s (n=26)
#  Bloc 96   → 0.00376 s (n=26)
#  Bloc 128  → 0.06237 s (n=26)
#  Bloc 160  → 0.00722 s (n=26)
#  Bloc 192  → 0.00765 s (n=26)
#  Bloc 224  → 0.00838 s (n=26)
#  Bloc 256  → 0.00940 s (n=26)
#  Bloc 288  → 0.00920 s (n=26)
#  Bloc 320  → 0.06240 s (n=26)
#  Bloc 352  → 0.01310 s (n=26)
#  Bloc 384  → 0.01147 s (n=26)
#  Bloc 416  → 0.01197 s (n=26)
#  Bloc 448  → 0.01231 s (n=26)
#  Bloc 480  → 0.05832 s (n=26)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00602)
#   -> Bloc 64 vs Bloc 32: p=0.4940
#   -> Bloc 64 vs Bloc 96: p=0.1365
#   -> Bloc 64 vs Bloc 128: p=0.0031
#   -> Bloc 64 vs Bloc 160: p=0.0110
#   -> Bloc 64 vs Bloc 192: p=0.0076
#   -> Bloc 64 vs Bloc 224: p=0.0116
#   -> Bloc 64 vs Bloc 256: p=0.0139
#   -> Bloc 64 vs Bloc 288: p=0.0070
#   -> Bloc 64 vs Bloc 320: p=0.0012
#   -> Bloc 64 vs Bloc 352: p=0.0004
#   -> Bloc 64 vs Bloc 384: p=0.0012
#   -> Bloc 64 vs Bloc 416: p=0.0013
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 25 : mesure de tous les blocs
#  Bloc 32   → 0.00498 s (n=27)
#  Bloc 64   → 0.00430 s (n=27)
#  Bloc 96   → 0.00470 s (n=27)
#  Bloc 128  → 0.00605 s (n=27)
#  Bloc 160  → 0.06686 s (n=27)
#  Bloc 192  → 0.00935 s (n=27)
#  Bloc 224  → 0.00839 s (n=27)
#  Bloc 256  → 0.00932 s (n=27)
#  Bloc 288  → 0.00936 s (n=27)
#  Bloc 320  → 0.06136 s (n=27)
#  Bloc 352  → 0.01242 s (n=27)
#  Bloc 384  → 0.01158 s (n=27)
#  Bloc 416  → 0.01186 s (n=27)
#  Bloc 448  → 0.01236 s (n=27)
#  Bloc 480  → 0.06114 s (n=27)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00596)
#   -> Bloc 64 vs Bloc 32: p=0.4900
#   -> Bloc 64 vs Bloc 96: p=0.1357
#   -> Bloc 64 vs Bloc 128: p=0.0031
#   -> Bloc 64 vs Bloc 160: p=0.0053
#   -> Bloc 64 vs Bloc 192: p=0.0069
#   -> Bloc 64 vs Bloc 224: p=0.0107
#   -> Bloc 64 vs Bloc 256: p=0.0124
#   -> Bloc 64 vs Bloc 288: p=0.0063
#   -> Bloc 64 vs Bloc 320: p=0.0005
#   -> Bloc 64 vs Bloc 352: p=0.0004
#   -> Bloc 64 vs Bloc 384: p=0.0010
#   -> Bloc 64 vs Bloc 416: p=0.0011
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 26 : mesure de tous les blocs
#  Bloc 32   → 0.00595 s (n=28)
#  Bloc 64   → 0.00462 s (n=28)
#  Bloc 96   → 0.00482 s (n=28)
#  Bloc 128  → 0.00613 s (n=28)
#  Bloc 160  → 0.06792 s (n=28)
#  Bloc 192  → 0.00893 s (n=28)
#  Bloc 224  → 0.00830 s (n=28)
#  Bloc 256  → 0.00925 s (n=28)
#  Bloc 288  → 0.00930 s (n=28)
#  Bloc 320  → 0.06014 s (n=28)
#  Bloc 352  → 0.01368 s (n=28)
#  Bloc 384  → 0.01260 s (n=28)
#  Bloc 416  → 0.01231 s (n=28)
#  Bloc 448  → 0.01231 s (n=28)
#  Bloc 480  → 0.05446 s (n=28)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00591)
#   -> Bloc 64 vs Bloc 32: p=0.4823
#   -> Bloc 64 vs Bloc 96: p=0.1354
#   -> Bloc 64 vs Bloc 128: p=0.0031
#   -> Bloc 64 vs Bloc 160: p=0.0026
#   -> Bloc 64 vs Bloc 192: p=0.0064
#   -> Bloc 64 vs Bloc 224: p=0.0100
#   -> Bloc 64 vs Bloc 256: p=0.0112
#   -> Bloc 64 vs Bloc 288: p=0.0057
#   -> Bloc 64 vs Bloc 320: p=0.0002
#   -> Bloc 64 vs Bloc 352: p=0.0003
#   -> Bloc 64 vs Bloc 384: p=0.0008
#   -> Bloc 64 vs Bloc 416: p=0.0008
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 27 : mesure de tous les blocs
#  Bloc 32   → 0.00496 s (n=29)
#  Bloc 64   → 0.00429 s (n=29)
#  Bloc 96   → 0.00475 s (n=29)
#  Bloc 128  → 0.00605 s (n=29)
#  Bloc 160  → 0.00663 s (n=29)
#  Bloc 192  → 0.06827 s (n=29)
#  Bloc 224  → 0.00935 s (n=29)
#  Bloc 256  → 0.00914 s (n=29)
#  Bloc 288  → 0.00960 s (n=29)
#  Bloc 320  → 0.00982 s (n=29)
#  Bloc 352  → 0.06106 s (n=29)
#  Bloc 384  → 0.01173 s (n=29)
#  Bloc 416  → 0.01188 s (n=29)
#  Bloc 448  → 0.01227 s (n=29)
#  Bloc 480  → 0.06728 s (n=29)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00586)
#   -> Bloc 64 vs Bloc 32: p=0.4784
#   -> Bloc 64 vs Bloc 96: p=0.1345
#   -> Bloc 64 vs Bloc 128: p=0.0031
#   -> Bloc 64 vs Bloc 160: p=0.0025
#   -> Bloc 64 vs Bloc 192: p=0.0031
#   -> Bloc 64 vs Bloc 224: p=0.0090
#   -> Bloc 64 vs Bloc 256: p=0.0100
#   -> Bloc 64 vs Bloc 288: p=0.0052
#   -> Bloc 64 vs Bloc 320: p=0.0002
#   -> Bloc 64 vs Bloc 352: p=0.0001
#   -> Bloc 64 vs Bloc 384: p=0.0006
#   -> Bloc 64 vs Bloc 416: p=0.0006
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 28 : mesure de tous les blocs
#  Bloc 32   → 0.00506 s (n=30)
#  Bloc 64   → 0.00430 s (n=30)
#  Bloc 96   → 0.00474 s (n=30)
#  Bloc 128  → 0.00610 s (n=30)
#  Bloc 160  → 0.07079 s (n=30)
#  Bloc 192  → 0.00934 s (n=30)
#  Bloc 224  → 0.00856 s (n=30)
#  Bloc 256  → 0.00861 s (n=30)
#  Bloc 288  → 0.00821 s (n=30)
#  Bloc 320  → 0.05329 s (n=30)
#  Bloc 352  → 0.01514 s (n=30)
#  Bloc 384  → 0.01045 s (n=30)
#  Bloc 416  → 0.01090 s (n=30)
#  Bloc 448  → 0.01137 s (n=30)
#  Bloc 480  → 0.06340 s (n=30)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00580)
#   -> Bloc 64 vs Bloc 32: p=0.4739
#   -> Bloc 64 vs Bloc 96: p=0.1336
#   -> Bloc 64 vs Bloc 128: p=0.0030
#   -> Bloc 64 vs Bloc 160: p=0.0012
#   -> Bloc 64 vs Bloc 192: p=0.0029
#   -> Bloc 64 vs Bloc 224: p=0.0082
#   -> Bloc 64 vs Bloc 256: p=0.0090
#   -> Bloc 64 vs Bloc 288: p=0.0048
#   -> Bloc 64 vs Bloc 320: p=0.0001
#   -> Bloc 64 vs Bloc 352: p=0.0001
#   -> Bloc 64 vs Bloc 384: p=0.0005
#   -> Bloc 64 vs Bloc 416: p=0.0005
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 29 : mesure de tous les blocs
#  Bloc 32   → 0.00513 s (n=31)
#  Bloc 64   → 0.00338 s (n=31)
#  Bloc 96   → 0.00385 s (n=31)
#  Bloc 128  → 0.00487 s (n=31)
#  Bloc 160  → 0.00552 s (n=31)
#  Bloc 192  → 0.06220 s (n=31)
#  Bloc 224  → 0.01490 s (n=31)
#  Bloc 256  → 0.01005 s (n=31)
#  Bloc 288  → 0.00818 s (n=31)
#  Bloc 320  → 0.00880 s (n=31)
#  Bloc 352  → 0.05799 s (n=31)
#  Bloc 384  → 0.01562 s (n=31)
#  Bloc 416  → 0.01190 s (n=31)
#  Bloc 448  → 0.01152 s (n=31)
#  Bloc 480  → 0.06052 s (n=31)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00573)
#   -> Bloc 64 vs Bloc 32: p=0.4637
#   -> Bloc 64 vs Bloc 96: p=0.1328
#   -> Bloc 64 vs Bloc 128: p=0.0030
#   -> Bloc 64 vs Bloc 160: p=0.0012
#   -> Bloc 64 vs Bloc 192: p=0.0014
#   -> Bloc 64 vs Bloc 224: p=0.0064
#   -> Bloc 64 vs Bloc 256: p=0.0077
#   -> Bloc 64 vs Bloc 288: p=0.0044
#   -> Bloc 64 vs Bloc 320: p=0.0001
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0004
#   -> Bloc 64 vs Bloc 416: p=0.0004
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 30 : mesure de tous les blocs
#  Bloc 32   → 0.00640 s (n=32)
#  Bloc 64   → 0.00350 s (n=32)
#  Bloc 96   → 0.00378 s (n=32)
#  Bloc 128  → 0.00490 s (n=32)
#  Bloc 160  → 0.00497 s (n=32)
#  Bloc 192  → 0.00626 s (n=32)
#  Bloc 224  → 0.06660 s (n=32)
#  Bloc 256  → 0.01012 s (n=32)
#  Bloc 288  → 0.00805 s (n=32)
#  Bloc 320  → 0.00907 s (n=32)
#  Bloc 352  → 0.00951 s (n=32)
#  Bloc 384  → 0.01011 s (n=32)
#  Bloc 416  → 0.05284 s (n=32)
#  Bloc 448  → 0.01411 s (n=32)
#  Bloc 480  → 0.01538 s (n=32)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00566)
#   -> Bloc 64 vs Bloc 32: p=0.4469
#   -> Bloc 64 vs Bloc 96: p=0.1324
#   -> Bloc 64 vs Bloc 128: p=0.0030
#   -> Bloc 64 vs Bloc 160: p=0.0012
#   -> Bloc 64 vs Bloc 192: p=0.0013
#   -> Bloc 64 vs Bloc 224: p=0.0032
#   -> Bloc 64 vs Bloc 256: p=0.0065
#   -> Bloc 64 vs Bloc 288: p=0.0040
#   -> Bloc 64 vs Bloc 320: p=0.0001
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0003
#   -> Bloc 64 vs Bloc 416: p=0.0002
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 31 : mesure de tous les blocs
#  Bloc 32   → 0.00664 s (n=33)
#  Bloc 64   → 0.05440 s (n=33)
#  Bloc 96   → 0.00738 s (n=33)
#  Bloc 128  → 0.00744 s (n=33)
#  Bloc 160  → 0.00520 s (n=33)
#  Bloc 192  → 0.00585 s (n=33)
#  Bloc 224  → 0.00767 s (n=33)
#  Bloc 256  → 0.06663 s (n=33)
#  Bloc 288  → 0.01106 s (n=33)
#  Bloc 320  → 0.08824 s (n=33)
#  Bloc 352  → 0.01094 s (n=33)
#  Bloc 384  → 0.01171 s (n=33)
#  Bloc 416  → 0.01278 s (n=33)
#  Bloc 448  → 0.01285 s (n=33)
#  Bloc 480  → 0.06314 s (n=33)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00596)
#   -> Bloc 32 vs Bloc 64: p=0.3228
#   -> Bloc 32 vs Bloc 96: p=0.1459
#   -> Bloc 32 vs Bloc 128: p=0.0033
#   -> Bloc 32 vs Bloc 160: p=0.0014
#   -> Bloc 32 vs Bloc 192: p=0.0015
#   -> Bloc 32 vs Bloc 224: p=0.0035
#   -> Bloc 32 vs Bloc 256: p=0.0040
#   -> Bloc 32 vs Bloc 288: p=0.0040
#   -> Bloc 32 vs Bloc 320: p=0.0001
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0003
#   -> Bloc 32 vs Bloc 416: p=0.0002
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 32 : mesure de tous les blocs
#  Bloc 32   → 0.00652 s (n=34)
#  Bloc 64   → 0.00508 s (n=34)
#  Bloc 96   → 0.00532 s (n=34)
#  Bloc 128  → 0.06270 s (n=34)
#  Bloc 160  → 0.01049 s (n=34)
#  Bloc 192  → 0.00724 s (n=34)
#  Bloc 224  → 0.00802 s (n=34)
#  Bloc 256  → 0.00874 s (n=34)
#  Bloc 288  → 0.00900 s (n=34)
#  Bloc 320  → 0.05914 s (n=34)
#  Bloc 352  → 0.01429 s (n=34)
#  Bloc 384  → 0.01178 s (n=34)
#  Bloc 416  → 0.01226 s (n=34)
#  Bloc 448  → 0.01267 s (n=34)
#  Bloc 480  → 0.06320 s (n=34)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00598)
#   -> Bloc 32 vs Bloc 64: p=0.3289
#   -> Bloc 32 vs Bloc 96: p=0.1488
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0013
#   -> Bloc 32 vs Bloc 192: p=0.0015
#   -> Bloc 32 vs Bloc 224: p=0.0034
#   -> Bloc 32 vs Bloc 256: p=0.0038
#   -> Bloc 32 vs Bloc 288: p=0.0038
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0002
#   -> Bloc 32 vs Bloc 416: p=0.0001
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 33 : mesure de tous les blocs
#  Bloc 32   → 0.00417 s (n=35)
#  Bloc 64   → 0.00373 s (n=35)
#  Bloc 96   → 0.00421 s (n=35)
#  Bloc 128  → 0.00554 s (n=35)
#  Bloc 160  → 0.06551 s (n=35)
#  Bloc 192  → 0.01121 s (n=35)
#  Bloc 224  → 0.00807 s (n=35)
#  Bloc 256  → 0.00954 s (n=35)
#  Bloc 288  → 0.00934 s (n=35)
#  Bloc 320  → 0.06135 s (n=35)
#  Bloc 352  → 0.01335 s (n=35)
#  Bloc 384  → 0.01147 s (n=35)
#  Bloc 416  → 0.01208 s (n=35)
#  Bloc 448  → 0.06293 s (n=35)
#  Bloc 480  → 0.01559 s (n=35)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00593)
#   -> Bloc 32 vs Bloc 64: p=0.3309
#   -> Bloc 32 vs Bloc 96: p=0.1489
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0006
#   -> Bloc 32 vs Bloc 192: p=0.0013
#   -> Bloc 32 vs Bloc 224: p=0.0031
#   -> Bloc 32 vs Bloc 256: p=0.0033
#   -> Bloc 32 vs Bloc 288: p=0.0034
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0002
#   -> Bloc 32 vs Bloc 416: p=0.0001
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 34 : mesure de tous les blocs
#  Bloc 32   → 0.00513 s (n=36)
#  Bloc 64   → 0.00429 s (n=36)
#  Bloc 96   → 0.00474 s (n=36)
#  Bloc 128  → 0.00549 s (n=36)
#  Bloc 160  → 0.06332 s (n=36)
#  Bloc 192  → 0.00805 s (n=36)
#  Bloc 224  → 0.00762 s (n=36)
#  Bloc 256  → 0.00885 s (n=36)
#  Bloc 288  → 0.00833 s (n=36)
#  Bloc 320  → 0.06110 s (n=36)
#  Bloc 352  → 0.01153 s (n=36)
#  Bloc 384  → 0.01195 s (n=36)
#  Bloc 416  → 0.01230 s (n=36)
#  Bloc 448  → 0.01229 s (n=36)
#  Bloc 480  → 0.06330 s (n=36)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00590)
#   -> Bloc 32 vs Bloc 64: p=0.3345
#   -> Bloc 32 vs Bloc 96: p=0.1499
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0003
#   -> Bloc 32 vs Bloc 192: p=0.0013
#   -> Bloc 32 vs Bloc 224: p=0.0030
#   -> Bloc 32 vs Bloc 256: p=0.0030
#   -> Bloc 32 vs Bloc 288: p=0.0032
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0002
#   -> Bloc 32 vs Bloc 416: p=0.0001
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 35 : mesure de tous les blocs
#  Bloc 32   → 0.00499 s (n=37)
#  Bloc 64   → 0.00430 s (n=37)
#  Bloc 96   → 0.00470 s (n=37)
#  Bloc 128  → 0.00547 s (n=37)
#  Bloc 160  → 0.06372 s (n=37)
#  Bloc 192  → 0.00891 s (n=37)
#  Bloc 224  → 0.00786 s (n=37)
#  Bloc 256  → 0.00921 s (n=37)
#  Bloc 288  → 0.00832 s (n=37)
#  Bloc 320  → 0.00941 s (n=37)
#  Bloc 352  → 0.06506 s (n=37)
#  Bloc 384  → 0.01178 s (n=37)
#  Bloc 416  → 0.01212 s (n=37)
#  Bloc 448  → 0.01223 s (n=37)
#  Bloc 480  → 0.06703 s (n=37)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00588)
#   -> Bloc 32 vs Bloc 64: p=0.3375
#   -> Bloc 32 vs Bloc 96: p=0.1506
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0002
#   -> Bloc 32 vs Bloc 192: p=0.0012
#   -> Bloc 32 vs Bloc 224: p=0.0028
#   -> Bloc 32 vs Bloc 256: p=0.0027
#   -> Bloc 32 vs Bloc 288: p=0.0030
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0001
#   -> Bloc 32 vs Bloc 416: p=0.0001
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 36 : mesure de tous les blocs
#  Bloc 32   → 0.00506 s (n=38)
#  Bloc 64   → 0.00432 s (n=38)
#  Bloc 96   → 0.00565 s (n=38)
#  Bloc 128  → 0.00589 s (n=38)
#  Bloc 160  → 0.07918 s (n=38)
#  Bloc 192  → 0.00702 s (n=38)
#  Bloc 224  → 0.00717 s (n=38)
#  Bloc 256  → 0.00752 s (n=38)
#  Bloc 288  → 0.00777 s (n=38)
#  Bloc 320  → 0.05518 s (n=38)
#  Bloc 352  → 0.00950 s (n=38)
#  Bloc 384  → 0.01019 s (n=38)
#  Bloc 416  → 0.01112 s (n=38)
#  Bloc 448  → 0.01183 s (n=38)
#  Bloc 480  → 0.06308 s (n=38)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00586)
#   -> Bloc 32 vs Bloc 64: p=0.3408
#   -> Bloc 32 vs Bloc 96: p=0.1492
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0001
#   -> Bloc 32 vs Bloc 192: p=0.0011
#   -> Bloc 32 vs Bloc 224: p=0.0027
#   -> Bloc 32 vs Bloc 256: p=0.0026
#   -> Bloc 32 vs Bloc 288: p=0.0028
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0001
#   -> Bloc 32 vs Bloc 416: p=0.0000
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 37 : mesure de tous les blocs
#  Bloc 32   → 0.00369 s (n=39)
#  Bloc 64   → 0.00326 s (n=39)
#  Bloc 96   → 0.00372 s (n=39)
#  Bloc 128  → 0.00473 s (n=39)
#  Bloc 160  → 0.00501 s (n=39)
#  Bloc 192  → 0.00563 s (n=39)
#  Bloc 224  → 0.06814 s (n=39)
#  Bloc 256  → 0.00818 s (n=39)
#  Bloc 288  → 0.00797 s (n=39)
#  Bloc 320  → 0.00900 s (n=39)
#  Bloc 352  → 0.00961 s (n=39)
#  Bloc 384  → 0.06272 s (n=39)
#  Bloc 416  → 0.01420 s (n=39)
#  Bloc 448  → 0.01306 s (n=39)
#  Bloc 480  → 0.01370 s (n=39)
#  Meilleur moyen actuel : Bloc 32 (mean=0.00580)
#   -> Bloc 32 vs Bloc 64: p=0.3428
#   -> Bloc 32 vs Bloc 96: p=0.1493
#   -> Bloc 32 vs Bloc 128: p=0.0017
#   -> Bloc 32 vs Bloc 160: p=0.0001
#   -> Bloc 32 vs Bloc 192: p=0.0011
#   -> Bloc 32 vs Bloc 224: p=0.0014
#   -> Bloc 32 vs Bloc 256: p=0.0023
#   -> Bloc 32 vs Bloc 288: p=0.0026
#   -> Bloc 32 vs Bloc 320: p=0.0000
#   -> Bloc 32 vs Bloc 352: p=0.0000
#   -> Bloc 32 vs Bloc 384: p=0.0001
#   -> Bloc 32 vs Bloc 416: p=0.0000
#   -> Bloc 32 vs Bloc 448: p=0.0000
#   -> Bloc 32 vs Bloc 480: p=0.0000
#
# 🔁 Itération 38 : mesure de tous les blocs
#  Bloc 32   → 0.04990 s (n=40)
#  Bloc 64   → 0.00569 s (n=40)
#  Bloc 96   → 0.00498 s (n=40)
#  Bloc 128  → 0.00563 s (n=40)
#  Bloc 160  → 0.00591 s (n=40)
#  Bloc 192  → 0.00673 s (n=40)
#  Bloc 224  → 0.00766 s (n=40)
#  Bloc 256  → 0.07027 s (n=40)
#  Bloc 288  → 0.00944 s (n=40)
#  Bloc 320  → 0.00989 s (n=40)
#  Bloc 352  → 0.01051 s (n=40)
#  Bloc 384  → 0.01167 s (n=40)
#  Bloc 416  → 0.05243 s (n=40)
#  Bloc 448  → 0.01421 s (n=40)
#  Bloc 480  → 0.01340 s (n=40)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00665)
#   -> Bloc 64 vs Bloc 32: p=0.4574
#   -> Bloc 64 vs Bloc 96: p=0.2762
#   -> Bloc 64 vs Bloc 128: p=0.0045
#   -> Bloc 64 vs Bloc 160: p=0.0002
#   -> Bloc 64 vs Bloc 192: p=0.0032
#   -> Bloc 64 vs Bloc 224: p=0.0040
#   -> Bloc 64 vs Bloc 256: p=0.0046
#   -> Bloc 64 vs Bloc 288: p=0.0080
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0004
#   -> Bloc 64 vs Bloc 416: p=0.0002
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 39 : mesure de tous les blocs
#  Bloc 32   → 0.00498 s (n=41)
#  Bloc 64   → 0.00430 s (n=41)
#  Bloc 96   → 0.05336 s (n=41)
#  Bloc 128  → 0.00648 s (n=41)
#  Bloc 160  → 0.00804 s (n=41)
#  Bloc 192  → 0.00694 s (n=41)
#  Bloc 224  → 0.00772 s (n=41)
#  Bloc 256  → 0.00895 s (n=41)
#  Bloc 288  → 0.06477 s (n=41)
#  Bloc 320  → 0.01071 s (n=41)
#  Bloc 352  → 0.01051 s (n=41)
#  Bloc 384  → 0.01142 s (n=41)
#  Bloc 416  → 0.01217 s (n=41)
#  Bloc 448  → 0.05462 s (n=41)
#  Bloc 480  → 0.01454 s (n=41)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00659)
#   -> Bloc 64 vs Bloc 32: p=0.4545
#   -> Bloc 64 vs Bloc 96: p=0.1682
#   -> Bloc 64 vs Bloc 128: p=0.0044
#   -> Bloc 64 vs Bloc 160: p=0.0002
#   -> Bloc 64 vs Bloc 192: p=0.0031
#   -> Bloc 64 vs Bloc 224: p=0.0038
#   -> Bloc 64 vs Bloc 256: p=0.0043
#   -> Bloc 64 vs Bloc 288: p=0.0040
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0003
#   -> Bloc 64 vs Bloc 416: p=0.0002
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 40 : mesure de tous les blocs
#  Bloc 32   → 0.00537 s (n=42)
#  Bloc 64   → 0.00428 s (n=42)
#  Bloc 96   → 0.00474 s (n=42)
#  Bloc 128  → 0.00552 s (n=42)
#  Bloc 160  → 0.06714 s (n=42)
#  Bloc 192  → 0.00856 s (n=42)
#  Bloc 224  → 0.00777 s (n=42)
#  Bloc 256  → 0.00896 s (n=42)
#  Bloc 288  → 0.00905 s (n=42)
#  Bloc 320  → 0.05886 s (n=42)
#  Bloc 352  → 0.01072 s (n=42)
#  Bloc 384  → 0.01191 s (n=42)
#  Bloc 416  → 0.01241 s (n=42)
#  Bloc 448  → 0.06007 s (n=42)
#  Bloc 480  → 0.01643 s (n=42)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00654)
#   -> Bloc 64 vs Bloc 32: p=0.4500
#   -> Bloc 64 vs Bloc 96: p=0.1674
#   -> Bloc 64 vs Bloc 128: p=0.0044
#   -> Bloc 64 vs Bloc 160: p=0.0001
#   -> Bloc 64 vs Bloc 192: p=0.0029
#   -> Bloc 64 vs Bloc 224: p=0.0036
#   -> Bloc 64 vs Bloc 256: p=0.0039
#   -> Bloc 64 vs Bloc 288: p=0.0037
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0002
#   -> Bloc 64 vs Bloc 416: p=0.0001
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 41 : mesure de tous les blocs
#  Bloc 32   → 0.00501 s (n=43)
#  Bloc 64   → 0.00429 s (n=43)
#  Bloc 96   → 0.00476 s (n=43)
#  Bloc 128  → 0.00556 s (n=43)
#  Bloc 160  → 0.06485 s (n=43)
#  Bloc 192  → 0.00940 s (n=43)
#  Bloc 224  → 0.00796 s (n=43)
#  Bloc 256  → 0.00960 s (n=43)
#  Bloc 288  → 0.00949 s (n=43)
#  Bloc 320  → 0.05871 s (n=43)
#  Bloc 352  → 0.01610 s (n=43)
#  Bloc 384  → 0.01163 s (n=43)
#  Bloc 416  → 0.01206 s (n=43)
#  Bloc 448  → 0.06254 s (n=43)
#  Bloc 480  → 0.01536 s (n=43)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00649)
#   -> Bloc 64 vs Bloc 32: p=0.4470
#   -> Bloc 64 vs Bloc 96: p=0.1665
#   -> Bloc 64 vs Bloc 128: p=0.0043
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0026
#   -> Bloc 64 vs Bloc 224: p=0.0034
#   -> Bloc 64 vs Bloc 256: p=0.0035
#   -> Bloc 64 vs Bloc 288: p=0.0033
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0002
#   -> Bloc 64 vs Bloc 416: p=0.0001
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 42 : mesure de tous les blocs
#  Bloc 32   → 0.00503 s (n=44)
#  Bloc 64   → 0.00429 s (n=44)
#  Bloc 96   → 0.00591 s (n=44)
#  Bloc 128  → 0.06253 s (n=44)
#  Bloc 160  → 0.00676 s (n=44)
#  Bloc 192  → 0.00712 s (n=44)
#  Bloc 224  → 0.00802 s (n=44)
#  Bloc 256  → 0.00897 s (n=44)
#  Bloc 288  → 0.00916 s (n=44)
#  Bloc 320  → 0.06204 s (n=44)
#  Bloc 352  → 0.01078 s (n=44)
#  Bloc 384  → 0.01150 s (n=44)
#  Bloc 416  → 0.01209 s (n=44)
#  Bloc 448  → 0.06132 s (n=44)
#  Bloc 480  → 0.01482 s (n=44)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00644)
#   -> Bloc 64 vs Bloc 32: p=0.4440
#   -> Bloc 64 vs Bloc 96: p=0.1632
#   -> Bloc 64 vs Bloc 128: p=0.0022
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0025
#   -> Bloc 64 vs Bloc 224: p=0.0032
#   -> Bloc 64 vs Bloc 256: p=0.0032
#   -> Bloc 64 vs Bloc 288: p=0.0030
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0002
#   -> Bloc 64 vs Bloc 416: p=0.0001
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 43 : mesure de tous les blocs
#  Bloc 32   → 0.00506 s (n=45)
#  Bloc 64   → 0.00430 s (n=45)
#  Bloc 96   → 0.00473 s (n=45)
#  Bloc 128  → 0.00557 s (n=45)
#  Bloc 160  → 0.06332 s (n=45)
#  Bloc 192  → 0.00803 s (n=45)
#  Bloc 224  → 0.00780 s (n=45)
#  Bloc 256  → 0.00891 s (n=45)
#  Bloc 288  → 0.00904 s (n=45)
#  Bloc 320  → 0.00983 s (n=45)
#  Bloc 352  → 0.05978 s (n=45)
#  Bloc 384  → 0.01421 s (n=45)
#  Bloc 416  → 0.01222 s (n=45)
#  Bloc 448  → 0.01225 s (n=45)
#  Bloc 480  → 0.06331 s (n=45)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00639)
#   -> Bloc 64 vs Bloc 32: p=0.4408
#   -> Bloc 64 vs Bloc 96: p=0.1624
#   -> Bloc 64 vs Bloc 128: p=0.0022
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0024
#   -> Bloc 64 vs Bloc 224: p=0.0030
#   -> Bloc 64 vs Bloc 256: p=0.0029
#   -> Bloc 64 vs Bloc 288: p=0.0028
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0001
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 44 : mesure de tous les blocs
#  Bloc 32   → 0.00504 s (n=46)
#  Bloc 64   → 0.00433 s (n=46)
#  Bloc 96   → 0.00473 s (n=46)
#  Bloc 128  → 0.00552 s (n=46)
#  Bloc 160  → 0.00611 s (n=46)
#  Bloc 192  → 0.06616 s (n=46)
#  Bloc 224  → 0.01210 s (n=46)
#  Bloc 256  → 0.00916 s (n=46)
#  Bloc 288  → 0.00913 s (n=46)
#  Bloc 320  → 0.00983 s (n=46)
#  Bloc 352  → 0.06039 s (n=46)
#  Bloc 384  → 0.01328 s (n=46)
#  Bloc 416  → 0.01189 s (n=46)
#  Bloc 448  → 0.01222 s (n=46)
#  Bloc 480  → 0.06884 s (n=46)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00634)
#   -> Bloc 64 vs Bloc 32: p=0.4379
#   -> Bloc 64 vs Bloc 96: p=0.1617
#   -> Bloc 64 vs Bloc 128: p=0.0022
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0012
#   -> Bloc 64 vs Bloc 224: p=0.0026
#   -> Bloc 64 vs Bloc 256: p=0.0027
#   -> Bloc 64 vs Bloc 288: p=0.0025
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 45 : mesure de tous les blocs
#  Bloc 32   → 0.00581 s (n=47)
#  Bloc 64   → 0.00438 s (n=47)
#  Bloc 96   → 0.00477 s (n=47)
#  Bloc 128  → 0.00559 s (n=47)
#  Bloc 160  → 0.06470 s (n=47)
#  Bloc 192  → 0.01235 s (n=47)
#  Bloc 224  → 0.00786 s (n=47)
#  Bloc 256  → 0.00882 s (n=47)
#  Bloc 288  → 0.00899 s (n=47)
#  Bloc 320  → 0.05853 s (n=47)
#  Bloc 352  → 0.01145 s (n=47)
#  Bloc 384  → 0.01223 s (n=47)
#  Bloc 416  → 0.01203 s (n=47)
#  Bloc 448  → 0.01226 s (n=47)
#  Bloc 480  → 0.06354 s (n=47)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00630)
#   -> Bloc 64 vs Bloc 32: p=0.4320
#   -> Bloc 64 vs Bloc 96: p=0.1610
#   -> Bloc 64 vs Bloc 128: p=0.0022
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0010
#   -> Bloc 64 vs Bloc 224: p=0.0024
#   -> Bloc 64 vs Bloc 256: p=0.0024
#   -> Bloc 64 vs Bloc 288: p=0.0023
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 46 : mesure de tous les blocs
#  Bloc 32   → 0.00498 s (n=48)
#  Bloc 64   → 0.00434 s (n=48)
#  Bloc 96   → 0.00473 s (n=48)
#  Bloc 128  → 0.00556 s (n=48)
#  Bloc 160  → 0.00611 s (n=48)
#  Bloc 192  → 0.06818 s (n=48)
#  Bloc 224  → 0.00851 s (n=48)
#  Bloc 256  → 0.00949 s (n=48)
#  Bloc 288  → 0.00916 s (n=48)
#  Bloc 320  → 0.00980 s (n=48)
#  Bloc 352  → 0.05770 s (n=48)
#  Bloc 384  → 0.01156 s (n=48)
#  Bloc 416  → 0.01211 s (n=48)
#  Bloc 448  → 0.01230 s (n=48)
#  Bloc 480  → 0.06778 s (n=48)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00626)
#   -> Bloc 64 vs Bloc 32: p=0.4293
#   -> Bloc 64 vs Bloc 96: p=0.1603
#   -> Bloc 64 vs Bloc 128: p=0.0021
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0005
#   -> Bloc 64 vs Bloc 224: p=0.0022
#   -> Bloc 64 vs Bloc 256: p=0.0022
#   -> Bloc 64 vs Bloc 288: p=0.0021
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0001
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 47 : mesure de tous les blocs
#  Bloc 32   → 0.00503 s (n=49)
#  Bloc 64   → 0.00562 s (n=49)
#  Bloc 96   → 0.00716 s (n=49)
# ...
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 86 : mesure de tous les blocs
#  Bloc 32   → 0.00374 s (n=88)
#  Bloc 64   → 0.00327 s (n=88)
#  Bloc 96   → 0.00387 s (n=88)
#  Bloc 128  → 0.00514 s (n=88)
#  Bloc 160  → 0.06241 s (n=88)
#  Bloc 192  → 0.00978 s (n=88)
#  Bloc 224  → 0.00685 s (n=88)
#  Bloc 256  → 0.00879 s (n=88)
#  Bloc 288  → 0.00843 s (n=88)
#  Bloc 320  → 0.00930 s (n=88)
#  Bloc 352  → 0.06165 s (n=88)
#  Bloc 384  → 0.01276 s (n=88)
#  Bloc 416  → 0.01163 s (n=88)
#  Bloc 448  → 0.01268 s (n=88)
#  Bloc 480  → 0.06936 s (n=88)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00531)
#   -> Bloc 64 vs Bloc 32: p=0.3088
#   -> Bloc 64 vs Bloc 96: p=0.0079
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 87 : mesure de tous les blocs
#  Bloc 32   → 0.00562 s (n=89)
#  Bloc 64   → 0.00564 s (n=89)
#  Bloc 96   → 0.00528 s (n=89)
#  Bloc 128  → 0.06271 s (n=89)
#  Bloc 160  → 0.00817 s (n=89)
#  Bloc 192  → 0.00688 s (n=89)
#  Bloc 224  → 0.00669 s (n=89)
#  Bloc 256  → 0.00807 s (n=89)
#  Bloc 288  → 0.00815 s (n=89)
#  Bloc 320  → 0.00893 s (n=89)
#  Bloc 352  → 0.06249 s (n=89)
#  Bloc 384  → 0.01412 s (n=89)
#  Bloc 416  → 0.01335 s (n=89)
#  Bloc 448  → 0.01189 s (n=89)
#  Bloc 480  → 0.06674 s (n=89)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00532)
#   -> Bloc 64 vs Bloc 32: p=0.3089
#   -> Bloc 64 vs Bloc 96: p=0.0080
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 88 : mesure de tous les blocs
#  Bloc 32   → 0.00410 s (n=90)
#  Bloc 64   → 0.00325 s (n=90)
#  Bloc 96   → 0.00369 s (n=90)
#  Bloc 128  → 0.00485 s (n=90)
#  Bloc 160  → 0.00529 s (n=90)
#  Bloc 192  → 0.06799 s (n=90)
#  Bloc 224  → 0.00852 s (n=90)
#  Bloc 256  → 0.00917 s (n=90)
#  Bloc 288  → 0.00976 s (n=90)
#  Bloc 320  → 0.01129 s (n=90)
#  Bloc 352  → 0.06180 s (n=90)
#  Bloc 384  → 0.01425 s (n=90)
#  Bloc 416  → 0.01502 s (n=90)
#  Bloc 448  → 0.06045 s (n=90)
#  Bloc 480  → 0.01760 s (n=90)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00529)
#   -> Bloc 64 vs Bloc 32: p=0.3058
#   -> Bloc 64 vs Bloc 96: p=0.0079
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 89 : mesure de tous les blocs
#  Bloc 32   → 0.00747 s (n=91)
#  Bloc 64   → 0.00581 s (n=91)
#  Bloc 96   → 0.06373 s (n=91)
#  Bloc 128  → 0.00619 s (n=91)
#  Bloc 160  → 0.00732 s (n=91)
#  Bloc 192  → 0.00708 s (n=91)
#  Bloc 224  → 0.00766 s (n=91)
#  Bloc 256  → 0.00811 s (n=91)
#  Bloc 288  → 0.00825 s (n=91)
#  Bloc 320  → 0.06741 s (n=91)
#  Bloc 352  → 0.01046 s (n=91)
#  Bloc 384  → 0.01076 s (n=91)
#  Bloc 416  → 0.01108 s (n=91)
#  Bloc 448  → 0.05573 s (n=91)
#  Bloc 480  → 0.01554 s (n=91)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00530)
#   -> Bloc 64 vs Bloc 32: p=0.2998
#   -> Bloc 64 vs Bloc 96: p=0.0045
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 90 : mesure de tous les blocs
#  Bloc 32   → 0.00384 s (n=92)
#  Bloc 64   → 0.00355 s (n=92)
#  Bloc 96   → 0.00412 s (n=92)
#  Bloc 128  → 0.06164 s (n=92)
#  Bloc 160  → 0.00957 s (n=92)
#  Bloc 192  → 0.00781 s (n=92)
#  Bloc 224  → 0.00815 s (n=92)
#  Bloc 256  → 0.00837 s (n=92)
#  Bloc 288  → 0.00783 s (n=92)
#  Bloc 320  → 0.05823 s (n=92)
#  Bloc 352  → 0.01424 s (n=92)
#  Bloc 384  → 0.01294 s (n=92)
#  Bloc 416  → 0.01139 s (n=92)
#  Bloc 448  → 0.01165 s (n=92)
#  Bloc 480  → 0.06070 s (n=92)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00528)
#   -> Bloc 64 vs Bloc 32: p=0.2988
#   -> Bloc 64 vs Bloc 96: p=0.0044
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 91 : mesure de tous les blocs
#  Bloc 32   → 0.00369 s (n=93)
#  Bloc 64   → 0.00357 s (n=93)
#  Bloc 96   → 0.00382 s (n=93)
#  Bloc 128  → 0.00503 s (n=93)
#  Bloc 160  → 0.00542 s (n=93)
#  Bloc 192  → 0.06466 s (n=93)
#  Bloc 224  → 0.00991 s (n=93)
#  Bloc 256  → 0.00839 s (n=93)
#  Bloc 288  → 0.00817 s (n=93)
#  Bloc 320  → 0.00914 s (n=93)
#  Bloc 352  → 0.00962 s (n=93)
#  Bloc 384  → 0.06452 s (n=93)
#  Bloc 416  → 0.01111 s (n=93)
#  Bloc 448  → 0.01206 s (n=93)
#  Bloc 480  → 0.06209 s (n=93)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00526)
#   -> Bloc 64 vs Bloc 32: p=0.2984
#   -> Bloc 64 vs Bloc 96: p=0.0044
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 92 : mesure de tous les blocs
#  Bloc 32   → 0.00404 s (n=94)
#  Bloc 64   → 0.00338 s (n=94)
#  Bloc 96   → 0.00424 s (n=94)
#  Bloc 128  → 0.00573 s (n=94)
#  Bloc 160  → 0.00571 s (n=94)
#  Bloc 192  → 0.00694 s (n=94)
#  Bloc 224  → 0.07161 s (n=94)
#  Bloc 256  → 0.00827 s (n=94)
#  Bloc 288  → 0.00861 s (n=94)
#  Bloc 320  → 0.00908 s (n=94)
#  Bloc 352  → 0.00961 s (n=94)
#  Bloc 384  → 0.01081 s (n=94)
#  Bloc 416  → 0.04028 s (n=94)
#  Bloc 448  → 0.01461 s (n=94)
#  Bloc 480  → 0.01282 s (n=94)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00524)
#   -> Bloc 64 vs Bloc 32: p=0.2961
#   -> Bloc 64 vs Bloc 96: p=0.0044
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 93 : mesure de tous les blocs
#  Bloc 32   → 0.00374 s (n=95)
#  Bloc 64   → 0.00330 s (n=95)
#  Bloc 96   → 0.00381 s (n=95)
#  Bloc 128  → 0.06126 s (n=95)
#  Bloc 160  → 0.00640 s (n=95)
#  Bloc 192  → 0.00747 s (n=95)
#  Bloc 224  → 0.00859 s (n=95)
#  Bloc 256  → 0.00868 s (n=95)
#  Bloc 288  → 0.06528 s (n=95)
#  Bloc 320  → 0.01031 s (n=95)
#  Bloc 352  → 0.00931 s (n=95)
#  Bloc 384  → 0.01126 s (n=95)
#  Bloc 416  → 0.01128 s (n=95)
#  Bloc 448  → 0.01193 s (n=95)
#  Bloc 480  → 0.05508 s (n=95)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00522)
#   -> Bloc 64 vs Bloc 32: p=0.2946
#   -> Bloc 64 vs Bloc 96: p=0.0044
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 94 : mesure de tous les blocs
#  Bloc 32   → 0.00532 s (n=96)
#  Bloc 64   → 0.00340 s (n=96)
#  Bloc 96   → 0.00373 s (n=96)
#  Bloc 128  → 0.00579 s (n=96)
#  Bloc 160  → 0.06233 s (n=96)
#  Bloc 192  → 0.01144 s (n=96)
#  Bloc 224  → 0.00690 s (n=96)
#  Bloc 256  → 0.00806 s (n=96)
#  Bloc 288  → 0.00821 s (n=96)
#  Bloc 320  → 0.01080 s (n=96)
#  Bloc 352  → 0.06243 s (n=96)
#  Bloc 384  → 0.01126 s (n=96)
#  Bloc 416  → 0.01157 s (n=96)
#  Bloc 448  → 0.01196 s (n=96)
#  Bloc 480  → 0.06906 s (n=96)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00520)
#   -> Bloc 64 vs Bloc 32: p=0.2877
#   -> Bloc 64 vs Bloc 96: p=0.0044
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 95 : mesure de tous les blocs
#  Bloc 32   → 0.00521 s (n=97)
#  Bloc 64   → 0.00438 s (n=97)
#  Bloc 96   → 0.00472 s (n=97)
#  Bloc 128  → 0.00582 s (n=97)
#  Bloc 160  → 0.06674 s (n=97)
#  Bloc 192  → 0.00973 s (n=97)
#  Bloc 224  → 0.00741 s (n=97)
#  Bloc 256  → 0.00853 s (n=97)
#  Bloc 288  → 0.00883 s (n=97)
#  Bloc 320  → 0.00937 s (n=97)
#  Bloc 352  → 0.06176 s (n=97)
#  Bloc 384  → 0.01148 s (n=97)
#  Bloc 416  → 0.01204 s (n=97)
#  Bloc 448  → 0.06166 s (n=97)
#  Bloc 480  → 0.02041 s (n=97)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00519)
#   -> Bloc 64 vs Bloc 32: p=0.2848
#   -> Bloc 64 vs Bloc 96: p=0.0043
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 96 : mesure de tous les blocs
#  Bloc 32   → 0.00533 s (n=98)
#  Bloc 64   → 0.00431 s (n=98)
#  Bloc 96   → 0.00482 s (n=98)
#  Bloc 128  → 0.00611 s (n=98)
#  Bloc 160  → 0.00783 s (n=98)
#  Bloc 192  → 0.00801 s (n=98)
#  Bloc 224  → 0.00833 s (n=98)
#  Bloc 256  → 0.00949 s (n=98)
#  Bloc 288  → 0.00966 s (n=98)
#  Bloc 320  → 0.06586 s (n=98)
#  Bloc 352  → 0.01197 s (n=98)
#  Bloc 384  → 0.01051 s (n=98)
#  Bloc 416  → 0.01136 s (n=98)
#  Bloc 448  → 0.01246 s (n=98)
#  Bloc 480  → 0.06165 s (n=98)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00518)
#   -> Bloc 64 vs Bloc 32: p=0.2811
#   -> Bloc 64 vs Bloc 96: p=0.0043
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 97 : mesure de tous les blocs
#  Bloc 32   → 0.00516 s (n=99)
#  Bloc 64   → 0.00433 s (n=99)
#  Bloc 96   → 0.00480 s (n=99)
#  Bloc 128  → 0.06385 s (n=99)
#  Bloc 160  → 0.00808 s (n=99)
#  Bloc 192  → 0.00683 s (n=99)
#  Bloc 224  → 0.00768 s (n=99)
#  Bloc 256  → 0.00920 s (n=99)
#  Bloc 288  → 0.00800 s (n=99)
#  Bloc 320  → 0.05704 s (n=99)
#  Bloc 352  → 0.01359 s (n=99)
#  Bloc 384  → 0.01039 s (n=99)
#  Bloc 416  → 0.01085 s (n=99)
#  Bloc 448  → 0.01195 s (n=99)
#  Bloc 480  → 0.06886 s (n=99)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00518)
#   -> Bloc 64 vs Bloc 32: p=0.2782
#   -> Bloc 64 vs Bloc 96: p=0.0043
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 98 : mesure de tous les blocs
#  Bloc 32   → 0.00557 s (n=100)
#  Bloc 64   → 0.00381 s (n=100)
#  Bloc 96   → 0.00468 s (n=100)
#  Bloc 128  → 0.00577 s (n=100)
#  Bloc 160  → 0.06734 s (n=100)
#  Bloc 192  → 0.00805 s (n=100)
#  Bloc 224  → 0.00724 s (n=100)
#  Bloc 256  → 0.00862 s (n=100)
#  Bloc 288  → 0.00958 s (n=100)
#  Bloc 320  → 0.06074 s (n=100)
#  Bloc 352  → 0.01218 s (n=100)
#  Bloc 384  → 0.01074 s (n=100)
#  Bloc 416  → 0.01184 s (n=100)
#  Bloc 448  → 0.01317 s (n=100)
#  Bloc 480  → 0.05780 s (n=100)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00516)
#   -> Bloc 64 vs Bloc 32: p=0.2721
#   -> Bloc 64 vs Bloc 96: p=0.0042
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 99 : mesure de tous les blocs
#  Bloc 32   → 0.00382 s (n=101)
#  Bloc 64   → 0.00326 s (n=101)
#  Bloc 96   → 0.00372 s (n=101)
#  Bloc 128  → 0.00516 s (n=101)
#  Bloc 160  → 0.00599 s (n=101)
#  Bloc 192  → 0.06738 s (n=101)
#  Bloc 224  → 0.00786 s (n=101)
#  Bloc 256  → 0.00805 s (n=101)
#  Bloc 288  → 0.00812 s (n=101)
#  Bloc 320  → 0.00894 s (n=101)
#  Bloc 352  → 0.05827 s (n=101)
#  Bloc 384  → 0.01730 s (n=101)
#  Bloc 416  → 0.01271 s (n=101)
#  Bloc 448  → 0.01212 s (n=101)
#  Bloc 480  → 0.06487 s (n=101)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00514)
#   -> Bloc 64 vs Bloc 32: p=0.2702
#   -> Bloc 64 vs Bloc 96: p=0.0042
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# 🔁 Itération 100 : mesure de tous les blocs
#  Bloc 32   → 0.00698 s (n=102)
#  Bloc 64   → 0.00390 s (n=102)
#  Bloc 96   → 0.00432 s (n=102)
#  Bloc 128  → 0.00575 s (n=102)
#  Bloc 160  → 0.00568 s (n=102)
#  Bloc 192  → 0.06953 s (n=102)
#  Bloc 224  → 0.00768 s (n=102)
#  Bloc 256  → 0.00905 s (n=102)
#  Bloc 288  → 0.00963 s (n=102)
#  Bloc 320  → 0.00963 s (n=102)
#  Bloc 352  → 0.05757 s (n=102)
#  Bloc 384  → 0.01354 s (n=102)
#  Bloc 416  → 0.01121 s (n=102)
#  Bloc 448  → 0.01189 s (n=102)
#  Bloc 480  → 0.06546 s (n=102)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00513)
#   -> Bloc 64 vs Bloc 32: p=0.2597
#   -> Bloc 64 vs Bloc 96: p=0.0042
#   -> Bloc 64 vs Bloc 128: p=0.0000
#   -> Bloc 64 vs Bloc 160: p=0.0000
#   -> Bloc 64 vs Bloc 192: p=0.0000
#   -> Bloc 64 vs Bloc 224: p=0.0000
#   -> Bloc 64 vs Bloc 256: p=0.0000
#   -> Bloc 64 vs Bloc 288: p=0.0000
#   -> Bloc 64 vs Bloc 320: p=0.0000
#   -> Bloc 64 vs Bloc 352: p=0.0000
#   -> Bloc 64 vs Bloc 384: p=0.0000
#   -> Bloc 64 vs Bloc 416: p=0.0000
#   -> Bloc 64 vs Bloc 448: p=0.0000
#   -> Bloc 64 vs Bloc 480: p=0.0000
#
# ❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de 95 %.

# %%
from matplotlib.ticker import MultipleLocator


figsize = (24, 6)
# 1) Évolution du best par itération
fig, ax = plt.subplots(figsize=figsize)
iterations = list(range(1, len(best_track) + 1))

ax.plot(iterations, best_track, marker='o')
ax.set_xlabel("Itération")
ax.set_ylabel("Meilleur bloc")
ax.set_title("Évolution du bloc sélectionné")
ax.grid(True)
ax.yaxis.set_major_locator(MultipleLocator(step))   # un tick par itération
plt.tight_layout()
plt.show()


# 2) Distribution des temps par bloc
plt.figure(figsize=figsize)
plt.boxplot([results[b] for b in blocks],
            labels=[str(b) for b in blocks],
            showfliers=False)
plt.xlabel("Taille de bloc")
plt.ylabel("Temps mesuré (s)")
plt.title("Distribution des temps par bloc")
plt.grid(True)

# 3) Temps du best à chaque mesure, coloré aux changements
indices = [idx for idx, _, _ in best_meas]
blocks_seq = [bsz for _, bsz, _ in best_meas]
times_seq  = [t   for _, _, t in best_meas]
colors = ['red' if curr!=prev else 'blue'
            for prev, curr in zip(blocks_seq, blocks_seq[1:])]

plt.figure(figsize=figsize)
for i in range(len(times_seq)-1):
    plt.plot([indices[i], indices[i+1]],
                [times_seq[i], times_seq[i+1]],
                color=colors[i], linewidth=2)
plt.scatter(indices[0], times_seq[0], color='blue')
plt.xlabel("Numéro de mesure du best")
plt.ylabel("Temps mesuré (s)")
plt.title("Évolution du temps du best\n(rouge = changement de bloc)")
plt.grid(True)
plt.legend([
    plt.Line2D([0],[0], color='blue', lw=2),
    plt.Line2D([0],[0], color='red',  lw=2)
], ["Même bloc", "Changement"])
plt.tight_layout()
plt.show()

# 4) Heatmap de confiance
p_df = pd.DataFrame(p_hist)             # colonnes = blocs dans l’ordre original
blocks = list(p_df.columns)                # on récupère cet ordre

plt.figure(figsize=(24, 6))
plt.imshow(
    p_df.T.values,            # matrice blocs × itérations
    aspect='auto',
    origin='upper',           # ligne index 0 (bloc blocks[0]) tout en haut
    interpolation='nearest',
    cmap='viridis',
    vmin=0, vmax=1
)
plt.colorbar(label="p = P(best plus rapide que bloc)")
# lignes = blocs dans l’ordre de `blocks`
plt.yticks(np.arange(len(blocks)), blocks)
# colonnes = itérations de 1 à N
plt.xticks(np.arange(len(p_df.index)), np.arange(1, len(p_df.index)+1))
plt.xlabel("Itération")
plt.ylabel("Bloc candidat (ordre d’index)")
plt.title("Évolution de la confiance que le best soit plus rapide")
plt.tight_layout()
plt.show()


# 5) Heatmap de confiance
p_max = [max(d.values()) if d else 0.0 for d in p_hist]

# 2) Tracer l’évolution de cette p‐value
fig, ax = plt.subplots(figsize=(24, 6))
iterations = list(range(1, len(p_max) + 1))

ax.plot(iterations, p_max, marker='o', label="max p-value")
ax.axhline(0.05, color='red', linestyle='--', label="seuil p_stop=0.05")

ax.set_xlabel("Itération")
ax.set_ylabel("max P(b < best)")
ax.set_title("Évolution de la p-value maximale par itération")
ax.grid(True)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_60677/2830853949.py:21: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([results[b] for b in blocks],

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# best_track et p_max déjà définis
iterations = np.arange(1, len(p_max) + 1)

# Palette simple pour les blocs
unique_blocks = sorted(set(best_track))
cmap = plt.cm.tab10_r
color_map = {b: cmap(i % 10) for i, b in enumerate(unique_blocks)}

fig, ax = plt.subplots(figsize=(24, 6))

# 1) Courbe p_max en gris clair, fine et transparente, zorder=1
ax.plot(iterations, p_max,
        color='gray',
        linestyle='-',
        linewidth=1,
        alpha=0.5,
        zorder=1,
        label='max p-value')

# 2) Points colorés par bloc, zorder=2
for b in unique_blocks:
    xs = [i+1 for i, bb in enumerate(best_track) if bb == b]
    ys = [p_max[i] for i, bb in enumerate(best_track) if bb == b]
    ax.scatter(xs, ys,
               color=color_map[b],
               edgecolor='white',
               s=100,
               zorder=2,
               label=f'Bloc {b}')

# 3) Seuil p_stop en rouge, zorder=0
ax.axhline(0.05,
           color='red',
           linestyle='--',
           linewidth=1.5,
           zorder=0,
           label='seuil p_stop = 0.05')

# Mise en forme
ax.set_xlim(0, len(p_max))
ax.set_xlabel("Itération")
ax.set_ylabel("max P(b < best)")
ax.set_title("Évolution de la p-value maximale par itération")
ax.grid(True)

# Graduations à chaque itération
ax.xaxis.set_major_locator(MultipleLocator(5))

# Légende sans doublons
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(),
          by_label.keys(),
          ncol=3,
          loc='upper right',
          framealpha=0.9)

plt.tight_layout()
plt.show()

# %%
# Tracé
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=False)

# --- HAUT : nuage de points de tous les temps + IC best par itération ---
# On positionne chaque point selon son bloc (axe x=bloc, axe y=temps)
for b in blocks:
    y = results[b]
    x_b = [b] * len(y)
    axes[0].scatter(x_b, y, label=f"Bloc {b}", alpha=0.6)
# Ajout de l'évolution de l'IC du bloc best
ic_means = []
ic_uppers = []
ic_locs = []
for i, (iteration, bestb, m, s, ci_upper) in enumerate(hist):
    ic_means.append(m)
    ic_uppers.append(ci_upper)
    ic_locs.append(bestb)
    axes[0].errorbar(bestb, m, yerr=[[0], [ci_upper - m]], fmt='o', color='black', capsize=5, lw=2, label='IC best' if i==0 else "")

# On force les graduations de l'axe x sur les blocs testés
axes[0].set_xticks(list(blocks))
axes[0].set_xticklabels([str(b) for b in blocks], rotation=45, ha="right")

axes[0].set_title("Temps de calcul pour chaque bloc (nuage de points) et IC du best")
axes[0].set_xlabel("Taille de bloc")
axes[0].set_ylabel("Temps (s)")
if len(blocks) < 20:
    axes[0].set_xticks(list(blocks))
    axes[0].legend()
axes[0].grid(True)

# --- BAS : évolution de la moyenne et de l'IC du best ---
iterations = [h[0] for h in hist]
axes[1].plot(iterations, ic_means, marker='o', label='Moyenne best')
axes[1].plot(iterations, ic_uppers, marker='s', label='CI supérieur')
axes[1].fill_between(iterations, ic_means, ic_uppers, color='orange', alpha=0.3, label='IC best')
axes[1].set_xlabel("Itération")
axes[1].set_ylabel("Temps (s)")
axes[1].set_title("Évolution de la moyenne et de l'IC du best")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 14
#      12 ic_uppers = []
#      13 ic_locs = []
# ---> 14 for i, (iteration, bestb, m, s, ci_upper) in enumerate(hist):
#      15     ic_means.append(m)
#      16     ic_uppers.append(ci_upper)
#
# NameError: name 'hist' is not defined

# %% [markdown]
# ## Meilleur Benchmark

# %%
# -*- coding: utf-8 -*-
"""
Benchmark adaptatif jusqu'à décision probabiliste,
avec traçage des performances.
"""

from math import sqrt
import numpy as np
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

def _prob_b_faster_than_a(mean_a, std_a, n_a, mean_b, std_b, n_b):
    var = (std_a ** 2) / n_a + (std_b ** 2) / n_b
    if var == 0:
        return 0.5
    se = sqrt(var)
    diff = mean_b - mean_a
    t_stat = diff / se
    df = var**2 / (
        (std_a**4) / (n_a**2 * (n_a - 1)) +
        (std_b**4) / (n_b**2 * (n_b - 1))
    )
    return student_t.cdf(-t_stat, df)


def smart_benchmark_probabilistic(
    x,
    block_sizes,
    *,
    p_switch: float         = 0.50,
    initial_repeats: int    = 2,
    confidence: float       = 0.95,
    free_runs: int          = 1,
    extra_repeats_best: int = 1,
    max_iter: int           = 10,
    verbose: bool           = True,
):
    # ---------------------------------------------------------------
    # Préparation
    # ---------------------------------------------------------------
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}
    history = []          # [ (iter, best, {b: p_better}) ]
    best_track = []       # suivi du best
    p_stop = 1 - confidence

    # Pour le troisième graphique :
    best_measurements = []            # liste de tuples (idx, best, t)
    global_measure_counter = 0        # compteur de mesures best

    # (1) réchauffe-caches
    if free_runs > 0 and verbose:
        print(f"⚙️  Phase 0 : {free_runs} free runs")
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once_np(x, b)
    if verbose:
        print("Fin des free runs\n")

    # (2) mesures initiales
    if verbose:
        print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            results[b].append(measure_time(x, b))
        if verbose:
            print(f"Bloc {b:<4} → {np.mean(results[b]):.5f} s (n={len(results[b])})")

    # (3) best initial + répétitions bonus
    best = min(block_sizes, key=lambda b: np.mean(results[b]))
    if verbose:
        print(f"\nBest initial : {best}")
    for _ in range(extra_repeats_best):
        t = measure_time(x, best)
        # enregistrement pour graphique 3
        global_measure_counter += 1
        best_measurements.append((global_measure_counter, best, t))
        results[best].append(t)

    # ---------------------------------------------------------------
    # Boucle principale
    # ---------------------------------------------------------------
    for it in range(1, max_iter + 1):
        # Stats de tous les blocs
        stats = {
            b: (
                np.mean(results[b]),
                np.std(results[b], ddof=1) if len(results[b]) > 1 else 0.0,
                len(results[b]),
            )
            for b in block_sizes
        }
        mean_best, std_best, n_best = stats[best]

        # Probabilités P(b < best)
        p_better = {}
        for b in block_sizes:
            if b == best:
                continue
            mean_b, std_b, n_b = stats[b]
            p_better[b] = _prob_b_faster_than_a(
                mean_best, std_best, n_best,
                mean_b, std_b, n_b
            )

        history.append((it, best, p_better.copy()))
        best_track.append(best)

        if verbose:
            print(f"\n🔁 Itération {it}: best = {best}")
            for b, p in sorted(p_better.items()):
                print(f"  P({b} plus rapide que {best}) = {p:.3f}")

        # Décision : stop ? switch ?
        max_p = max(p_better.values(), default=0.0)
        if max_p < p_stop:
            if verbose:
                print(f"\n✅ Arrêt, toutes proba < {p_stop:.2f}")
            break

        if max_p > p_switch:
            new_best = max(p_better, key=p_better.get)
            if verbose:
                print(f"↪️ Switch : {best} → {new_best} (p={max_p:.3f})")
            best = new_best

        # Sélection des blocs à remesurer
        to_measure = [best] + [b for b, p in p_better.items() if p >= p_stop]
        if verbose:
            print("Mesures supplémentaires :", to_measure)

        for b in to_measure:
            t = measure_time(x, b)
            # n’enregistrer que si c’est le best
            if b == best:
                global_measure_counter += 1
                best_measurements.append((global_measure_counter, best, t))
            results[b].append(t)
            if verbose:
                print(f"  Bloc {b:<4} → {t:.5f} s (n={len(results[b])})")
        
        if it == max_iter:
            print(f"\n❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de {confidence*100:.0f} %.")

    # Résultat final
    if verbose:
        m_final = float(np.median(results[best]))
        tot = sum(len(v) for v in results.values())
        print(f"\n🏁 Best final : {best} (médiane={m_final:.5f} s), mesures={tot}")
        

    return best, results, history, best_track, best_measurements

# %%
# ------------------------
# Exécution
# ------------------------
seq_len, d_model = 2048, 64
x = np.random.randn(seq_len, d_model)
blocks = list(range(0, 512, 16))

best, results, history, best_blocks_by_iter, best_measurements = \
    smart_benchmark_probabilistic(
        x, blocks,
        initial_repeats    = 2,
        free_runs          = 1,
        extra_repeats_best = 0,
        verbose            = True
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       5 x = np.random.randn(seq_len, d_model)
#       6 blocks = list(range(0, 512, 16))
#       8 best, results, history, best_blocks_by_iter, best_measurements = \
# ----> 9     smart_benchmark_probabilistic(
#      10         x, blocks,
#      11         initial_repeats    = 2,
#      12         free_runs          = 1,
#      13         extra_repeats_best = 0,
#      14         verbose            = True
#      15     )
#
# Cell In[17], line 54, in smart_benchmark_probabilistic(x, block_sizes, p_switch, initial_repeats, confidence, free_runs, extra_repeats_best, max_iter, verbose)
#      52 for _ in range(free_runs):
#      53     for b in block_sizes:
# ---> 54         run_attention_once(x, b)
#      55 if verbose:
#      56     print("End of free runs")
#
# NameError: name 'run_attention_once' is not defined

# %%
# ------------------------
# Tracés
# ------------------------

# 1) Évolution du bloc sélectionné par itération
plt.figure()
plt.plot(
    range(1, len(best_blocks_by_iter) + 1),
    best_blocks_by_iter,
    marker='o'
)
plt.xlabel("Itération")
plt.ylabel("Meilleur bloc")
plt.title("Bloc sélectionné au fil des itérations")
plt.grid(True)

# 2) Distribution des temps par bloc
plt.figure()
plt.boxplot(
    [results[b] for b in blocks],
    labels=[str(b) for b in blocks],
    showfliers=False
)
plt.xlabel("Taille de bloc")
plt.ylabel("Temps mesuré (s)")
plt.title("Distribution des temps par bloc")
plt.grid(True)

# 3) Temps du best à chaque mesure, segments colorés
# Préparation des données
indices = [idx for idx, _, _ in best_measurements]
blocks_seq = [bsz for _, bsz, _ in best_measurements]
times_seq  = [t   for _, _, t in best_measurements]
# Couleurs : rouge si changement de best, bleu sinon
colors = [
    'red' if curr != prev else 'blue'
    for prev, curr in zip(blocks_seq, blocks_seq[1:])
]
# Tracé segment par segment
plt.figure()
for i in range(len(times_seq)-1):
    plt.plot(
        [indices[i], indices[i+1]],
        [times_seq[i], times_seq[i+1]],
        color=colors[i],
        linewidth=2
    )
# Premier point
plt.scatter(indices[0], times_seq[0], color='blue')
plt.xlabel("Numéro de mesure du best")
plt.ylabel("Temps mesuré (s)")
plt.title("Évolution du temps du best (rouge = changement de bloc)")
plt.grid(True)
plt.legend([
    plt.Line2D([0],[0], color='blue', lw=2),
    plt.Line2D([0],[0], color='red',  lw=2)
], ["Même bloc", "Changement"])
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_43280/1544241572.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
