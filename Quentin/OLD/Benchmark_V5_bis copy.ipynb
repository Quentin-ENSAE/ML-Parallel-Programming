# %% [markdown]
# ## Calcul de l'attention (avec numpy)

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
# ------------------------
# Fonction d'attention (inchangée)
# ------------------------
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def run_attention_once_np(x, block_size):
    seq_len, d_model = x.shape
    output = np.zeros_like(x)
    for i in range(0, seq_len, block_size):
        end = min(i + block_size, seq_len)
        Q = x[i:end]
        K = x[i:end]
        V = x[i:end]
        scores = np.matmul(Q, K.T) / np.sqrt(d_model)
        weights = softmax(scores)
        output[i:end] = np.matmul(weights, V)
    return output


# ------------------------
# Mesure de temps
# ------------------------
def measure_time(x, block_size):
    start = time.perf_counter()
    _ = run_attention_once_np(x, block_size)
    return time.perf_counter() - start

# %% [markdown]
# ## Grille exhaustive qui teste toutes les combinaisons
#
# * Mesure initiale : pour chaque block_size, effectue initial_repeats mesures et stocke les temps.
#
# * Choix du candidat : identifie le bloc dont la moyenne des temps initiaux est la plus faible.
#
# * Échauffement : relance 5 mesures supplémentaires sur ce “best” pour estimer son intervalle de confiance (IC) à 95 % (Student-t).
#
# * Itération : jusqu’à max_iter, répète :
#
# * Recalcule la moyenne, l’écart-type et l’IC supérieur du “best”.
#
# * Sélectionne tous les blocs dont la moyenne courante ≤ IC supérieur.
#
# * Mesure chacun de ces candidats une fois de plus.
#
# * Met à jour le “best” en choisissant, parmi les candidats, celui à la plus petite moyenne.
#
# * Test de confiance : pour chaque autre bloc, effectue un test t de Welch contre le “best” et calcule la p-value unilatérale.
#
# * Arrêt : dès que toutes les p-values sont < 0.05 (95 % de confiance que le “best” est plus rapide), on sort.
#
# * Résultat : retourne la taille de bloc optimale, toutes les mesures accumulées, et le nombre total de tests effectués.

# %%
# -*- coding: utf-8 -*-
import numpy as np
import time
import math
from math import sqrt
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

# ------------------------
# Grille exhaustive jusqu'à confiance 95%, avec suivi pour tracés
# ------------------------
def exhaustive_grid_until_confidence(
    x, 
    block_sizes,
    initial_repeats=2,
    free_runs=1,
    confidence=0.95,
    max_iter=100,
    verbose=True
):
    alpha = 1 - confidence
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}

    # Pour les tracés
    best_track = []             # meilleur par itération
    best_measurements = []      # tuples (mesure_index, best_block, time_s)
    measure_counter = 0         # compteur global de mesures

    # (0) Free runs pour chauffer les caches / JIT
    if free_runs > 0 and verbose:
        print(f"⚙️  Phase 0 : {free_runs} free runs")
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once_np(x, b)
    if verbose and free_runs > 0:
        print("Fin des free runs\n")

    # Phase initiale
    if verbose:
        print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            t = measure_time(x, b)
            measure_counter += 1
            results[b].append(t)
        med = np.median(results[b])
        if verbose:
            print(f"Bloc {b:<4} → médiane init : {med:.5f} s")
    total_tests = initial_repeats * len(block_sizes)

    # Boucle d'itérations
    for it in range(1, max_iter+1):
        if verbose:
            print(f"\n🔁 Itération {it} : mesure de tous les blocs")

        # Mesures
        for b in block_sizes:
            t = measure_time(x, b)
            measure_counter += 1
            results[b].append(t)
            if verbose:
                print(f" Bloc {b:<4} → {t:.5f} s (n={len(results[b])})")

        total_tests += len(block_sizes)

        # Moyennes et variances
        means = {b: np.mean(results[b]) for b in block_sizes}
        vars_  = {b: np.var(results[b], ddof=1) for b in block_sizes}
        ns     = {b: len(results[b]) for b in block_sizes}

        # Choix du best
        best = min(means, key=means.get)
        best_track.append(best)
        if verbose:
            print(f" Meilleur moyen actuel : Bloc {best} (mean={means[best]:.5f})")
        # Enregistrement de la dernière mesure du best
        best_measurements.append(
            (measure_counter - (len(block_sizes)-block_sizes.index(best)), 
             best, 
             results[best][-1])
        )

        # Test de confiance pair à pair
        all_confident = True
        for b in block_sizes:
            if b == best:
                continue
            diff     = means[b] - means[best]
            var_diff = vars_[b]/ns[b] + vars_[best]/ns[best]
            t_stat   = diff / math.sqrt(var_diff)
            # ddl Welch–Satterthwaite
            df = (var_diff**2) / (
                (vars_[b]**2)/(ns[b]**2*(ns[b]-1)) +
                (vars_[best]**2)/(ns[best]**2*(ns[best]-1))
            )
            p_value = 1 - student_t.cdf(t_stat, df)
            if verbose:
                print(f"  -> Bloc {best} vs Bloc {b}: p={p_value:.4f}")
            if p_value >= alpha:
                all_confident = False

        if all_confident:
            if verbose:
                print("\n✅ Confiance 95% atteinte pour le meilleur bloc.")
            break

        if it == max_iter and verbose:
            print(f"\n❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de {confidence*100:.0f} %.")

    if verbose and it < max_iter:
        print(f"\n✅ Résultat final : Bloc {best}, tests totaux = {total_tests}")

    return best, results, total_tests, best_track, best_measurements

# %%
# ------------------------
# Exécution
# ------------------------
seq_len, d_model = 2048, 64
x = np.random.randn(seq_len, d_model)
blocks = list(range(16, 512, 16))

best, results, total_tests, best_track, best_meas = \
    exhaustive_grid_until_confidence(
        x, blocks,
        initial_repeats=2,
        confidence=0.95,
        max_iter=50,
        verbose=True
    )
# Out:
# ⚙️  Phase 0 : 1 free runs
# Fin des free runs
#
# 🔍 Phase 1 : mesures initiales
# Bloc 16   → médiane init : 0.00809 s
# Bloc 32   → médiane init : 0.00423 s
# Bloc 48   → médiane init : 0.03416 s
# Bloc 64   → médiane init : 0.00450 s
# Bloc 80   → médiane init : 0.00448 s
# Bloc 96   → médiane init : 0.00405 s
# Bloc 112  → médiane init : 0.00358 s
# Bloc 128  → médiane init : 0.03082 s
# Bloc 144  → médiane init : 0.00485 s
# Bloc 160  → médiane init : 0.00595 s
# Bloc 176  → médiane init : 0.00519 s
# Bloc 192  → médiane init : 0.00568 s
# Bloc 208  → médiane init : 0.00576 s
# Bloc 224  → médiane init : 0.00691 s
# Bloc 240  → médiane init : 0.00657 s
# Bloc 256  → médiane init : 0.00792 s
# Bloc 272  → médiane init : 0.00698 s
# Bloc 288  → médiane init : 0.00864 s
# Bloc 304  → médiane init : 0.00764 s
# Bloc 320  → médiane init : 0.00874 s
# Bloc 336  → médiane init : 0.02012 s
# Bloc 352  → médiane init : 0.00981 s
# Bloc 368  → médiane init : 0.00906 s
# Bloc 384  → médiane init : 0.03253 s
# Bloc 400  → médiane init : 0.01011 s
# Bloc 416  → médiane init : 0.03787 s
# Bloc 432  → médiane init : 0.01097 s
# Bloc 448  → médiane init : 0.04033 s
# Bloc 464  → médiane init : 0.01165 s
# Bloc 480  → médiane init : 0.04194 s
# Bloc 496  → médiane init : 0.04390 s
#
# 🔁 Itération 1 : mesure de tous les blocs
#  Bloc 16   → 0.00987 s (n=3)
#  Bloc 32   → 0.00373 s (n=3)
#  Bloc 48   → 0.00318 s (n=3)
#  Bloc 64   → 0.00341 s (n=3)
#  Bloc 80   → 0.00346 s (n=3)
#  Bloc 96   → 0.00373 s (n=3)
#  Bloc 112  → 0.06433 s (n=3)
#  Bloc 128  → 0.00729 s (n=3)
#  Bloc 144  → 0.00626 s (n=3)
#  Bloc 160  → 0.00621 s (n=3)
#  Bloc 176  → 0.00551 s (n=3)
#  Bloc 192  → 0.00729 s (n=3)
#  Bloc 208  → 0.00778 s (n=3)
#  Bloc 224  → 0.00773 s (n=3)
#  Bloc 240  → 0.05009 s (n=3)
#  Bloc 256  → 0.00897 s (n=3)
#  Bloc 272  → 0.00817 s (n=3)
#  Bloc 288  → 0.00909 s (n=3)
#  Bloc 304  → 0.00773 s (n=3)
#  Bloc 320  → 0.00930 s (n=3)
#  Bloc 336  → 0.01036 s (n=3)
#  Bloc 352  → 0.01016 s (n=3)
#  Bloc 368  → 0.03425 s (n=3)
#  Bloc 384  → 0.01989 s (n=3)
#  Bloc 400  → 0.01019 s (n=3)
#  Bloc 416  → 0.01085 s (n=3)
#  Bloc 432  → 0.06329 s (n=3)
#  Bloc 448  → 0.01243 s (n=3)
#  Bloc 464  → 0.01106 s (n=3)
#  Bloc 480  → 0.07180 s (n=3)
#  Bloc 496  → 0.01665 s (n=3)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00394)
#   -> Bloc 96 vs Bloc 16: p=0.0027
#   -> Bloc 96 vs Bloc 32: p=0.4350
#   -> Bloc 96 vs Bloc 48: p=0.1961
#   -> Bloc 96 vs Bloc 64: p=0.3604
#   -> Bloc 96 vs Bloc 80: p=0.3522
#   -> Bloc 96 vs Bloc 112: p=0.2148
#   -> Bloc 96 vs Bloc 128: p=0.1768
#   -> Bloc 96 vs Bloc 144: p=0.0925
#   -> Bloc 96 vs Bloc 160: p=0.0054
#   -> Bloc 96 vs Bloc 176: p=0.0203
#   -> Bloc 96 vs Bloc 192: p=0.0156
#   -> Bloc 96 vs Bloc 208: p=0.0234
#   -> Bloc 96 vs Bloc 224: p=0.0012
#   -> Bloc 96 vs Bloc 240: p=0.1795
#   -> Bloc 96 vs Bloc 256: p=0.0006
#   -> Bloc 96 vs Bloc 272: p=0.0015
#   -> Bloc 96 vs Bloc 288: p=0.0003
#   -> Bloc 96 vs Bloc 304: p=0.0039
#   -> Bloc 96 vs Bloc 320: p=0.0005
#   -> Bloc 96 vs Bloc 336: p=0.1076
#   -> Bloc 96 vs Bloc 352: p=0.0002
#   -> Bloc 96 vs Bloc 368: p=0.1243
#   -> Bloc 96 vs Bloc 384: p=0.1017
#   -> Bloc 96 vs Bloc 400: p=0.0015
#   -> Bloc 96 vs Bloc 416: p=0.1505
#   -> Bloc 96 vs Bloc 432: p=0.1478
#   -> Bloc 96 vs Bloc 448: p=0.1285
#   -> Bloc 96 vs Bloc 464: p=0.0001
#   -> Bloc 96 vs Bloc 480: p=0.0665
#   -> Bloc 96 vs Bloc 496: p=0.1309
#
# 🔁 Itération 2 : mesure de tous les blocs
#  Bloc 16   → 0.00963 s (n=4)
#  Bloc 32   → 0.06283 s (n=4)
#  Bloc 48   → 0.00790 s (n=4)
#  Bloc 64   → 0.00575 s (n=4)
#  Bloc 80   → 0.00460 s (n=4)
#  Bloc 96   → 0.00480 s (n=4)
#  Bloc 112  → 0.00511 s (n=4)
#  Bloc 128  → 0.00670 s (n=4)
#  Bloc 144  → 0.00485 s (n=4)
#  Bloc 160  → 0.00529 s (n=4)
#  Bloc 176  → 0.06353 s (n=4)
#  Bloc 192  → 0.00843 s (n=4)
#  Bloc 208  → 0.00716 s (n=4)
#  Bloc 224  → 0.00802 s (n=4)
#  Bloc 240  → 0.00779 s (n=4)
#  Bloc 256  → 0.00888 s (n=4)
#  Bloc 272  → 0.00830 s (n=4)
#  Bloc 288  → 0.00911 s (n=4)
#  Bloc 304  → 0.00902 s (n=4)
#  Bloc 320  → 0.01038 s (n=4)
#  Bloc 336  → 0.01287 s (n=4)
#  Bloc 352  → 0.01039 s (n=4)
#  Bloc 368  → 0.01014 s (n=4)
#  Bloc 384  → 0.01141 s (n=4)
#  Bloc 400  → 0.01155 s (n=4)
#  Bloc 416  → 0.06342 s (n=4)
#  Bloc 432  → 0.01395 s (n=4)
#  Bloc 448  → 0.01228 s (n=4)
#  Bloc 464  → 0.07606 s (n=4)
#  Bloc 480  → 0.01379 s (n=4)
#  Bloc 496  → 0.01242 s (n=4)
#  Meilleur moyen actuel : Bloc 96 (mean=0.00416)
#   -> Bloc 96 vs Bloc 16: p=0.0002
#   -> Bloc 96 vs Bloc 32: p=0.1969
#   -> Bloc 96 vs Bloc 48: p=0.1660
#   -> Bloc 96 vs Bloc 64: p=0.2686
#   -> Bloc 96 vs Bloc 80: p=0.4115
#   -> Bloc 96 vs Bloc 112: p=0.1965
#   -> Bloc 96 vs Bloc 128: p=0.1524
#   -> Bloc 96 vs Bloc 144: p=0.0742
#   -> Bloc 96 vs Bloc 160: p=0.0039
#   -> Bloc 96 vs Bloc 176: p=0.1800
#   -> Bloc 96 vs Bloc 192: p=0.0109
#   -> Bloc 96 vs Bloc 208: p=0.0048
#   -> Bloc 96 vs Bloc 224: p=0.0002
#   -> Bloc 96 vs Bloc 240: p=0.1482
#   -> Bloc 96 vs Bloc 256: p=0.0000
#   -> Bloc 96 vs Bloc 272: p=0.0002
#   -> Bloc 96 vs Bloc 288: p=0.0000
#   -> Bloc 96 vs Bloc 304: p=0.0001
#   -> Bloc 96 vs Bloc 320: p=0.0000
#   -> Bloc 96 vs Bloc 336: p=0.0548
#   -> Bloc 96 vs Bloc 352: p=0.0000
#   -> Bloc 96 vs Bloc 368: p=0.0810
#   -> Bloc 96 vs Bloc 384: p=0.0724
#   -> Bloc 96 vs Bloc 400: p=0.0000
#   -> Bloc 96 vs Bloc 416: p=0.0595
#   -> Bloc 96 vs Bloc 432: p=0.1033
#   -> Bloc 96 vs Bloc 448: p=0.0941
#   -> Bloc 96 vs Bloc 464: p=0.1213
#   -> Bloc 96 vs Bloc 480: p=0.0534
#   -> Bloc 96 vs Bloc 496: p=0.0987
#
# 🔁 Itération 3 : mesure de tous les blocs
#  Bloc 16   → 0.00927 s (n=5)
#  Bloc 32   → 0.00522 s (n=5)
#  Bloc 48   → 0.00447 s (n=5)
#  Bloc 64   → 0.00452 s (n=5)
#  Bloc 80   → 0.00450 s (n=5)
#  Bloc 96   → 0.06847 s (n=5)
#  Bloc 112  → 0.00383 s (n=5)
#  Bloc 128  → 0.00464 s (n=5)
#  Bloc 144  → 0.00508 s (n=5)
#  Bloc 160  → 0.00673 s (n=5)
#  Bloc 176  → 0.00680 s (n=5)
#  Bloc 192  → 0.00713 s (n=5)
#  Bloc 208  → 0.00742 s (n=5)
#  Bloc 224  → 0.00808 s (n=5)
#  Bloc 240  → 0.00773 s (n=5)
#  Bloc 256  → 0.00926 s (n=5)
#  Bloc 272  → 0.00828 s (n=5)
#  Bloc 288  → 0.00896 s (n=5)
#  Bloc 304  → 0.00883 s (n=5)
#  Bloc 320  → 0.00963 s (n=5)
#  Bloc 336  → 0.00987 s (n=5)
#  Bloc 352  → 0.01042 s (n=5)
#  Bloc 368  → 0.00993 s (n=5)
#  Bloc 384  → 0.01123 s (n=5)
#  Bloc 400  → 0.01072 s (n=5)
#  Bloc 416  → 0.05686 s (n=5)
#  Bloc 432  → 0.01119 s (n=5)
#  Bloc 448  → 0.01203 s (n=5)
#  Bloc 464  → 0.07383 s (n=5)
#  Bloc 480  → 0.01307 s (n=5)
#  Bloc 496  → 0.01236 s (n=5)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00430)
#   -> Bloc 80 vs Bloc 16: p=0.0000
#   -> Bloc 80 vs Bloc 32: p=0.1862
#   -> Bloc 80 vs Bloc 48: p=0.1596
#   -> Bloc 80 vs Bloc 64: p=0.3034
#   -> Bloc 80 vs Bloc 96: p=0.1895
#   -> Bloc 80 vs Bloc 112: p=0.1920
#   -> Bloc 80 vs Bloc 128: p=0.1459
#   -> Bloc 80 vs Bloc 144: p=0.0513
#   -> Bloc 80 vs Bloc 160: p=0.0006
#   -> Bloc 80 vs Bloc 176: p=0.1632
#   -> Bloc 80 vs Bloc 192: p=0.0029
#   -> Bloc 80 vs Bloc 208: p=0.0011
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.1268
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0346
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0543
#   -> Bloc 80 vs Bloc 384: p=0.0532
#   -> Bloc 80 vs Bloc 400: p=0.0000
#   -> Bloc 80 vs Bloc 416: p=0.0209
#   -> Bloc 80 vs Bloc 432: p=0.0801
#   -> Bloc 80 vs Bloc 448: p=0.0712
#   -> Bloc 80 vs Bloc 464: p=0.0523
#   -> Bloc 80 vs Bloc 480: p=0.0432
#   -> Bloc 80 vs Bloc 496: p=0.0765
#
# 🔁 Itération 4 : mesure de tous les blocs
#  Bloc 16   → 0.01282 s (n=6)
#  Bloc 32   → 0.00532 s (n=6)
#  Bloc 48   → 0.00446 s (n=6)
#  Bloc 64   → 0.00450 s (n=6)
#  Bloc 80   → 0.00451 s (n=6)
#  Bloc 96   → 0.00479 s (n=6)
#  Bloc 112  → 0.06039 s (n=6)
#  Bloc 128  → 0.00465 s (n=6)
#  Bloc 144  → 0.00425 s (n=6)
#  Bloc 160  → 0.00604 s (n=6)
#  Bloc 176  → 0.00621 s (n=6)
#  Bloc 192  → 0.00746 s (n=6)
#  Bloc 208  → 0.00704 s (n=6)
#  Bloc 224  → 0.00785 s (n=6)
#  Bloc 240  → 0.00767 s (n=6)
#  Bloc 256  → 0.00911 s (n=6)
#  Bloc 272  → 0.00825 s (n=6)
#  Bloc 288  → 0.00903 s (n=6)
#  Bloc 304  → 0.00902 s (n=6)
#  Bloc 320  → 0.00977 s (n=6)
#  Bloc 336  → 0.00973 s (n=6)
#  Bloc 352  → 0.01036 s (n=6)
#  Bloc 368  → 0.00997 s (n=6)
#  Bloc 384  → 0.01132 s (n=6)
#  Bloc 400  → 0.05962 s (n=6)
#  Bloc 416  → 0.01629 s (n=6)
#  Bloc 432  → 0.01139 s (n=6)
#  Bloc 448  → 0.01250 s (n=6)
#  Bloc 464  → 0.06833 s (n=6)
#  Bloc 480  → 0.01245 s (n=6)
#  Bloc 496  → 0.01245 s (n=6)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00434)
#   -> Bloc 80 vs Bloc 16: p=0.0002
#   -> Bloc 80 vs Bloc 32: p=0.1771
#   -> Bloc 80 vs Bloc 48: p=0.1549
#   -> Bloc 80 vs Bloc 64: p=0.2996
#   -> Bloc 80 vs Bloc 96: p=0.1828
#   -> Bloc 80 vs Bloc 112: p=0.0904
#   -> Bloc 80 vs Bloc 128: p=0.1408
#   -> Bloc 80 vs Bloc 144: p=0.0662
#   -> Bloc 80 vs Bloc 160: p=0.0001
#   -> Bloc 80 vs Bloc 176: p=0.1512
#   -> Bloc 80 vs Bloc 192: p=0.0006
#   -> Bloc 80 vs Bloc 208: p=0.0002
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.1089
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0216
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0354
#   -> Bloc 80 vs Bloc 384: p=0.0386
#   -> Bloc 80 vs Bloc 400: p=0.0696
#   -> Bloc 80 vs Bloc 416: p=0.0156
#   -> Bloc 80 vs Bloc 432: p=0.0616
#   -> Bloc 80 vs Bloc 448: p=0.0529
#   -> Bloc 80 vs Bloc 464: p=0.0202
#   -> Bloc 80 vs Bloc 480: p=0.0353
#   -> Bloc 80 vs Bloc 496: p=0.0592
#
# 🔁 Itération 5 : mesure de tous les blocs
#  Bloc 16   → 0.07016 s (n=7)
#  Bloc 32   → 0.00526 s (n=7)
#  Bloc 48   → 0.00446 s (n=7)
#  Bloc 64   → 0.00445 s (n=7)
#  Bloc 80   → 0.00449 s (n=7)
#  Bloc 96   → 0.00478 s (n=7)
#  Bloc 112  → 0.00508 s (n=7)
#  Bloc 128  → 0.06666 s (n=7)
#  Bloc 144  → 0.00613 s (n=7)
#  Bloc 160  → 0.00562 s (n=7)
#  Bloc 176  → 0.00586 s (n=7)
#  Bloc 192  → 0.00593 s (n=7)
#  Bloc 208  → 0.00574 s (n=7)
#  Bloc 224  → 0.00732 s (n=7)
#  Bloc 240  → 0.00669 s (n=7)
#  Bloc 256  → 0.00771 s (n=7)
#  Bloc 272  → 0.00725 s (n=7)
#  Bloc 288  → 0.00827 s (n=7)
#  Bloc 304  → 0.00819 s (n=7)
#  Bloc 320  → 0.00888 s (n=7)
#  Bloc 336  → 0.01236 s (n=7)
#  Bloc 352  → 0.00998 s (n=7)
#  Bloc 368  → 0.00952 s (n=7)
#  Bloc 384  → 0.01011 s (n=7)
#  Bloc 400  → 0.01056 s (n=7)
#  Bloc 416  → 0.06578 s (n=7)
#  Bloc 432  → 0.01127 s (n=7)
#  Bloc 448  → 0.01204 s (n=7)
#  Bloc 464  → 0.06907 s (n=7)
#  Bloc 480  → 0.01241 s (n=7)
#  Bloc 496  → 0.01197 s (n=7)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00436)
#   -> Bloc 80 vs Bloc 16: p=0.0798
#   -> Bloc 80 vs Bloc 32: p=0.1701
#   -> Bloc 80 vs Bloc 48: p=0.1517
#   -> Bloc 80 vs Bloc 64: p=0.3029
#   -> Bloc 80 vs Bloc 96: p=0.1779
#   -> Bloc 80 vs Bloc 112: p=0.0877
#   -> Bloc 80 vs Bloc 128: p=0.0701
#   -> Bloc 80 vs Bloc 144: p=0.0301
#   -> Bloc 80 vs Bloc 160: p=0.0000
#   -> Bloc 80 vs Bloc 176: p=0.1426
#   -> Bloc 80 vs Bloc 192: p=0.0003
#   -> Bloc 80 vs Bloc 208: p=0.0001
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.0976
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0105
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0236
#   -> Bloc 80 vs Bloc 384: p=0.0296
#   -> Bloc 80 vs Bloc 400: p=0.0545
#   -> Bloc 80 vs Bloc 416: p=0.0056
#   -> Bloc 80 vs Bloc 432: p=0.0474
#   -> Bloc 80 vs Bloc 448: p=0.0398
#   -> Bloc 80 vs Bloc 464: p=0.0073
#   -> Bloc 80 vs Bloc 480: p=0.0288
#   -> Bloc 80 vs Bloc 496: p=0.0464
#
# 🔁 Itération 6 : mesure de tous les blocs
#  Bloc 16   → 0.00554 s (n=8)
#  Bloc 32   → 0.06112 s (n=8)
#  Bloc 48   → 0.00688 s (n=8)
#  Bloc 64   → 0.00798 s (n=8)
#  Bloc 80   → 0.00490 s (n=8)
#  Bloc 96   → 0.00378 s (n=8)
#  Bloc 112  → 0.00414 s (n=8)
#  Bloc 128  → 0.00590 s (n=8)
#  Bloc 144  → 0.00456 s (n=8)
#  Bloc 160  → 0.06374 s (n=8)
#  Bloc 176  → 0.00714 s (n=8)
#  Bloc 192  → 0.00706 s (n=8)
#  Bloc 208  → 0.00625 s (n=8)
#  Bloc 224  → 0.00702 s (n=8)
#  Bloc 240  → 0.00643 s (n=8)
#  Bloc 256  → 0.00885 s (n=8)
#  Bloc 272  → 0.00689 s (n=8)
#  Bloc 288  → 0.00785 s (n=8)
#  Bloc 304  → 0.00783 s (n=8)
#  Bloc 320  → 0.00931 s (n=8)
#  Bloc 336  → 0.00863 s (n=8)
#  Bloc 352  → 0.01922 s (n=8)
#  Bloc 368  → 0.00915 s (n=8)
#  Bloc 384  → 0.01027 s (n=8)
#  Bloc 400  → 0.01061 s (n=8)
#  Bloc 416  → 0.01278 s (n=8)
#  Bloc 432  → 0.05968 s (n=8)
#  Bloc 448  → 0.01161 s (n=8)
#  Bloc 464  → 0.01092 s (n=8)
#  Bloc 480  → 0.06927 s (n=8)
#  Bloc 496  → 0.01692 s (n=8)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00443)
#   -> Bloc 80 vs Bloc 16: p=0.0772
#   -> Bloc 80 vs Bloc 32: p=0.0823
#   -> Bloc 80 vs Bloc 48: p=0.1411
#   -> Bloc 80 vs Bloc 64: p=0.1660
#   -> Bloc 80 vs Bloc 96: p=0.1795
#   -> Bloc 80 vs Bloc 112: p=0.0881
#   -> Bloc 80 vs Bloc 128: p=0.0675
#   -> Bloc 80 vs Bloc 144: p=0.0381
#   -> Bloc 80 vs Bloc 160: p=0.1322
#   -> Bloc 80 vs Bloc 176: p=0.1318
#   -> Bloc 80 vs Bloc 192: p=0.0001
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.0900
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0073
#   -> Bloc 80 vs Bloc 352: p=0.0003
#   -> Bloc 80 vs Bloc 368: p=0.0164
#   -> Bloc 80 vs Bloc 384: p=0.0227
#   -> Bloc 80 vs Bloc 400: p=0.0430
#   -> Bloc 80 vs Bloc 416: p=0.0050
#   -> Bloc 80 vs Bloc 432: p=0.0236
#   -> Bloc 80 vs Bloc 448: p=0.0306
#   -> Bloc 80 vs Bloc 464: p=0.0071
#   -> Bloc 80 vs Bloc 480: p=0.0123
#   -> Bloc 80 vs Bloc 496: p=0.0315
#
# 🔁 Itération 7 : mesure de tous les blocs
#  Bloc 16   → 0.01044 s (n=9)
#  Bloc 32   → 0.06320 s (n=9)
#  Bloc 48   → 0.00581 s (n=9)
#  Bloc 64   → 0.00526 s (n=9)
#  Bloc 80   → 0.00507 s (n=9)
#  Bloc 96   → 0.00559 s (n=9)
#  Bloc 112  → 0.00576 s (n=9)
#  Bloc 128  → 0.00661 s (n=9)
#  Bloc 144  → 0.00483 s (n=9)
#  Bloc 160  → 0.00669 s (n=9)
#  Bloc 176  → 0.00680 s (n=9)
#  Bloc 192  → 0.05156 s (n=9)
#  Bloc 208  → 0.00818 s (n=9)
#  Bloc 224  → 0.00936 s (n=9)
#  Bloc 240  → 0.00810 s (n=9)
#  Bloc 256  → 0.01010 s (n=9)
#  Bloc 272  → 0.00959 s (n=9)
#  Bloc 288  → 0.01035 s (n=9)
#  Bloc 304  → 0.01022 s (n=9)
#  Bloc 320  → 0.01149 s (n=9)
#  Bloc 336  → 0.01934 s (n=9)
#  Bloc 352  → 0.01186 s (n=9)
#  Bloc 368  → 0.01154 s (n=9)
#  Bloc 384  → 0.01287 s (n=9)
#  Bloc 400  → 0.01248 s (n=9)
#  Bloc 416  → 0.05652 s (n=9)
#  Bloc 432  → 0.01288 s (n=9)
#  Bloc 448  → 0.01427 s (n=9)
#  Bloc 464  → 0.07099 s (n=9)
#  Bloc 480  → 0.01412 s (n=9)
#  Bloc 496  → 0.01445 s (n=9)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00450)
#   -> Bloc 80 vs Bloc 16: p=0.0649
#   -> Bloc 80 vs Bloc 32: p=0.0393
#   -> Bloc 80 vs Bloc 48: p=0.1361
#   -> Bloc 80 vs Bloc 64: p=0.1549
#   -> Bloc 80 vs Bloc 96: p=0.1752
#   -> Bloc 80 vs Bloc 112: p=0.0856
#   -> Bloc 80 vs Bloc 128: p=0.0641
#   -> Bloc 80 vs Bloc 144: p=0.0447
#   -> Bloc 80 vs Bloc 160: p=0.1245
#   -> Bloc 80 vs Bloc 176: p=0.1238
#   -> Bloc 80 vs Bloc 192: p=0.0904
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.0783
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0028
#   -> Bloc 80 vs Bloc 352: p=0.0001
#   -> Bloc 80 vs Bloc 368: p=0.0094
#   -> Bloc 80 vs Bloc 384: p=0.0154
#   -> Bloc 80 vs Bloc 400: p=0.0315
#   -> Bloc 80 vs Bloc 416: p=0.0018
#   -> Bloc 80 vs Bloc 432: p=0.0183
#   -> Bloc 80 vs Bloc 448: p=0.0213
#   -> Bloc 80 vs Bloc 464: p=0.0026
#   -> Bloc 80 vs Bloc 480: p=0.0100
#   -> Bloc 80 vs Bloc 496: p=0.0228
#
# 🔁 Itération 8 : mesure de tous les blocs
#  Bloc 16   → 0.00989 s (n=10)
#  Bloc 32   → 0.00674 s (n=10)
#  Bloc 48   → 0.00585 s (n=10)
#  Bloc 64   → 0.00582 s (n=10)
#  Bloc 80   → 0.00572 s (n=10)
#  Bloc 96   → 0.06276 s (n=10)
#  Bloc 112  → 0.00629 s (n=10)
#  Bloc 128  → 0.00832 s (n=10)
#  Bloc 144  → 0.00706 s (n=10)
#  Bloc 160  → 0.00766 s (n=10)
#  Bloc 176  → 0.00765 s (n=10)
#  Bloc 192  → 0.00858 s (n=10)
#  Bloc 208  → 0.00837 s (n=10)
#  Bloc 224  → 0.00963 s (n=10)
#  Bloc 240  → 0.00923 s (n=10)
#  Bloc 256  → 0.01024 s (n=10)
#  Bloc 272  → 0.00974 s (n=10)
#  Bloc 288  → 0.01068 s (n=10)
#  Bloc 304  → 0.01040 s (n=10)
#  Bloc 320  → 0.01143 s (n=10)
#  Bloc 336  → 0.01170 s (n=10)
#  Bloc 352  → 0.01189 s (n=10)
#  Bloc 368  → 0.01123 s (n=10)
#  Bloc 384  → 0.04524 s (n=10)
#  Bloc 400  → 0.01319 s (n=10)
#  Bloc 416  → 0.01393 s (n=10)
#  Bloc 432  → 0.01328 s (n=10)
#  Bloc 448  → 0.06577 s (n=10)
#  Bloc 464  → 0.01354 s (n=10)
#  Bloc 480  → 0.01431 s (n=10)
#  Bloc 496  → 0.01594 s (n=10)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00462)
#   -> Bloc 80 vs Bloc 16: p=0.0562
#   -> Bloc 80 vs Bloc 32: p=0.0382
#   -> Bloc 80 vs Bloc 48: p=0.1338
#   -> Bloc 80 vs Bloc 64: p=0.1599
#   -> Bloc 80 vs Bloc 96: p=0.0871
#   -> Bloc 80 vs Bloc 112: p=0.0834
#   -> Bloc 80 vs Bloc 128: p=0.0591
#   -> Bloc 80 vs Bloc 144: p=0.0471
#   -> Bloc 80 vs Bloc 160: p=0.1163
#   -> Bloc 80 vs Bloc 176: p=0.1156
#   -> Bloc 80 vs Bloc 192: p=0.0795
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0000
#   -> Bloc 80 vs Bloc 240: p=0.0665
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0015
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0056
#   -> Bloc 80 vs Bloc 384: p=0.0079
#   -> Bloc 80 vs Bloc 400: p=0.0228
#   -> Bloc 80 vs Bloc 416: p=0.0016
#   -> Bloc 80 vs Bloc 432: p=0.0141
#   -> Bloc 80 vs Bloc 448: p=0.0131
#   -> Bloc 80 vs Bloc 464: p=0.0024
#   -> Bloc 80 vs Bloc 480: p=0.0081
#   -> Bloc 80 vs Bloc 496: p=0.0159
#
# 🔁 Itération 9 : mesure de tous les blocs
#  Bloc 16   → 0.01051 s (n=11)
#  Bloc 32   → 0.00647 s (n=11)
#  Bloc 48   → 0.00545 s (n=11)
#  Bloc 64   → 0.05678 s (n=11)
#  Bloc 80   → 0.00357 s (n=11)
#  Bloc 96   → 0.00500 s (n=11)
#  Bloc 112  → 0.00547 s (n=11)
#  Bloc 128  → 0.00601 s (n=11)
#  Bloc 144  → 0.00436 s (n=11)
#  Bloc 160  → 0.00583 s (n=11)
#  Bloc 176  → 0.00607 s (n=11)
#  Bloc 192  → 0.00609 s (n=11)
#  Bloc 208  → 0.00731 s (n=11)
#  Bloc 224  → 0.04963 s (n=11)
#  Bloc 240  → 0.00916 s (n=11)
#  Bloc 256  → 0.00817 s (n=11)
#  Bloc 272  → 0.00682 s (n=11)
#  Bloc 288  → 0.00778 s (n=11)
#  Bloc 304  → 0.00827 s (n=11)
#  Bloc 320  → 0.00884 s (n=11)
#  Bloc 336  → 0.00847 s (n=11)
#  Bloc 352  → 0.00914 s (n=11)
#  Bloc 368  → 0.03382 s (n=11)
#  Bloc 384  → 0.01095 s (n=11)
#  Bloc 400  → 0.00987 s (n=11)
#  Bloc 416  → 0.01054 s (n=11)
#  Bloc 432  → 0.01098 s (n=11)
#  Bloc 448  → 0.06314 s (n=11)
#  Bloc 464  → 0.01070 s (n=11)
#  Bloc 480  → 0.01121 s (n=11)
#  Bloc 496  → 0.06839 s (n=11)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00453)
#   -> Bloc 80 vs Bloc 16: p=0.0451
#   -> Bloc 80 vs Bloc 32: p=0.0360
#   -> Bloc 80 vs Bloc 48: p=0.1261
#   -> Bloc 80 vs Bloc 64: p=0.1461
#   -> Bloc 80 vs Bloc 96: p=0.0841
#   -> Bloc 80 vs Bloc 112: p=0.0795
#   -> Bloc 80 vs Bloc 128: p=0.0555
#   -> Bloc 80 vs Bloc 144: p=0.0383
#   -> Bloc 80 vs Bloc 160: p=0.1084
#   -> Bloc 80 vs Bloc 176: p=0.1070
#   -> Bloc 80 vs Bloc 192: p=0.0717
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0449
#   -> Bloc 80 vs Bloc 240: p=0.0520
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0000
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0010
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0038
#   -> Bloc 80 vs Bloc 384: p=0.0058
#   -> Bloc 80 vs Bloc 400: p=0.0174
#   -> Bloc 80 vs Bloc 416: p=0.0015
#   -> Bloc 80 vs Bloc 432: p=0.0112
#   -> Bloc 80 vs Bloc 448: p=0.0060
#   -> Bloc 80 vs Bloc 464: p=0.0023
#   -> Bloc 80 vs Bloc 480: p=0.0069
#   -> Bloc 80 vs Bloc 496: p=0.0089
#
# 🔁 Itération 10 : mesure de tous les blocs
#  Bloc 16   → 0.00563 s (n=12)
#  Bloc 32   → 0.00468 s (n=12)
#  Bloc 48   → 0.00320 s (n=12)
#  Bloc 64   → 0.00331 s (n=12)
#  Bloc 80   → 0.00488 s (n=12)
#  Bloc 96   → 0.00440 s (n=12)
#  Bloc 112  → 0.00501 s (n=12)
#  Bloc 128  → 0.06581 s (n=12)
#  Bloc 144  → 0.00536 s (n=12)
#  Bloc 160  → 0.00463 s (n=12)
#  Bloc 176  → 0.00538 s (n=12)
#  Bloc 192  → 0.00529 s (n=12)
#  Bloc 208  → 0.00537 s (n=12)
#  Bloc 224  → 0.00593 s (n=12)
#  Bloc 240  → 0.00607 s (n=12)
#  Bloc 256  → 0.00742 s (n=12)
#  Bloc 272  → 0.00683 s (n=12)
#  Bloc 288  → 0.00764 s (n=12)
#  Bloc 304  → 0.03697 s (n=12)
#  Bloc 320  → 0.01043 s (n=12)
#  Bloc 336  → 0.00864 s (n=12)
#  Bloc 352  → 0.00921 s (n=12)
#  Bloc 368  → 0.00877 s (n=12)
#  Bloc 384  → 0.01003 s (n=12)
#  Bloc 400  → 0.05321 s (n=12)
#  Bloc 416  → 0.01252 s (n=12)
#  Bloc 432  → 0.01024 s (n=12)
#  Bloc 448  → 0.01094 s (n=12)
#  Bloc 464  → 0.07146 s (n=12)
#  Bloc 480  → 0.01150 s (n=12)
#  Bloc 496  → 0.01168 s (n=12)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00455)
#   -> Bloc 80 vs Bloc 16: p=0.0439
#   -> Bloc 80 vs Bloc 32: p=0.0363
#   -> Bloc 80 vs Bloc 48: p=0.1316
#   -> Bloc 80 vs Bloc 64: p=0.1521
#   -> Bloc 80 vs Bloc 96: p=0.0845
#   -> Bloc 80 vs Bloc 112: p=0.0788
#   -> Bloc 80 vs Bloc 128: p=0.0277
#   -> Bloc 80 vs Bloc 144: p=0.0297
#   -> Bloc 80 vs Bloc 160: p=0.1084
#   -> Bloc 80 vs Bloc 176: p=0.1046
#   -> Bloc 80 vs Bloc 192: p=0.0700
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0425
#   -> Bloc 80 vs Bloc 240: p=0.0489
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0104
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0007
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0029
#   -> Bloc 80 vs Bloc 384: p=0.0047
#   -> Bloc 80 vs Bloc 400: p=0.0100
#   -> Bloc 80 vs Bloc 416: p=0.0013
#   -> Bloc 80 vs Bloc 432: p=0.0093
#   -> Bloc 80 vs Bloc 448: p=0.0052
#   -> Bloc 80 vs Bloc 464: p=0.0009
#   -> Bloc 80 vs Bloc 480: p=0.0059
#   -> Bloc 80 vs Bloc 496: p=0.0073
#
# 🔁 Itération 11 : mesure de tous les blocs
#  Bloc 16   → 0.06524 s (n=13)
#  Bloc 32   → 0.00764 s (n=13)
#  Bloc 48   → 0.00319 s (n=13)
#  Bloc 64   → 0.00382 s (n=13)
#  Bloc 80   → 0.00348 s (n=13)
#  Bloc 96   → 0.00375 s (n=13)
#  Bloc 112  → 0.00421 s (n=13)
#  Bloc 128  → 0.00482 s (n=13)
#  Bloc 144  → 0.00434 s (n=13)
#  Bloc 160  → 0.06509 s (n=13)
#  Bloc 176  → 0.00768 s (n=13)
#  Bloc 192  → 0.00784 s (n=13)
#  Bloc 208  → 0.00853 s (n=13)
#  Bloc 224  → 0.00804 s (n=13)
#  Bloc 240  → 0.00645 s (n=13)
#  Bloc 256  → 0.00783 s (n=13)
#  Bloc 272  → 0.00676 s (n=13)
#  Bloc 288  → 0.00779 s (n=13)
#  Bloc 304  → 0.00762 s (n=13)
#  Bloc 320  → 0.00863 s (n=13)
#  Bloc 336  → 0.01669 s (n=13)
#  Bloc 352  → 0.00966 s (n=13)
#  Bloc 368  → 0.00909 s (n=13)
#  Bloc 384  → 0.01011 s (n=13)
#  Bloc 400  → 0.00972 s (n=13)
#  Bloc 416  → 0.05874 s (n=13)
#  Bloc 432  → 0.01087 s (n=13)
#  Bloc 448  → 0.01102 s (n=13)
#  Bloc 464  → 0.01125 s (n=13)
#  Bloc 480  → 0.06875 s (n=13)
#  Bloc 496  → 0.01573 s (n=13)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00447)
#   -> Bloc 80 vs Bloc 16: p=0.0233
#   -> Bloc 80 vs Bloc 32: p=0.0331
#   -> Bloc 80 vs Bloc 48: p=0.1326
#   -> Bloc 80 vs Bloc 64: p=0.1503
#   -> Bloc 80 vs Bloc 96: p=0.0840
#   -> Bloc 80 vs Bloc 112: p=0.0775
#   -> Bloc 80 vs Bloc 128: p=0.0272
#   -> Bloc 80 vs Bloc 144: p=0.0235
#   -> Bloc 80 vs Bloc 160: p=0.0541
#   -> Bloc 80 vs Bloc 176: p=0.0920
#   -> Bloc 80 vs Bloc 192: p=0.0584
#   -> Bloc 80 vs Bloc 208: p=0.0000
#   -> Bloc 80 vs Bloc 224: p=0.0342
#   -> Bloc 80 vs Bloc 240: p=0.0428
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0075
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0002
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0020
#   -> Bloc 80 vs Bloc 384: p=0.0035
#   -> Bloc 80 vs Bloc 400: p=0.0080
#   -> Bloc 80 vs Bloc 416: p=0.0005
#   -> Bloc 80 vs Bloc 432: p=0.0073
#   -> Bloc 80 vs Bloc 448: p=0.0043
#   -> Bloc 80 vs Bloc 464: p=0.0009
#   -> Bloc 80 vs Bloc 480: p=0.0026
#   -> Bloc 80 vs Bloc 496: p=0.0051
#
# 🔁 Itération 12 : mesure de tous les blocs
#  Bloc 16   → 0.00586 s (n=14)
#  Bloc 32   → 0.00361 s (n=14)
#  Bloc 48   → 0.00316 s (n=14)
#  Bloc 64   → 0.00330 s (n=14)
#  Bloc 80   → 0.00341 s (n=14)
#  Bloc 96   → 0.06301 s (n=14)
#  Bloc 112  → 0.00662 s (n=14)
#  Bloc 128  → 0.00597 s (n=14)
#  Bloc 144  → 0.00756 s (n=14)
#  Bloc 160  → 0.00601 s (n=14)
#  Bloc 176  → 0.00670 s (n=14)
#  Bloc 192  → 0.00649 s (n=14)
#  Bloc 208  → 0.05724 s (n=14)
#  Bloc 224  → 0.01217 s (n=14)
#  Bloc 240  → 0.00770 s (n=14)
#  Bloc 256  → 0.00909 s (n=14)
#  Bloc 272  → 0.00859 s (n=14)
#  Bloc 288  → 0.00893 s (n=14)
#  Bloc 304  → 0.00885 s (n=14)
#  Bloc 320  → 0.00958 s (n=14)
#  Bloc 336  → 0.00948 s (n=14)
#  Bloc 352  → 0.02742 s (n=14)
#  Bloc 368  → 0.01162 s (n=14)
#  Bloc 384  → 0.01122 s (n=14)
#  Bloc 400  → 0.01077 s (n=14)
#  Bloc 416  → 0.06123 s (n=14)
#  Bloc 432  → 0.01681 s (n=14)
#  Bloc 448  → 0.01207 s (n=14)
#  Bloc 464  → 0.01155 s (n=14)
#  Bloc 480  → 0.07174 s (n=14)
#  Bloc 496  → 0.01260 s (n=14)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00440)
#   -> Bloc 80 vs Bloc 16: p=0.0220
#   -> Bloc 80 vs Bloc 32: p=0.0333
#   -> Bloc 80 vs Bloc 48: p=0.1334
#   -> Bloc 80 vs Bloc 64: p=0.1506
#   -> Bloc 80 vs Bloc 96: p=0.0410
#   -> Bloc 80 vs Bloc 112: p=0.0717
#   -> Bloc 80 vs Bloc 128: p=0.0258
#   -> Bloc 80 vs Bloc 144: p=0.0078
#   -> Bloc 80 vs Bloc 160: p=0.0507
#   -> Bloc 80 vs Bloc 176: p=0.0830
#   -> Bloc 80 vs Bloc 192: p=0.0512
#   -> Bloc 80 vs Bloc 208: p=0.0554
#   -> Bloc 80 vs Bloc 224: p=0.0226
#   -> Bloc 80 vs Bloc 240: p=0.0350
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0049
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0011
#   -> Bloc 80 vs Bloc 384: p=0.0025
#   -> Bloc 80 vs Bloc 400: p=0.0061
#   -> Bloc 80 vs Bloc 416: p=0.0002
#   -> Bloc 80 vs Bloc 432: p=0.0046
#   -> Bloc 80 vs Bloc 448: p=0.0034
#   -> Bloc 80 vs Bloc 464: p=0.0008
#   -> Bloc 80 vs Bloc 480: p=0.0011
#   -> Bloc 80 vs Bloc 496: p=0.0039
#
# 🔁 Itération 13 : mesure de tous les blocs
#  Bloc 16   → 0.00834 s (n=15)
#  Bloc 32   → 0.06755 s (n=15)
#  Bloc 48   → 0.00655 s (n=15)
#  Bloc 64   → 0.00470 s (n=15)
#  Bloc 80   → 0.00463 s (n=15)
#  Bloc 96   → 0.00493 s (n=15)
#  Bloc 112  → 0.00545 s (n=15)
#  Bloc 128  → 0.00586 s (n=15)
#  Bloc 144  → 0.06485 s (n=15)
#  Bloc 160  → 0.00707 s (n=15)
#  Bloc 176  → 0.00678 s (n=15)
#  Bloc 192  → 0.00690 s (n=15)
#  Bloc 208  → 0.00730 s (n=15)
#  Bloc 224  → 0.00812 s (n=15)
#  Bloc 240  → 0.00779 s (n=15)
#  Bloc 256  → 0.00901 s (n=15)
#  Bloc 272  → 0.00818 s (n=15)
#  Bloc 288  → 0.00908 s (n=15)
#  Bloc 304  → 0.00874 s (n=15)
#  Bloc 320  → 0.00965 s (n=15)
#  Bloc 336  → 0.00948 s (n=15)
#  Bloc 352  → 0.01029 s (n=15)
#  Bloc 368  → 0.00989 s (n=15)
#  Bloc 384  → 0.01116 s (n=15)
#  Bloc 400  → 0.01071 s (n=15)
#  Bloc 416  → 0.05810 s (n=15)
#  Bloc 432  → 0.01305 s (n=15)
#  Bloc 448  → 0.01199 s (n=15)
#  Bloc 464  → 0.06759 s (n=15)
#  Bloc 480  → 0.01637 s (n=15)
#  Bloc 496  → 0.01259 s (n=15)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00441)
#   -> Bloc 80 vs Bloc 16: p=0.0199
#   -> Bloc 80 vs Bloc 32: p=0.0165
#   -> Bloc 80 vs Bloc 48: p=0.1257
#   -> Bloc 80 vs Bloc 64: p=0.1496
#   -> Bloc 80 vs Bloc 96: p=0.0408
#   -> Bloc 80 vs Bloc 112: p=0.0701
#   -> Bloc 80 vs Bloc 128: p=0.0251
#   -> Bloc 80 vs Bloc 144: p=0.1208
#   -> Bloc 80 vs Bloc 160: p=0.0475
#   -> Bloc 80 vs Bloc 176: p=0.0772
#   -> Bloc 80 vs Bloc 192: p=0.0461
#   -> Bloc 80 vs Bloc 208: p=0.0497
#   -> Bloc 80 vs Bloc 224: p=0.0187
#   -> Bloc 80 vs Bloc 240: p=0.0298
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0034
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0007
#   -> Bloc 80 vs Bloc 384: p=0.0018
#   -> Bloc 80 vs Bloc 400: p=0.0048
#   -> Bloc 80 vs Bloc 416: p=0.0001
#   -> Bloc 80 vs Bloc 432: p=0.0034
#   -> Bloc 80 vs Bloc 448: p=0.0027
#   -> Bloc 80 vs Bloc 464: p=0.0003
#   -> Bloc 80 vs Bloc 480: p=0.0009
#   -> Bloc 80 vs Bloc 496: p=0.0030
#
# 🔁 Itération 14 : mesure de tous les blocs
#  Bloc 16   → 0.00731 s (n=16)
#  Bloc 32   → 0.05740 s (n=16)
#  Bloc 48   → 0.00843 s (n=16)
#  Bloc 64   → 0.00586 s (n=16)
#  Bloc 80   → 0.00449 s (n=16)
#  Bloc 96   → 0.00481 s (n=16)
#  Bloc 112  → 0.00511 s (n=16)
#  Bloc 128  → 0.00580 s (n=16)
#  Bloc 144  → 0.00553 s (n=16)
#  Bloc 160  → 0.06837 s (n=16)
#  Bloc 176  → 0.00789 s (n=16)
#  Bloc 192  → 0.00709 s (n=16)
#  Bloc 208  → 0.00768 s (n=16)
#  Bloc 224  → 0.00936 s (n=16)
#  Bloc 240  → 0.00801 s (n=16)
#  Bloc 256  → 0.00880 s (n=16)
#  Bloc 272  → 0.00825 s (n=16)
#  Bloc 288  → 0.00901 s (n=16)
#  Bloc 304  → 0.00864 s (n=16)
#  Bloc 320  → 0.01257 s (n=16)
#  Bloc 336  → 0.00966 s (n=16)
#  Bloc 352  → 0.01025 s (n=16)
#  Bloc 368  → 0.00987 s (n=16)
#  Bloc 384  → 0.01109 s (n=16)
#  Bloc 400  → 0.01080 s (n=16)
#  Bloc 416  → 0.05959 s (n=16)
#  Bloc 432  → 0.01242 s (n=16)
#  Bloc 448  → 0.01201 s (n=16)
#  Bloc 464  → 0.07095 s (n=16)
#  Bloc 480  → 0.01454 s (n=16)
#  Bloc 496  → 0.01227 s (n=16)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00442)
#   -> Bloc 80 vs Bloc 16: p=0.0184
#   -> Bloc 80 vs Bloc 32: p=0.0080
#   -> Bloc 80 vs Bloc 48: p=0.1118
#   -> Bloc 80 vs Bloc 64: p=0.1432
#   -> Bloc 80 vs Bloc 96: p=0.0405
#   -> Bloc 80 vs Bloc 112: p=0.0688
#   -> Bloc 80 vs Bloc 128: p=0.0244
#   -> Bloc 80 vs Bloc 144: p=0.1170
#   -> Bloc 80 vs Bloc 160: p=0.0245
#   -> Bloc 80 vs Bloc 176: p=0.0690
#   -> Bloc 80 vs Bloc 192: p=0.0409
#   -> Bloc 80 vs Bloc 208: p=0.0436
#   -> Bloc 80 vs Bloc 224: p=0.0144
#   -> Bloc 80 vs Bloc 240: p=0.0249
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0024
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0005
#   -> Bloc 80 vs Bloc 384: p=0.0013
#   -> Bloc 80 vs Bloc 400: p=0.0037
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0025
#   -> Bloc 80 vs Bloc 448: p=0.0022
#   -> Bloc 80 vs Bloc 464: p=0.0001
#   -> Bloc 80 vs Bloc 480: p=0.0007
#   -> Bloc 80 vs Bloc 496: p=0.0024
#
# 🔁 Itération 15 : mesure de tous les blocs
#  Bloc 16   → 0.06973 s (n=17)
#  Bloc 32   → 0.00526 s (n=17)
#  Bloc 48   → 0.00446 s (n=17)
#  Bloc 64   → 0.00446 s (n=17)
#  Bloc 80   → 0.00451 s (n=17)
#  Bloc 96   → 0.00483 s (n=17)
#  Bloc 112  → 0.00507 s (n=17)
#  Bloc 128  → 0.06188 s (n=17)
#  Bloc 144  → 0.00524 s (n=17)
#  Bloc 160  → 0.00681 s (n=17)
#  Bloc 176  → 0.00601 s (n=17)
#  Bloc 192  → 0.00636 s (n=17)
#  Bloc 208  → 0.00668 s (n=17)
#  Bloc 224  → 0.00798 s (n=17)
#  Bloc 240  → 0.00762 s (n=17)
#  Bloc 256  → 0.00887 s (n=17)
#  Bloc 272  → 0.00806 s (n=17)
#  Bloc 288  → 0.00909 s (n=17)
#  Bloc 304  → 0.00889 s (n=17)
#  Bloc 320  → 0.00958 s (n=17)
#  Bloc 336  → 0.01214 s (n=17)
#  Bloc 352  → 0.01004 s (n=17)
#  Bloc 368  → 0.01542 s (n=17)
#  Bloc 384  → 0.01089 s (n=17)
#  Bloc 400  → 0.01069 s (n=17)
#  Bloc 416  → 0.06069 s (n=17)
#  Bloc 432  → 0.01108 s (n=17)
#  Bloc 448  → 0.01195 s (n=17)
#  Bloc 464  → 0.06726 s (n=17)
#  Bloc 480  → 0.01629 s (n=17)
#  Bloc 496  → 0.01236 s (n=17)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00442)
#   -> Bloc 80 vs Bloc 16: p=0.0100
#   -> Bloc 80 vs Bloc 32: p=0.0080
#   -> Bloc 80 vs Bloc 48: p=0.1116
#   -> Bloc 80 vs Bloc 64: p=0.1429
#   -> Bloc 80 vs Bloc 96: p=0.0403
#   -> Bloc 80 vs Bloc 112: p=0.0678
#   -> Bloc 80 vs Bloc 128: p=0.0121
#   -> Bloc 80 vs Bloc 144: p=0.1142
#   -> Bloc 80 vs Bloc 160: p=0.0232
#   -> Bloc 80 vs Bloc 176: p=0.0654
#   -> Bloc 80 vs Bloc 192: p=0.0374
#   -> Bloc 80 vs Bloc 208: p=0.0398
#   -> Bloc 80 vs Bloc 224: p=0.0118
#   -> Bloc 80 vs Bloc 240: p=0.0212
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0016
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0002
#   -> Bloc 80 vs Bloc 384: p=0.0010
#   -> Bloc 80 vs Bloc 400: p=0.0029
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0020
#   -> Bloc 80 vs Bloc 448: p=0.0017
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0005
#   -> Bloc 80 vs Bloc 496: p=0.0018
#
# 🔁 Itération 16 : mesure de tous les blocs
#  Bloc 16   → 0.06992 s (n=18)
#  Bloc 32   → 0.00614 s (n=18)
#  Bloc 48   → 0.00447 s (n=18)
#  Bloc 64   → 0.00517 s (n=18)
#  Bloc 80   → 0.00458 s (n=18)
#  Bloc 96   → 0.00488 s (n=18)
#  Bloc 112  → 0.00506 s (n=18)
#  Bloc 128  → 0.06433 s (n=18)
#  Bloc 144  → 0.00538 s (n=18)
#  Bloc 160  → 0.00603 s (n=18)
#  Bloc 176  → 0.00562 s (n=18)
#  Bloc 192  → 0.00632 s (n=18)
#  Bloc 208  → 0.00548 s (n=18)
#  Bloc 224  → 0.00641 s (n=18)
#  Bloc 240  → 0.00638 s (n=18)
#  Bloc 256  → 0.00756 s (n=18)
#  Bloc 272  → 0.00689 s (n=18)
#  Bloc 288  → 0.00778 s (n=18)
#  Bloc 304  → 0.00765 s (n=18)
#  Bloc 320  → 0.00855 s (n=18)
#  Bloc 336  → 0.00842 s (n=18)
#  Bloc 352  → 0.00916 s (n=18)
#  Bloc 368  → 0.00871 s (n=18)
#  Bloc 384  → 0.00988 s (n=18)
#  Bloc 400  → 0.01107 s (n=18)
#  Bloc 416  → 0.01169 s (n=18)
#  Bloc 432  → 0.06177 s (n=18)
#  Bloc 448  → 0.01213 s (n=18)
#  Bloc 464  → 0.01162 s (n=18)
#  Bloc 480  → 0.07202 s (n=18)
#  Bloc 496  → 0.01343 s (n=18)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00443)
#   -> Bloc 80 vs Bloc 16: p=0.0051
#   -> Bloc 80 vs Bloc 32: p=0.0079
#   -> Bloc 80 vs Bloc 48: p=0.1116
#   -> Bloc 80 vs Bloc 64: p=0.1400
#   -> Bloc 80 vs Bloc 96: p=0.0400
#   -> Bloc 80 vs Bloc 112: p=0.0668
#   -> Bloc 80 vs Bloc 128: p=0.0059
#   -> Bloc 80 vs Bloc 144: p=0.1113
#   -> Bloc 80 vs Bloc 160: p=0.0225
#   -> Bloc 80 vs Bloc 176: p=0.0630
#   -> Bloc 80 vs Bloc 192: p=0.0344
#   -> Bloc 80 vs Bloc 208: p=0.0383
#   -> Bloc 80 vs Bloc 224: p=0.0106
#   -> Bloc 80 vs Bloc 240: p=0.0192
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0012
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0007
#   -> Bloc 80 vs Bloc 400: p=0.0022
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0013
#   -> Bloc 80 vs Bloc 448: p=0.0014
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0002
#   -> Bloc 80 vs Bloc 496: p=0.0014
#
# 🔁 Itération 17 : mesure de tous les blocs
#  Bloc 16   → 0.00527 s (n=19)
#  Bloc 32   → 0.00359 s (n=19)
#  Bloc 48   → 0.00396 s (n=19)
#  Bloc 64   → 0.00357 s (n=19)
#  Bloc 80   → 0.00330 s (n=19)
#  Bloc 96   → 0.05932 s (n=19)
#  Bloc 112  → 0.00663 s (n=19)
#  Bloc 128  → 0.00674 s (n=19)
#  Bloc 144  → 0.00646 s (n=19)
#  Bloc 160  → 0.00736 s (n=19)
#  Bloc 176  → 0.00727 s (n=19)
#  Bloc 192  → 0.00779 s (n=19)
#  Bloc 208  → 0.06553 s (n=19)
#  Bloc 224  → 0.00646 s (n=19)
#  Bloc 240  → 0.00645 s (n=19)
#  Bloc 256  → 0.00762 s (n=19)
#  Bloc 272  → 0.00751 s (n=19)
#  Bloc 288  → 0.00787 s (n=19)
#  Bloc 304  → 0.00746 s (n=19)
#  Bloc 320  → 0.00868 s (n=19)
#  Bloc 336  → 0.00890 s (n=19)
#  Bloc 352  → 0.00946 s (n=19)
#  Bloc 368  → 0.02114 s (n=19)
#  Bloc 384  → 0.01033 s (n=19)
#  Bloc 400  → 0.00977 s (n=19)
#  Bloc 416  → 0.01073 s (n=19)
#  Bloc 432  → 0.00994 s (n=19)
#  Bloc 448  → 0.06740 s (n=19)
#  Bloc 464  → 0.01092 s (n=19)
#  Bloc 480  → 0.01209 s (n=19)
#  Bloc 496  → 0.07695 s (n=19)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00437)
#   -> Bloc 80 vs Bloc 16: p=0.0050
#   -> Bloc 80 vs Bloc 32: p=0.0080
#   -> Bloc 80 vs Bloc 48: p=0.1095
#   -> Bloc 80 vs Bloc 64: p=0.1389
#   -> Bloc 80 vs Bloc 96: p=0.0199
#   -> Bloc 80 vs Bloc 112: p=0.0616
#   -> Bloc 80 vs Bloc 128: p=0.0056
#   -> Bloc 80 vs Bloc 144: p=0.1017
#   -> Bloc 80 vs Bloc 160: p=0.0206
#   -> Bloc 80 vs Bloc 176: p=0.0552
#   -> Bloc 80 vs Bloc 192: p=0.0279
#   -> Bloc 80 vs Bloc 208: p=0.0254
#   -> Bloc 80 vs Bloc 224: p=0.0090
#   -> Bloc 80 vs Bloc 240: p=0.0164
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0008
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0005
#   -> Bloc 80 vs Bloc 400: p=0.0017
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0010
#   -> Bloc 80 vs Bloc 448: p=0.0008
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0002
#   -> Bloc 80 vs Bloc 496: p=0.0010
#
# 🔁 Itération 18 : mesure de tous les blocs
#  Bloc 16   → 0.00822 s (n=20)
#  Bloc 32   → 0.00518 s (n=20)
#  Bloc 48   → 0.00444 s (n=20)
#  Bloc 64   → 0.06476 s (n=20)
#  Bloc 80   → 0.00622 s (n=20)
#  Bloc 96   → 0.00583 s (n=20)
#  Bloc 112  → 0.00549 s (n=20)
#  Bloc 128  → 0.00546 s (n=20)
#  Bloc 144  → 0.00444 s (n=20)
#  Bloc 160  → 0.00439 s (n=20)
#  Bloc 176  → 0.00463 s (n=20)
#  Bloc 192  → 0.00530 s (n=20)
#  Bloc 208  → 0.00539 s (n=20)
#  Bloc 224  → 0.04660 s (n=20)
#  Bloc 240  → 0.00908 s (n=20)
#  Bloc 256  → 0.00757 s (n=20)
#  Bloc 272  → 0.00763 s (n=20)
#  Bloc 288  → 0.00813 s (n=20)
#  Bloc 304  → 0.00753 s (n=20)
#  Bloc 320  → 0.00864 s (n=20)
#  Bloc 336  → 0.00844 s (n=20)
#  Bloc 352  → 0.00908 s (n=20)
#  Bloc 368  → 0.03608 s (n=20)
#  Bloc 384  → 0.00987 s (n=20)
#  Bloc 400  → 0.00968 s (n=20)
#  Bloc 416  → 0.01051 s (n=20)
#  Bloc 432  → 0.00999 s (n=20)
#  Bloc 448  → 0.06259 s (n=20)
#  Bloc 464  → 0.01275 s (n=20)
#  Bloc 480  → 0.01271 s (n=20)
#  Bloc 496  → 0.07084 s (n=20)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00446)
#   -> Bloc 80 vs Bloc 16: p=0.0048
#   -> Bloc 80 vs Bloc 32: p=0.0083
#   -> Bloc 80 vs Bloc 48: p=0.1150
#   -> Bloc 80 vs Bloc 64: p=0.0738
#   -> Bloc 80 vs Bloc 96: p=0.0200
#   -> Bloc 80 vs Bloc 112: p=0.0625
#   -> Bloc 80 vs Bloc 128: p=0.0058
#   -> Bloc 80 vs Bloc 144: p=0.1066
#   -> Bloc 80 vs Bloc 160: p=0.0215
#   -> Bloc 80 vs Bloc 176: p=0.0579
#   -> Bloc 80 vs Bloc 192: p=0.0290
#   -> Bloc 80 vs Bloc 208: p=0.0259
#   -> Bloc 80 vs Bloc 224: p=0.0072
#   -> Bloc 80 vs Bloc 240: p=0.0139
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0007
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0004
#   -> Bloc 80 vs Bloc 400: p=0.0014
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0009
#   -> Bloc 80 vs Bloc 448: p=0.0004
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0002
#   -> Bloc 80 vs Bloc 496: p=0.0006
#
# 🔁 Itération 19 : mesure de tous les blocs
#  Bloc 16   → 0.00798 s (n=21)
#  Bloc 32   → 0.00520 s (n=21)
#  Bloc 48   → 0.00443 s (n=21)
#  Bloc 64   → 0.00445 s (n=21)
#  Bloc 80   → 0.00355 s (n=21)
#  Bloc 96   → 0.06469 s (n=21)
#  Bloc 112  → 0.00810 s (n=21)
#  Bloc 128  → 0.00528 s (n=21)
#  Bloc 144  → 0.00377 s (n=21)
#  Bloc 160  → 0.00483 s (n=21)
#  Bloc 176  → 0.00629 s (n=21)
#  Bloc 192  → 0.00559 s (n=21)
#  Bloc 208  → 0.00538 s (n=21)
#  Bloc 224  → 0.00630 s (n=21)
#  Bloc 240  → 0.00641 s (n=21)
#  Bloc 256  → 0.00776 s (n=21)
#  Bloc 272  → 0.00715 s (n=21)
#  Bloc 288  → 0.03127 s (n=21)
#  Bloc 304  → 0.00769 s (n=21)
#  Bloc 320  → 0.00863 s (n=21)
#  Bloc 336  → 0.00830 s (n=21)
#  Bloc 352  → 0.00912 s (n=21)
#  Bloc 368  → 0.00874 s (n=21)
#  Bloc 384  → 0.00980 s (n=21)
#  Bloc 400  → 0.05498 s (n=21)
#  Bloc 416  → 0.01070 s (n=21)
#  Bloc 432  → 0.01029 s (n=21)
#  Bloc 448  → 0.01151 s (n=21)
#  Bloc 464  → 0.06576 s (n=21)
#  Bloc 480  → 0.01211 s (n=21)
#  Bloc 496  → 0.01194 s (n=21)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00442)
#   -> Bloc 80 vs Bloc 16: p=0.0043
#   -> Bloc 80 vs Bloc 32: p=0.0081
#   -> Bloc 80 vs Bloc 48: p=0.1120
#   -> Bloc 80 vs Bloc 64: p=0.0723
#   -> Bloc 80 vs Bloc 96: p=0.0099
#   -> Bloc 80 vs Bloc 112: p=0.0559
#   -> Bloc 80 vs Bloc 128: p=0.0056
#   -> Bloc 80 vs Bloc 144: p=0.1060
#   -> Bloc 80 vs Bloc 160: p=0.0210
#   -> Bloc 80 vs Bloc 176: p=0.0528
#   -> Bloc 80 vs Bloc 192: p=0.0264
#   -> Bloc 80 vs Bloc 208: p=0.0246
#   -> Bloc 80 vs Bloc 224: p=0.0064
#   -> Bloc 80 vs Bloc 240: p=0.0120
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0005
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0003
#   -> Bloc 80 vs Bloc 400: p=0.0009
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0007
#   -> Bloc 80 vs Bloc 448: p=0.0003
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0002
#   -> Bloc 80 vs Bloc 496: p=0.0005
#
# 🔁 Itération 20 : mesure de tous les blocs
#  Bloc 16   → 0.01109 s (n=22)
#  Bloc 32   → 0.00578 s (n=22)
#  Bloc 48   → 0.00449 s (n=22)
#  Bloc 64   → 0.00448 s (n=22)
#  Bloc 80   → 0.00454 s (n=22)
#  Bloc 96   → 0.00483 s (n=22)
#  Bloc 112  → 0.06340 s (n=22)
#  Bloc 128  → 0.00765 s (n=22)
#  Bloc 144  → 0.00484 s (n=22)
#  Bloc 160  → 0.00553 s (n=22)
#  Bloc 176  → 0.00479 s (n=22)
#  Bloc 192  → 0.00540 s (n=22)
#  Bloc 208  → 0.00537 s (n=22)
#  Bloc 224  → 0.00635 s (n=22)
#  Bloc 240  → 0.00620 s (n=22)
#  Bloc 256  → 0.00854 s (n=22)
#  Bloc 272  → 0.00695 s (n=22)
#  Bloc 288  → 0.00780 s (n=22)
#  Bloc 304  → 0.00761 s (n=22)
#  Bloc 320  → 0.00955 s (n=22)
#  Bloc 336  → 0.00857 s (n=22)
#  Bloc 352  → 0.00937 s (n=22)
#  Bloc 368  → 0.00917 s (n=22)
#  Bloc 384  → 0.01009 s (n=22)
#  Bloc 400  → 0.00985 s (n=22)
#  Bloc 416  → 0.01067 s (n=22)
#  Bloc 432  → 0.05777 s (n=22)
#  Bloc 448  → 0.01324 s (n=22)
#  Bloc 464  → 0.01074 s (n=22)
#  Bloc 480  → 0.01114 s (n=22)
#  Bloc 496  → 0.07456 s (n=22)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00443)
#   -> Bloc 80 vs Bloc 16: p=0.0037
#   -> Bloc 80 vs Bloc 32: p=0.0079
#   -> Bloc 80 vs Bloc 48: p=0.1119
#   -> Bloc 80 vs Bloc 64: p=0.0723
#   -> Bloc 80 vs Bloc 96: p=0.0100
#   -> Bloc 80 vs Bloc 112: p=0.0290
#   -> Bloc 80 vs Bloc 128: p=0.0053
#   -> Bloc 80 vs Bloc 144: p=0.1049
#   -> Bloc 80 vs Bloc 160: p=0.0205
#   -> Bloc 80 vs Bloc 176: p=0.0523
#   -> Bloc 80 vs Bloc 192: p=0.0253
#   -> Bloc 80 vs Bloc 208: p=0.0241
#   -> Bloc 80 vs Bloc 224: p=0.0059
#   -> Bloc 80 vs Bloc 240: p=0.0109
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0003
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0002
#   -> Bloc 80 vs Bloc 400: p=0.0008
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0004
#   -> Bloc 80 vs Bloc 448: p=0.0002
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0001
#   -> Bloc 80 vs Bloc 496: p=0.0002
#
# 🔁 Itération 21 : mesure de tous les blocs
#  Bloc 16   → 0.00985 s (n=23)
#  Bloc 32   → 0.06483 s (n=23)
#  Bloc 48   → 0.00538 s (n=23)
#  Bloc 64   → 0.00501 s (n=23)
#  Bloc 80   → 0.00454 s (n=23)
#  Bloc 96   → 0.00480 s (n=23)
#  Bloc 112  → 0.00524 s (n=23)
#  Bloc 128  → 0.00555 s (n=23)
#  Bloc 144  → 0.00444 s (n=23)
#  Bloc 160  → 0.00535 s (n=23)
#  Bloc 176  → 0.00544 s (n=23)
#  Bloc 192  → 0.00619 s (n=23)
#  Bloc 208  → 0.04372 s (n=23)
#  Bloc 224  → 0.00819 s (n=23)
#  Bloc 240  → 0.00800 s (n=23)
#  Bloc 256  → 0.00912 s (n=23)
#  Bloc 272  → 0.00856 s (n=23)
#  Bloc 288  → 0.00928 s (n=23)
#  Bloc 304  → 0.00932 s (n=23)
#  Bloc 320  → 0.00980 s (n=23)
#  Bloc 336  → 0.00971 s (n=23)
#  Bloc 352  → 0.03072 s (n=23)
#  Bloc 368  → 0.01090 s (n=23)
#  Bloc 384  → 0.01161 s (n=23)
#  Bloc 400  → 0.01204 s (n=23)
#  Bloc 416  → 0.06166 s (n=23)
#  Bloc 432  → 0.01667 s (n=23)
#  Bloc 448  → 0.01202 s (n=23)
#  Bloc 464  → 0.01156 s (n=23)
#  Bloc 480  → 0.07305 s (n=23)
#  Bloc 496  → 0.01285 s (n=23)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00443)
#   -> Bloc 80 vs Bloc 16: p=0.0033
#   -> Bloc 80 vs Bloc 32: p=0.0040
#   -> Bloc 80 vs Bloc 48: p=0.1089
#   -> Bloc 80 vs Bloc 64: p=0.0713
#   -> Bloc 80 vs Bloc 96: p=0.0100
#   -> Bloc 80 vs Bloc 112: p=0.0285
#   -> Bloc 80 vs Bloc 128: p=0.0052
#   -> Bloc 80 vs Bloc 144: p=0.1050
#   -> Bloc 80 vs Bloc 160: p=0.0202
#   -> Bloc 80 vs Bloc 176: p=0.0506
#   -> Bloc 80 vs Bloc 192: p=0.0232
#   -> Bloc 80 vs Bloc 208: p=0.0124
#   -> Bloc 80 vs Bloc 224: p=0.0050
#   -> Bloc 80 vs Bloc 240: p=0.0089
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0002
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0002
#   -> Bloc 80 vs Bloc 400: p=0.0006
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0003
#   -> Bloc 80 vs Bloc 448: p=0.0002
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0001
#   -> Bloc 80 vs Bloc 496: p=0.0002
#
# 🔁 Itération 22 : mesure de tous les blocs
#  Bloc 16   → 0.00757 s (n=24)
#  Bloc 32   → 0.05607 s (n=24)
#  Bloc 48   → 0.00571 s (n=24)
#  Bloc 64   → 0.00500 s (n=24)
#  Bloc 80   → 0.00454 s (n=24)
#  Bloc 96   → 0.00482 s (n=24)
#  Bloc 112  → 0.00507 s (n=24)
#  Bloc 128  → 0.00556 s (n=24)
#  Bloc 144  → 0.00536 s (n=24)
#  Bloc 160  → 0.06296 s (n=24)
#  Bloc 176  → 0.00800 s (n=24)
#  Bloc 192  → 0.00728 s (n=24)
#  Bloc 208  → 0.00685 s (n=24)
#  Bloc 224  → 0.00795 s (n=24)
#  Bloc 240  → 0.00865 s (n=24)
#  Bloc 256  → 0.01497 s (n=24)
#  Bloc 272  → 0.00895 s (n=24)
#  Bloc 288  → 0.00907 s (n=24)
#  Bloc 304  → 0.00882 s (n=24)
#  Bloc 320  → 0.01780 s (n=24)
#  Bloc 336  → 0.01049 s (n=24)
#  Bloc 352  → 0.00933 s (n=24)
#  Bloc 368  → 0.00896 s (n=24)
#  Bloc 384  → 0.01014 s (n=24)
#  Bloc 400  → 0.00985 s (n=24)
#  Bloc 416  → 0.06666 s (n=24)
#  Bloc 432  → 0.01138 s (n=24)
#  Bloc 448  → 0.01202 s (n=24)
#  Bloc 464  → 0.07511 s (n=24)
#  Bloc 480  → 0.01267 s (n=24)
#  Bloc 496  → 0.01236 s (n=24)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00444)
#   -> Bloc 80 vs Bloc 16: p=0.0031
#   -> Bloc 80 vs Bloc 32: p=0.0020
#   -> Bloc 80 vs Bloc 48: p=0.1049
#   -> Bloc 80 vs Bloc 64: p=0.0704
#   -> Bloc 80 vs Bloc 96: p=0.0100
#   -> Bloc 80 vs Bloc 112: p=0.0282
#   -> Bloc 80 vs Bloc 128: p=0.0052
#   -> Bloc 80 vs Bloc 144: p=0.1023
#   -> Bloc 80 vs Bloc 160: p=0.0104
#   -> Bloc 80 vs Bloc 176: p=0.0448
#   -> Bloc 80 vs Bloc 192: p=0.0202
#   -> Bloc 80 vs Bloc 208: p=0.0116
#   -> Bloc 80 vs Bloc 224: p=0.0042
#   -> Bloc 80 vs Bloc 240: p=0.0070
#   -> Bloc 80 vs Bloc 256: p=0.0000
#   -> Bloc 80 vs Bloc 272: p=0.0000
#   -> Bloc 80 vs Bloc 288: p=0.0000
#   -> Bloc 80 vs Bloc 304: p=0.0001
#   -> Bloc 80 vs Bloc 320: p=0.0000
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0001
#   -> Bloc 80 vs Bloc 400: p=0.0005
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0002
#   -> Bloc 80 vs Bloc 448: p=0.0002
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0001
#   -> Bloc 80 vs Bloc 496: p=0.0002
#
# 🔁 Itération 23 : mesure de tous les blocs
#  Bloc 16   → 0.00908 s (n=25)
#  Bloc 32   → 0.00529 s (n=25)
#  Bloc 48   → 0.00448 s (n=25)
#  Bloc 64   → 0.00451 s (n=25)
#  Bloc 80   → 0.00451 s (n=25)
#  Bloc 96   → 0.00480 s (n=25)
#  Bloc 112  → 0.06397 s (n=25)
#  Bloc 128  → 0.00686 s (n=25)
#  Bloc 144  → 0.00565 s (n=25)
#  Bloc 160  → 0.00529 s (n=25)
#  Bloc 176  → 0.00494 s (n=25)
#  Bloc 192  → 0.00561 s (n=25)
#  Bloc 208  → 0.00733 s (n=25)
#  Bloc 224  → 0.00815 s (n=25)
#  Bloc 240  → 0.00799 s (n=25)
#  Bloc 256  → 0.00898 s (n=25)
#  Bloc 272  → 0.00824 s (n=25)
#  Bloc 288  → 0.00902 s (n=25)
#  Bloc 304  → 0.00885 s (n=25)
#  Bloc 320  → 0.00957 s (n=25)
#  Bloc 336  → 0.00949 s (n=25)
#  Bloc 352  → 0.01031 s (n=25)
#  Bloc 368  → 0.00994 s (n=25)
#  Bloc 384  → 0.01113 s (n=25)
#  Bloc 400  → 0.01060 s (n=25)
#  Bloc 416  → 0.05770 s (n=25)
#  Bloc 432  → 0.01131 s (n=25)
#  Bloc 448  → 0.01198 s (n=25)
#  Bloc 464  → 0.06942 s (n=25)
#  Bloc 480  → 0.01316 s (n=25)
#  Bloc 496  → 0.01221 s (n=25)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00444)
#   -> Bloc 80 vs Bloc 16: p=0.0028
#   -> Bloc 80 vs Bloc 32: p=0.0020
#   -> Bloc 80 vs Bloc 48: p=0.1049
#   -> Bloc 80 vs Bloc 64: p=0.0704
#   -> Bloc 80 vs Bloc 96: p=0.0100
#   -> Bloc 80 vs Bloc 112: p=0.0147
#   -> Bloc 80 vs Bloc 128: p=0.0049
#   -> Bloc 80 vs Bloc 144: p=0.0989
#   -> Bloc 80 vs Bloc 160: p=0.0103
#   -> Bloc 80 vs Bloc 176: p=0.0440
#   -> Bloc 80 vs Bloc 192: p=0.0191
#   -> Bloc 80 vs Bloc 208: p=0.0106
#   -> Bloc 80 vs Bloc 224: p=0.0036
#   -> Bloc 80 vs Bloc 240: p=0.0057
#   -> Bloc 80 vs Bloc 256: p=0.0000
# ...
#  Bloc 320  → 0.00942 s (n=45)
#  Bloc 336  → 0.01743 s (n=45)
#  Bloc 352  → 0.01001 s (n=45)
#  Bloc 368  → 0.01029 s (n=45)
#  Bloc 384  → 0.01132 s (n=45)
#  Bloc 400  → 0.01051 s (n=45)
#  Bloc 416  → 0.06028 s (n=45)
#  Bloc 432  → 0.01215 s (n=45)
#  Bloc 448  → 0.01177 s (n=45)
#  Bloc 464  → 0.07163 s (n=45)
#  Bloc 480  → 0.01513 s (n=45)
#  Bloc 496  → 0.01218 s (n=45)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00585)
#   -> Bloc 80 vs Bloc 16: p=0.0003
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3536
#   -> Bloc 80 vs Bloc 64: p=0.1501
#   -> Bloc 80 vs Bloc 96: p=0.0379
#   -> Bloc 80 vs Bloc 112: p=0.0090
#   -> Bloc 80 vs Bloc 128: p=0.0013
#   -> Bloc 80 vs Bloc 144: p=0.0273
#   -> Bloc 80 vs Bloc 160: p=0.0023
#   -> Bloc 80 vs Bloc 176: p=0.0896
#   -> Bloc 80 vs Bloc 192: p=0.0275
#   -> Bloc 80 vs Bloc 208: p=0.0317
#   -> Bloc 80 vs Bloc 224: p=0.0162
#   -> Bloc 80 vs Bloc 240: p=0.0766
#   -> Bloc 80 vs Bloc 256: p=0.0165
#   -> Bloc 80 vs Bloc 272: p=0.0792
#   -> Bloc 80 vs Bloc 288: p=0.0056
#   -> Bloc 80 vs Bloc 304: p=0.0150
#   -> Bloc 80 vs Bloc 320: p=0.0019
#   -> Bloc 80 vs Bloc 336: p=0.0005
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0001
#   -> Bloc 80 vs Bloc 400: p=0.0002
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 44 : mesure de tous les blocs
#  Bloc 16   → 0.05928 s (n=46)
#  Bloc 32   → 0.00565 s (n=46)
#  Bloc 48   → 0.00449 s (n=46)
#  Bloc 64   → 0.00451 s (n=46)
#  Bloc 80   → 0.00452 s (n=46)
#  Bloc 96   → 0.00484 s (n=46)
#  Bloc 112  → 0.00508 s (n=46)
#  Bloc 128  → 0.00562 s (n=46)
#  Bloc 144  → 0.06168 s (n=46)
#  Bloc 160  → 0.00623 s (n=46)
#  Bloc 176  → 0.00478 s (n=46)
#  Bloc 192  → 0.00520 s (n=46)
#  Bloc 208  → 0.00535 s (n=46)
#  Bloc 224  → 0.00645 s (n=46)
#  Bloc 240  → 0.00649 s (n=46)
#  Bloc 256  → 0.00909 s (n=46)
#  Bloc 272  → 0.00818 s (n=46)
#  Bloc 288  → 0.00888 s (n=46)
#  Bloc 304  → 0.00905 s (n=46)
#  Bloc 320  → 0.01004 s (n=46)
#  Bloc 336  → 0.01724 s (n=46)
#  Bloc 352  → 0.01000 s (n=46)
#  Bloc 368  → 0.00984 s (n=46)
#  Bloc 384  → 0.01106 s (n=46)
#  Bloc 400  → 0.01055 s (n=46)
#  Bloc 416  → 0.06188 s (n=46)
#  Bloc 432  → 0.01449 s (n=46)
#  Bloc 448  → 0.01170 s (n=46)
#  Bloc 464  → 0.01133 s (n=46)
#  Bloc 480  → 0.07582 s (n=46)
#  Bloc 496  → 0.01236 s (n=46)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00582)
#   -> Bloc 80 vs Bloc 16: p=0.0002
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3537
#   -> Bloc 80 vs Bloc 64: p=0.1501
#   -> Bloc 80 vs Bloc 96: p=0.0378
#   -> Bloc 80 vs Bloc 112: p=0.0090
#   -> Bloc 80 vs Bloc 128: p=0.0012
#   -> Bloc 80 vs Bloc 144: p=0.0147
#   -> Bloc 80 vs Bloc 160: p=0.0023
#   -> Bloc 80 vs Bloc 176: p=0.0892
#   -> Bloc 80 vs Bloc 192: p=0.0272
#   -> Bloc 80 vs Bloc 208: p=0.0312
#   -> Bloc 80 vs Bloc 224: p=0.0154
#   -> Bloc 80 vs Bloc 240: p=0.0728
#   -> Bloc 80 vs Bloc 256: p=0.0136
#   -> Bloc 80 vs Bloc 272: p=0.0705
#   -> Bloc 80 vs Bloc 288: p=0.0046
#   -> Bloc 80 vs Bloc 304: p=0.0126
#   -> Bloc 80 vs Bloc 320: p=0.0014
#   -> Bloc 80 vs Bloc 336: p=0.0003
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0001
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 45 : mesure de tous les blocs
#  Bloc 16   → 0.00632 s (n=47)
#  Bloc 32   → 0.06195 s (n=47)
#  Bloc 48   → 0.00698 s (n=47)
#  Bloc 64   → 0.00453 s (n=47)
#  Bloc 80   → 0.00451 s (n=47)
#  Bloc 96   → 0.00485 s (n=47)
#  Bloc 112  → 0.00507 s (n=47)
#  Bloc 128  → 0.00555 s (n=47)
#  Bloc 144  → 0.06163 s (n=47)
#  Bloc 160  → 0.00650 s (n=47)
#  Bloc 176  → 0.00577 s (n=47)
#  Bloc 192  → 0.00676 s (n=47)
#  Bloc 208  → 0.00596 s (n=47)
#  Bloc 224  → 0.00637 s (n=47)
#  Bloc 240  → 0.00617 s (n=47)
#  Bloc 256  → 0.00850 s (n=47)
#  Bloc 272  → 0.00806 s (n=47)
#  Bloc 288  → 0.00891 s (n=47)
#  Bloc 304  → 0.00876 s (n=47)
#  Bloc 320  → 0.00935 s (n=47)
#  Bloc 336  → 0.01755 s (n=47)
#  Bloc 352  → 0.01005 s (n=47)
#  Bloc 368  → 0.00972 s (n=47)
#  Bloc 384  → 0.01097 s (n=47)
#  Bloc 400  → 0.01037 s (n=47)
#  Bloc 416  → 0.06305 s (n=47)
#  Bloc 432  → 0.01167 s (n=47)
#  Bloc 448  → 0.01180 s (n=47)
#  Bloc 464  → 0.01143 s (n=47)
#  Bloc 480  → 0.07011 s (n=47)
#  Bloc 496  → 0.01218 s (n=47)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00580)
#   -> Bloc 80 vs Bloc 16: p=0.0002
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3423
#   -> Bloc 80 vs Bloc 64: p=0.1502
#   -> Bloc 80 vs Bloc 96: p=0.0377
#   -> Bloc 80 vs Bloc 112: p=0.0090
#   -> Bloc 80 vs Bloc 128: p=0.0012
#   -> Bloc 80 vs Bloc 144: p=0.0078
#   -> Bloc 80 vs Bloc 160: p=0.0022
#   -> Bloc 80 vs Bloc 176: p=0.0873
#   -> Bloc 80 vs Bloc 192: p=0.0260
#   -> Bloc 80 vs Bloc 208: p=0.0303
#   -> Bloc 80 vs Bloc 224: p=0.0147
#   -> Bloc 80 vs Bloc 240: p=0.0697
#   -> Bloc 80 vs Bloc 256: p=0.0115
#   -> Bloc 80 vs Bloc 272: p=0.0627
#   -> Bloc 80 vs Bloc 288: p=0.0038
#   -> Bloc 80 vs Bloc 304: p=0.0106
#   -> Bloc 80 vs Bloc 320: p=0.0011
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0001
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 46 : mesure de tous les blocs
#  Bloc 16   → 0.00789 s (n=48)
#  Bloc 32   → 0.06667 s (n=48)
#  Bloc 48   → 0.00454 s (n=48)
#  Bloc 64   → 0.00461 s (n=48)
#  Bloc 80   → 0.00450 s (n=48)
#  Bloc 96   → 0.00483 s (n=48)
#  Bloc 112  → 0.00571 s (n=48)
#  Bloc 128  → 0.00576 s (n=48)
#  Bloc 144  → 0.06337 s (n=48)
#  Bloc 160  → 0.00838 s (n=48)
#  Bloc 176  → 0.00486 s (n=48)
#  Bloc 192  → 0.00557 s (n=48)
#  Bloc 208  → 0.00564 s (n=48)
#  Bloc 224  → 0.00677 s (n=48)
#  Bloc 240  → 0.00672 s (n=48)
#  Bloc 256  → 0.00874 s (n=48)
#  Bloc 272  → 0.00827 s (n=48)
#  Bloc 288  → 0.00901 s (n=48)
#  Bloc 304  → 0.00909 s (n=48)
#  Bloc 320  → 0.00962 s (n=48)
#  Bloc 336  → 0.01275 s (n=48)
#  Bloc 352  → 0.01035 s (n=48)
#  Bloc 368  → 0.01006 s (n=48)
#  Bloc 384  → 0.01118 s (n=48)
#  Bloc 400  → 0.01089 s (n=48)
#  Bloc 416  → 0.05584 s (n=48)
#  Bloc 432  → 0.01111 s (n=48)
#  Bloc 448  → 0.01167 s (n=48)
#  Bloc 464  → 0.01041 s (n=48)
#  Bloc 480  → 0.07082 s (n=48)
#  Bloc 496  → 0.01512 s (n=48)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00577)
#   -> Bloc 80 vs Bloc 16: p=0.0002
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3422
#   -> Bloc 80 vs Bloc 64: p=0.1500
#   -> Bloc 80 vs Bloc 96: p=0.0376
#   -> Bloc 80 vs Bloc 112: p=0.0088
#   -> Bloc 80 vs Bloc 128: p=0.0012
#   -> Bloc 80 vs Bloc 144: p=0.0041
#   -> Bloc 80 vs Bloc 160: p=0.0021
#   -> Bloc 80 vs Bloc 176: p=0.0868
#   -> Bloc 80 vs Bloc 192: p=0.0255
#   -> Bloc 80 vs Bloc 208: p=0.0296
#   -> Bloc 80 vs Bloc 224: p=0.0138
#   -> Bloc 80 vs Bloc 240: p=0.0657
#   -> Bloc 80 vs Bloc 256: p=0.0096
#   -> Bloc 80 vs Bloc 272: p=0.0552
#   -> Bloc 80 vs Bloc 288: p=0.0031
#   -> Bloc 80 vs Bloc 304: p=0.0088
#   -> Bloc 80 vs Bloc 320: p=0.0009
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 47 : mesure de tous les blocs
#  Bloc 16   → 0.00520 s (n=49)
#  Bloc 32   → 0.00360 s (n=49)
#  Bloc 48   → 0.00317 s (n=49)
#  Bloc 64   → 0.06439 s (n=49)
#  Bloc 80   → 0.00751 s (n=49)
#  Bloc 96   → 0.00555 s (n=49)
#  Bloc 112  → 0.00527 s (n=49)
#  Bloc 128  → 0.00567 s (n=49)
#  Bloc 144  → 0.07037 s (n=49)
#  Bloc 160  → 0.00825 s (n=49)
#  Bloc 176  → 0.00606 s (n=49)
#  Bloc 192  → 0.00556 s (n=49)
#  Bloc 208  → 0.00681 s (n=49)
#  Bloc 224  → 0.00799 s (n=49)
#  Bloc 240  → 0.00776 s (n=49)
#  Bloc 256  → 0.00886 s (n=49)
#  Bloc 272  → 0.00826 s (n=49)
#  Bloc 288  → 0.00902 s (n=49)
#  Bloc 304  → 0.01066 s (n=49)
#  Bloc 320  → 0.01356 s (n=49)
#  Bloc 336  → 0.00978 s (n=49)
#  Bloc 352  → 0.01063 s (n=49)
#  Bloc 368  → 0.01011 s (n=49)
#  Bloc 384  → 0.01127 s (n=49)
#  Bloc 400  → 0.01069 s (n=49)
#  Bloc 416  → 0.05754 s (n=49)
#  Bloc 432  → 0.01152 s (n=49)
#  Bloc 448  → 0.01185 s (n=49)
#  Bloc 464  → 0.01142 s (n=49)
#  Bloc 480  → 0.07452 s (n=49)
#  Bloc 496  → 0.01271 s (n=49)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00580)
#   -> Bloc 80 vs Bloc 16: p=0.0002
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3624
#   -> Bloc 80 vs Bloc 64: p=0.0848
#   -> Bloc 80 vs Bloc 96: p=0.0388
#   -> Bloc 80 vs Bloc 112: p=0.0092
#   -> Bloc 80 vs Bloc 128: p=0.0013
#   -> Bloc 80 vs Bloc 144: p=0.0023
#   -> Bloc 80 vs Bloc 160: p=0.0021
#   -> Bloc 80 vs Bloc 176: p=0.0891
#   -> Bloc 80 vs Bloc 192: p=0.0266
#   -> Bloc 80 vs Bloc 208: p=0.0301
#   -> Bloc 80 vs Bloc 224: p=0.0137
#   -> Bloc 80 vs Bloc 240: p=0.0653
#   -> Bloc 80 vs Bloc 256: p=0.0090
#   -> Bloc 80 vs Bloc 272: p=0.0538
#   -> Bloc 80 vs Bloc 288: p=0.0029
#   -> Bloc 80 vs Bloc 304: p=0.0078
#   -> Bloc 80 vs Bloc 320: p=0.0006
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 48 : mesure de tous les blocs
#  Bloc 16   → 0.07072 s (n=50)
#  Bloc 32   → 0.00537 s (n=50)
#  Bloc 48   → 0.00446 s (n=50)
#  Bloc 64   → 0.00454 s (n=50)
#  Bloc 80   → 0.00460 s (n=50)
#  Bloc 96   → 0.00485 s (n=50)
#  Bloc 112  → 0.00521 s (n=50)
#  Bloc 128  → 0.06617 s (n=50)
#  Bloc 144  → 0.00687 s (n=50)
#  Bloc 160  → 0.00598 s (n=50)
#  Bloc 176  → 0.00603 s (n=50)
#  Bloc 192  → 0.00701 s (n=50)
#  Bloc 208  → 0.00779 s (n=50)
#  Bloc 224  → 0.00830 s (n=50)
#  Bloc 240  → 0.00776 s (n=50)
#  Bloc 256  → 0.00892 s (n=50)
#  Bloc 272  → 0.00827 s (n=50)
#  Bloc 288  → 0.00913 s (n=50)
#  Bloc 304  → 0.00892 s (n=50)
#  Bloc 320  → 0.00975 s (n=50)
#  Bloc 336  → 0.00956 s (n=50)
#  Bloc 352  → 0.01029 s (n=50)
#  Bloc 368  → 0.00991 s (n=50)
#  Bloc 384  → 0.01111 s (n=50)
#  Bloc 400  → 0.01060 s (n=50)
#  Bloc 416  → 0.05242 s (n=50)
#  Bloc 432  → 0.01128 s (n=50)
#  Bloc 448  → 0.01197 s (n=50)
#  Bloc 464  → 0.06741 s (n=50)
#  Bloc 480  → 0.01339 s (n=50)
#  Bloc 496  → 0.01274 s (n=50)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00578)
#   -> Bloc 80 vs Bloc 16: p=0.0001
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3631
#   -> Bloc 80 vs Bloc 64: p=0.0849
#   -> Bloc 80 vs Bloc 96: p=0.0387
#   -> Bloc 80 vs Bloc 112: p=0.0091
#   -> Bloc 80 vs Bloc 128: p=0.0007
#   -> Bloc 80 vs Bloc 144: p=0.0022
#   -> Bloc 80 vs Bloc 160: p=0.0020
#   -> Bloc 80 vs Bloc 176: p=0.0869
#   -> Bloc 80 vs Bloc 192: p=0.0253
#   -> Bloc 80 vs Bloc 208: p=0.0280
#   -> Bloc 80 vs Bloc 224: p=0.0123
#   -> Bloc 80 vs Bloc 240: p=0.0599
#   -> Bloc 80 vs Bloc 256: p=0.0075
#   -> Bloc 80 vs Bloc 272: p=0.0473
#   -> Bloc 80 vs Bloc 288: p=0.0024
#   -> Bloc 80 vs Bloc 304: p=0.0065
#   -> Bloc 80 vs Bloc 320: p=0.0005
#   -> Bloc 80 vs Bloc 336: p=0.0001
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 49 : mesure de tous les blocs
#  Bloc 16   → 0.06635 s (n=51)
#  Bloc 32   → 0.00807 s (n=51)
#  Bloc 48   → 0.00553 s (n=51)
#  Bloc 64   → 0.00459 s (n=51)
#  Bloc 80   → 0.00451 s (n=51)
#  Bloc 96   → 0.00487 s (n=51)
#  Bloc 112  → 0.00517 s (n=51)
#  Bloc 128  → 0.00550 s (n=51)
#  Bloc 144  → 0.06573 s (n=51)
#  Bloc 160  → 0.00620 s (n=51)
#  Bloc 176  → 0.00543 s (n=51)
#  Bloc 192  → 0.00582 s (n=51)
#  Bloc 208  → 0.00575 s (n=51)
#  Bloc 224  → 0.00626 s (n=51)
#  Bloc 240  → 0.00904 s (n=51)
#  Bloc 256  → 0.00772 s (n=51)
#  Bloc 272  → 0.00718 s (n=51)
#  Bloc 288  → 0.00828 s (n=51)
#  Bloc 304  → 0.00783 s (n=51)
#  Bloc 320  → 0.00933 s (n=51)
#  Bloc 336  → 0.01136 s (n=51)
#  Bloc 352  → 0.01003 s (n=51)
#  Bloc 368  → 0.00976 s (n=51)
#  Bloc 384  → 0.00978 s (n=51)
#  Bloc 400  → 0.00956 s (n=51)
#  Bloc 416  → 0.05859 s (n=51)
#  Bloc 432  → 0.01613 s (n=51)
#  Bloc 448  → 0.01195 s (n=51)
#  Bloc 464  → 0.01189 s (n=51)
#  Bloc 480  → 0.07809 s (n=51)
#  Bloc 496  → 0.01213 s (n=51)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00576)
#   -> Bloc 80 vs Bloc 16: p=0.0000
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3583
#   -> Bloc 80 vs Bloc 64: p=0.0849
#   -> Bloc 80 vs Bloc 96: p=0.0386
#   -> Bloc 80 vs Bloc 112: p=0.0091
#   -> Bloc 80 vs Bloc 128: p=0.0007
#   -> Bloc 80 vs Bloc 144: p=0.0011
#   -> Bloc 80 vs Bloc 160: p=0.0020
#   -> Bloc 80 vs Bloc 176: p=0.0855
#   -> Bloc 80 vs Bloc 192: p=0.0246
#   -> Bloc 80 vs Bloc 208: p=0.0273
#   -> Bloc 80 vs Bloc 224: p=0.0118
#   -> Bloc 80 vs Bloc 240: p=0.0528
#   -> Bloc 80 vs Bloc 256: p=0.0064
#   -> Bloc 80 vs Bloc 272: p=0.0430
#   -> Bloc 80 vs Bloc 288: p=0.0020
#   -> Bloc 80 vs Bloc 304: p=0.0057
#   -> Bloc 80 vs Bloc 320: p=0.0004
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0001
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# 🔁 Itération 50 : mesure de tous les blocs
#  Bloc 16   → 0.07086 s (n=52)
#  Bloc 32   → 0.00609 s (n=52)
#  Bloc 48   → 0.00452 s (n=52)
#  Bloc 64   → 0.00449 s (n=52)
#  Bloc 80   → 0.00451 s (n=52)
#  Bloc 96   → 0.00480 s (n=52)
#  Bloc 112  → 0.00513 s (n=52)
#  Bloc 128  → 0.06243 s (n=52)
#  Bloc 144  → 0.00605 s (n=52)
#  Bloc 160  → 0.00543 s (n=52)
#  Bloc 176  → 0.00510 s (n=52)
#  Bloc 192  → 0.00553 s (n=52)
#  Bloc 208  → 0.00638 s (n=52)
#  Bloc 224  → 0.00620 s (n=52)
#  Bloc 240  → 0.00648 s (n=52)
#  Bloc 256  → 0.00875 s (n=52)
#  Bloc 272  → 0.00793 s (n=52)
#  Bloc 288  → 0.00880 s (n=52)
#  Bloc 304  → 0.00875 s (n=52)
#  Bloc 320  → 0.00939 s (n=52)
#  Bloc 336  → 0.01247 s (n=52)
#  Bloc 352  → 0.00985 s (n=52)
#  Bloc 368  → 0.00994 s (n=52)
#  Bloc 384  → 0.01097 s (n=52)
#  Bloc 400  → 0.01037 s (n=52)
#  Bloc 416  → 0.05348 s (n=52)
#  Bloc 432  → 0.01133 s (n=52)
#  Bloc 448  → 0.01150 s (n=52)
#  Bloc 464  → 0.01124 s (n=52)
#  Bloc 480  → 0.07230 s (n=52)
#  Bloc 496  → 0.11193 s (n=52)
#  Meilleur moyen actuel : Bloc 80 (mean=0.00573)
#   -> Bloc 80 vs Bloc 16: p=0.0000
#   -> Bloc 80 vs Bloc 32: p=0.0000
#   -> Bloc 80 vs Bloc 48: p=0.3583
#   -> Bloc 80 vs Bloc 64: p=0.0850
#   -> Bloc 80 vs Bloc 96: p=0.0384
#   -> Bloc 80 vs Bloc 112: p=0.0090
#   -> Bloc 80 vs Bloc 128: p=0.0003
#   -> Bloc 80 vs Bloc 144: p=0.0011
#   -> Bloc 80 vs Bloc 160: p=0.0020
#   -> Bloc 80 vs Bloc 176: p=0.0847
#   -> Bloc 80 vs Bloc 192: p=0.0242
#   -> Bloc 80 vs Bloc 208: p=0.0262
#   -> Bloc 80 vs Bloc 224: p=0.0113
#   -> Bloc 80 vs Bloc 240: p=0.0500
#   -> Bloc 80 vs Bloc 256: p=0.0053
#   -> Bloc 80 vs Bloc 272: p=0.0380
#   -> Bloc 80 vs Bloc 288: p=0.0016
#   -> Bloc 80 vs Bloc 304: p=0.0047
#   -> Bloc 80 vs Bloc 320: p=0.0003
#   -> Bloc 80 vs Bloc 336: p=0.0000
#   -> Bloc 80 vs Bloc 352: p=0.0000
#   -> Bloc 80 vs Bloc 368: p=0.0000
#   -> Bloc 80 vs Bloc 384: p=0.0000
#   -> Bloc 80 vs Bloc 400: p=0.0000
#   -> Bloc 80 vs Bloc 416: p=0.0000
#   -> Bloc 80 vs Bloc 432: p=0.0000
#   -> Bloc 80 vs Bloc 448: p=0.0001
#   -> Bloc 80 vs Bloc 464: p=0.0000
#   -> Bloc 80 vs Bloc 480: p=0.0000
#   -> Bloc 80 vs Bloc 496: p=0.0000
#
# ❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de 95 %.

# %%
figsize = (24, 6)
# 1) Évolution du best par itération
plt.figure(figsize=figsize)
plt.plot(range(1, len(best_track)+1), best_track, marker='o')
plt.xlabel("Itération")
plt.ylabel("Meilleur bloc")
plt.title("Évolution du bloc sélectionné")
plt.grid(True)

# 2) Distribution des temps par bloc
plt.figure(figsize=figsize)
plt.boxplot([results[b] for b in blocks],
            labels=[str(b) for b in blocks],
            showfliers=False)
plt.xlabel("Taille de bloc")
plt.ylabel("Temps mesuré (s)")
plt.title("Distribution des temps par bloc")
plt.grid(True)

# 3) Temps du best à chaque mesure, coloré aux changements
indices = [idx for idx, _, _ in best_meas]
blocks_seq = [bsz for _, bsz, _ in best_meas]
times_seq  = [t   for _, _, t in best_meas]
colors = ['red' if curr!=prev else 'blue'
            for prev, curr in zip(blocks_seq, blocks_seq[1:])]

plt.figure(figsize=figsize)
for i in range(len(times_seq)-1):
    plt.plot([indices[i], indices[i+1]],
                [times_seq[i], times_seq[i+1]],
                color=colors[i], linewidth=2)
plt.scatter(indices[0], times_seq[0], color='blue')
plt.xlabel("Numéro de mesure du best")
plt.ylabel("Temps mesuré (s)")
plt.title("Évolution du temps du best\n(rouge = changement de bloc)")
plt.grid(True)
plt.legend([
    plt.Line2D([0],[0], color='blue', lw=2),
    plt.Line2D([0],[0], color='red',  lw=2)
], ["Même bloc", "Changement"])
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_58769/2148266109.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([results[b] for b in blocks],

# %% [markdown]
# ## Meilleur Benchmark

# %%
# -*- coding: utf-8 -*-
"""
Benchmark adaptatif jusqu'à décision probabiliste,
avec traçage des performances.
"""

from math import sqrt
import numpy as np
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

def _prob_b_faster_than_a(mean_a, std_a, n_a, mean_b, std_b, n_b):
    var = (std_a ** 2) / n_a + (std_b ** 2) / n_b
    if var == 0:
        return 0.5
    se = sqrt(var)
    diff = mean_b - mean_a
    t_stat = diff / se
    df = var**2 / (
        (std_a**4) / (n_a**2 * (n_a - 1)) +
        (std_b**4) / (n_b**2 * (n_b - 1))
    )
    return student_t.cdf(-t_stat, df)


def smart_benchmark_probabilistic(
    x,
    block_sizes,
    *,
    p_switch: float         = 0.50,
    initial_repeats: int    = 2,
    confidence: float       = 0.95,
    free_runs: int          = 1,
    extra_repeats_best: int = 1,
    max_iter: int           = 10,
    verbose: bool           = True,
):
    # ---------------------------------------------------------------
    # Préparation
    # ---------------------------------------------------------------
    block_sizes = sorted(set(block_sizes))
    results = {b: [] for b in block_sizes}
    history = []          # [ (iter, best, {b: p_better}) ]
    best_track = []       # suivi du best
    p_stop = 1 - confidence

    # Pour le troisième graphique :
    best_measurements = []            # liste de tuples (idx, best, t)
    global_measure_counter = 0        # compteur de mesures best

    # (1) réchauffe-caches
    if free_runs > 0 and verbose:
        print(f"⚙️  Phase 0 : {free_runs} free runs")
    for _ in range(free_runs):
        for b in block_sizes:
            run_attention_once_np(x, b)
    if verbose:
        print("Fin des free runs\n")

    # (2) mesures initiales
    if verbose:
        print("🔍 Phase 1 : mesures initiales")
    for b in block_sizes:
        for _ in range(initial_repeats):
            results[b].append(measure_time(x, b))
        if verbose:
            print(f"Bloc {b:<4} → {np.mean(results[b]):.5f} s (n={len(results[b])})")

    # (3) best initial + répétitions bonus
    best = min(block_sizes, key=lambda b: np.mean(results[b]))
    if verbose:
        print(f"\nBest initial : {best}")
    for _ in range(extra_repeats_best):
        t = measure_time(x, best)
        # enregistrement pour graphique 3
        global_measure_counter += 1
        best_measurements.append((global_measure_counter, best, t))
        results[best].append(t)

    # ---------------------------------------------------------------
    # Boucle principale
    # ---------------------------------------------------------------
    for it in range(1, max_iter + 1):
        # Stats de tous les blocs
        stats = {
            b: (
                np.mean(results[b]),
                np.std(results[b], ddof=1) if len(results[b]) > 1 else 0.0,
                len(results[b]),
            )
            for b in block_sizes
        }
        mean_best, std_best, n_best = stats[best]

        # Probabilités P(b < best)
        p_better = {}
        for b in block_sizes:
            if b == best:
                continue
            mean_b, std_b, n_b = stats[b]
            p_better[b] = _prob_b_faster_than_a(
                mean_best, std_best, n_best,
                mean_b, std_b, n_b
            )

        history.append((it, best, p_better.copy()))
        best_track.append(best)

        if verbose:
            print(f"\n🔁 Itération {it}: best = {best}")
            for b, p in sorted(p_better.items()):
                print(f"  P({b} plus rapide que {best}) = {p:.3f}")

        # Décision : stop ? switch ?
        max_p = max(p_better.values(), default=0.0)
        if max_p < p_stop:
            if verbose:
                print(f"\n✅ Arrêt, toutes proba < {p_stop:.2f}")
            break

        if max_p > p_switch:
            new_best = max(p_better, key=p_better.get)
            if verbose:
                print(f"↪️ Switch : {best} → {new_best} (p={max_p:.3f})")
            best = new_best

        # Sélection des blocs à remesurer
        to_measure = [best] + [b for b, p in p_better.items() if p >= p_stop]
        if verbose:
            print("Mesures supplémentaires :", to_measure)

        for b in to_measure:
            t = measure_time(x, b)
            # n’enregistrer que si c’est le best
            if b == best:
                global_measure_counter += 1
                best_measurements.append((global_measure_counter, best, t))
            results[b].append(t)
            if verbose:
                print(f"  Bloc {b:<4} → {t:.5f} s (n={len(results[b])})")
        
        if it == max_iter:
            print(f"\n❌ L’algorithme n’a convergé pour aucune taille de bloc avec une confiance de {confidence*100:.0f} %.")

    # Résultat final
    if verbose:
        m_final = float(np.median(results[best]))
        tot = sum(len(v) for v in results.values())
        print(f"\n🏁 Best final : {best} (médiane={m_final:.5f} s), mesures={tot}")
        

    return best, results, history, best_track, best_measurements

# %%
# ------------------------
# Exécution
# ------------------------
seq_len, d_model = 2048, 64
x = np.random.randn(seq_len, d_model)
blocks = list(range(0, 512, 16))

best, results, history, best_blocks_by_iter, best_measurements = \
    smart_benchmark_probabilistic(
        x, blocks,
        initial_repeats    = 2,
        free_runs          = 1,
        extra_repeats_best = 0,
        verbose            = True
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       5 x = np.random.randn(seq_len, d_model)
#       6 blocks = list(range(0, 512, 16))
#       8 best, results, history, best_blocks_by_iter, best_measurements = \
# ----> 9     smart_benchmark_probabilistic(
#      10         x, blocks,
#      11         initial_repeats    = 2,
#      12         free_runs          = 1,
#      13         extra_repeats_best = 0,
#      14         verbose            = True
#      15     )
#
# Cell In[17], line 54, in smart_benchmark_probabilistic(x, block_sizes, p_switch, initial_repeats, confidence, free_runs, extra_repeats_best, max_iter, verbose)
#      52 for _ in range(free_runs):
#      53     for b in block_sizes:
# ---> 54         run_attention_once(x, b)
#      55 if verbose:
#      56     print("End of free runs")
#
# NameError: name 'run_attention_once' is not defined

# %%
# ------------------------
# Tracés
# ------------------------

# 1) Évolution du bloc sélectionné par itération
plt.figure()
plt.plot(
    range(1, len(best_blocks_by_iter) + 1),
    best_blocks_by_iter,
    marker='o'
)
plt.xlabel("Itération")
plt.ylabel("Meilleur bloc")
plt.title("Bloc sélectionné au fil des itérations")
plt.grid(True)

# 2) Distribution des temps par bloc
plt.figure()
plt.boxplot(
    [results[b] for b in blocks],
    labels=[str(b) for b in blocks],
    showfliers=False
)
plt.xlabel("Taille de bloc")
plt.ylabel("Temps mesuré (s)")
plt.title("Distribution des temps par bloc")
plt.grid(True)

# 3) Temps du best à chaque mesure, segments colorés
# Préparation des données
indices = [idx for idx, _, _ in best_measurements]
blocks_seq = [bsz for _, bsz, _ in best_measurements]
times_seq  = [t   for _, _, t in best_measurements]
# Couleurs : rouge si changement de best, bleu sinon
colors = [
    'red' if curr != prev else 'blue'
    for prev, curr in zip(blocks_seq, blocks_seq[1:])
]
# Tracé segment par segment
plt.figure()
for i in range(len(times_seq)-1):
    plt.plot(
        [indices[i], indices[i+1]],
        [times_seq[i], times_seq[i+1]],
        color=colors[i],
        linewidth=2
    )
# Premier point
plt.scatter(indices[0], times_seq[0], color='blue')
plt.xlabel("Numéro de mesure du best")
plt.ylabel("Temps mesuré (s)")
plt.title("Évolution du temps du best (rouge = changement de bloc)")
plt.grid(True)
plt.legend([
    plt.Line2D([0],[0], color='blue', lw=2),
    plt.Line2D([0],[0], color='red',  lw=2)
], ["Même bloc", "Changement"])
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_43280/1544241572.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
