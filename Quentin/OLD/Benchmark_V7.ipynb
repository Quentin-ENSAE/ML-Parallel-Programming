# %%
import numpy as np

# ------------------------------------------------
# Choix des tailles de matrice (Q, K, V) et d
# ------------------------------------------------
seq_len, d_model = 2048, 64
x = np.random.randn(seq_len, d_model)

# ------------------------------------------------
# Choix des tailles de blocs à tester 
# ------------------------------------------------
min_size, max_size, step = 64, 512, 64
blocks = list(range(min_size, max_size + step, step))

# %%
import os

os.chdir('..')

# %%
import sys
sys.path.append('./cython_mat')
sys.path.append('./Quentin')
import mmat

# %%
import os
print(os.listdir('./cython_mat'))
# Out:
# ['mmat.cpython-312-x86_64-linux-gnu.so', 'test_mmat.py', 'mmat_impl.h', 'mmat.cpp', 'mmat.pyx', 'setup.py', 'mmat_impl.cpp', 'build']

# %% [markdown]
# ## Calcul de l'attention (avec numpy)

# %%
import numpy as np
import pandas as pd
import time
import math
from math import sqrt
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

# %%
# ------------------------
# Fonction d'attention (inchangée)
# ------------------------
def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

def run_attention_once_np(x, block_size):
    seq_len, d_model = x.shape
    output = np.zeros_like(x)
    for i in range(0, seq_len, block_size):
        end = min(i + block_size, seq_len)
        Q = x[i:end]
        K = x[i:end]
        V = x[i:end]
        scores = np.matmul(Q, K.T) / np.sqrt(d_model)
        weights = softmax(scores)
        output[i:end] = np.matmul(weights, V)
    return output


# ------------------------
# Mesure de temps
# ------------------------
def measure_time(x, block_size):
    start = time.perf_counter()
    _ = run_attention_once_np(x, block_size)
    return time.perf_counter() - start

# %% [markdown]
# ## Grille exhaustive qui teste toutes les combinaisons
#
# * Mesure initiale : pour chaque block_size, effectue initial_repeats mesures et stocke les temps.
#
# * Choix du candidat : identifie le bloc dont la moyenne des temps initiaux est la plus faible.
#
# * Échauffement : relance 5 mesures supplémentaires sur ce “best” pour estimer son intervalle de confiance (IC) à 95 % (Student-t).
#
# * Itération : jusqu’à max_iter, répète :
#
# * Recalcule la moyenne, l’écart-type et l’IC supérieur du “best”.
#
# * Sélectionne tous les blocs dont la moyenne courante ≤ IC supérieur.
#
# * Mesure chacun de ces candidats une fois de plus.
#
# * Met à jour le “best” en choisissant, parmi les candidats, celui à la plus petite moyenne.
#
# * Test de confiance : pour chaque autre bloc, effectue un test t de Welch contre le “best” et calcule la p-value unilatérale.
#
# * Arrêt : dès que toutes les p-values sont < 0.05 (95 % de confiance que le “best” est plus rapide), on sort.
#
# * Résultat : retourne la taille de bloc optimale, toutes les mesures accumulées, et le nombre total de tests effectués.

# %%
from benchmark import exhaustive_grid_until_confidence

result_grille = \
    exhaustive_grid_until_confidence(
        x, blocks,
        initial_repeats=4,
        free_runs=20,
        confidence=0.95,
        max_iter=1000,
        verbose=True
    )
# Out:
# ⚙️  Phase 0 : 20 free runs
# Fin des free runs
#
# 🔍 Phase 1 : mesures initiales
# Bloc 64   → médiane init : 0.00564 s
# Bloc 128  → médiane init : 0.00730 s
# Bloc 192  → médiane init : 0.00653 s
# Bloc 256  → médiane init : 0.00845 s
# Bloc 320  → médiane init : 0.01228 s
# Bloc 384  → médiane init : 0.01704 s
# Bloc 448  → médiane init : 0.04129 s
# Bloc 512  → médiane init : 0.05473 s
#
# 🔁 Itération 1 : mesure de tous les blocs
#  Bloc 64   → 0.00380 s (n=5)
#  Bloc 128  → 0.00573 s (n=5)
#  Bloc 192  → 0.00696 s (n=5)
#  Bloc 256  → 0.07359 s (n=5)
#  Bloc 320  → 0.01053 s (n=5)
#  Bloc 384  → 0.01486 s (n=5)
#  Bloc 448  → 0.08197 s (n=5)
#  Bloc 512  → 0.07970 s (n=5)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00640)
#   -> Bloc 64 vs Bloc 128: p=0.1829
#   -> Bloc 64 vs Bloc 192: p=0.4223
#   -> Bloc 64 vs Bloc 256: p=0.1542
#   -> Bloc 64 vs Bloc 320: p=0.0052
#   -> Bloc 64 vs Bloc 384: p=0.0354
#   -> Bloc 64 vs Bloc 448: p=0.0170
#   -> Bloc 64 vs Bloc 512: p=0.0091
#
# 🔁 Itération 2 : mesure de tous les blocs
#  Bloc 64   → 0.00485 s (n=6)
#  Bloc 128  → 0.00621 s (n=6)
#  Bloc 192  → 0.00738 s (n=6)
#  Bloc 256  → 0.01051 s (n=6)
#  Bloc 320  → 0.07028 s (n=6)
#  Bloc 384  → 0.01694 s (n=6)
#  Bloc 448  → 0.01593 s (n=6)
#  Bloc 512  → 0.09095 s (n=6)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00614)
#   -> Bloc 64 vs Bloc 128: p=0.1729
#   -> Bloc 64 vs Bloc 192: p=0.2932
#   -> Bloc 64 vs Bloc 256: p=0.1318
#   -> Bloc 64 vs Bloc 320: p=0.0861
#   -> Bloc 64 vs Bloc 384: p=0.0185
#   -> Bloc 64 vs Bloc 448: p=0.0147
#   -> Bloc 64 vs Bloc 512: p=0.0026
#
# 🔁 Itération 3 : mesure de tous les blocs
#  Bloc 64   → 0.00393 s (n=7)
#  Bloc 128  → 0.06246 s (n=7)
#  Bloc 192  → 0.01174 s (n=7)
#  Bloc 256  → 0.00957 s (n=7)
#  Bloc 320  → 0.01019 s (n=7)
#  Bloc 384  → 0.07438 s (n=7)
#  Bloc 448  → 0.01785 s (n=7)
#  Bloc 512  → 0.02225 s (n=7)
#  Meilleur moyen actuel : Bloc 64 (mean=0.00583)
#   -> Bloc 64 vs Bloc 128: p=0.0785
#   -> Bloc 64 vs Bloc 192: p=0.1000
#   -> Bloc 64 vs Bloc 256: p=0.1132
#   -> Bloc 64 vs Bloc 320: p=0.0711
#   -> Bloc 64 vs Bloc 384: p=0.0191
#   -> Bloc 64 vs Bloc 448: p=0.0112
#   -> Bloc 64 vs Bloc 512: p=0.0024
#
# 🔁 Itération 4 : mesure de tous les blocs
#  Bloc 64   → 0.05697 s (n=8)
#  Bloc 128  → 0.00894 s (n=8)
#  Bloc 192  → 0.00733 s (n=8)
#  Bloc 256  → 0.00909 s (n=8)
#  Bloc 320  → 0.01050 s (n=8)
#  Bloc 384  → 0.02309 s (n=8)
#  Bloc 448  → 0.01807 s (n=8)
#  Bloc 512  → 0.07290 s (n=8)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00748)
#   -> Bloc 192 vs Bloc 64: p=0.2440
#   -> Bloc 192 vs Bloc 128: p=0.0927
#   -> Bloc 192 vs Bloc 256: p=0.1355
#   -> Bloc 192 vs Bloc 320: p=0.0837
#   -> Bloc 192 vs Bloc 384: p=0.0148
#   -> Bloc 192 vs Bloc 448: p=0.0107
#   -> Bloc 192 vs Bloc 512: p=0.0008
#
# 🔁 Itération 5 : mesure de tous les blocs
#  Bloc 64   → 0.00423 s (n=9)
#  Bloc 128  → 0.00577 s (n=9)
#  Bloc 192  → 0.00702 s (n=9)
#  Bloc 256  → 0.00944 s (n=9)
#  Bloc 320  → 0.07257 s (n=9)
#  Bloc 384  → 0.01525 s (n=9)
#  Bloc 448  → 0.07430 s (n=9)
#  Bloc 512  → 0.03333 s (n=9)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00743)
#   -> Bloc 192 vs Bloc 64: p=0.2593
#   -> Bloc 192 vs Bloc 128: p=0.0950
#   -> Bloc 192 vs Bloc 256: p=0.1262
#   -> Bloc 192 vs Bloc 320: p=0.0422
#   -> Bloc 192 vs Bloc 384: p=0.0113
#   -> Bloc 192 vs Bloc 448: p=0.0042
#   -> Bloc 192 vs Bloc 512: p=0.0005
#
# 🔁 Itération 6 : mesure de tous les blocs
#  Bloc 64   → 0.06642 s (n=10)
#  Bloc 128  → 0.00831 s (n=10)
#  Bloc 192  → 0.00729 s (n=10)
#  Bloc 256  → 0.00994 s (n=10)
#  Bloc 320  → 0.06942 s (n=10)
#  Bloc 384  → 0.01577 s (n=10)
#  Bloc 448  → 0.02051 s (n=10)
#  Bloc 512  → 0.07685 s (n=10)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00742)
#   -> Bloc 192 vs Bloc 64: p=0.1218
#   -> Bloc 192 vs Bloc 128: p=0.0921
#   -> Bloc 192 vs Bloc 256: p=0.1170
#   -> Bloc 192 vs Bloc 320: p=0.0196
#   -> Bloc 192 vs Bloc 384: p=0.0085
#   -> Bloc 192 vs Bloc 448: p=0.0032
#   -> Bloc 192 vs Bloc 512: p=0.0001
#
# 🔁 Itération 7 : mesure de tous les blocs
#  Bloc 64   → 0.00535 s (n=11)
#  Bloc 128  → 0.00568 s (n=11)
#  Bloc 192  → 0.00736 s (n=11)
#  Bloc 256  → 0.06993 s (n=11)
#  Bloc 320  → 0.01049 s (n=11)
#  Bloc 384  → 0.01400 s (n=11)
#  Bloc 448  → 0.07712 s (n=11)
#  Bloc 512  → 0.02261 s (n=11)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00741)
#   -> Bloc 192 vs Bloc 64: p=0.1265
#   -> Bloc 192 vs Bloc 128: p=0.0954
#   -> Bloc 192 vs Bloc 256: p=0.0577
#   -> Bloc 192 vs Bloc 320: p=0.0185
#   -> Bloc 192 vs Bloc 384: p=0.0068
#   -> Bloc 192 vs Bloc 448: p=0.0013
#   -> Bloc 192 vs Bloc 512: p=0.0001
#
# 🔁 Itération 8 : mesure de tous les blocs
#  Bloc 64   → 0.00391 s (n=12)
#  Bloc 128  → 0.06510 s (n=12)
#  Bloc 192  → 0.01004 s (n=12)
#  Bloc 256  → 0.00853 s (n=12)
#  Bloc 320  → 0.00990 s (n=12)
#  Bloc 384  → 0.07694 s (n=12)
#  Bloc 448  → 0.01617 s (n=12)
#  Bloc 512  → 0.07151 s (n=12)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00763)
#   -> Bloc 192 vs Bloc 64: p=0.1427
#   -> Bloc 192 vs Bloc 128: p=0.0493
#   -> Bloc 192 vs Bloc 256: p=0.0591
#   -> Bloc 192 vs Bloc 320: p=0.0186
#   -> Bloc 192 vs Bloc 384: p=0.0047
#   -> Bloc 192 vs Bloc 448: p=0.0012
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 9 : mesure de tous les blocs
#  Bloc 64   → 0.00830 s (n=13)
#  Bloc 128  → 0.00566 s (n=13)
#  Bloc 192  → 0.00683 s (n=13)
#  Bloc 256  → 0.00849 s (n=13)
#  Bloc 320  → 0.06598 s (n=13)
#  Bloc 384  → 0.01715 s (n=13)
#  Bloc 448  → 0.01566 s (n=13)
#  Bloc 512  → 0.07371 s (n=13)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00757)
#   -> Bloc 192 vs Bloc 64: p=0.1379
#   -> Bloc 192 vs Bloc 128: p=0.0510
#   -> Bloc 192 vs Bloc 256: p=0.0569
#   -> Bloc 192 vs Bloc 320: p=0.0085
#   -> Bloc 192 vs Bloc 384: p=0.0036
#   -> Bloc 192 vs Bloc 448: p=0.0010
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 10 : mesure de tous les blocs
#  Bloc 64   → 0.00564 s (n=14)
#  Bloc 128  → 0.00679 s (n=14)
#  Bloc 192  → 0.00727 s (n=14)
#  Bloc 256  → 0.01037 s (n=14)
#  Bloc 320  → 0.07379 s (n=14)
#  Bloc 384  → 0.01578 s (n=14)
#  Bloc 448  → 0.07128 s (n=14)
#  Bloc 512  → 0.03512 s (n=14)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00755)
#   -> Bloc 192 vs Bloc 64: p=0.1422
#   -> Bloc 192 vs Bloc 128: p=0.0516
#   -> Bloc 192 vs Bloc 256: p=0.0529
#   -> Bloc 192 vs Bloc 320: p=0.0039
#   -> Bloc 192 vs Bloc 384: p=0.0028
#   -> Bloc 192 vs Bloc 448: p=0.0004
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 11 : mesure de tous les blocs
#  Bloc 64   → 0.06138 s (n=15)
#  Bloc 128  → 0.01300 s (n=15)
#  Bloc 192  → 0.00959 s (n=15)
#  Bloc 256  → 0.00905 s (n=15)
#  Bloc 320  → 0.07227 s (n=15)
#  Bloc 384  → 0.01886 s (n=15)
#  Bloc 448  → 0.08152 s (n=15)
#  Bloc 512  → 0.03043 s (n=15)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00768)
#   -> Bloc 192 vs Bloc 64: p=0.0749
#   -> Bloc 192 vs Bloc 128: p=0.0475
#   -> Bloc 192 vs Bloc 256: p=0.0531
#   -> Bloc 192 vs Bloc 320: p=0.0018
#   -> Bloc 192 vs Bloc 384: p=0.0021
#   -> Bloc 192 vs Bloc 448: p=0.0002
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 12 : mesure de tous les blocs
#  Bloc 64   → 0.06114 s (n=16)
#  Bloc 128  → 0.00699 s (n=16)
#  Bloc 192  → 0.00821 s (n=16)
#  Bloc 256  → 0.00988 s (n=16)
#  Bloc 320  → 0.01090 s (n=16)
#  Bloc 384  → 0.08015 s (n=16)
#  Bloc 448  → 0.01792 s (n=16)
#  Bloc 512  → 0.07459 s (n=16)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00772)
#   -> Bloc 192 vs Bloc 64: p=0.0386
#   -> Bloc 192 vs Bloc 128: p=0.0488
#   -> Bloc 192 vs Bloc 256: p=0.0509
#   -> Bloc 192 vs Bloc 320: p=0.0018
#   -> Bloc 192 vs Bloc 384: p=0.0013
#   -> Bloc 192 vs Bloc 448: p=0.0001
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 13 : mesure de tous les blocs
#  Bloc 64   → 0.00465 s (n=17)
#  Bloc 128  → 0.00641 s (n=17)
#  Bloc 192  → 0.00796 s (n=17)
#  Bloc 256  → 0.06633 s (n=17)
#  Bloc 320  → 0.01671 s (n=17)
#  Bloc 384  → 0.01586 s (n=17)
#  Bloc 448  → 0.07558 s (n=17)
#  Bloc 512  → 0.02667 s (n=17)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00773)
#   -> Bloc 192 vs Bloc 64: p=0.0416
#   -> Bloc 192 vs Bloc 128: p=0.0506
#   -> Bloc 192 vs Bloc 256: p=0.0257
#   -> Bloc 192 vs Bloc 320: p=0.0015
#   -> Bloc 192 vs Bloc 384: p=0.0011
#   -> Bloc 192 vs Bloc 448: p=0.0001
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# 🔁 Itération 14 : mesure de tous les blocs
#  Bloc 64   → 0.06327 s (n=18)
#  Bloc 128  → 0.01319 s (n=18)
#  Bloc 192  → 0.00721 s (n=18)
#  Bloc 256  → 0.00963 s (n=18)
#  Bloc 320  → 0.01139 s (n=18)
#  Bloc 384  → 0.07232 s (n=18)
#  Bloc 448  → 0.02066 s (n=18)
#  Bloc 512  → 0.08132 s (n=18)
#  Meilleur moyen actuel : Bloc 192 (mean=0.00770)
#   -> Bloc 192 vs Bloc 64: p=0.0209
#   -> Bloc 192 vs Bloc 128: p=0.0443
#   -> Bloc 192 vs Bloc 256: p=0.0245
#   -> Bloc 192 vs Bloc 320: p=0.0014
#   -> Bloc 192 vs Bloc 384: p=0.0005
#   -> Bloc 192 vs Bloc 448: p=0.0000
#   -> Bloc 192 vs Bloc 512: p=0.0000
#
# ✅ Confiance 95% atteinte pour le meilleur bloc.
#
# ✅ Résultat final : Bloc 192, tests totaux = 144

# %%
from graphique import plot_all_graphs

plot_dict_grille = {
    'best_track': result_grille['best_track'],
    'best_measurements': result_grille['best_measurements'],
    'results': result_grille['results'],
    'measure_per_iter': result_grille['measure_per_iter'],
    'p_history': result_grille['p_history'],
}

plot_all_graphs(
    blocks,
    **plot_dict_grille,
    p_switch=0.5,
    figsize=(24, 6),
    step=step,
)

# %% [markdown]
# ## Meilleur Benchmark

# %%
from benchmark import smart_benchmark_probabilistic


result_adaptatif_benchmark = \
    smart_benchmark_probabilistic(
        x, blocks,
        initial_repeats=4,
        free_runs=20,
        confidence=0.95,
        max_iter=1000,
        extra_repeats_best=0,
        verbose=True
    )
# Out:
# ⚙️  Phase 0 : 20 free runs
# Fin des free runs
#
# 🔍 Phase 1 : mesures initiales
# Bloc 64   → 0.01948 s (n=4)
# Bloc 128  → 0.02087 s (n=4)
# Bloc 192  → 0.00914 s (n=4)
# Bloc 256  → 0.01109 s (n=4)
# Bloc 320  → 0.01207 s (n=4)
# Bloc 384  → 0.02224 s (n=4)
# Bloc 448  → 0.02555 s (n=4)
# Bloc 512  → 0.05176 s (n=4)
#
# Best initial : 192
#
# 🔁 Itération 1: best = 192
#   P(64 plus rapide que 192) = 0.261
#   P(128 plus rapide que 192) = 0.235
#   P(256 plus rapide que 192) = 0.001
#   P(320 plus rapide que 192) = 0.000
#   P(384 plus rapide que 192) = 0.136
#   P(448 plus rapide que 192) = 0.146
#   P(512 plus rapide que 192) = 0.078
# Mesures supplémentaires : [192, 64, 128, 384, 448, 512]
#   Bloc 192  → 0.00755 s (n=5)
#   Bloc 64   → 0.06193 s (n=5)
#   Bloc 128  → 0.00780 s (n=5)
#   Bloc 384  → 0.01337 s (n=5)
#   Bloc 448  → 0.01459 s (n=5)
#   Bloc 512  → 0.07922 s (n=5)
#
# 🔁 Itération 2: best = 192
#   P(64 plus rapide que 192) = 0.121
#   P(128 plus rapide que 192) = 0.225
#   P(256 plus rapide que 192) = 0.001
#   P(320 plus rapide que 192) = 0.000
#   P(384 plus rapide que 192) = 0.104
#   P(448 plus rapide que 192) = 0.114
#   P(512 plus rapide que 192) = 0.029
# Mesures supplémentaires : [192, 64, 128, 384, 448]
#   Bloc 192  → 0.00895 s (n=6)
#   Bloc 64   → 0.00678 s (n=6)
#   Bloc 128  → 0.06379 s (n=6)
#   Bloc 384  → 0.01401 s (n=6)
#   Bloc 448  → 0.01444 s (n=6)
#
# 🔁 Itération 3: best = 192
#   P(64 plus rapide que 192) = 0.124
#   P(128 plus rapide que 192) = 0.107
#   P(256 plus rapide que 192) = 0.000
#   P(320 plus rapide que 192) = 0.000
#   P(384 plus rapide que 192) = 0.081
#   P(448 plus rapide que 192) = 0.093
#   P(512 plus rapide que 192) = 0.029
# Mesures supplémentaires : [192, 64, 128, 384, 448]
#   Bloc 192  → 0.00854 s (n=7)
#   Bloc 64   → 0.06163 s (n=7)
#   Bloc 128  → 0.00754 s (n=7)
#   Bloc 384  → 0.01358 s (n=7)
#   Bloc 448  → 0.01394 s (n=7)
#
# 🔁 Itération 4: best = 192
#   P(64 plus rapide que 192) = 0.058
#   P(128 plus rapide que 192) = 0.108
#   P(256 plus rapide que 192) = 0.000
#   P(320 plus rapide que 192) = 0.000
#   P(384 plus rapide que 192) = 0.063
#   P(448 plus rapide que 192) = 0.076
#   P(512 plus rapide que 192) = 0.029
# Mesures supplémentaires : [192, 64, 128, 384, 448]
#   Bloc 192  → 0.06623 s (n=8)
#   Bloc 64   → 0.00586 s (n=8)
#   Bloc 128  → 0.00712 s (n=8)
#   Bloc 384  → 0.01414 s (n=8)
#   Bloc 448  → 0.07174 s (n=8)
#
# 🔁 Itération 5: best = 192
#   P(64 plus rapide que 192) = 0.203
#   P(128 plus rapide que 192) = 0.331
#   P(256 plus rapide que 192) = 0.741
#   P(320 plus rapide que 192) = 0.699
#   P(384 plus rapide que 192) = 0.409
#   P(448 plus rapide que 192) = 0.175
#   P(512 plus rapide que 192) = 0.044
# ↪️ Switch : 192 → 256 (p=0.741)
# Mesures supplémentaires : [256, 64, 128, 256, 320, 384, 448]
#   Bloc 256  → 0.01085 s (n=5)
#   Bloc 64   → 0.00524 s (n=9)
#   Bloc 128  → 0.00694 s (n=9)
#   Bloc 256  → 0.01053 s (n=6)
#   Bloc 320  → 0.06849 s (n=5)
#   Bloc 384  → 0.01332 s (n=9)
#   Bloc 448  → 0.01394 s (n=9)
#
# 🔁 Itération 6: best = 256
#   P(64 plus rapide que 256) = 0.096
#   P(128 plus rapide que 256) = 0.164
#   P(192 plus rapide que 256) = 0.253
#   P(320 plus rapide que 256) = 0.167
#   P(384 plus rapide que 256) = 0.082
#   P(448 plus rapide que 256) = 0.052
#   P(512 plus rapide que 256) = 0.033
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.06708 s (n=7)
#   Bloc 64   → 0.00521 s (n=10)
#   Bloc 128  → 0.00694 s (n=10)
#   Bloc 192  → 0.00866 s (n=9)
#   Bloc 320  → 0.01146 s (n=6)
#   Bloc 384  → 0.07582 s (n=10)
#   Bloc 448  → 0.01428 s (n=10)
#
# 🔁 Itération 7: best = 256
#   P(64 plus rapide que 256) = 0.386
#   P(128 plus rapide que 256) = 0.522
#   P(192 plus rapide que 256) = 0.642
#   P(320 plus rapide que 256) = 0.425
#   P(384 plus rapide que 256) = 0.344
#   P(448 plus rapide que 256) = 0.308
#   P(512 plus rapide que 256) = 0.055
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448, 512]
#   Bloc 256  → 0.01013 s (n=8)
#   Bloc 64   → 0.00515 s (n=11)
#   Bloc 128  → 0.00649 s (n=11)
#   Bloc 192  → 0.05231 s (n=10)
#   Bloc 320  → 0.01029 s (n=7)
#   Bloc 384  → 0.01059 s (n=11)
#   Bloc 448  → 0.01147 s (n=11)
#   Bloc 512  → 0.07223 s (n=6)
#
# 🔁 Itération 8: best = 256
#   P(64 plus rapide que 256) = 0.390
#   P(128 plus rapide que 256) = 0.523
#   P(192 plus rapide que 256) = 0.459
#   P(320 plus rapide que 256) = 0.430
#   P(384 plus rapide que 256) = 0.329
#   P(448 plus rapide que 256) = 0.291
#   P(512 plus rapide que 256) = 0.020
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.00854 s (n=9)
#   Bloc 64   → 0.00370 s (n=12)
#   Bloc 128  → 0.00495 s (n=12)
#   Bloc 192  → 0.00615 s (n=11)
#   Bloc 320  → 0.06790 s (n=8)
#   Bloc 384  → 0.01335 s (n=12)
#   Bloc 448  → 0.01127 s (n=12)
#
# 🔁 Itération 9: best = 256
#   P(64 plus rapide que 256) = 0.395
#   P(128 plus rapide que 256) = 0.525
#   P(192 plus rapide que 256) = 0.460
#   P(320 plus rapide que 256) = 0.219
#   P(384 plus rapide que 256) = 0.300
#   P(448 plus rapide que 256) = 0.270
#   P(512 plus rapide que 256) = 0.018
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.00805 s (n=10)
#   Bloc 64   → 0.06023 s (n=13)
#   Bloc 128  → 0.00871 s (n=13)
#   Bloc 192  → 0.00780 s (n=12)
#   Bloc 320  → 0.01060 s (n=9)
#   Bloc 384  → 0.01101 s (n=13)
#   Bloc 448  → 0.07989 s (n=13)
#
# 🔁 Itération 10: best = 256
#   P(64 plus rapide que 256) = 0.244
#   P(128 plus rapide que 256) = 0.513
#   P(192 plus rapide que 256) = 0.454
#   P(320 plus rapide que 256) = 0.216
#   P(384 plus rapide que 256) = 0.280
#   P(448 plus rapide que 256) = 0.126
#   P(512 plus rapide que 256) = 0.017
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.00956 s (n=11)
#   Bloc 64   → 0.00369 s (n=14)
#   Bloc 128  → 0.00509 s (n=14)
#   Bloc 192  → 0.00632 s (n=13)
#   Bloc 320  → 0.05883 s (n=10)
#   Bloc 384  → 0.01159 s (n=14)
#   Bloc 448  → 0.01487 s (n=14)
#
# 🔁 Itération 11: best = 256
#   P(64 plus rapide que 256) = 0.255
#   P(128 plus rapide que 256) = 0.524
#   P(192 plus rapide que 256) = 0.462
#   P(320 plus rapide que 256) = 0.114
#   P(384 plus rapide que 256) = 0.267
#   P(448 plus rapide que 256) = 0.114
#   P(512 plus rapide que 256) = 0.016
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.00930 s (n=12)
#   Bloc 64   → 0.06333 s (n=15)
#   Bloc 128  → 0.00731 s (n=15)
#   Bloc 192  → 0.00678 s (n=14)
#   Bloc 320  → 0.00968 s (n=11)
#   Bloc 384  → 0.01090 s (n=15)
#   Bloc 448  → 0.06977 s (n=15)
#
# 🔁 Itération 12: best = 256
#   P(64 plus rapide que 256) = 0.148
#   P(128 plus rapide que 256) = 0.526
#   P(192 plus rapide que 256) = 0.468
#   P(320 plus rapide que 256) = 0.117
#   P(384 plus rapide que 256) = 0.255
#   P(448 plus rapide que 256) = 0.055
#   P(512 plus rapide que 256) = 0.015
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.00878 s (n=13)
#   Bloc 64   → 0.00364 s (n=16)
#   Bloc 128  → 0.00539 s (n=16)
#   Bloc 192  → 0.00954 s (n=15)
#   Bloc 320  → 0.07313 s (n=12)
#   Bloc 384  → 0.01113 s (n=16)
#   Bloc 448  → 0.01180 s (n=16)
#
# 🔁 Itération 13: best = 256
#   P(64 plus rapide que 256) = 0.156
#   P(128 plus rapide que 256) = 0.533
#   P(192 plus rapide que 256) = 0.461
#   P(320 plus rapide que 256) = 0.054
#   P(384 plus rapide que 256) = 0.243
#   P(448 plus rapide que 256) = 0.051
#   P(512 plus rapide que 256) = 0.015
# Mesures supplémentaires : [256, 64, 128, 192, 320, 384, 448]
#   Bloc 256  → 0.06526 s (n=14)
#   Bloc 64   → 0.00395 s (n=17)
#   Bloc 128  → 0.00526 s (n=17)
#   Bloc 192  → 0.00709 s (n=16)
#   Bloc 320  → 0.01007 s (n=13)
#   Bloc 384  → 0.01271 s (n=17)
#   Bloc 448  → 0.07708 s (n=17)
#
# 🔁 Itération 14: best = 256
#   P(64 plus rapide que 256) = 0.336
#   P(128 plus rapide que 256) = 0.742
#   P(192 plus rapide que 256) = 0.689
#   P(320 plus rapide que 256) = 0.139
#   P(384 plus rapide que 256) = 0.473
#   P(448 plus rapide que 256) = 0.079
#   P(512 plus rapide que 256) = 0.020
# ↪️ Switch : 256 → 128 (p=0.742)
# Mesures supplémentaires : [128, 64, 128, 192, 320, 384, 448]
#   Bloc 128  → 0.00598 s (n=18)
#   Bloc 64   → 0.00449 s (n=18)
#   Bloc 128  → 0.00599 s (n=19)
#   Bloc 192  → 0.06448 s (n=17)
#   Bloc 320  → 0.01275 s (n=14)
#   Bloc 384  → 0.01444 s (n=18)
#   Bloc 448  → 0.07319 s (n=18)
#
# 🔁 Itération 15: best = 128
#   P(64 plus rapide que 128) = 0.142
#   P(192 plus rapide que 128) = 0.230
#   P(256 plus rapide que 128) = 0.216
#   P(320 plus rapide que 128) = 0.043
#   P(384 plus rapide que 128) = 0.165
#   P(448 plus rapide que 128) = 0.008
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.00727 s (n=20)
#   Bloc 64   → 0.00506 s (n=19)
#   Bloc 192  → 0.00855 s (n=18)
#   Bloc 256  → 0.00998 s (n=15)
#   Bloc 384  → 0.06920 s (n=19)
#
# 🔁 Itération 16: best = 128
#   P(64 plus rapide que 128) = 0.147
#   P(192 plus rapide que 128) = 0.229
#   P(256 plus rapide que 128) = 0.214
#   P(320 plus rapide que 128) = 0.039
#   P(384 plus rapide que 128) = 0.082
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.00559 s (n=21)
#   Bloc 64   → 0.00346 s (n=20)
#   Bloc 192  → 0.00842 s (n=19)
#   Bloc 256  → 0.00807 s (n=16)
#   Bloc 384  → 0.01008 s (n=20)
#
# 🔁 Itération 17: best = 128
#   P(64 plus rapide que 128) = 0.153
#   P(192 plus rapide que 128) = 0.224
#   P(256 plus rapide que 128) = 0.213
#   P(320 plus rapide que 128) = 0.035
#   P(384 plus rapide que 128) = 0.078
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.012
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.05411 s (n=22)
#   Bloc 64   → 0.00864 s (n=21)
#   Bloc 192  → 0.01206 s (n=20)
#   Bloc 256  → 0.00952 s (n=17)
#   Bloc 384  → 0.01104 s (n=21)
#
# 🔁 Itération 18: best = 128
#   P(64 plus rapide que 128) = 0.247
#   P(192 plus rapide que 128) = 0.344
#   P(256 plus rapide que 128) = 0.338
#   P(320 plus rapide que 128) = 0.057
#   P(384 plus rapide que 128) = 0.154
#   P(448 plus rapide que 128) = 0.011
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00540 s (n=23)
#   Bloc 64   → 0.00368 s (n=22)
#   Bloc 192  → 0.04718 s (n=21)
#   Bloc 256  → 0.01364 s (n=18)
#   Bloc 320  → 0.00935 s (n=15)
#   Bloc 384  → 0.01045 s (n=22)
#
# 🔁 Itération 19: best = 128
#   P(64 plus rapide que 128) = 0.253
#   P(192 plus rapide que 128) = 0.237
#   P(256 plus rapide que 128) = 0.317
#   P(320 plus rapide que 128) = 0.059
#   P(384 plus rapide que 128) = 0.147
#   P(448 plus rapide que 128) = 0.010
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00545 s (n=24)
#   Bloc 64   → 0.00340 s (n=23)
#   Bloc 192  → 0.00660 s (n=22)
#   Bloc 256  → 0.05001 s (n=19)
#   Bloc 320  → 0.01631 s (n=16)
#   Bloc 384  → 0.01418 s (n=23)
#
# 🔁 Itération 20: best = 128
#   P(64 plus rapide que 128) = 0.260
#   P(192 plus rapide que 128) = 0.237
#   P(256 plus rapide que 128) = 0.202
#   P(320 plus rapide que 128) = 0.053
#   P(384 plus rapide que 128) = 0.133
#   P(448 plus rapide que 128) = 0.008
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00642 s (n=25)
#   Bloc 64   → 0.00391 s (n=24)
#   Bloc 192  → 0.00686 s (n=23)
#   Bloc 256  → 0.05074 s (n=20)
#   Bloc 320  → 0.01488 s (n=17)
#   Bloc 384  → 0.01274 s (n=24)
#
# 🔁 Itération 21: best = 128
#   P(64 plus rapide que 128) = 0.267
#   P(192 plus rapide que 128) = 0.239
#   P(256 plus rapide que 128) = 0.123
#   P(320 plus rapide que 128) = 0.048
#   P(384 plus rapide que 128) = 0.123
#   P(448 plus rapide que 128) = 0.008
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.00529 s (n=26)
#   Bloc 64   → 0.00357 s (n=25)
#   Bloc 192  → 0.00630 s (n=24)
#   Bloc 256  → 0.00867 s (n=21)
#   Bloc 384  → 0.05665 s (n=25)
#
# 🔁 Itération 22: best = 128
#   P(64 plus rapide que 128) = 0.272
#   P(192 plus rapide que 128) = 0.239
#   P(256 plus rapide que 128) = 0.121
#   P(320 plus rapide que 128) = 0.043
#   P(384 plus rapide que 128) = 0.068
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.00601 s (n=27)
#   Bloc 64   → 0.00387 s (n=26)
#   Bloc 192  → 0.00630 s (n=25)
#   Bloc 256  → 0.00848 s (n=22)
#   Bloc 384  → 0.01079 s (n=26)
#
# 🔁 Itération 23: best = 128
#   P(64 plus rapide que 128) = 0.279
#   P(192 plus rapide que 128) = 0.240
#   P(256 plus rapide que 128) = 0.121
#   P(320 plus rapide que 128) = 0.039
#   P(384 plus rapide que 128) = 0.065
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 256, 384]
#   Bloc 128  → 0.04640 s (n=28)
#   Bloc 64   → 0.00617 s (n=27)
#   Bloc 192  → 0.00803 s (n=26)
#   Bloc 256  → 0.00856 s (n=23)
#   Bloc 384  → 0.01071 s (n=27)
#
# 🔁 Itération 24: best = 128
#   P(64 plus rapide que 128) = 0.377
#   P(192 plus rapide que 128) = 0.341
#   P(256 plus rapide que 128) = 0.190
#   P(320 plus rapide que 128) = 0.056
#   P(384 plus rapide que 128) = 0.111
#   P(448 plus rapide que 128) = 0.009
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00558 s (n=29)
#   Bloc 64   → 0.00378 s (n=28)
#   Bloc 192  → 0.00660 s (n=27)
#   Bloc 256  → 0.04970 s (n=24)
#   Bloc 320  → 0.01062 s (n=18)
#   Bloc 384  → 0.01651 s (n=28)
#
# 🔁 Itération 25: best = 128
#   P(64 plus rapide que 128) = 0.382
#   P(192 plus rapide que 128) = 0.340
#   P(256 plus rapide que 128) = 0.119
#   P(320 plus rapide que 128) = 0.056
#   P(384 plus rapide que 128) = 0.097
#   P(448 plus rapide que 128) = 0.008
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00694 s (n=30)
#   Bloc 64   → 0.00522 s (n=29)
#   Bloc 192  → 0.00869 s (n=28)
#   Bloc 256  → 0.05092 s (n=25)
#   Bloc 320  → 0.01102 s (n=19)
#   Bloc 384  → 0.01269 s (n=29)
#
# 🔁 Itération 26: best = 128
#   P(64 plus rapide que 128) = 0.387
#   P(192 plus rapide que 128) = 0.337
#   P(256 plus rapide que 128) = 0.072
#   P(320 plus rapide que 128) = 0.056
#   P(384 plus rapide que 128) = 0.091
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 256, 320, 384]
#   Bloc 128  → 0.00671 s (n=31)
#   Bloc 64   → 0.00528 s (n=30)
#   Bloc 192  → 0.00849 s (n=29)
#   Bloc 256  → 0.05090 s (n=26)
#   Bloc 320  → 0.01188 s (n=20)
#   Bloc 384  → 0.01360 s (n=30)
#
# 🔁 Itération 27: best = 128
#   P(64 plus rapide que 128) = 0.392
#   P(192 plus rapide que 128) = 0.334
#   P(256 plus rapide que 128) = 0.042
#   P(320 plus rapide que 128) = 0.055
#   P(384 plus rapide que 128) = 0.084
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 320, 384]
#   Bloc 128  → 0.00735 s (n=32)
#   Bloc 64   → 0.00570 s (n=31)
#   Bloc 192  → 0.00871 s (n=30)
#   Bloc 320  → 0.05225 s (n=21)
#   Bloc 384  → 0.01352 s (n=31)
#
# 🔁 Itération 28: best = 128
#   P(64 plus rapide que 128) = 0.397
#   P(192 plus rapide que 128) = 0.331
#   P(256 plus rapide que 128) = 0.037
#   P(320 plus rapide que 128) = 0.031
#   P(384 plus rapide que 128) = 0.077
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.00740 s (n=33)
#   Bloc 64   → 0.00588 s (n=32)
#   Bloc 192  → 0.01111 s (n=31)
#   Bloc 384  → 0.05552 s (n=32)
#
# 🔁 Itération 29: best = 128
#   P(64 plus rapide que 128) = 0.401
#   P(192 plus rapide que 128) = 0.322
#   P(256 plus rapide que 128) = 0.034
#   P(320 plus rapide que 128) = 0.028
#   P(384 plus rapide que 128) = 0.044
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192]
#   Bloc 128  → 0.00763 s (n=34)
#   Bloc 64   → 0.00549 s (n=33)
#   Bloc 192  → 0.00866 s (n=32)
#
# 🔁 Itération 30: best = 128
#   P(64 plus rapide que 128) = 0.407
#   P(192 plus rapide que 128) = 0.320
#   P(256 plus rapide que 128) = 0.031
#   P(320 plus rapide que 128) = 0.026
#   P(384 plus rapide que 128) = 0.040
#   P(448 plus rapide que 128) = 0.005
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192]
#   Bloc 128  → 0.00677 s (n=35)
#   Bloc 64   → 0.00637 s (n=34)
#   Bloc 192  → 0.00945 s (n=33)
#
# 🔁 Itération 31: best = 128
#   P(64 plus rapide que 128) = 0.409
#   P(192 plus rapide que 128) = 0.314
#   P(256 plus rapide que 128) = 0.027
#   P(320 plus rapide que 128) = 0.024
#   P(384 plus rapide que 128) = 0.035
#   P(448 plus rapide que 128) = 0.005
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192]
#   Bloc 128  → 0.04775 s (n=36)
#   Bloc 64   → 0.00562 s (n=35)
#   Bloc 192  → 0.00888 s (n=34)
#
# 🔁 Itération 32: best = 128
#   P(64 plus rapide que 128) = 0.515
#   P(192 plus rapide que 128) = 0.421
#   P(256 plus rapide que 128) = 0.043
#   P(320 plus rapide que 128) = 0.035
#   P(384 plus rapide que 128) = 0.058
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.00711 s (n=37)
#   Bloc 64   → 0.00526 s (n=36)
#   Bloc 192  → 0.00860 s (n=35)
#   Bloc 384  → 0.01317 s (n=33)
#
# 🔁 Itération 33: best = 128
#   P(64 plus rapide que 128) = 0.520
#   P(192 plus rapide que 128) = 0.418
#   P(256 plus rapide que 128) = 0.039
#   P(320 plus rapide que 128) = 0.032
#   P(384 plus rapide que 128) = 0.054
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.00697 s (n=38)
#   Bloc 64   → 0.00537 s (n=37)
#   Bloc 192  → 0.03327 s (n=36)
#   Bloc 384  → 0.01313 s (n=34)
#
# 🔁 Itération 34: best = 128
#   P(64 plus rapide que 128) = 0.524
#   P(192 plus rapide que 128) = 0.347
#   P(256 plus rapide que 128) = 0.036
#   P(320 plus rapide que 128) = 0.030
#   P(384 plus rapide que 128) = 0.051
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.00717 s (n=39)
#   Bloc 64   → 0.00549 s (n=38)
#   Bloc 192  → 0.00881 s (n=37)
#   Bloc 384  → 0.01311 s (n=35)
#
# 🔁 Itération 35: best = 128
#   P(64 plus rapide que 128) = 0.529
#   P(192 plus rapide que 128) = 0.344
#   P(256 plus rapide que 128) = 0.033
#   P(320 plus rapide que 128) = 0.028
#   P(384 plus rapide que 128) = 0.047
#   P(448 plus rapide que 128) = 0.006
#   P(512 plus rapide que 128) = 0.013
# Mesures supplémentaires : [128, 64, 192]
#   Bloc 128  → 0.04769 s (n=40)
#   Bloc 64   → 0.00507 s (n=39)
#   Bloc 192  → 0.00854 s (n=38)
#
# 🔁 Itération 36: best = 128
#   P(64 plus rapide que 128) = 0.628
#   P(192 plus rapide que 128) = 0.448
#   P(256 plus rapide que 128) = 0.048
#   P(320 plus rapide que 128) = 0.039
#   P(384 plus rapide que 128) = 0.074
#   P(448 plus rapide que 128) = 0.008
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.00683 s (n=41)
#   Bloc 64   → 0.00518 s (n=40)
#   Bloc 192  → 0.00839 s (n=39)
#   Bloc 384  → 0.01259 s (n=36)
#
# 🔁 Itération 37: best = 128
#   P(64 plus rapide que 128) = 0.633
#   P(192 plus rapide que 128) = 0.445
#   P(256 plus rapide que 128) = 0.044
#   P(320 plus rapide que 128) = 0.036
#   P(384 plus rapide que 128) = 0.070
#   P(448 plus rapide que 128) = 0.007
#   P(512 plus rapide que 128) = 0.014
# Mesures supplémentaires : [128, 64, 192, 384]
#   Bloc 128  → 0.04825 s (n=42)
#   Bloc 64   → 0.00429 s (n=41)
#   Bloc 192  → 0.00615 s (n=40)
#   Bloc 384  → 0.01021 s (n=37)
#
# 🔁 Itération 38: best = 128
#   P(64 plus rapide que 128) = 0.723
#   P(192 plus rapide que 128) = 0.555
#   P(256 plus rapide que 128) = 0.062
#   P(320 plus rapide que 128) = 0.048
#   P(384 plus rapide que 128) = 0.113
#   P(448 plus rapide que 128) = 0.009
#   P(512 plus rapide que 128) = 0.015
# ↪️ Switch : 128 → 64 (p=0.723)
# Mesures supplémentaires : [64, 64, 192, 256, 384]
#   Bloc 64   → 0.00345 s (n=42)
#   Bloc 64   → 0.00334 s (n=43)
#   Bloc 192  → 0.00618 s (n=41)
#   Bloc 256  → 0.00807 s (n=27)
#   Bloc 384  → 0.05297 s (n=38)
#
# 🔁 Itération 39: best = 64
#   P(128 plus rapide que 64) = 0.241
#   P(192 plus rapide que 64) = 0.288
#   P(256 plus rapide que 64) = 0.023
#   P(320 plus rapide que 64) = 0.018
#   P(384 plus rapide que 64) = 0.020
#   P(448 plus rapide que 64) = 0.004
#   P(512 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00515 s (n=44)
#   Bloc 128  → 0.00503 s (n=43)
#   Bloc 192  → 0.00599 s (n=42)
#
# 🔁 Itération 40: best = 64
#   P(128 plus rapide que 64) = 0.242
#   P(192 plus rapide que 64) = 0.287
#   P(256 plus rapide que 64) = 0.021
#   P(320 plus rapide que 64) = 0.017
#   P(384 plus rapide que 64) = 0.017
#   P(448 plus rapide que 64) = 0.004
#   P(512 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00385 s (n=45)
#   Bloc 128  → 0.00469 s (n=44)
#   Bloc 192  → 0.00593 s (n=43)
#
# 🔁 Itération 41: best = 64
#   P(128 plus rapide que 64) = 0.241
#   P(192 plus rapide que 64) = 0.284
#   P(256 plus rapide que 64) = 0.019
#   P(320 plus rapide que 64) = 0.016
#   P(384 plus rapide que 64) = 0.015
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00332 s (n=46)
#   Bloc 128  → 0.00477 s (n=45)
#   Bloc 192  → 0.00592 s (n=44)
#
# 🔁 Itération 42: best = 64
#   P(128 plus rapide que 64) = 0.239
#   P(192 plus rapide que 64) = 0.279
#   P(256 plus rapide que 64) = 0.017
#   P(320 plus rapide que 64) = 0.014
#   P(384 plus rapide que 64) = 0.013
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00338 s (n=47)
#   Bloc 128  → 0.05000 s (n=46)
#   Bloc 192  → 0.00663 s (n=45)
#
# 🔁 Itération 43: best = 64
#   P(128 plus rapide que 64) = 0.168
#   P(192 plus rapide que 64) = 0.273
#   P(256 plus rapide que 64) = 0.015
#   P(320 plus rapide que 64) = 0.013
#   P(384 plus rapide que 64) = 0.011
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.012
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00341 s (n=48)
#   Bloc 128  → 0.00445 s (n=47)
#   Bloc 192  → 0.00557 s (n=46)
#
# 🔁 Itération 44: best = 64
#   P(128 plus rapide que 64) = 0.167
#   P(192 plus rapide que 64) = 0.270
#   P(256 plus rapide que 64) = 0.013
#   P(320 plus rapide que 64) = 0.012
#   P(384 plus rapide que 64) = 0.009
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00296 s (n=49)
#   Bloc 128  → 0.00458 s (n=48)
#   Bloc 192  → 0.00551 s (n=47)
#
# 🔁 Itération 45: best = 64
#   P(128 plus rapide que 64) = 0.166
#   P(192 plus rapide que 64) = 0.266
#   P(256 plus rapide que 64) = 0.012
#   P(320 plus rapide que 64) = 0.011
#   P(384 plus rapide que 64) = 0.008
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00357 s (n=50)
#   Bloc 128  → 0.00501 s (n=49)
#   Bloc 192  → 0.00604 s (n=48)
#
# 🔁 Itération 46: best = 64
#   P(128 plus rapide que 64) = 0.164
#   P(192 plus rapide que 64) = 0.261
#   P(256 plus rapide que 64) = 0.011
#   P(320 plus rapide que 64) = 0.010
#   P(384 plus rapide que 64) = 0.007
#   P(448 plus rapide que 64) = 0.003
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00327 s (n=51)
#   Bloc 128  → 0.00545 s (n=50)
#   Bloc 192  → 0.00628 s (n=49)
#
# 🔁 Itération 47: best = 64
#   P(128 plus rapide que 64) = 0.162
#   P(192 plus rapide que 64) = 0.256
#   P(256 plus rapide que 64) = 0.010
#   P(320 plus rapide que 64) = 0.010
#   P(384 plus rapide que 64) = 0.006
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00306 s (n=52)
#   Bloc 128  → 0.00564 s (n=51)
#   Bloc 192  → 0.00628 s (n=50)
#
# 🔁 Itération 48: best = 64
#   P(128 plus rapide que 64) = 0.159
#   P(192 plus rapide que 64) = 0.251
#   P(256 plus rapide que 64) = 0.009
#   P(320 plus rapide que 64) = 0.009
#   P(384 plus rapide que 64) = 0.005
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00365 s (n=53)
#   Bloc 128  → 0.00481 s (n=52)
#   Bloc 192  → 0.00768 s (n=51)
#
# 🔁 Itération 49: best = 64
#   P(128 plus rapide que 64) = 0.158
#   P(192 plus rapide que 64) = 0.243
#   P(256 plus rapide que 64) = 0.008
#   P(320 plus rapide que 64) = 0.008
#   P(384 plus rapide que 64) = 0.005
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00451 s (n=54)
#   Bloc 128  → 0.00592 s (n=53)
#   Bloc 192  → 0.00650 s (n=52)
#
# 🔁 Itération 50: best = 64
#   P(128 plus rapide que 64) = 0.157
#   P(192 plus rapide que 64) = 0.240
#   P(256 plus rapide que 64) = 0.008
#   P(320 plus rapide que 64) = 0.008
#   P(384 plus rapide que 64) = 0.004
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00366 s (n=55)
#   Bloc 128  → 0.00534 s (n=54)
#   Bloc 192  → 0.00802 s (n=53)
#
# 🔁 Itération 51: best = 64
#   P(128 plus rapide que 64) = 0.155
#   P(192 plus rapide que 64) = 0.232
#   P(256 plus rapide que 64) = 0.007
#   P(320 plus rapide que 64) = 0.007
#   P(384 plus rapide que 64) = 0.003
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00485 s (n=56)
#   Bloc 128  → 0.00607 s (n=55)
#   Bloc 192  → 0.00692 s (n=54)
#
# 🔁 Itération 52: best = 64
#   P(128 plus rapide que 64) = 0.154
#   P(192 plus rapide que 64) = 0.229
#   P(256 plus rapide que 64) = 0.006
#   P(320 plus rapide que 64) = 0.007
#   P(384 plus rapide que 64) = 0.003
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00366 s (n=57)
#   Bloc 128  → 0.00495 s (n=56)
#   Bloc 192  → 0.00639 s (n=55)
#
# 🔁 Itération 53: best = 64
#   P(128 plus rapide que 64) = 0.152
#   P(192 plus rapide que 64) = 0.224
#   P(256 plus rapide que 64) = 0.006
#   P(320 plus rapide que 64) = 0.007
#   P(384 plus rapide que 64) = 0.003
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00366 s (n=58)
#   Bloc 128  → 0.00490 s (n=57)
#   Bloc 192  → 0.00645 s (n=56)
#
# 🔁 Itération 54: best = 64
#   P(128 plus rapide que 64) = 0.151
#   P(192 plus rapide que 64) = 0.220
#   P(256 plus rapide que 64) = 0.006
#   P(320 plus rapide que 64) = 0.006
#   P(384 plus rapide que 64) = 0.002
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.011
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00434 s (n=59)
#   Bloc 128  → 0.00495 s (n=58)
#   Bloc 192  → 0.00642 s (n=57)
#
# 🔁 Itération 55: best = 64
#   P(128 plus rapide que 64) = 0.151
#   P(192 plus rapide que 64) = 0.216
#   P(256 plus rapide que 64) = 0.005
#   P(320 plus rapide que 64) = 0.006
#   P(384 plus rapide que 64) = 0.002
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00362 s (n=60)
#   Bloc 128  → 0.00516 s (n=59)
#   Bloc 192  → 0.00648 s (n=58)
#
# 🔁 Itération 56: best = 64
#   P(128 plus rapide que 64) = 0.149
#   P(192 plus rapide que 64) = 0.212
#   P(256 plus rapide que 64) = 0.005
#   P(320 plus rapide que 64) = 0.006
#   P(384 plus rapide que 64) = 0.002
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00386 s (n=61)
#   Bloc 128  → 0.00506 s (n=60)
#   Bloc 192  → 0.00977 s (n=59)
#
# 🔁 Itération 57: best = 64
#   P(128 plus rapide que 64) = 0.148
#   P(192 plus rapide que 64) = 0.202
#   P(256 plus rapide que 64) = 0.004
#   P(320 plus rapide que 64) = 0.005
#   P(384 plus rapide que 64) = 0.002
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00453 s (n=62)
#   Bloc 128  → 0.00507 s (n=61)
#   Bloc 192  → 0.00632 s (n=60)
#
# 🔁 Itération 58: best = 64
#   P(128 plus rapide que 64) = 0.148
#   P(192 plus rapide que 64) = 0.199
#   P(256 plus rapide que 64) = 0.004
#   P(320 plus rapide que 64) = 0.005
#   P(384 plus rapide que 64) = 0.002
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00363 s (n=63)
#   Bloc 128  → 0.00502 s (n=62)
#   Bloc 192  → 0.00642 s (n=61)
#
# 🔁 Itération 59: best = 64
#   P(128 plus rapide que 64) = 0.146
#   P(192 plus rapide que 64) = 0.195
#   P(256 plus rapide que 64) = 0.004
#   P(320 plus rapide que 64) = 0.005
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.002
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00362 s (n=64)
#   Bloc 128  → 0.00490 s (n=63)
#   Bloc 192  → 0.00635 s (n=62)
#
# 🔁 Itération 60: best = 64
#   P(128 plus rapide que 64) = 0.145
#   P(192 plus rapide que 64) = 0.191
#   P(256 plus rapide que 64) = 0.004
#   P(320 plus rapide que 64) = 0.005
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00459 s (n=65)
#   Bloc 128  → 0.00531 s (n=64)
#   Bloc 192  → 0.00641 s (n=63)
#
# 🔁 Itération 61: best = 64
#   P(128 plus rapide que 64) = 0.144
#   P(192 plus rapide que 64) = 0.188
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.005
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00361 s (n=66)
#   Bloc 128  → 0.00511 s (n=65)
#   Bloc 192  → 0.00634 s (n=64)
#
# 🔁 Itération 62: best = 64
#   P(128 plus rapide que 64) = 0.143
#   P(192 plus rapide que 64) = 0.184
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00355 s (n=67)
#   Bloc 128  → 0.00486 s (n=66)
#   Bloc 192  → 0.00617 s (n=65)
#
# 🔁 Itération 63: best = 64
#   P(128 plus rapide que 64) = 0.142
#   P(192 plus rapide que 64) = 0.180
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00364 s (n=68)
#   Bloc 128  → 0.00526 s (n=67)
#   Bloc 192  → 0.00641 s (n=66)
#
# 🔁 Itération 64: best = 64
#   P(128 plus rapide que 64) = 0.140
#   P(192 plus rapide que 64) = 0.176
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00373 s (n=69)
#   Bloc 128  → 0.00508 s (n=68)
#   Bloc 192  → 0.00624 s (n=67)
#
# 🔁 Itération 65: best = 64
#   P(128 plus rapide que 64) = 0.139
#   P(192 plus rapide que 64) = 0.172
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00366 s (n=70)
#   Bloc 128  → 0.00508 s (n=69)
#   Bloc 192  → 0.00636 s (n=68)
#
# 🔁 Itération 66: best = 64
#   P(128 plus rapide que 64) = 0.137
#   P(192 plus rapide que 64) = 0.169
#   P(256 plus rapide que 64) = 0.003
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00368 s (n=71)
#   Bloc 128  → 0.00506 s (n=70)
#   Bloc 192  → 0.00637 s (n=69)
#
# 🔁 Itération 67: best = 64
#   P(128 plus rapide que 64) = 0.136
#   P(192 plus rapide que 64) = 0.165
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.004
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00363 s (n=72)
#   Bloc 128  → 0.00498 s (n=71)
#   Bloc 192  → 0.00632 s (n=70)
#
# 🔁 Itération 68: best = 64
#   P(128 plus rapide que 64) = 0.134
#   P(192 plus rapide que 64) = 0.161
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00400 s (n=73)
#   Bloc 128  → 0.00555 s (n=72)
#   Bloc 192  → 0.00708 s (n=71)
#
# 🔁 Itération 69: best = 64
#   P(128 plus rapide que 64) = 0.133
#   P(192 plus rapide que 64) = 0.157
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.001
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00386 s (n=74)
#   Bloc 128  → 0.00506 s (n=73)
#   Bloc 192  → 0.00663 s (n=72)
#
# 🔁 Itération 70: best = 64
#   P(128 plus rapide que 64) = 0.132
#   P(192 plus rapide que 64) = 0.153
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00356 s (n=75)
#   Bloc 128  → 0.00511 s (n=74)
#   Bloc 192  → 0.00633 s (n=73)
#
# 🔁 Itération 71: best = 64
#   P(128 plus rapide que 64) = 0.130
#   P(192 plus rapide que 64) = 0.149
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00355 s (n=76)
#   Bloc 128  → 0.00491 s (n=75)
#   Bloc 192  → 0.00628 s (n=74)
#
# 🔁 Itération 72: best = 64
#   P(128 plus rapide que 64) = 0.129
#   P(192 plus rapide que 64) = 0.146
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00485 s (n=77)
#   Bloc 128  → 0.00514 s (n=76)
#   Bloc 192  → 0.00650 s (n=75)
#
# 🔁 Itération 73: best = 64
#   P(128 plus rapide que 64) = 0.129
#   P(192 plus rapide que 64) = 0.144
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00363 s (n=78)
#   Bloc 128  → 0.00504 s (n=77)
#   Bloc 192  → 0.00637 s (n=76)
#
# 🔁 Itération 74: best = 64
#   P(128 plus rapide que 64) = 0.127
#   P(192 plus rapide que 64) = 0.140
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00360 s (n=79)
#   Bloc 128  → 0.00503 s (n=78)
#   Bloc 192  → 0.00630 s (n=77)
#
# 🔁 Itération 75: best = 64
#   P(128 plus rapide que 64) = 0.126
#   P(192 plus rapide que 64) = 0.137
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.010
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00363 s (n=80)
#   Bloc 128  → 0.00494 s (n=79)
#   Bloc 192  → 0.00643 s (n=78)
#
# 🔁 Itération 76: best = 64
#   P(128 plus rapide que 64) = 0.125
#   P(192 plus rapide que 64) = 0.133
#   P(256 plus rapide que 64) = 0.002
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00366 s (n=81)
#   Bloc 128  → 0.00503 s (n=80)
#   Bloc 192  → 0.00650 s (n=79)
#
# 🔁 Itération 77: best = 64
#   P(128 plus rapide que 64) = 0.123
#   P(192 plus rapide que 64) = 0.130
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00361 s (n=82)
#   Bloc 128  → 0.00492 s (n=81)
#   Bloc 192  → 0.00634 s (n=80)
#
# 🔁 Itération 78: best = 64
#   P(128 plus rapide que 64) = 0.122
#   P(192 plus rapide que 64) = 0.127
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.003
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00405 s (n=83)
#   Bloc 128  → 0.00506 s (n=82)
#   Bloc 192  → 0.00662 s (n=81)
#
# 🔁 Itération 79: best = 64
#   P(128 plus rapide que 64) = 0.121
#   P(192 plus rapide que 64) = 0.124
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00362 s (n=84)
#   Bloc 128  → 0.00491 s (n=83)
#   Bloc 192  → 0.00644 s (n=82)
#
# 🔁 Itération 80: best = 64
#   P(128 plus rapide que 64) = 0.120
#   P(192 plus rapide que 64) = 0.120
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00765 s (n=85)
#   Bloc 128  → 0.00840 s (n=84)
#   Bloc 192  → 0.00631 s (n=83)
#
# 🔁 Itération 81: best = 64
#   P(128 plus rapide que 64) = 0.119
#   P(192 plus rapide que 64) = 0.122
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00381 s (n=86)
#   Bloc 128  → 0.00542 s (n=85)
#   Bloc 192  → 0.00638 s (n=84)
#
# 🔁 Itération 82: best = 64
#   P(128 plus rapide que 64) = 0.117
#   P(192 plus rapide que 64) = 0.119
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00362 s (n=87)
#   Bloc 128  → 0.00500 s (n=86)
#   Bloc 192  → 0.00622 s (n=85)
#
# 🔁 Itération 83: best = 64
#   P(128 plus rapide que 64) = 0.116
#   P(192 plus rapide que 64) = 0.116
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00360 s (n=88)
#   Bloc 128  → 0.00503 s (n=87)
#   Bloc 192  → 0.00680 s (n=86)
#
# 🔁 Itération 84: best = 64
#   P(128 plus rapide que 64) = 0.115
#   P(192 plus rapide que 64) = 0.113
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00379 s (n=89)
#   Bloc 128  → 0.00489 s (n=88)
#   Bloc 192  → 0.00620 s (n=87)
#
# 🔁 Itération 85: best = 64
#   P(128 plus rapide que 64) = 0.114
#   P(192 plus rapide que 64) = 0.110
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00354 s (n=90)
#   Bloc 128  → 0.00475 s (n=89)
#   Bloc 192  → 0.00629 s (n=88)
#
# 🔁 Itération 86: best = 64
#   P(128 plus rapide que 64) = 0.113
#   P(192 plus rapide que 64) = 0.107
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00361 s (n=91)
#   Bloc 128  → 0.00493 s (n=90)
#   Bloc 192  → 0.00638 s (n=89)
#
# 🔁 Itération 87: best = 64
#   P(128 plus rapide que 64) = 0.111
#   P(192 plus rapide que 64) = 0.104
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00358 s (n=92)
#   Bloc 128  → 0.00541 s (n=91)
#   Bloc 192  → 0.00619 s (n=90)
#
# 🔁 Itération 88: best = 64
#   P(128 plus rapide que 64) = 0.110
#   P(192 plus rapide que 64) = 0.102
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00353 s (n=93)
#   Bloc 128  → 0.00483 s (n=92)
#   Bloc 192  → 0.00616 s (n=91)
#
# 🔁 Itération 89: best = 64
#   P(128 plus rapide que 64) = 0.109
#   P(192 plus rapide que 64) = 0.099
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00356 s (n=94)
#   Bloc 128  → 0.00494 s (n=93)
#   Bloc 192  → 0.00617 s (n=92)
#
# 🔁 Itération 90: best = 64
#   P(128 plus rapide que 64) = 0.107
#   P(192 plus rapide que 64) = 0.097
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00360 s (n=95)
#   Bloc 128  → 0.00480 s (n=94)
#   Bloc 192  → 0.00600 s (n=93)
#
# 🔁 Itération 91: best = 64
#   P(128 plus rapide que 64) = 0.106
#   P(192 plus rapide que 64) = 0.094
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00351 s (n=96)
#   Bloc 128  → 0.00476 s (n=95)
#   Bloc 192  → 0.00602 s (n=94)
#
# 🔁 Itération 92: best = 64
#   P(128 plus rapide que 64) = 0.105
#   P(192 plus rapide que 64) = 0.092
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00356 s (n=97)
#   Bloc 128  → 0.00594 s (n=96)
#   Bloc 192  → 0.00597 s (n=95)
#
# 🔁 Itération 93: best = 64
#   P(128 plus rapide que 64) = 0.103
#   P(192 plus rapide que 64) = 0.090
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00312 s (n=98)
#   Bloc 128  → 0.00419 s (n=97)
#   Bloc 192  → 0.00520 s (n=96)
#
# 🔁 Itération 94: best = 64
#   P(128 plus rapide que 64) = 0.102
#   P(192 plus rapide que 64) = 0.088
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00272 s (n=99)
#   Bloc 128  → 0.00526 s (n=98)
#   Bloc 192  → 0.00765 s (n=97)
#
# 🔁 Itération 95: best = 64
#   P(128 plus rapide que 64) = 0.100
#   P(192 plus rapide que 64) = 0.083
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00529 s (n=100)
#   Bloc 128  → 0.00603 s (n=99)
#   Bloc 192  → 0.00866 s (n=98)
#
# 🔁 Itération 96: best = 64
#   P(128 plus rapide que 64) = 0.099
#   P(192 plus rapide que 64) = 0.080
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00322 s (n=101)
#   Bloc 128  → 0.00414 s (n=100)
#   Bloc 192  → 0.00537 s (n=99)
#
# 🔁 Itération 97: best = 64
#   P(128 plus rapide que 64) = 0.098
#   P(192 plus rapide que 64) = 0.079
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00292 s (n=102)
#   Bloc 128  → 0.00434 s (n=101)
#   Bloc 192  → 0.00553 s (n=100)
#
# 🔁 Itération 98: best = 64
#   P(128 plus rapide que 64) = 0.097
#   P(192 plus rapide que 64) = 0.076
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00317 s (n=103)
#   Bloc 128  → 0.00414 s (n=102)
#   Bloc 192  → 0.00569 s (n=101)
#
# 🔁 Itération 99: best = 64
#   P(128 plus rapide que 64) = 0.096
#   P(192 plus rapide que 64) = 0.074
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00314 s (n=104)
#   Bloc 128  → 0.00458 s (n=103)
#   Bloc 192  → 0.00541 s (n=102)
#
# 🔁 Itération 100: best = 64
#   P(128 plus rapide que 64) = 0.095
#   P(192 plus rapide que 64) = 0.073
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00339 s (n=105)
#   Bloc 128  → 0.00462 s (n=104)
#   Bloc 192  → 0.00592 s (n=103)
#
# 🔁 Itération 101: best = 64
#   P(128 plus rapide que 64) = 0.094
#   P(192 plus rapide que 64) = 0.071
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00322 s (n=106)
#   Bloc 128  → 0.00467 s (n=105)
#   Bloc 192  → 0.00550 s (n=104)
#
# 🔁 Itération 102: best = 64
#   P(128 plus rapide que 64) = 0.093
#   P(192 plus rapide que 64) = 0.069
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00334 s (n=107)
#   Bloc 128  → 0.00462 s (n=106)
#   Bloc 192  → 0.00579 s (n=105)
#
# 🔁 Itération 103: best = 64
#   P(128 plus rapide que 64) = 0.092
#   P(192 plus rapide que 64) = 0.067
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00339 s (n=108)
#   Bloc 128  → 0.00471 s (n=107)
#   Bloc 192  → 0.00581 s (n=106)
#
# 🔁 Itération 104: best = 64
#   P(128 plus rapide que 64) = 0.091
#   P(192 plus rapide que 64) = 0.065
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.002
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00327 s (n=109)
#   Bloc 128  → 0.00485 s (n=108)
#   Bloc 192  → 0.00591 s (n=107)
#
# 🔁 Itération 105: best = 64
#   P(128 plus rapide que 64) = 0.090
#   P(192 plus rapide que 64) = 0.064
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00346 s (n=110)
#   Bloc 128  → 0.00478 s (n=109)
#   Bloc 192  → 0.00595 s (n=108)
#
# 🔁 Itération 106: best = 64
#   P(128 plus rapide que 64) = 0.089
#   P(192 plus rapide que 64) = 0.062
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00342 s (n=111)
#   Bloc 128  → 0.00481 s (n=110)
#   Bloc 192  → 0.00586 s (n=109)
#
# 🔁 Itération 107: best = 64
#   P(128 plus rapide que 64) = 0.088
#   P(192 plus rapide que 64) = 0.060
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00342 s (n=112)
#   Bloc 128  → 0.00465 s (n=111)
#   Bloc 192  → 0.00571 s (n=110)
#
# 🔁 Itération 108: best = 64
#   P(128 plus rapide que 64) = 0.087
#   P(192 plus rapide que 64) = 0.059
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00341 s (n=113)
#   Bloc 128  → 0.00480 s (n=112)
#   Bloc 192  → 0.00587 s (n=111)
#
# 🔁 Itération 109: best = 64
#   P(128 plus rapide que 64) = 0.086
#   P(192 plus rapide que 64) = 0.057
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00408 s (n=114)
#   Bloc 128  → 0.00505 s (n=113)
#   Bloc 192  → 0.00796 s (n=112)
#
# 🔁 Itération 110: best = 64
#   P(128 plus rapide que 64) = 0.085
#   P(192 plus rapide que 64) = 0.054
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00405 s (n=115)
#   Bloc 128  → 0.00482 s (n=114)
#   Bloc 192  → 0.00607 s (n=113)
#
# 🔁 Itération 111: best = 64
#   P(128 plus rapide que 64) = 0.084
#   P(192 plus rapide que 64) = 0.053
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00354 s (n=116)
#   Bloc 128  → 0.00492 s (n=115)
#   Bloc 192  → 0.00609 s (n=114)
#
# 🔁 Itération 112: best = 64
#   P(128 plus rapide que 64) = 0.083
#   P(192 plus rapide que 64) = 0.052
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128, 192]
#   Bloc 64   → 0.00394 s (n=117)
#   Bloc 128  → 0.00514 s (n=116)
#   Bloc 192  → 0.00664 s (n=115)
#
# 🔁 Itération 113: best = 64
#   P(128 plus rapide que 64) = 0.082
#   P(192 plus rapide que 64) = 0.050
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00361 s (n=118)
#   Bloc 128  → 0.00602 s (n=117)
#
# 🔁 Itération 114: best = 64
#   P(128 plus rapide que 64) = 0.080
#   P(192 plus rapide que 64) = 0.047
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00569 s (n=119)
#   Bloc 128  → 0.00537 s (n=118)
#
# 🔁 Itération 115: best = 64
#   P(128 plus rapide que 64) = 0.081
#   P(192 plus rapide que 64) = 0.046
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00365 s (n=120)
#   Bloc 128  → 0.00497 s (n=119)
#
# 🔁 Itération 116: best = 64
#   P(128 plus rapide que 64) = 0.080
#   P(192 plus rapide que 64) = 0.044
#   P(256 plus rapide que 64) = 0.001
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00358 s (n=121)
#   Bloc 128  → 0.00497 s (n=120)
#
# 🔁 Itération 117: best = 64
#   P(128 plus rapide que 64) = 0.079
#   P(192 plus rapide que 64) = 0.041
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00361 s (n=122)
#   Bloc 128  → 0.00557 s (n=121)
#
# 🔁 Itération 118: best = 64
#   P(128 plus rapide que 64) = 0.077
#   P(192 plus rapide que 64) = 0.039
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00384 s (n=123)
#   Bloc 128  → 0.00540 s (n=122)
#
# 🔁 Itération 119: best = 64
#   P(128 plus rapide que 64) = 0.076
#   P(192 plus rapide que 64) = 0.037
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00373 s (n=124)
#   Bloc 128  → 0.00626 s (n=123)
#
# 🔁 Itération 120: best = 64
#   P(128 plus rapide que 64) = 0.074
#   P(192 plus rapide que 64) = 0.035
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00368 s (n=125)
#   Bloc 128  → 0.00535 s (n=124)
#
# 🔁 Itération 121: best = 64
#   P(128 plus rapide que 64) = 0.073
#   P(192 plus rapide que 64) = 0.034
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00571 s (n=126)
#   Bloc 128  → 0.00705 s (n=125)
#
# 🔁 Itération 122: best = 64
#   P(128 plus rapide que 64) = 0.072
#   P(192 plus rapide que 64) = 0.033
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00549 s (n=127)
#   Bloc 128  → 0.00670 s (n=126)
#
# 🔁 Itération 123: best = 64
#   P(128 plus rapide que 64) = 0.071
#   P(192 plus rapide que 64) = 0.032
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00365 s (n=128)
#   Bloc 128  → 0.00649 s (n=127)
#
# 🔁 Itération 124: best = 64
#   P(128 plus rapide que 64) = 0.069
#   P(192 plus rapide que 64) = 0.030
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00447 s (n=129)
#   Bloc 128  → 0.00622 s (n=128)
#
# 🔁 Itération 125: best = 64
#   P(128 plus rapide que 64) = 0.068
#   P(192 plus rapide que 64) = 0.029
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00411 s (n=130)
#   Bloc 128  → 0.00577 s (n=129)
#
# 🔁 Itération 126: best = 64
#   P(128 plus rapide que 64) = 0.067
#   P(192 plus rapide que 64) = 0.028
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00393 s (n=131)
#   Bloc 128  → 0.00528 s (n=130)
#
# 🔁 Itération 127: best = 64
#   P(128 plus rapide que 64) = 0.066
#   P(192 plus rapide que 64) = 0.026
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.009
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00370 s (n=132)
#   Bloc 128  → 0.00514 s (n=131)
#
# 🔁 Itération 128: best = 64
#   P(128 plus rapide que 64) = 0.065
#   P(192 plus rapide que 64) = 0.025
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00357 s (n=133)
#   Bloc 128  → 0.00513 s (n=132)
#
# 🔁 Itération 129: best = 64
#   P(128 plus rapide que 64) = 0.064
#   P(192 plus rapide que 64) = 0.024
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00362 s (n=134)
#   Bloc 128  → 0.00503 s (n=133)
#
# 🔁 Itération 130: best = 64
#   P(128 plus rapide que 64) = 0.063
#   P(192 plus rapide que 64) = 0.022
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00368 s (n=135)
#   Bloc 128  → 0.00528 s (n=134)
#
# 🔁 Itération 131: best = 64
#   P(128 plus rapide que 64) = 0.062
#   P(192 plus rapide que 64) = 0.021
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00366 s (n=136)
#   Bloc 128  → 0.00524 s (n=135)
#
# 🔁 Itération 132: best = 64
#   P(128 plus rapide que 64) = 0.061
#   P(192 plus rapide que 64) = 0.020
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00363 s (n=137)
#   Bloc 128  → 0.00501 s (n=136)
#
# 🔁 Itération 133: best = 64
#   P(128 plus rapide que 64) = 0.060
#   P(192 plus rapide que 64) = 0.019
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00357 s (n=138)
#   Bloc 128  → 0.00510 s (n=137)
#
# 🔁 Itération 134: best = 64
#   P(128 plus rapide que 64) = 0.059
#   P(192 plus rapide que 64) = 0.018
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00356 s (n=139)
#   Bloc 128  → 0.00494 s (n=138)
#
# 🔁 Itération 135: best = 64
#   P(128 plus rapide que 64) = 0.058
#   P(192 plus rapide que 64) = 0.017
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00361 s (n=140)
#   Bloc 128  → 0.00489 s (n=139)
#
# 🔁 Itération 136: best = 64
#   P(128 plus rapide que 64) = 0.058
#   P(192 plus rapide que 64) = 0.016
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00358 s (n=141)
#   Bloc 128  → 0.00507 s (n=140)
#
# 🔁 Itération 137: best = 64
#   P(128 plus rapide que 64) = 0.057
#   P(192 plus rapide que 64) = 0.015
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00359 s (n=142)
#   Bloc 128  → 0.00488 s (n=141)
#
# 🔁 Itération 138: best = 64
#   P(128 plus rapide que 64) = 0.056
#   P(192 plus rapide que 64) = 0.015
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00364 s (n=143)
#   Bloc 128  → 0.00501 s (n=142)
#
# 🔁 Itération 139: best = 64
#   P(128 plus rapide que 64) = 0.055
#   P(192 plus rapide que 64) = 0.014
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00361 s (n=144)
#   Bloc 128  → 0.00500 s (n=143)
#
# 🔁 Itération 140: best = 64
#   P(128 plus rapide que 64) = 0.054
#   P(192 plus rapide que 64) = 0.013
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00360 s (n=145)
#   Bloc 128  → 0.00493 s (n=144)
#
# 🔁 Itération 141: best = 64
#   P(128 plus rapide que 64) = 0.054
#   P(192 plus rapide que 64) = 0.012
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00360 s (n=146)
#   Bloc 128  → 0.00483 s (n=145)
#
# 🔁 Itération 142: best = 64
#   P(128 plus rapide que 64) = 0.053
#   P(192 plus rapide que 64) = 0.012
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00343 s (n=147)
#   Bloc 128  → 0.00568 s (n=146)
#
# 🔁 Itération 143: best = 64
#   P(128 plus rapide que 64) = 0.052
#   P(192 plus rapide que 64) = 0.011
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00372 s (n=148)
#   Bloc 128  → 0.00625 s (n=147)
#
# 🔁 Itération 144: best = 64
#   P(128 plus rapide que 64) = 0.050
#   P(192 plus rapide que 64) = 0.011
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
# Mesures supplémentaires : [64, 128]
#   Bloc 64   → 0.00753 s (n=149)
#   Bloc 128  → 0.00828 s (n=148)
#
# 🔁 Itération 145: best = 64
#   P(128 plus rapide que 64) = 0.050
#   P(192 plus rapide que 64) = 0.011
#   P(256 plus rapide que 64) = 0.000
#   P(320 plus rapide que 64) = 0.001
#   P(384 plus rapide que 64) = 0.000
#   P(448 plus rapide que 64) = 0.001
#   P(512 plus rapide que 64) = 0.008
#
# ✅ Arrêt, toutes proba < 0.05
#
# 🏁 Best final : 64 (médiane=0.00366 s), mesures=522

# %%
from graphique import plot_all_graphs

plot_dict_adaptatif_benchmark = {
    'best_track':           result_adaptatif_benchmark['best_track'],
    'best_measurements':    result_adaptatif_benchmark['best_measurements'],
    'results':              result_adaptatif_benchmark['results'],
    'measure_per_iter':     result_adaptatif_benchmark['measure_per_iter'],
    'p_history':            result_adaptatif_benchmark['p_history'],
}

plot_all_graphs(
    blocks,
    **plot_dict_adaptatif_benchmark,
    step=step,
    figsize=(24, 6),
    p_switch=0.7
)

# %% [markdown]
# ## On compare l'evolution des p_value pour les 2 méthodes benchamrks (grille et adaptatif)

# %%
from graphique import compare_pvalue_evolution

compare_pvalue_evolution(
    result_grille['best_track'], result_grille['p_history'], 'Grille',
    result_adaptatif_benchmark['best_track'], result_adaptatif_benchmark['p_history'], 'Adaptatif',
    step=step,
    figsize=(24, 12)
)

# %% [markdown]
# # On test 20 fois le méthode grille VS le benchmark adaptatif pour comparer les 2 méthodes entre elles

# %%
N_REPEATS = 20

iterations_grille = []
mesures_grille = []
best_bloc_grille = []

iteration_smartB = []
mesures_smartB = []
best_bloc_smartB = []

for i in range(N_REPEATS):  
    # On change de matrice à chaque iteration
    x = np.random.randn(seq_len, d_model)

    # Grille exhaustive
    result_grille = exhaustive_grid_until_confidence(
        x, blocks, initial_repeats=2, free_runs=2, confidence=0.95, max_iter=1_000, verbose=False
    )
    n_iterations_grille = len(result_grille['best_track'])
    n_mesures_grille = result_grille['measure_per_iter'][-1] if result_grille['measure_per_iter'] else 0
    best_block_g = result_grille['best']  # <---- récupère le best trouvé

    iterations_grille.append(n_iterations_grille)
    mesures_grille.append(n_mesures_grille)
    best_bloc_grille.append(best_block_g)

    # Smart benchmark
    result_smartB = smart_benchmark_probabilistic(
        x, blocks, initial_repeats=2, free_runs=2, confidence=0.95, max_iter=1_000, p_switch=0.70, verbose=False
    )
    n_iterations_smart_bench = len(result_smartB['best_track'])
    n_mesures_smart_bench = result_smartB['measure_per_iter'][-1] if result_smartB['measure_per_iter'] else 0
    best_block_s = result_smartB['best']  # <---- récupère le best trouvé

    iteration_smartB.append(n_iterations_smart_bench)
    mesures_smartB.append(n_mesures_smart_bench)
    best_bloc_smartB.append(best_block_s)

    print(f"Test {i+1} terminé pour les 2 benchmark (grille et adaptatif)")

# --- Construction du tableau final ---
df = pd.DataFrame({
    "best_bloc_grille": best_bloc_grille,
    "best_bloc_adaptatif": best_bloc_smartB
})
df["meme_resultat"] = df["best_bloc_grille"] == df["best_bloc_adaptatif"]

print(df)
# Out:
# Test 1 terminé pour les 2 benchmark (grille et adaptatif)
# Test 2 terminé pour les 2 benchmark (grille et adaptatif)
# Test 3 terminé pour les 2 benchmark (grille et adaptatif)
# Test 4 terminé pour les 2 benchmark (grille et adaptatif)
# Test 5 terminé pour les 2 benchmark (grille et adaptatif)
# Test 6 terminé pour les 2 benchmark (grille et adaptatif)
# Test 7 terminé pour les 2 benchmark (grille et adaptatif)
# Test 8 terminé pour les 2 benchmark (grille et adaptatif)
# Test 9 terminé pour les 2 benchmark (grille et adaptatif)
# Test 10 terminé pour les 2 benchmark (grille et adaptatif)
# Test 11 terminé pour les 2 benchmark (grille et adaptatif)
# Test 12 terminé pour les 2 benchmark (grille et adaptatif)
# Test 13 terminé pour les 2 benchmark (grille et adaptatif)
# Test 14 terminé pour les 2 benchmark (grille et adaptatif)
# Test 15 terminé pour les 2 benchmark (grille et adaptatif)
# Test 16 terminé pour les 2 benchmark (grille et adaptatif)
# Test 17 terminé pour les 2 benchmark (grille et adaptatif)
# Test 18 terminé pour les 2 benchmark (grille et adaptatif)
# Test 19 terminé pour les 2 benchmark (grille et adaptatif)
# Test 20 terminé pour les 2 benchmark (grille et adaptatif)
#     best_bloc_grille  best_bloc_adaptatif  meme_resultat
# 0                 64                   64           True
# 1                 64                   64           True
# 2                 64                   64           True
# 3                 64                   64           True
# 4                 64                   64           True
# 5                 64                   64           True
# 6                 64                   64           True
# 7                128                   64          False
# 8                 64                   64           True
# 9                 64                   64           True
# 10                64                   64           True
# 11                64                   64           True
# 12                64                   64           True
# 13                64                   64           True
# 14                64                   64           True
# 15                64                   64           True
# 16                64                   64           True
# 17                64                   64           True
# 18                64                   64           True
# 19                64                   64           True

# %%
# Affichage des moyennes
print("=== Résumé sur", N_REPEATS, "lancements ===")
print(f"Grille exhaustive   : {np.mean(iterations_grille):.1f} itérations, {np.mean(mesures_grille):.1f} mesures en moyenne")
print(f"Benchmark adaptatif : {np.mean(iteration_smartB):.1f} itérations, {np.mean(mesures_smartB):.1f} mesures en moyenne")

# Graphique des mesures réalisées à chaque test
plt.figure(figsize=(12, 5))
plt.plot(range(1, N_REPEATS+1), mesures_grille, marker='o', color='blue', label="Grille exhaustive")
plt.plot(range(1, N_REPEATS+1), mesures_smartB, marker='s', color='orange', label="Benchmark adaptatif")
plt.xlabel("Relance n°")
plt.ylabel("Nombre total de mesures")
plt.title("Nombre de mesures réalisées à chaque test")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Résumé sur 20 lancements ===
# Grille exhaustive   : 56.9 itérations, 471.2 mesures en moyenne
# Benchmark adaptatif : 87.9 itérations, 366.1 mesures en moyenne
